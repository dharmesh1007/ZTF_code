# %% [markdown]
# # Build Dataset
#
# We focus on objects classified as CV within AAVSO VSX. This resource is the most up-to-date catalogue of transients/variable stars available online. The resource also includes subtypes that are going to be important for this work.

# %% [markdown]
# ## 1. Imports

# %%
import os
import lasair
import pandas as pd
from astropy import units as u
from astropy.coordinates import SkyCoord

# %% [markdown]
# ## 2. Generate list of CVs from those catalogued in AAVSO VSX
#
# ### 2.1 Load csv of CVs and suspected CVs
#
# See https://www.aavso.org/vsx/. From this link, I dowloaded a list of targets classified as CV by AAVSO. The variability types are detailed in https://www.aavso.org/vsx/index.php?view=about.vartypes.

# %%
AAVSO_CVS = pd.read_csv("../processed_data/AAVSOCVsraw_21032023.csv")
print(f'Number of examples: {AAVSO_CVS.shape[0]}')

# Convert coordinates to ra and dec.
AAVSO_CVS['ra'] = AAVSO_CVS.apply(lambda x: SkyCoord(f'{x["Coords"]}', unit=(u.hourangle, u.deg), equinox='J2000').ra.deg, axis=1)
AAVSO_CVS['dec'] = AAVSO_CVS.apply(lambda x: SkyCoord(f'{x["Coords"]}', unit=(u.hourangle, u.deg), equinox='J2000').dec.deg, axis=1)

AAVSO_CVS.head()
# Out:
# Number of examples: 15392
# WARNING: IllegalSecondWarning: 'second' was found  to be '60.0', which is not in range [0,60). Treating as 0 sec, +1 min [astropy.coordinates.angle_formats]
# WARNING: IllegalSecondWarning: 'second' was found  to be '60.0', which is not in range [0,60). Treating as 0 sec, +1 min [astropy.coordinates.angle_formats]
#                        Name         AUID                   Coords Const Type  \
# 0               ASASSN-19dp  000-BMZ-678  02 22 59.02 +43 39 13.1   And   AM
# 1                 BMAM-V789  000-BNS-414  02 33 58.15 +41 37 26.3   And   AM
# 2  CSS 091026:002637+242916           --  00 26 37.06 +24 29 15.7   And   AM
# 3                MGAB-V3453           --  00 35 53.37 +43 33 41.5   And   AM
# 4                MGAB-V3769           --  23 34 33.16 +40 25 50.2   And   AM
#
#       Period            Mag          ra        dec
# 0         --  16.5 - 20.9 g   35.745917  43.653639
# 1  0.0714789  18.5 - 21.7 r   38.492292  41.623972
# 2         --   17.1 - 21 CV    6.654417  24.487694
# 3         --  18.2 - 20.9 r    8.972375  43.561528
# 4         --  18.8 - 20.8 r  353.638167  40.430611

# %% [markdown]
# ### 2.2 Identify those observable by ZTF.
#
# Perform some processing to acquire the coordinates in degree format; select only those observable by ZTF (greater than -31 degree declination); inspect the subtypes.

# %%
pd.options.display.max_rows = 10

# Select those observable with ZTF.
AAVSO_CVS_1 = AAVSO_CVS.copy()[AAVSO_CVS['dec']>-31]
AAVSO_CVS_1 = AAVSO_CVS_1.reset_index(drop=True)
AAVSO_CVS_1
# Out:
#                            Name         AUID                   Coords Const  \
# 0                   ASASSN-19dp  000-BMZ-678  02 22 59.02 +43 39 13.1   And
# 1                     BMAM-V789  000-BNS-414  02 33 58.15 +41 37 26.3   And
# 2      CSS 091026:002637+242916           --  00 26 37.06 +24 29 15.7   And
# 3                    MGAB-V3453           --  00 35 53.37 +43 33 41.5   And
# 4                    MGAB-V3769           --  23 34 33.16 +40 25 50.2   And
# ...                         ...          ...                      ...   ...
# 11158                 V1309 Sco  000-BFT-812  17 57 32.94 -30 43 10.0   Sco
# 11159                    CK Vul  000-BCH-958  19 47 38.12 +27 18 47.8   Vul
# 11160              ZTF19adakuot  000-BNK-782  00 40 37.91 +40 34 52.8   And
# 11161                    DLT18x  000-BMR-583  00 14 01.72 -23 11 35.8   Cet
# 11162                 V5634 Sgr           --  18 09 51.09 -19 43 51.9   Sgr
#
#            Type     Period              Mag          ra        dec
# 0            AM         --    16.5 - 20.9 g   35.745917  43.653639
# 1            AM  0.0714789    18.5 - 21.7 r   38.492292  41.623972
# 2            AM         --     17.1 - 21 CV    6.654417  24.487694
# 3            AM         --    18.2 - 20.9 r    8.972375  43.561528
# 4            AM         --    18.8 - 20.8 r  353.638167  40.430611
# ...         ...        ...              ...         ...        ...
# 11158   V838MON         --    7.9 - 20.4: V  269.387250 -30.719444
# 11159   V838MON         --   2.6 V - <23 r'  296.908833  27.313278
# 11160  V838MON:         --  14.9 - <22 r CR   10.157958  40.581333
# 11161  V838MON:         --     16.2 - <22 r    3.507167 -23.193278
# 11162        XP         --  20.8 - 21.36 Ks  272.462875 -19.731083
#
# [11163 rows x 9 columns]

# %% [markdown]
# ### 2.3 Inspect CV subtypes

# %%
pd.options.display.max_rows = None

# Display subtypes.
print(f'Number of CVs observable with ZTF: {AAVSO_CVS_1.shape[0]}')
AAVSO_CVS_1.Type.value_counts()
# Out:
# Number of CVs observable with ZTF: 11163
# UG                    5687
# UG:                   1487
# UGSU                   738
# CV                     598
# UGSU:                  256
# UGWZ                   157
# NL/VY                  147
# CV:                    137
# UGSS                   129
# AM                     120
# UGZ                     97
# UG+E                    86
# UGZ/IW                  86
# NL+E                    75
# UG|SN                   75
# SN|UG                   73
# NL                      72
# UGSU+E                  50
# DQ                      48
# UGWZ:                   45
# N                       44
# UGZ:                    44
# NL/VY:                  38
# NL:                     36
# AM:                     35
# NB                      32
# UGER                    30
# AM+E                    30
# N:                      29
# UGSU/IBWD               26
# CV+E                    26
# UG/IBWD                 23
# UGZ/IW:                 22
# UG+E:                   19
# UGSS:                   18
# IBWD                    16
# UGSS+E                  15
# NL/VY+E                 13
# UG/DQ                   13
# UG/IBWD:                11
# CV|QSO                  11
# DQ:                     11
# NA:                     10
# UGER:                   10
# NR                       9
# IBWD+E                   8
# NA+E                     8
# LMXB|CV+EA               7
# UGZ+E                    7
# CV+E:                    6
# UGSU:+E                  6
# UGWZ+E                   6
# UGWZ+ZZ/GWLIB            6
# UGSU/IBWD:               6
# NA+UG                    6
# SN|UG:                   6
# NL:+E                    6
# DQ+E                     5
# V838MON                  5
# UG/DQ:                   5
# UGSU/IBWD+E              4
# NC                       4
# NB:                      4
# NB+E                     4
# NC:                      4
# AM|DQ                    4
# NC+M                     3
# UG/DQ+E                  3
# UG:+E                    3
# NR+E                     3
# UGSU:/IBWD               3
# N+E                      3
# UG|QSO                   3
# NA/DQ:                   3
# UGSU+E:                  3
# AM:+E                    3
# NA+EA                    3
# NR:                      3
# UG+ELL                   3
# UG/IBWD+E                2
# UGSU/DQ                  2
# NA/DQ                    2
# LMXB|CV                  2
# NA+NL/VY                 2
# EA/WD+NL                 2
# IBWD:                    2
# NB+UG                    2
# DQ|AM                    2
# CV|LMXB                  2
# NA+E:                    2
# CV+ZZ/GWLIB              2
# NA+UG:                   2
# UGWZ+E+ZZ/GWLIB          2
# NA/DQ+UG                 2
# V838MON:                 2
# EA+NL                    2
# UG|QSO:                  1
# UGZ+N                    1
# UG|N                     1
# UG|SN:                   1
# UGZ:/DQ                  1
# UGZ:+E                   1
# UGZ/DQ:                  1
# UV|UG                    1
# UGSU/DQ+E                1
# UGZ+E:                   1
# UGWZ|SN                  1
# UGSS+ZZ                  1
# UGWZ:|N                  1
# UGSS+ZZ:                 1
# UGSS/DQ:                 1
# UGWZ:+E                  1
# UGWZ/DQ+E+ZZ/GWLIB       1
# UGWZ+ZZ                  1
# UGWZ+E:                  1
# UG:/DQ                   1
# UGWZ+E+ZZ                1
# UG:|UV:                  1
# NL/VY+E:                 1
# UG:+ZZ/GWLIB             1
# UG:+E:                   1
# N:+UG+E                  1
# N:+E                     1
# N+ELL                    1
# N+CBSS:                  1
# LMXB|CV+ELL              1
# LMXB/XN|UGWZ|NR          1
# IBWD+ZZB:                1
# EA+CV:                   1
# E/WD+NL                  1
# E+NL                     1
# E+DQ:                    1
# DQ|LMXB                  1
# DQ+E:                    1
# DCEP|CV                  1
# CV|LMXB|RS:              1
# CV:+E                    1
# CBSS/V+E                 1
# CBSS+E                   1
# BY|LMXB|CV               1
# AM|DQ:                   1
# AM:+E:                   1
# AM+ELL                   1
# AM+E:                    1
# NA+ELL                   1
# NA+UGZ/DQ:               1
# NA+ZAND:+E:              1
# NL:+E:                   1
# UG/DQ:+E                 1
# UG+EA                    1
# ROT|CV|LMXB              1
# N|NL                     1
# NR:+ELL                  1
# NR+ZAND+M                1
# NR+LB                    1
# NR+ELL                   1
# NL|UGZ:                  1
# NL|UG                    1
# NL+ZZ:                   1
# NA/AM+E                  1
# NL+E:                    1
# NC+SR                    1
# NC+EA+SR                 1
# NC+E                     1
# NB/DQ+EA                 1
# NB/DQ                    1
# NB/AM                    1
# NB+EA                    1
# NB+E:                    1
# NA/VY                    1
# XP                       1
# Name: Type, dtype: int64

# %% [markdown]
# ### 2.4 Refine subtypes
#
# A colon ( : ) after the variability type -or any other field- means the value/classification is uncertain.
#
# A pipe character ( | ) between two different types signifies a logical OR; the classification is uncertain and all possible types are indicated. An example of this is ELL|DSCT, where the star may be an ellipsoidal binary system or a DSCT-type pulsating variable with half the given period.

# %%
pd.options.display.max_rows=50

# Remove objects with uncertain classification and or have several possible types (:, |). 
AAVSO_CVS_2 = AAVSO_CVS_1[(AAVSO_CVS_1['Type'].str.contains(':', regex=True)==False)]
AAVSO_CVS_2 = AAVSO_CVS_2[(AAVSO_CVS_2['Type'].str.contains('\|', regex=True)==False)]
AAVSO_CVS_2 = AAVSO_CVS_2.reset_index(drop=True)

# Inspect dataframe for different CV transient types.
# Eclipsing = AAVSO_CVS_2[(AAVSO_CVS_2.Type.str.contains('E', regex=True)==True) & (AAVSO_CVS_2.Type!='UGER')]
# Eclipsing.Type.value_counts()
AAVSO_CVS_2
# Out:
#                           Name         AUID                   Coords Const  \
# 0                  ASASSN-19dp  000-BMZ-678  02 22 59.02 +43 39 13.1   And
# 1                    BMAM-V789  000-BNS-414  02 33 58.15 +41 37 26.3   And
# 2     CSS 091026:002637+242916           --  00 26 37.06 +24 29 15.7   And
# 3                   MGAB-V3453           --  00 35 53.37 +43 33 41.5   And
# 4                   MGAB-V3769           --  23 34 33.16 +40 25 50.2   And
# ...                        ...          ...                      ...   ...
# 8490                 V4332 Sgr  000-BCD-402  18 50 36.70 -21 23 28.9   Sgr
# 8491         OGLE-2002-BLG-360           --  17 57 38.97 -29 46 04.8   Sgr
# 8492                 V1309 Sco  000-BFT-812  17 57 32.94 -30 43 10.0   Sco
# 8493                    CK Vul  000-BCH-958  19 47 38.12 +27 18 47.8   Vul
# 8494                 V5634 Sgr           --  18 09 51.09 -19 43 51.9   Sgr
#
#          Type     Period              Mag          ra        dec
# 0          AM         --    16.5 - 20.9 g   35.745917  43.653639
# 1          AM  0.0714789    18.5 - 21.7 r   38.492292  41.623972
# 2          AM         --     17.1 - 21 CV    6.654417  24.487694
# 3          AM         --    18.2 - 20.9 r    8.972375  43.561528
# 4          AM         --    18.8 - 20.8 r  353.638167  40.430611
# ...       ...        ...              ...         ...        ...
# 8490  V838MON         --     8.0 - 19.8 V  282.652917 -21.391361
# 8491  V838MON       240:     11.3 - 20 Ic  269.412375 -29.768000
# 8492  V838MON         --    7.9 - 20.4: V  269.387250 -30.719444
# 8493  V838MON         --   2.6 V - <23 r'  296.908833  27.313278
# 8494       XP         --  20.8 - 21.36 Ks  272.462875 -19.731083
#
# [8495 rows x 9 columns]

# %% [markdown]
# ## 3. Coordinate cross match AAVSO VSX CVs with ZTF targets within Lasair
#
# ### 3.1 Define Lasair token and create cache

# %%
# Tokens required for Lasair database access via the API: https://lasair-iris.roe.ac.uk/api.
# Starter token - Ten attempts per hour
starterToken = '4b762569bb349bd8d60f1bc7da3f39dbfaefff9a'
# User token - 100 queries an hour
token = '4607a33defa78fa20bef98791680574b6cc13b23'

if not os.path.exists('../cacheLasairXmatch'):
    os.makedirs('../cacheLasairXmatch')

# %% [markdown]
# ### 3.2 Crossmatch with Lasair to obtain ZTF counterparts

# %%
def get_ZTFcounterparts(df, racol, deccol, radius):
    # Make a copy of the dataframe.
    df = df.copy()
    
    # Initialise Lasair client.
    L = lasair.lasair_client(token, cache='../cacheLasairXmatch')

    # Loop through the AAVSO CVs list to identify ZTF counterparts.
    for count, (ra, dec) in enumerate(zip(df[racol], df[deccol]), start=0):
        print(count, ra, dec)

        try:
            # Performs a cone search of ZTF objects within Lasair that are within x arccseconds of the coordinated given. 
            c = L.cone(ra=ra, dec=dec, radius=radius, requestType='nearest')
            print(c)

            # Append ZTF object ID and separation from coordinated given into new columns using pd.DataFrame.at().
            df.at[count, 'Xmatch_obj']=c['object']
            df.at[count, 'separation']=c['separation']

        # Print the error that caused the except pathway to be triggered. 
        except Exception as e:
            print(e)
            pass

    return df

# %%
# Get ZTF counterparts for first 5000 objects.
pt1 = get_ZTFcounterparts(AAVSO_CVS_2[0:4500].reset_index(drop=True), 'ra', 'dec', radius=2)

# Save the dataframe to a csv file.
pt1.to_csv('../processed_data/AAVSOCVsZTFxmatch_21032023_0_4499.csv', index=False)
# Out:
# 0 35.74591666666666 43.653638888888885
# {'object': 'ZTF18abryuah', 'separation': 0.37855041059646055}
# 1 38.49229166666666 41.62397222222222
# {'object': 'ZTF18abtrvgp', 'separation': 0.13425622485012198}
# 2 6.654416666666666 24.487694444444447
# {'object': 'ZTF17aaaehby', 'separation': 0.30876912482879415}
# 3 8.972375 43.561527777777776
# {'object': 'ZTF18abgjgiq', 'separation': 0.5224733104298058}
# 4 353.6381666666666 40.43061111111111
# {'object': 'ZTF18abumlux', 'separation': 0.031041688163620965}
# 5 349.0150833333333 -5.452472222222222
# {'object': 'ZTF18absgnqy', 'separation': 0.1854113319169726}
# 6 326.72229166666665 -2.3056666666666663
# {'object': 'ZTF19abisjkc', 'separation': 0.46469110574878286}
# 7 312.11629166666665 0.8358055555555556
# {'object': 'ZTF18abwvggo', 'separation': 0.3596882610423953}
# 8 295.35437499999995 15.382027777777779
# {'object': 'ZTF18aaxdlbl', 'separation': 0.7601020139145069}
# 9 302.76704166666667 0.9219444444444445
# {'object': 'ZTF18absgzlu', 'separation': 0.15063703104736983}
# 10 300.16120833333326 10.718833333333334
# {'object': 'ZTF18acegnyn', 'separation': 0.2738597118630392}
# 11 47.43829166666666 29.880833333333335
# {'object': 'ZTF18aaadtna', 'separation': 0.5836818271834341}
# 12 112.294625 36.97738888888889
# {'object': 'ZTF18acywwfg', 'separation': 0.23867333522026804}
# 13 82.13616666666665 28.643805555555556
# {'object': 'ZTF17aabxrtj', 'separation': 1.6278021381950707}
# 14 95.95075 40.828500000000005
# {'object': 'ZTF18aagqeuv', 'separation': 0.08315737783185731}
# 15 234.57224999999997 51.39388888888889
# {'object': 'ZTF18aahmxsl', 'separation': 0.2642925791011209}
# 16 85.70333333333332 60.85872222222223
# {'object': 'ZTF17aaarxou', 'separation': 0.6990092147152146}
# 17 106.04166666666666 62.05772222222222
# {'object': 'ZTF17aaairkd', 'separation': 0.35328852245830084}
# 18 71.92645833333333 57.27005555555556
# {'object': 'ZTF19aabiema', 'separation': 0.00434670577101264}
# 19 132.86316666666664 11.782611111111112
# Bad Request:{"error":"No object found ra=132.86317 dec=11.78261 radius=2.00"}
# 20 133.50875 13.60913888888889
# Bad Request:{"error":"No object found ra=133.50875 dec=13.60914 radius=2.00"}
# 21 140.34516666666664 20.64913888888889
# Bad Request:{"error":"No object found ra=140.34517 dec=20.64914 radius=2.00"}
# 22 107.298875 -23.09047222222222
# {'object': 'ZTF18aculrrh', 'separation': 0.03119348216498702}
# 23 122.62754166666664 0.4079166666666667
# {'object': 'ZTF18acnnsmq', 'separation': 0.2309896867670774}
# 24 13.490916666666664 65.75630555555556
# {'object': 'ZTF18abcrbmk', 'separation': 0.2947117800864204}
# 25 30.160291666666662 61.52155555555555
# {'object': 'ZTF18admxenl', 'separation': 0.2424043662887357}
# 26 355.0857083333333 76.70288888888889
# {'object': 'ZTF18abwiccd', 'separation': 0.3241138872252423}
# 27 22.218916666666665 -23.66222222222222
# {'object': 'ZTF18abwpsyj', 'separation': 0.537631454100129}
# 28 16.49308333333333 -8.910388888888889
# {'object': 'ZTF18abtmpnp', 'separation': 0.24123238021470242}
# 29 203.28829166666665 14.618583333333333
# {'object': 'ZTF18aaznyge', 'separation': 0.19531176434011177}
# 30 238.55166666666665 27.364222222222224
# {'object': 'ZTF18aaylcic', 'separation': 1.6960119595410947}
# 31 235.26954166666664 36.048027777777776
# {'object': 'ZTF18aagrcve', 'separation': 0.3573563198166687}
# 32 315.5060416666667 33.99163888888889
# {'object': 'ZTF20abragvw', 'separation': 0.1691309862339543}
# 33 319.83079166666664 41.20977777777778
# {'object': 'ZTF19abhpnxh', 'separation': 0.684437099502931}
# 34 318.2143749999999 32.632666666666665
# {'object': 'ZTF18adlhiaq', 'separation': 0.3218617488311642}
# 35 292.8857499999999 52.156305555555555
# {'object': 'ZTF18aazucqe', 'separation': 0.24259914684751538}
# 36 312.18629166666665 19.505416666666665
# {'object': 'ZTF18abnbluc', 'separation': 0.2575950405614726}
# 37 238.37966666666662 55.270694444444445
# {'object': 'ZTF18aajqtnw', 'separation': 1.0622961179673285}
# 38 281.74499999999995 55.641333333333336
# {'object': 'ZTF18aapovzp', 'separation': 0.054809874279193496}
# 39 274.8880416666666 58.10725
# {'object': 'ZTF18aainbrb', 'separation': 0.46213271411362483}
# 40 244.89899999999994 52.775527777777775
# {'object': 'ZTF18aauxwft', 'separation': 0.46206116150929205}
# 41 294.6352916666666 62.39169444444445
# {'object': 'ZTF18aaxcqso', 'separation': 0.45069700769308685}
# 42 48.555208333333326 -22.59525
# Bad Request:{"error":"No object found ra=48.55521 dec=-22.59525 radius=2.00"}
# 43 66.47995833333333 -19.758472222222224
# {'object': 'ZTF19abtsrif', 'separation': 1.0011068287356346}
# 44 51.41429166666666 -8.245222222222221
# {'object': 'ZTF18abuhqfi', 'separation': 0.3924451896935876}
# 45 53.019166666666656 -25.94863888888889
# {'object': 'ZTF19aakuyyr', 'separation': 0.2884424953810428}
# 46 113.44274999999999 26.323916666666666
# {'object': 'ZTF17aacbuuj', 'separation': 0.2051718795574498}
# 47 101.78124999999999 31.33975
# Bad Request:{"error":"No object found ra=101.78125 dec=31.33975 radius=2.00"}
# 48 116.25241666666665 33.48319444444444
# {'object': 'ZTF17aadnfyi', 'separation': 0.2978365839274336}
# 49 270.527 18.078833333333332
# {'object': 'ZTF20abbndvn', 'separation': 0.36831759475902587}
# 50 261.0262083333333 41.23547222222222
# {'object': 'ZTF18aaldiqd', 'separation': 0.8434401461294517}
# 51 247.40229166666663 26.588805555555556
# {'object': 'ZTF18aaojabr', 'separation': 0.6584219107581681}
# 52 255.22208333333327 40.06605555555555
# {'object': 'ZTF18aabpzjg', 'separation': 0.4017941144169786}
# 53 240.94199999999995 19.594444444444445
# {'object': 'ZTF18acviwua', 'separation': 0.452099193501279}
# 54 246.534 33.47438888888889
# {'object': 'ZTF22aajarut', 'separation': 0.01894685119314915}
# 55 150.54879166666666 -19.427055555555558
# {'object': 'ZTF18aalurkz', 'separation': 0.38876903368523524}
# 56 123.04266666666665 4.064277777777778
# {'object': 'ZTF18acurptp', 'separation': 0.13565622334490088}
# 57 139.9025833333333 -5.9221111111111115
# {'object': 'ZTF18acrxpcz', 'separation': 0.2611824060905578}
# 58 151.894375 -20.292361111111113
# {'object': 'ZTF18aaqphee', 'separation': 0.13895868372674633}
# 59 134.78824999999998 5.615138888888889
# {'object': 'ZTF17aaaizfe', 'separation': 0.27643476737051165}
# 60 153.8945 9.078333333333333
# {'object': 'ZTF18aaarims', 'separation': 0.6150627064326177}
# 61 157.7525 20.476
# Bad Request:{"error":"No object found ra=157.75250 dec=20.47600 radius=2.00"}
# 62 171.9529583333333 -5.710083333333333
# Bad Request:{"error":"No object found ra=171.95296 dec=-5.71008 radius=2.00"}
# 63 141.23308333333333 13.347888888888889
# Bad Request:{"error":"No object found ra=141.23308 dec=13.34789 radius=2.00"}
# 64 166.41570833333333 25.107944444444446
# {'object': 'ZTF17aaajlfw', 'separation': 0.6340307737588018}
# 65 156.61454166666664 38.75075
# {'object': 'ZTF17aabtvrf', 'separation': 0.8856299673366957}
# 66 164.77112499999998 27.465416666666666
# Bad Request:{"error":"No object found ra=164.77112 dec=27.46542 radius=2.00"}
# 67 90.1385 -27.15511111111111
# Bad Request:{"error":"No object found ra=90.13850 dec=-27.15511 radius=2.00"}
# 68 86.79637499999998 -19.42366666666667
# {'object': 'ZTF19aakvlvn', 'separation': 0.31669860806566064}
# 69 225.97474999999997 -22.11975
# {'object': 'ZTF19aapzvoj', 'separation': 0.8965179440943865}
# 70 125.21283333333332 49.575500000000005
# Bad Request:{"error":"No object found ra=125.21283 dec=49.57550 radius=2.00"}
# 71 133.55841666666666 39.093722222222226
# {'object': 'ZTF18aaadlpa', 'separation': 0.9331558324542876}
# 72 105.22991666666665 53.42419444444444
# {'object': 'ZTF17aaairls', 'separation': 0.5452993929747134}
# 73 281.4720833333333 36.02744444444444
# {'object': 'ZTF18aaowqsq', 'separation': 0.06223535544406989}
# 74 279.39599999999996 37.534527777777775
# {'object': 'ZTF18aalgarl', 'separation': 0.07781696000648841}
# 75 281.06241666666665 44.90241666666667
# {'object': 'ZTF18aapobha', 'separation': 0.37761341865459136}
# 76 108.27554166666665 -8.75611111111111
# {'object': 'ZTF17aaagrxo', 'separation': 0.3661567521158851}
# 77 106.70391666666664 3.413194444444444
# {'object': 'ZTF17aaaufmh', 'separation': 1.913577666627404}
# 78 102.46183333333332 -7.6280833333333335
# {'object': 'ZTF17aabskxk', 'separation': 1.1382934441103791}
# 79 117.29329166666665 -5.8238055555555555
# {'object': 'ZTF18actbrbg', 'separation': 0.1425825506164648}
# 80 120.96820833333332 -3.9903333333333335
# {'object': 'ZTF18acqxpha', 'separation': 0.23239637100074131}
# 81 262.52687499999996 3.6388333333333334
# Bad Request:{"error":"No object found ra=262.52687 dec=3.63883 radius=2.00"}
# 82 265.8345416666666 -4.499138888888889
# Bad Request:{"error":"No object found ra=265.83454 dec=-4.49914 radius=2.00"}
# 83 245.96029166666662 -12.291972222222222
# {'object': 'ZTF19aaclwhr', 'separation': 0.3525658039602759}
# 84 261.871125 13.433944444444444
# {'object': 'ZTF18abttrrr', 'separation': 0.28594254748305836}
# 85 329.3847083333333 8.92086111111111
# {'object': 'ZTF18abcoxgp', 'separation': 0.3048122579332401}
# 86 328.6132916666666 15.953638888888888
# {'object': 'ZTF18abadsmu', 'separation': 0.04475207495003996}
# 87 353.94158333333326 12.579972222222223
# {'object': 'ZTF18abuescl', 'separation': 0.3818921789331215}
# 88 348.3784583333333 16.904666666666664
# {'object': 'ZTF18admesgz', 'separation': 0.17618909526749568}
# 89 334.63649999999996 19.422361111111112
# {'object': 'ZTF18abccodq', 'separation': 0.6007188263372788}
# 90 349.8767916666666 26.255305555555555
# {'object': 'ZTF18abcqzxh', 'separation': 0.6089267829944361}
# 91 40.71329166666666 56.692027777777774
# {'object': 'ZTF18abotfmi', 'separation': 0.3003633446516803}
# 92 28.834499999999995 55.83541666666667
# {'object': 'ZTF17aaabbhn', 'separation': 0.18751388434514843}
# 93 44.407291666666666 33.630694444444444
# {'object': 'ZTF20acowhlb', 'separation': 0.15723423326899924}
# 94 23.33 8.623694444444444
# {'object': 'ZTF17aacpvmc', 'separation': 0.29228162372392597}
# 95 267.8448333333333 -29.576777777777778
# Bad Request:{"error":"No object found ra=267.84483 dec=-29.57678 radius=2.00"}
# 96 295.94133333333326 -26.95997222222222
# {'object': 'ZTF19aayjhzx', 'separation': 0.3556471368077612}
# 97 242.27774999999997 -10.670277777777777
# {'object': 'ZTF18abcscfi', 'separation': 0.1682910655340137}
# 98 14.586083333333331 -26.220555555555553
# Bad Request:{"error":"No object found ra=14.58608 dec=-26.22056 radius=2.00"}
# 99 238.19724999999997 18.940444444444445
# Bad Request:{"error":"No object found ra=238.19725 dec=18.94044 radius=2.00"}
# 100 242.53129166666668 3.875777777777778
# {'object': 'ZTF18aavooiu', 'separation': 0.256418801354258}
# 101 232.59854166666665 22.112916666666667
# {'object': 'ZTF19abrdzkr', 'separation': 0.6991983954298079}
# 102 59.494416666666666 10.495111111111111
# Bad Request:{"error":"No object found ra=59.49442 dec=10.49511 radius=2.00"}
# 103 74.10270833333333 18.442888888888888
# {'object': 'ZTF17aacdkum', 'separation': 0.17927197397430691}
# 104 75.71224999999998 16.40611111111111
# {'object': 'ZTF19abyqoqu', 'separation': 1.4120138384640282}
# 105 52.229625 5.3815277777777775
# {'object': 'ZTF17aadihfl', 'separation': 1.6574462755700345}
# 106 30.952499999999993 29.990555555555556
# {'object': 'ZTF17aaaslvp', 'separation': 0.5708930992584993}
# 107 168.93591666666666 42.972861111111115
# {'object': 'ZTF18acsujbc', 'separation': 1.5189420115561483}
# 108 162.89649999999997 54.07669444444445
# {'object': 'ZTF18aaadhno', 'separation': 0.6652874227927316}
# 109 177.4820833333333 28.752027777777776
# {'object': 'ZTF18aabktwo', 'separation': 0.2897006841680628}
# 110 196.97441666666666 53.858444444444444
# {'object': 'ZTF18aalrikz', 'separation': 0.2750815760721324}
# 111 161.79120833333332 63.58722222222222
# Bad Request:{"error":"No object found ra=161.79121 dec=63.58722 radius=2.00"}
# 112 200.26670833333333 56.16611111111111
# {'object': 'ZTF17aaajocf', 'separation': 0.265042144271769}
# 113 144.66354166666665 53.73438888888889
# {'object': 'ZTF18acvgoll', 'separation': 0.06476445734556535}
# 114 131.81066666666663 61.00933333333333
# {'object': 'ZTF19aarsrls', 'separation': 0.6556181141562356}
# 115 201.04820833333332 3.3473611111111112
# Bad Request:{"error":"No object found ra=201.04821 dec=3.34736 radius=2.00"}
# 116 183.0387916666666 1.6077222222222223
# Bad Request:{"error":"No object found ra=183.03879 dec=1.60772 radius=2.00"}
# 117 216.1622083333333 -2.460916666666667
# {'object': 'ZTF18acuexzs', 'separation': 0.25401279764820917}
# 118 215.73466666666664 -2.352222222222222
# {'object': 'ZTF19aacitsy', 'separation': 0.19419610375924884}
# 119 301.42462499999993 22.66633333333333
# {'object': 'ZTF18adjvzzl', 'separation': 0.1425825506164648}
# 120 316.99245833333333 -5.294611111111111
# Bad Request:{"error":"No object found ra=316.99246 dec=-5.29461 radius=2.00"}
# 121 312.5744166666666 -5.6074722222222215
# Bad Request:{"error":"No object found ra=312.57442 dec=-5.60747 radius=2.00"}
# 122 318.0109583333333 -6.276888888888889
# {'object': 'ZTF18abmmszc', 'separation': 0.3408355075999675}
# 123 295.0475833333333 -10.423833333333333
# {'object': 'ZTF18abudxnu', 'separation': 0.2400153159304594}
# 124 307.9066249999999 -0.08644444444444443
# {'object': 'ZTF18abmqugk', 'separation': 0.9832062055075955}
# 125 36.88695833333333 13.10475
# {'object': 'ZTF18abvmlol', 'separation': 0.5144836308589118}
# 126 107.858375 44.068083333333334
# {'object': 'ZTF19adavmos', 'separation': 0.5625080654514264}
# 127 87.12774999999999 53.734027777777776
# {'object': 'ZTF17aaaheoj', 'separation': 0.43377858718955375}
# 128 109.810375 65.9623888888889
# {'object': 'ZTF18abvgcbb', 'separation': 0.5241431496590502}
# 129 72.35691666666665 56.658722222222224
# {'object': 'ZTF18aaakvdk', 'separation': 0.21898080735457537}
# 130 104.524625 -17.740277777777777
# {'object': 'ZTF17aaahsxa', 'separation': 1.5614084706711644}
# 131 93.71549999999999 -27.4265
# {'object': 'ZTF18acyutkw', 'separation': 0.2835538453006735}
# 132 342.6540416666666 57.53172222222222
# Bad Request:{"error":"No object found ra=342.65404 dec=57.53172 radius=2.00"}
# 133 28.930833333333325 0.4686666666666667
# {'object': 'ZTF18abvkzmr', 'separation': 1.4398130708745773}
# 134 198.09783333333328 17.61641666666667
# {'object': 'ZTF18aahvhsb', 'separation': 0.0999742327332917}
# 135 286.77579166666663 69.14552777777779
# {'object': 'ZTF18aaxcnxg', 'separation': 0.42849789334226734}
# 136 281.4275833333333 48.52522222222222
# {'object': 'ZTF20aaodweh', 'separation': 0.7494003128507241}
# 137 75.44337499999999 -3.989055555555556
# {'object': 'ZTF19aalfvlz', 'separation': 0.1106063676340173}
# 138 53.86933333333333 -25.73938888888889
# {'object': 'ZTF18acuajcr', 'separation': 0.2941021083766166}
# 139 274.05520833333327 49.868
# {'object': 'ZTF19aanvjhb', 'separation': 1.271476451190906}
# 140 142.2793333333333 -24.08486111111111
# {'object': 'ZTF19aamucki', 'separation': 0.2288324894155443}
# 141 169.31633333333332 17.961583333333333
# {'object': 'ZTF18aabpoqs', 'separation': 0.3415830458607995}
# 142 118.16854166666666 36.47313888888889
# {'object': 'ZTF18abztpda', 'separation': 0.09777672850037478}
# 143 270.14804166666664 8.170527777777778
# {'object': 'ZTF18abcpwci', 'separation': 1.089849252786717}
# 144 78.92254166666665 1.0779166666666666
# {'object': 'ZTF17aaaryjg', 'separation': 0.19885881994035218}
# 145 328.23374999999993 19.282805555555555
# {'object': 'ZTF18abadjvf', 'separation': 1.3881584454202782}
# 146 266.386625 -29.09786111111111
# Bad Request:{"error":"No object found ra=266.38662 dec=-29.09786 radius=2.00"}
# 147 278.2149166666666 -10.018166666666668
# Bad Request:{"error":"No object found ra=278.21492 dec=-10.01817 radius=2.00"}
# 148 32.374249999999996 28.541500000000003
# {'object': 'ZTF18aaaeozg', 'separation': 0.6391874805692459}
# 149 166.10687499999997 45.05383333333333
# {'object': 'ZTF17aabxhpg', 'separation': 1.366712404760911}
# 150 123.77829166666665 -19.054916666666667
# {'object': 'ZTF19aaerhgx', 'separation': 1.9062522636826649}
# 151 4.958041666666666 21.947805555555554
# {'object': 'ZTF18abpumun', 'separation': 0.5720254885742151}
# 152 305.0612083333333 21.10288888888889
# Bad Request:{"error":"No object found ra=305.06121 dec=21.10289 radius=2.00"}
# 153 20.152874999999995 49.400055555555554
# {'object': 'ZTF18aabfarp', 'separation': 0.2077798105484334}
# 154 33.89525 49.334472222222225
# {'object': 'ZTF18abnzpcu', 'separation': 0.49510486126615}
# 155 3.2566666666666664 41.34422222222222
# {'object': 'ZTF18abtcgjs', 'separation': 0.5396746372457049}
# 156 355.8844166666666 45.656749999999995
# {'object': 'ZTF20abmbzpi', 'separation': 0.5363207888324542}
# 157 36.36012499999999 38.54725
# Bad Request:{"error":"No object found ra=36.36012 dec=38.54725 radius=2.00"}
# 158 22.858624999999996 36.04436111111111
# Bad Request:{"error":"No object found ra=22.85862 dec=36.04436 radius=2.00"}
# 159 4.802416666666666 22.12586111111111
# Bad Request:{"error":"No object found ra=4.80242 dec=22.12586 radius=2.00"}
# 160 353.80045833333327 49.904694444444445
# Bad Request:{"error":"No object found ra=353.80046 dec=49.90469 radius=2.00"}
# 161 356.10887499999995 47.011916666666664
# Bad Request:{"error":"No object found ra=356.10887 dec=47.01192 radius=2.00"}
# 162 8.573749999999999 43.76091666666667
# {'object': 'ZTF17aabumcd', 'separation': 0.11116014840346247}
# 163 1.9137916666666666 45.680749999999996
# {'object': 'ZTF18abiuzar', 'separation': 0.14284732809729334}
# 164 17.618166666666667 34.83244444444445
# {'object': 'ZTF18abwxaix', 'separation': 0.32885924567519487}
# 165 9.063499999999998 38.85883333333334
# {'object': 'ZTF18accbuhi', 'separation': 0.18986697401605762}
# 166 1.4344999999999999 36.82930555555556
# {'object': 'ZTF19aczlxwf', 'separation': 0.6826127414838467}
# 167 153.44129166666664 -27.96611111111111
# Bad Request:{"error":"No object found ra=153.44129 dec=-27.96611 radius=2.00"}
# 168 146.5915 -29.093666666666664
# Bad Request:{"error":"No object found ra=146.59150 dec=-29.09367 radius=2.00"}
# 169 316.768875 1.7377500000000001
# Bad Request:{"error":"No object found ra=316.76887 dec=1.73775 radius=2.00"}
# 170 354.91145833333326 -5.551472222222222
# {'object': 'ZTF18accqcwt', 'separation': 0.08971499624619944}
# 171 311.68033333333324 -0.10836111111111112
# {'object': 'ZTF18abvvtdv', 'separation': 0.12155242296527254}
# 172 316.1377916666666 -6.9214722222222225
# Bad Request:{"error":"No object found ra=316.13779 dec=-6.92147 radius=2.00"}
# 173 295.1764166666666 -1.9611666666666667
# {'object': 'ZTF18abtinpl', 'separation': 0.11655333076306275}
# 174 292.308125 6.672166666666667
# {'object': 'ZTF18abfxckk', 'separation': 0.06740898441506903}
# 175 284.19641666666666 7.0153888888888885
# {'object': 'ZTF19aaimpde', 'separation': 0.44646402842837035}
# 176 302.89979166666666 2.9098055555555553
# {'object': 'ZTF18abudroz', 'separation': 0.20832468860953562}
# 177 298.72624999999994 15.633222222222223
# {'object': 'ZTF18abbnxlu', 'separation': 0.2603854537564231}
# 178 292.47470833333335 9.596555555555556
# {'object': 'ZTF18aazurmd', 'separation': 0.19038868994281605}
# 179 297.23087499999997 11.58286111111111
# {'object': 'ZTF18abmhqur', 'separation': 0.05305830573909658}
# 180 282.7083333333333 11.010694444444445
# {'object': 'ZTF18abajebz', 'separation': 0.1768046282719032}
# 181 295.5825833333333 3.7243055555555555
# {'object': 'ZTF18abjhbor', 'separation': 0.24582917364428536}
# 182 291.6410833333333 16.038972222222224
# {'object': 'ZTF18abkhgfg', 'separation': 0.05591898023381151}
# 183 296.4609583333333 7.929222222222222
# {'object': 'ZTF18abkhkyo', 'separation': 0.222171523588451}
# 184 303.0467083333333 -7.704361111111111
# {'object': 'ZTF18abnmtwb', 'separation': 0.09700071044975885}
# 185 301.0872916666666 11.546444444444445
# {'object': 'ZTF18admoeob', 'separation': 0.08774533780691776}
# 186 301.93587499999995 -0.4639166666666667
# {'object': 'ZTF18abudsie', 'separation': 0.15705388425158673}
# 187 30.761249999999993 19.65663888888889
# {'object': 'ZTF18abomwsj', 'separation': 0.03995660664457465}
# 188 41.589541666666655 27.1815
# {'object': 'ZTF19aclsycv', 'separation': 0.14061442007857494}
# 189 39.503791666666665 11.692416666666666
# Bad Request:{"error":"No object found ra=39.50379 dec=11.69242 radius=2.00"}
# 190 37.515791666666665 26.077861111111112
# Bad Request:{"error":"No object found ra=37.51579 dec=26.07786 radius=2.00"}
# 191 82.37883333333333 29.23777777777778
# Bad Request:{"error":"No object found ra=82.37883 dec=29.23778 radius=2.00"}
# 192 89.86116666666665 45.321361111111116
# {'object': 'ZTF18aacrzad', 'separation': 0.2206354623705408}
# 193 81.74583333333332 29.252333333333333
# {'object': 'ZTF17aacrftb', 'separation': 0.06358682353119641}
# 194 75.43079166666666 38.200722222222225
# {'object': 'ZTF18abondko', 'separation': 0.09892934270959786}
# 195 80.942375 29.842972222222222
# {'object': 'ZTF17aadgyxz', 'separation': 0.6745101433776187}
# 196 82.65233333333332 34.33075
# {'object': 'ZTF20acfgtxr', 'separation': 0.2705802521555472}
# 197 88.67133333333334 28.877583333333334
# {'object': 'ZTF17aadatmf', 'separation': 0.1410504348306745}
# 198 81.51166666666666 28.855972222222224
# {'object': 'ZTF17aacdrel', 'separation': 0.13083512166134223}
# 199 73.8655 38.98305555555556
# {'object': 'ZTF18aaadvfh', 'separation': 0.1035027224322195}
# 200 92.31049999999999 40.10044444444445
# {'object': 'ZTF18abuxzdj', 'separation': 0.48034540607965354}
# 201 74.18658333333333 50.75911111111111
# {'object': 'ZTF18abvlkyj', 'separation': 0.0643253712160784}
# 202 100.33874999999999 44.684888888888885
# {'object': 'ZTF18achtpcj', 'separation': 0.12412870554078266}
# 203 234.03062499999996 51.969722222222224
# {'object': 'ZTF18aajskry', 'separation': 0.265647386036816}
# 204 226.5460833333333 53.295249999999996
# {'object': 'ZTF19aalaoit', 'separation': 0.62402104959836}
# 205 218.93341666666666 23.610750000000003
# Bad Request:{"error":"No object found ra=218.93342 dec=23.61075 radius=2.00"}
# 206 226.1739583333333 8.797944444444445
# {'object': 'ZTF19abcgdbj', 'separation': 0.31061463332665934}
# 207 236.2493333333333 46.809805555555556
# Bad Request:{"error":"No object found ra=236.24933 dec=46.80981 radius=2.00"}
# 208 56.29829166666666 53.587361111111115
# {'object': 'ZTF17aaabwtm', 'separation': 0.3669041956707322}
# 209 60.535 72.40630555555556
# {'object': 'ZTF19abuscub', 'separation': 0.1506056711987845}
# 210 99.09533333333331 65.90416666666667
# {'object': 'ZTF17aaaiapl', 'separation': 0.3249289764270501}
# 211 119.85995833333332 59.89758333333333
# {'object': 'ZTF18abwkyxs', 'separation': 0.18718612873372129}
# 212 86.35499999999999 83.52894444444445
# Bad Request:{"error":"No object found ra=86.35500 dec=83.52894 radius=2.00"}
# 213 93.92720833333333 64.44655555555556
# Bad Request:{"error":"No object found ra=93.92721 dec=64.44656 radius=2.00"}
# 214 87.01045833333333 60.48305555555556
# {'object': 'ZTF18aaafkvm', 'separation': 0.0659210569070581}
# 215 92.51558333333332 66.67569444444445
# {'object': 'ZTF18abttpxu', 'separation': 0.24494371606607454}
# 216 139.29087499999997 31.71861111111111
# {'object': 'ZTF17aaclubr', 'separation': 0.8597032428440351}
# 217 118.92779166666665 10.834194444444446
# {'object': 'ZTF18abuqgyj', 'separation': 0.43440969646739996}
# 218 122.1083333333333 31.69038888888889
# {'object': 'ZTF20aciuzan', 'separation': 0.06268908214696546}
# 219 119.53670833333332 10.729305555555555
# {'object': 'ZTF18achdntb', 'separation': 0.18053224941289225}
# 220 119.68404166666666 12.031555555555556
# {'object': 'ZTF20acyistb', 'separation': 0.17720491094017135}
# 221 120.42654166666667 21.062722222222224
# {'object': 'ZTF19aaddrwk', 'separation': 0.440981815988594}
# 222 121.39370833333332 7.3414166666666665
# {'object': 'ZTF18acvwhbb', 'separation': 0.0718193660464436}
# 223 125.72133333333333 23.21683333333333
# Bad Request:{"error":"No object found ra=125.72133 dec=23.21683 radius=2.00"}
# 224 131.57129166666667 24.895583333333335
# {'object': 'ZTF18aaaxhyo', 'separation': 0.09408384144737701}
# 225 134.09583333333333 31.14275
# Bad Request:{"error":"No object found ra=134.09583 dec=31.14275 radius=2.00"}
# 226 134.64816666666664 28.232305555555556
# {'object': 'ZTF19aacxymc', 'separation': 0.238574362238521}
# 227 135.30629166666668 14.784611111111111
# {'object': 'ZTF18acppwkz', 'separation': 0.17966675968468054}
# 228 204.63774999999995 29.485666666666667
# {'object': 'ZTF19aailxac', 'separation': 0.39163794875258684}
# 229 184.87291666666664 47.25636111111111
# Bad Request:{"error":"No object found ra=184.87292 dec=47.25636 radius=2.00"}
# 230 202.2363333333333 31.14611111111111
# {'object': 'ZTF18aahkfwx', 'separation': 0.055495024306148534}
# 231 111.32745833333333 -16.173111111111112
# {'object': 'ZTF17aaanpkv', 'separation': 0.06817541610213809}
# 232 111.78283333333333 9.058166666666667
# Bad Request:{"error":"No object found ra=111.78283 dec=9.05817 radius=2.00"}
# 233 115.87995833333332 5.726805555555556
# {'object': 'ZTF19acbvdkk', 'separation': 0.7729867999131086}
# 234 305.04212499999994 -11.782111111111112
# Bad Request:{"error":"No object found ra=305.04212 dec=-11.78211 radius=2.00"}
# 235 309.55408333333327 -24.803722222222223
# {'object': 'ZTF19aaynnts', 'separation': 0.04681545389005153}
# 236 314.822625 -20.002944444444445
# {'object': 'ZTF18abwuper', 'separation': 0.08102847180630277}
# 237 24.66908333333333 58.13644444444444
# Bad Request:{"error":"No object found ra=24.66908 dec=58.13644 radius=2.00"}
# 238 10.945416666666665 58.017833333333336
# {'object': 'ZTF19acxfwej', 'separation': 0.11434397637545454}
# 239 2.1817083333333334 60.198499999999996
# Bad Request:{"error":"No object found ra=2.18171 dec=60.19850 radius=2.00"}
# 240 18.18945833333333 59.13261111111111
# Bad Request:{"error":"No object found ra=18.18946 dec=59.13261 radius=2.00"}
# 241 359.194125 55.236333333333334
# {'object': 'ZTF18abboafu', 'separation': 0.17365075954734577}
# 242 18.573875 59.59852777777778
# {'object': 'ZTF18abvytad', 'separation': 0.021733528855063206}
# 243 23.155249999999995 60.602583333333335
# {'object': 'ZTF18abzbknn', 'separation': 0.20657144676469522}
# 244 16.682958333333332 53.28941666666667
# {'object': 'ZTF18acrufyo', 'separation': 0.4517333708848184}
# 245 330.98749999999995 61.538805555555555
# {'object': 'ZTF17aabqmtu', 'separation': 0.286520126439046}
# 246 344.8272083333333 75.95225
# {'object': 'ZTF18ablsqnv', 'separation': 0.03252776751248476}
# 247 328.5726666666666 76.62655555555556
# {'object': 'ZTF18acbxzfi', 'separation': 0.1426818997521633}
# 248 306.333875 76.37288888888888
# Bad Request:{"error":"No object found ra=306.33387 dec=76.37289 radius=2.00"}
# 249 343.1315833333333 59.19308333333333
# {'object': 'ZTF18abccwds', 'separation': 0.2820003884935612}
# 250 312.5480833333333 56.34711111111111
# {'object': 'ZTF18abebznd', 'separation': 0.1383454774234854}
# 251 2.9772499999999993 75.92102777777778
# {'object': 'ZTF18adomhhg', 'separation': 0.23190805730202022}
# 252 335.89241666666663 55.781888888888886
# {'object': 'ZTF19aargrpf', 'separation': 0.31929801176715167}
# 253 4.0135 75.80438888888888
# {'object': 'ZTF19aawsdwq', 'separation': 0.14327654789400873}
# 254 35.04391666666667 -12.870861111111111
# {'object': 'ZTF18acmwzay', 'separation': 1.483105945822835}
# 255 19.361124999999994 -8.507472222222223
# Bad Request:{"error":"No object found ra=19.36112 dec=-8.50747 radius=2.00"}
# 256 17.183874999999997 2.444166666666667
# {'object': 'ZTF19abcekey', 'separation': 0.20464168899310198}
# 257 40.72270833333333 6.796055555555555
# {'object': 'ZTF19acumszo', 'separation': 0.5381320053602302}
# 258 42.823791666666665 5.629916666666667
# Bad Request:{"error":"No object found ra=42.82379 dec=5.62992 radius=2.00"}
# 259 6.515833333333332 -9.505833333333333
# Bad Request:{"error":"No object found ra=6.51583 dec=-9.50583 radius=2.00"}
# 260 9.330375 -21.953972222222223
# {'object': 'ZTF22abffdwx', 'separation': 0.0849555831292232}
# 261 9.921125 0.9076944444444445
# Bad Request:{"error":"No object found ra=9.92112 dec=0.90769 radius=2.00"}
# 262 10.896416666666665 -0.6249444444444445
# Bad Request:{"error":"No object found ra=10.89642 dec=-0.62494 radius=2.00"}
# 263 184.80433333333332 20.827305555555554
# Bad Request:{"error":"No object found ra=184.80433 dec=20.82731 radius=2.00"}
# 264 188.22962499999997 22.36927777777778
# {'object': 'ZTF18aajnorp', 'separation': 0.29758272785409623}
# 265 199.28779166666666 24.945611111111113
# Bad Request:{"error":"No object found ra=199.28779 dec=24.94561 radius=2.00"}
# 266 237.9212083333333 38.013527777777774
# {'object': 'ZTF18aagrcdr', 'separation': 0.29051477188593644}
# 267 233.05699999999996 37.018027777777775
# Bad Request:{"error":"No object found ra=233.05700 dec=37.01803 radius=2.00"}
# 268 185.65175 -18.180583333333335
# {'object': 'ZTF19aaslkvc', 'separation': 0.5897840663631468}
# 269 185.39337499999996 -14.964027777777778
# {'object': 'ZTF19aafmmdo', 'separation': 0.2110951153495388}
# 270 174.45816666666664 -20.127
# {'object': 'ZTF20abcbcql', 'separation': 0.16399816152494537}
# 271 316.9676666666667 44.095
# {'object': 'ZTF18aayfbcg', 'separation': 0.10840652821286928}
# 272 306.5039583333333 33.66233333333333
# {'object': 'ZTF18aayefwp', 'separation': 0.1997120917399471}
# 273 305.2338333333333 45.19161111111111
# {'object': 'ZTF18adkxyub', 'separation': 0.08865575018495997}
# 274 310.8974999999999 36.913333333333334
# {'object': 'ZTF18aazfitj', 'separation': 0.15029171281856366}
# 275 289.87949999999995 44.54555555555555
# Bad Request:{"error":"No object found ra=289.87950 dec=44.54556 radius=2.00"}
# 276 292.9022083333333 39.21544444444445
# {'object': 'ZTF18abddknn', 'separation': 0.08473289445490957}
# 277 295.6417916666666 39.81713888888889
# Bad Request:{"error":"No object found ra=295.64179 dec=39.81714 radius=2.00"}
# 278 318.20808333333326 37.70722222222223
# {'object': 'ZTF18abtjhfn', 'separation': 0.31941633602978914}
# 279 301.4917499999999 43.818083333333334
# {'object': 'ZTF17aabopno', 'separation': 0.37919869922021454}
# 280 320.2552083333333 31.118055555555557
# {'object': 'ZTF18acridto', 'separation': 0.18421008795210292}
# 281 321.8769166666666 36.319972222222226
# {'object': 'ZTF18absxaew', 'separation': 0.208188602788627}
# 282 329.3559583333333 50.66580555555555
# {'object': 'ZTF17aaaelhz', 'separation': 0.1813675679250148}
# 283 296.1488333333333 46.11725
# {'object': 'ZTF18aaqiklh', 'separation': 0.031793411765598106}
# 284 296.9495 33.674388888888885
# Bad Request:{"error":"No object found ra=296.94950 dec=33.67439 radius=2.00"}
# 285 322.5770416666666 47.15211111111111
# Bad Request:{"error":"No object found ra=322.57704 dec=47.15211 radius=2.00"}
# 286 320.36908333333326 29.261444444444443
# {'object': 'ZTF17aaaejau', 'separation': 0.1326991679992451}
# 287 295.9734166666666 47.595888888888894
# {'object': 'ZTF18aaueqpz', 'separation': 0.2994025323089659}
# 288 300.9174583333333 32.04436111111111
# {'object': 'ZTF18aaxyyfv', 'separation': 0.3166240258146522}
# 289 291.9899583333333 46.72563888888889
# {'object': 'ZTF18aayncoh', 'separation': 0.3214211841101314}
# 290 295.6272916666666 36.02202777777778
# {'object': 'ZTF18aaynycd', 'separation': 0.08638906857122128}
# 291 302.3454166666666 59.23002777777778
# {'object': 'ZTF18abaqnny', 'separation': 0.3923127715647392}
# 292 294.012 46.142
# Bad Request:{"error":"No object found ra=294.01200 dec=46.14200 radius=2.00"}
# 293 316.05525 45.172666666666665
# {'object': 'ZTF18abcbzzd', 'separation': 0.05896158575712552}
# 294 295.92295833333327 43.98663888888889
# {'object': 'ZTF18abdkpol', 'separation': 0.0737660430361381}
# 295 293.98974999999996 33.01372222222222
# {'object': 'ZTF18abdkwtr', 'separation': 0.07062560923471924}
# 296 299.8906666666667 36.796416666666666
# {'object': 'ZTF18abecrrv', 'separation': 0.09164233080875371}
# 297 297.11116666666663 59.552861111111106
# {'object': 'ZTF18abfhssx', 'separation': 0.0825874096492407}
# 298 297.24291666666664 58.439138888888884
# {'object': 'ZTF18ablxhlc', 'separation': 0.05261130278042982}
# 299 318.0694166666666 33.98983333333334
# {'object': 'ZTF18abmribl', 'separation': 0.13018365642660537}
# 300 327.857625 46.46763888888889
# {'object': 'ZTF18abochac', 'separation': 0.30125838339463235}
# 301 298.1297916666666 37.33702777777778
# {'object': 'ZTF18abrxtii', 'separation': 0.14363873209288935}
# 302 328.86154166666665 40.97811111111111
# {'object': 'ZTF18abvxaey', 'separation': 0.6967350395083745}
# 303 312.46624999999995 46.33061111111112
# {'object': 'ZTF18abzvpif', 'separation': 0.06298975093258025}
# 304 323.0287916666666 38.18277777777777
# {'object': 'ZTF18accpsbu', 'separation': 0.14682603331555646}
# 305 301.90433333333334 47.24161111111111
# {'object': 'ZTF19aaxiftc', 'separation': 0.17495153247915338}
# 306 303.90004166666665 37.08280555555556
# {'object': 'ZTF18aayovjs', 'separation': 0.38248540985993396}
# 307 307.7303749999999 17.50888888888889
# {'object': 'ZTF18absanwi', 'separation': 0.32708780415338445}
# 308 306.00724999999994 20.13722222222222
# {'object': 'ZTF18ablvyvm', 'separation': 0.07509869866606748}
# 309 308.29908333333333 13.831694444444445
# {'object': 'ZTF18abmrdyu', 'separation': 0.3378008488376152}
# 310 310.5674166666666 16.39397222222222
# Bad Request:{"error":"No object found ra=310.56742 dec=16.39397 radius=2.00"}
# 311 310.80845833333325 15.600666666666667
# {'object': 'ZTF18abtovcc', 'separation': 0.3618485703220794}
# 312 306.9183333333333 3.9379166666666667
# {'object': 'ZTF18absvavn', 'separation': 0.45240207957620354}
# 313 311.1195833333333 14.836472222222223
# {'object': 'ZTF18abxkbzz', 'separation': 0.2744627190990657}
# 314 310.2230833333333 18.450444444444443
# {'object': 'ZTF18acaqmki', 'separation': 0.13241409963992828}
# 315 308.1609583333333 4.116444444444444
# {'object': 'ZTF19aatvsho', 'separation': 0.18302676833989906}
# 316 315.2595833333333 14.11286111111111
# {'object': 'ZTF19abzwbwx', 'separation': 0.18047991363866225}
# 317 185.58408333333333 75.05761111111111
# {'object': 'ZTF18achdhsl', 'separation': 0.5620376285163053}
# 318 246.20862499999996 65.6836388888889
# Bad Request:{"error":"No object found ra=246.20862 dec=65.68364 radius=2.00"}
# 319 261.0255416666666 56.33419444444445
# {'object': 'ZTF18aarhxbo', 'separation': 0.719396219967684}
# 320 255.88641666666663 69.43672222222223
# {'object': 'ZTF18aditjsu', 'separation': 0.05532453227710345}
# 321 140.96424999999996 73.44002777777779
# {'object': 'ZTF18acanduo', 'separation': 0.17605499897341534}
# 322 201.84804166666663 67.73741666666666
# {'object': 'ZTF18abhhlxf', 'separation': 0.17283280511949617}
# 323 262.49566666666664 52.497194444444446
# Bad Request:{"error":"No object found ra=262.49567 dec=52.49719 radius=2.00"}
# 324 279.2947083333333 53.78502777777778
# {'object': 'ZTF18abdfkrf', 'separation': 0.31620604011979414}
# 325 291.6622083333333 59.81294444444444
# {'object': 'ZTF18adkcmyd', 'separation': 0.050504157185987}
# 326 247.85774999999995 73.90325
# {'object': 'ZTF18abbvroe', 'separation': 0.22521221807423378}
# 327 194.6448333333333 64.13975
# Bad Request:{"error":"No object found ra=194.64483 dec=64.13975 radius=2.00"}
# 328 194.64487499999998 66.59766666666667
# {'object': 'ZTF18aaqeyxt', 'separation': 0.20791616393325973}
# 329 222.51299999999998 58.750527777777776
# Bad Request:{"error":"No object found ra=222.51300 dec=58.75053 radius=2.00"}
# 330 231.8248333333333 54.623583333333336
# Bad Request:{"error":"No object found ra=231.82483 dec=54.62358 radius=2.00"}
# 331 258.19874999999996 60.76755555555555
# {'object': 'ZTF18aamnkzq', 'separation': 0.22669643773676207}
# 332 261.5081666666666 54.541888888888884
# Bad Request:{"error":"No object found ra=261.50817 dec=54.54189 radius=2.00"}
# 333 300.37966666666665 60.670138888888886
# {'object': 'ZTF18abcfvae', 'separation': 0.418820383026927}
# 334 280.90162499999997 49.88511111111111
# {'object': 'ZTF18aapaajf', 'separation': 0.1032742897493451}
# 335 266.8567083333333 63.046638888888886
# {'object': 'ZTF18aaploaw', 'separation': 0.21703080585938148}
# 336 299.59720833333324 64.6453888888889
# {'object': 'ZTF18aazrcyh', 'separation': 0.0922075537951729}
# 337 278.748 54.55416666666667
# {'object': 'ZTF18abfgyjt', 'separation': 0.15374071573839534}
# 338 66.64029166666667 -25.04138888888889
# {'object': 'ZTF17aabvifa', 'separation': 0.09023995681932896}
# 339 62.25 -30.483333333333334
# Bad Request:{"error":"No object found ra=62.25000 dec=-30.48333 radius=2.00"}
# 340 76.91987499999999 -9.227166666666667
# {'object': 'ZTF19abttqmi', 'separation': 0.11884087540558991}
# 341 55.67729166666666 -27.808500000000002
# {'object': 'ZTF18acuavel', 'separation': 0.18561502473524286}
# 342 93.22945833333333 22.170444444444446
# {'object': 'ZTF17aacmljo', 'separation': 0.6333972161315079}
# 343 99.14262499999998 13.067
# {'object': 'ZTF18aabipud', 'separation': 0.3569330997483379}
# 344 102.48712499999998 16.918916666666668
# Bad Request:{"error":"No object found ra=102.48712 dec=16.91892 radius=2.00"}
# 345 104.40833333333332 22.396722222222223
# {'object': 'ZTF18abzcucs', 'separation': 0.715822073382107}
# 346 108.06858333333332 35.230444444444444
# Bad Request:{"error":"No object found ra=108.06858 dec=35.23044 radius=2.00"}
# 347 109.07479166666666 16.993111111111112
# Bad Request:{"error":"No object found ra=109.07479 dec=16.99311 radius=2.00"}
# 348 98.51020833333331 20.482999999999997
# {'object': 'ZTF18abttlxr', 'separation': 0.0766549912242102}
# 349 94.53883333333332 22.136583333333334
# {'object': 'ZTF17aadkisd', 'separation': 0.11998797651237143}
# 350 117.60729166666665 34.34277777777778
# Bad Request:{"error":"No object found ra=117.60729 dec=34.34278 radius=2.00"}
# 351 118.78208333333333 14.596555555555556
# Bad Request:{"error":"No object found ra=118.78208 dec=14.59656 radius=2.00"}
# 352 97.86316666666664 22.207416666666667
# {'object': 'ZTF17aacmlmj', 'separation': 0.05446406720381326}
# 353 95.24824999999998 19.07027777777778
# {'object': 'ZTF18abzjuvh', 'separation': 0.09327710551371722}
# 354 255.68375000000003 22.596638888888886
# {'object': 'ZTF18aagvuyl', 'separation': 0.6222624716459318}
# 355 253.4442083333333 16.83025
# {'object': 'ZTF18absduqw', 'separation': 0.16106289921966624}
# 356 262.29162499999995 30.31361111111111
# {'object': 'ZTF18abhefjc', 'separation': 0.19228953825921574}
# 357 260.68312499999996 27.39875
# {'object': 'ZTF18aaseumb', 'separation': 0.15272347276456263}
# 358 263.27733333333333 44.72544444444445
# {'object': 'ZTF19aauezji', 'separation': 0.14533865791593956}
# 359 277.126 26.023694444444445
# {'object': 'ZTF18abguzyw', 'separation': 0.14091642013549321}
# 360 267.64320833333323 23.861611111111113
# {'object': 'ZTF18ablqqxo', 'separation': 0.3371710275610416}
# 361 237.65533333333332 40.91108333333333
# {'object': 'ZTF18aagwkrt', 'separation': 0.03450090747740618}
# 362 242.5522083333333 22.35302777777778
# {'object': 'ZTF18aazijsj', 'separation': 0.06147170253011499}
# 363 242.62645833333332 44.983805555555556
# Bad Request:{"error":"No object found ra=242.62646 dec=44.98381 radius=2.00"}
# 364 249.020875 46.86794444444445
# {'object': 'ZTF18aagtesn', 'separation': 0.2271959530785149}
# 365 268.83624999999995 29.41038888888889
# {'object': 'ZTF18abbxmwt', 'separation': 0.057910781061098295}
# 366 270.853125 17.875444444444444
# {'object': 'ZTF18abcmsux', 'separation': 0.016263883756242367}
# 367 261.6004583333333 36.418416666666666
# {'object': 'ZTF18abfwukx', 'separation': 0.14051360915386205}
# 368 256.1854583333333 26.34125
# Bad Request:{"error":"No object found ra=256.18546 dec=26.34125 radius=2.00"}
# 369 280.18379166666665 17.33438888888889
# {'object': 'ZTF18admeisx', 'separation': 0.19233866063535474}
# 370 162.545 -14.076888888888888
# Bad Request:{"error":"No object found ra=162.54500 dec=-14.07689 radius=2.00"}
# 371 149.35987499999996 -23.0705
# {'object': 'ZTF19aankizb', 'separation': 0.5514323521120894}
# 372 130.634 -13.230611111111111
# {'object': 'ZTF20aaqwhhx', 'separation': 0.22815030061262068}
# 373 133.22983333333332 -8.05175
# {'object': 'ZTF18acwxhax', 'separation': 0.033103524909981544}
# 374 143.15916666666664 1.1506944444444445
# {'object': 'ZTF19aaaehud', 'separation': 0.08366702945389641}
# 375 157.88808333333333 -24.57286111111111
# Bad Request:{"error":"No object found ra=157.88808 dec=-24.57286 radius=2.00"}
# 376 133.76470833333332 -13.564333333333334
# {'object': 'ZTF18acvwfyd', 'separation': 0.3346398888823477}
# 377 141.9050833333333 -8.091444444444445
# {'object': 'ZTF18acvwgbr', 'separation': 0.2129885827796288}
# 378 160.46995833333332 -20.47297222222222
# {'object': 'ZTF19aachvbn', 'separation': 0.7323651028584559}
# 379 206.95725 -26.977527777777777
# {'object': 'ZTF20aavhqhx', 'separation': 0.12462241199366485}
# 380 334.08883333333324 38.52591666666667
# Bad Request:{"error":"No object found ra=334.08883 dec=38.52592 radius=2.00"}
# 381 340.46225 37.20561111111111
# Bad Request:{"error":"No object found ra=340.46225 dec=37.20561 radius=2.00"}
# 382 337.28987499999994 52.35788888888889
# {'object': 'ZTF19aastacp', 'separation': 0.03887811832869965}
# 383 331.40412499999996 46.31472222222222
# {'object': 'ZTF18abcvgsz', 'separation': 0.16932636824540706}
# 384 331.2743333333333 37.734833333333334
# {'object': 'ZTF19aaprgqb', 'separation': 0.014416392116521405}
# 385 342.30683333333326 51.33441666666667
# {'object': 'ZTF18abblxwa', 'separation': 0.22059264131970172}
# 386 330.612875 40.23597222222222
# {'object': 'ZTF18abolzdh', 'separation': 0.20913934398705478}
# 387 329.57537499999995 42.08825
# {'object': 'ZTF18abuelzu', 'separation': 0.0883354995892295}
# 388 338.057375 44.09316666666667
# {'object': 'ZTF19aaprwuu', 'separation': 0.2000429367524966}
# 389 331.49054166666656 36.058611111111105
# {'object': 'ZTF17aaaehyg', 'separation': 0.40856722104567605}
# 390 344.24125 55.894888888888886
# Bad Request:{"error":"No object found ra=344.24125 dec=55.89489 radius=2.00"}
# 391 334.38191666666665 46.992472222222226
# {'object': 'ZTF18abmnbne', 'separation': 0.08966233114260247}
# 392 343.83916666666664 53.6455
# {'object': 'ZTF18abvburn', 'separation': 0.013745490554998244}
# 393 342.10825 38.919333333333334
# {'object': 'ZTF18acehgym', 'separation': 0.22661307813190776}
# 394 170.554625 14.439388888888889
# {'object': 'ZTF18aamqtld', 'separation': 1.3748445517868653}
# 395 146.49266666666665 29.38116666666667
# {'object': 'ZTF19aacwwsa', 'separation': 1.0194947967744983}
# 396 153.5898333333333 6.649388888888889
# {'object': 'ZTF20aaicimz', 'separation': 1.0684720911243466}
# 397 163.67941666666664 28.842416666666665
# Bad Request:{"error":"No object found ra=163.67942 dec=28.84242 radius=2.00"}
# 398 79.25958333333332 -26.718138888888888
# {'object': 'ZTF19aabaqng', 'separation': 0.2249603966558507}
# 399 236.1640416666666 -11.467888888888888
# {'object': 'ZTF19aatmqvx', 'separation': 0.8064398597097251}
# 400 220.13779166666663 -15.756416666666667
# {'object': 'ZTF18acyygqo', 'separation': 0.14251627938322342}
# 401 217.23820833333332 -16.609833333333334
# Bad Request:{"error":"No object found ra=217.23821 dec=-16.60983 radius=2.00"}
# 402 238.79649999999995 -13.648249999999999
# {'object': 'ZTF19aabzwkh', 'separation': 0.3928782460670376}
# 403 230.89749999999995 -10.190722222222222
# {'object': 'ZTF19aanycxa', 'separation': 0.04917736202409193}
# 404 231.9060833333333 -20.884777777777778
# {'object': 'ZTF19aauymhu', 'separation': 0.3450638337736964}
# 405 135.45870833333333 37.912305555555555
# Bad Request:{"error":"No object found ra=135.45871 dec=37.91231 radius=2.00"}
# 406 119.64633333333332 48.42322222222222
# Bad Request:{"error":"No object found ra=119.64633 dec=48.42322 radius=2.00"}
# 407 285.9098333333333 38.53747222222222
# {'object': 'ZTF19ackwxdf', 'separation': 0.2920067633338082}
# 408 290.84729166666665 39.03197222222222
# {'object': 'ZTF18abddiqk', 'separation': 0.018695888441191022}
# 409 291.22687499999995 43.38144444444445
# {'object': 'ZTF18abddgxi', 'separation': 0.24025135793072386}
# 410 291.76283333333333 42.192138888888884
# {'object': 'ZTF19aasrjeg', 'separation': 0.11209108329718787}
# 411 289.7450833333333 35.92805555555555
# {'object': 'ZTF18adkwcwx', 'separation': 0.4030031559550149}
# 412 290.18774999999994 37.27341666666666
# {'object': 'ZTF18abddhac', 'separation': 0.2804888514947256}
# 413 285.2434583333333 30.596527777777776
# {'object': 'ZTF18adjgvhi', 'separation': 0.015367925632528692}
# 414 279.27466666666663 37.29966666666667
# {'object': 'ZTF18abdklug', 'separation': 0.1789027213186716}
# 415 285.1344583333333 30.511111111111113
# {'object': 'ZTF18abqazwf', 'separation': 0.1061611141479961}
# 416 285.26924999999994 45.08777777777778
# {'object': 'ZTF18accntcd', 'separation': 0.2733590696160278}
# 417 280.71370833333333 33.94708333333333
# {'object': 'ZTF18acdwdgx', 'separation': 0.2911319560853345}
# 418 112.95029166666664 -4.998027777777778
# {'object': 'ZTF18actdcgj', 'separation': 0.352686359889243}
# 419 111.70925 -1.9921944444444446
# {'object': 'ZTF18acthnek', 'separation': 0.2005617334045074}
# 420 118.60933333333332 -0.9255833333333333
# {'object': 'ZTF18acnnteg', 'separation': 0.2169655039755926}
# 421 121.03304166666666 -0.37116666666666664
# {'object': 'ZTF18acpupju', 'separation': 0.2957357546114757}
# 422 97.50524999999999 -6.347305555555555
# {'object': 'ZTF17aaatdch', 'separation': 0.07273429931422545}
# 423 96.02579166666666 -9.647805555555555
# {'object': 'ZTF18acuxbmr', 'separation': 0.14896586209492}
# 424 97.94162499999999 9.912555555555556
# Bad Request:{"error":"No object found ra=97.94162 dec=9.91256 radius=2.00"}
# 425 104.54933333333332 6.6570833333333335
# {'object': 'ZTF18acgodtz', 'separation': 0.026439978994146733}
# 426 103.96183333333333 -9.543777777777777
# {'object': 'ZTF18acphaci', 'separation': 0.09821054406735001}
# 427 107.45587499999999 -1.9537499999999999
# {'object': 'ZTF18actcmzw', 'separation': 0.116957890572901}
# 428 98.22137499999998 -6.482666666666667
# {'object': 'ZTF19aanvlmz', 'separation': 0.5480987427920946}
# 429 258.5081666666666 -21.089555555555556
# {'object': 'ZTF18ablqkyb', 'separation': 0.10953353560870956}
# 430 265.1910833333333 6.064194444444444
# Bad Request:{"error":"No object found ra=265.19108 dec=6.06419 radius=2.00"}
# 431 271.79229166666664 5.818888888888889
# {'object': 'ZTF18abimokp', 'separation': 0.34225995466970033}
# 432 265.3907083333333 -28.676222222222222
# Bad Request:{"error":"No object found ra=265.39071 dec=-28.67622 radius=2.00"}
# 433 271.53904166666666 11.850694444444445
# Bad Request:{"error":"No object found ra=271.53904 dec=11.85069 radius=2.00"}
# 434 269.1139166666666 10.00911111111111
# {'object': 'ZTF18abjedyt', 'separation': 0.047714872447701645}
# 435 256.4654583333333 2.0873611111111114
# {'object': 'ZTF19abfrxaf', 'separation': 0.03149487546629003}
# 436 261.25008333333335 -29.358111111111114
# Bad Request:{"error":"No object found ra=261.25008 dec=-29.35811 radius=2.00"}
# 437 261.6173333333333 -29.41369444444444
# Bad Request:{"error":"No object found ra=261.61733 dec=-29.41369 radius=2.00"}
# 438 261.7492083333333 -29.132916666666667
# Bad Request:{"error":"No object found ra=261.74921 dec=-29.13292 radius=2.00"}
# 439 262.89145833333333 -28.238222222222223
# Bad Request:{"error":"No object found ra=262.89146 dec=-28.23822 radius=2.00"}
# 440 263.70991666666663 -27.09561111111111
# Bad Request:{"error":"No object found ra=263.70992 dec=-27.09561 radius=2.00"}
# 441 263.8918333333333 -27.228055555555553
# Bad Request:{"error":"No object found ra=263.89183 dec=-27.22806 radius=2.00"}
# 442 264.60004166666664 -21.90736111111111
# Bad Request:{"error":"No object found ra=264.60004 dec=-21.90736 radius=2.00"}
# 443 264.69149999999996 -21.111777777777778
# Bad Request:{"error":"No object found ra=264.69150 dec=-21.11178 radius=2.00"}
# 444 264.693375 -22.64547222222222
# Bad Request:{"error":"No object found ra=264.69338 dec=-22.64547 radius=2.00"}
# 445 264.71712499999995 -27.423472222222223
# Bad Request:{"error":"No object found ra=264.71712 dec=-27.42347 radius=2.00"}
# 446 262.7695416666666 12.741222222222222
# {'object': 'ZTF18abetdcw', 'separation': 0.20521791835070458}
# 447 268.7712916666666 13.422222222222222
# {'object': 'ZTF18abdjpbo', 'separation': 0.6935413904589152}
# 448 83.97312499999998 -0.66775
# Bad Request:{"error":"No object found ra=83.97312 dec=-0.66775 radius=2.00"}
# 449 84.24633333333333 0.3708611111111111
# Bad Request:{"error":"No object found ra=84.24633 dec=0.37086 radius=2.00"}
# 450 75.47295833333332 -3.702388888888889
# {'object': 'ZTF18abwtmcs', 'separation': 0.020846068559187744}
# 451 94.00091666666665 21.374972222222222
# {'object': 'ZTF18abyyhsf', 'separation': 0.11154192450755322}
# 452 347.45474999999993 21.58811111111111
# {'object': 'ZTF22abnxlhh', 'separation': 0.912166329662978}
# 453 339.99283333333324 23.310277777777777
# {'object': 'ZTF18acavizq', 'separation': 0.20503370115168243}
# 454 359.50141666666656 12.738722222222222
# {'object': 'ZTF18abspnfw', 'separation': 0.42066591141394233}
# 455 340.76591666666656 22.24888888888889
# {'object': 'ZTF18abhqdpp', 'separation': 0.24191672876755865}
# 456 325.6454166666666 28.30452777777778
# {'object': 'ZTF18abaaoaz', 'separation': 0.30986860293629437}
# 457 324.6069999999999 27.51
# {'object': 'ZTF18abaphmn', 'separation': 0.16682518578146413}
# 458 320.19183333333325 18.598027777777776
# {'object': 'ZTF18abcxifh', 'separation': 0.25347295818036203}
# ...
# 4354 226.96162499999997 -10.97488888888889
# {'object': 'ZTF20aayitwt', 'separation': 0.08439775974235085}
# 4355 222.98137499999999 -14.971916666666667
# {'object': 'ZTF21abbvorw', 'separation': 0.1623190540350366}
# 4356 238.6895833333333 -14.33313888888889
# Bad Request:{"error":"No object found ra=238.68958 dec=-14.33314 radius=2.00"}
# 4357 231.01895833333333 -20.478194444444444
# {'object': 'ZTF22aabzkfa', 'separation': 0.02697060002670598}
# 4358 222.54308333333333 -24.783333333333335
# Bad Request:{"error":"No object found ra=222.54308 dec=-24.78333 radius=2.00"}
# 4359 227.1697083333333 -29.162166666666664
# Bad Request:{"error":"No object found ra=227.16971 dec=-29.16217 radius=2.00"}
# 4360 234.42679166666665 -22.60452777777778
# Bad Request:{"error":"No object found ra=234.42679 dec=-22.60453 radius=2.00"}
# 4361 230.53779166666666 -3.7831944444444443
# {'object': 'ZTF19aadttiw', 'separation': 0.04538094055342241}
# 4362 219.82141666666666 -18.0775
# {'object': 'ZTF21abexegc', 'separation': 0.03713827038732537}
# 4363 219.55249999999998 -14.206444444444443
# {'object': 'ZTF19aapymxy', 'separation': 0.05270100668662734}
# 4364 231.6050833333333 -14.695833333333333
# {'object': 'ZTF19aanpgdw', 'separation': 0.48981029057878783}
# 4365 220.1589583333333 -22.236027777777778
# Bad Request:{"error":"No object found ra=220.15896 dec=-22.23603 radius=2.00"}
# 4366 235.9755833333333 -14.629305555555556
# {'object': 'ZTF19aarxpzx', 'separation': 0.1616483715217754}
# 4367 231.40766666666661 -7.944833333333333
# Bad Request:{"error":"No object found ra=231.40767 dec=-7.94483 radius=2.00"}
# 4368 237.84304166666664 -4.430611111111111
# Bad Request:{"error":"No object found ra=237.84304 dec=-4.43061 radius=2.00"}
# 4369 223.9777083333333 -11.331861111111111
# Bad Request:{"error":"No object found ra=223.97771 dec=-11.33186 radius=2.00"}
# 4370 229.65025 -5.800833333333333
# Bad Request:{"error":"No object found ra=229.65025 dec=-5.80083 radius=2.00"}
# 4371 225.20541666666665 -8.74636111111111
# {'object': 'ZTF18acwyzll', 'separation': 0.29292733670296095}
# 4372 224.4552083333333 -24.683111111111113
# Bad Request:{"error":"No object found ra=224.45521 dec=-24.68311 radius=2.00"}
# 4373 220.6083333333333 -11.591138888888889
# {'object': 'ZTF19aavxoyu', 'separation': 0.7103772715645427}
# 4374 216.47779166666663 -22.63525
# Bad Request:{"error":"No object found ra=216.47779 dec=-22.63525 radius=2.00"}
# 4375 229.30862499999998 -7.170722222222222
# Bad Request:{"error":"No object found ra=229.30862 dec=-7.17072 radius=2.00"}
# 4376 236.73008333333334 -12.248444444444443
# {'object': 'ZTF19aanxolm', 'separation': 0.06677536110049964}
# 4377 234.71429166666664 -5.570138888888889
# Bad Request:{"error":"No object found ra=234.71429 dec=-5.57014 radius=2.00"}
# 4378 234.19141666666664 -22.49727777777778
# {'object': 'ZTF19aaxlgob', 'separation': 0.14797963839074788}
# 4379 230.36279166666662 -11.322194444444444
# {'object': 'ZTF19aatmqlm', 'separation': 0.25242724238685155}
# 4380 234.1132083333333 -16.15694444444444
# {'object': 'ZTF19aanoxtr', 'separation': 0.8047747016887081}
# 4381 215.7105 -22.308027777777777
# Bad Request:{"error":"No object found ra=215.71050 dec=-22.30803 radius=2.00"}
# 4382 227.95624999999998 -22.063972222222223
# Bad Request:{"error":"No object found ra=227.95625 dec=-22.06397 radius=2.00"}
# 4383 218.43949999999998 -18.442583333333335
# Bad Request:{"error":"No object found ra=218.43950 dec=-18.44258 radius=2.00"}
# 4384 230.8833333333333 -10.233222222222222
# {'object': 'ZTF19abgplbp', 'separation': 0.13562139951597518}
# 4385 231.04762499999998 -16.365472222222223
# Bad Request:{"error":"No object found ra=231.04762 dec=-16.36547 radius=2.00"}
# 4386 229.95391666666666 -27.87777777777778
# Bad Request:{"error":"No object found ra=229.95392 dec=-27.87778 radius=2.00"}
# 4387 239.83116666666663 -7.738111111111111
# Bad Request:{"error":"No object found ra=239.83117 dec=-7.73811 radius=2.00"}
# 4388 234.81520833333332 -12.024638888888889
# Bad Request:{"error":"No object found ra=234.81521 dec=-12.02464 radius=2.00"}
# 4389 225.01499999999996 -21.285861111111114
# Bad Request:{"error":"No object found ra=225.01500 dec=-21.28586 radius=2.00"}
# 4390 218.26029166666666 -24.29127777777778
# Bad Request:{"error":"No object found ra=218.26029 dec=-24.29128 radius=2.00"}
# 4391 223.72991666666664 -22.06913888888889
# Bad Request:{"error":"No object found ra=223.72992 dec=-22.06914 radius=2.00"}
# 4392 227.9452083333333 -28.904249999999998
# Bad Request:{"error":"No object found ra=227.94521 dec=-28.90425 radius=2.00"}
# 4393 229.85674999999998 -18.51725
# Bad Request:{"error":"No object found ra=229.85675 dec=-18.51725 radius=2.00"}
# 4394 231.64824999999996 -21.905388888888886
# {'object': 'ZTF19aatyrpj', 'separation': 0.19424474398637584}
# 4395 232.77175 -26.076999999999998
# Bad Request:{"error":"No object found ra=232.77175 dec=-26.07700 radius=2.00"}
# 4396 233.8322083333333 -6.507944444444444
# {'object': 'ZTF19aaczyyy', 'separation': 0.4386297816399993}
# 4397 238.92854166666663 -19.19661111111111
# {'object': 'ZTF19aaqrlqb', 'separation': 1.2006353569919161}
# 4398 239.60737499999996 -3.9575
# {'object': 'ZTF19aatnfzx', 'separation': 0.22905943419327632}
# 4399 235.93091666666663 -8.31713888888889
# Bad Request:{"error":"No object found ra=235.93092 dec=-8.31714 radius=2.00"}
# 4400 234.6367083333333 -15.288527777777778
# {'object': 'ZTF20aaazrxx', 'separation': 0.257814987982129}
# 4401 224.06216666666663 -12.145111111111111
# Bad Request:{"error":"No object found ra=224.06217 dec=-12.14511 radius=2.00"}
# 4402 226.80670833333332 -13.737194444444444
# {'object': 'ZTF21abfzmnx', 'separation': 0.24103649518019457}
# 4403 229.3323333333333 -22.96488888888889
# Bad Request:{"error":"No object found ra=229.33233 dec=-22.96489 radius=2.00"}
# 4404 223.83729166666663 -1.8134166666666667
# {'object': 'ZTF18acwyzvb', 'separation': 0.4365031970239923}
# 4405 231.61391666666665 -23.02872222222222
# Bad Request:{"error":"No object found ra=231.61392 dec=-23.02872 radius=2.00"}
# 4406 233.27549999999997 -23.592944444444445
# Bad Request:{"error":"No object found ra=233.27550 dec=-23.59294 radius=2.00"}
# 4407 234.53412499999996 -18.633777777777777
# {'object': 'ZTF19aauxexa', 'separation': 0.4711315763670414}
# 4408 234.18849999999998 -14.428777777777777
# {'object': 'ZTF19aamwqtq', 'separation': 0.20496457701604873}
# 4409 235.18554166666664 -18.94825
# Bad Request:{"error":"No object found ra=235.18554 dec=-18.94825 radius=2.00"}
# 4410 227.48854166666663 -23.81625
# {'object': 'ZTF20abistfy', 'separation': 0.049750321494718634}
# 4411 233.95941666666664 -21.453277777777778
# Bad Request:{"error":"No object found ra=233.95942 dec=-21.45328 radius=2.00"}
# 4412 234.00729166666665 -16.71633333333333
# {'object': 'ZTF19aaaqqaj', 'separation': 0.5303070111728413}
# 4413 227.6747083333333 -9.074083333333332
# {'object': 'ZTF18adbafkf', 'separation': 0.06852096021181445}
# 4414 237.4425833333333 -10.593583333333333
# {'object': 'ZTF19aaseplf', 'separation': 0.12116320511372144}
# 4415 233.7567083333333 -16.448166666666665
# {'object': 'ZTF19aatysfx', 'separation': 0.04379184721572153}
# 4416 223.45529166666662 -4.1219166666666665
# {'object': 'ZTF22aaflcke', 'separation': 0.05420326410643417}
# 4417 225.292625 -6.843388888888889
# {'object': 'ZTF22aalwamk', 'separation': 0.19980667478656602}
# 4418 239.11487499999998 -30.86527777777778
# Bad Request:{"error":"No object found ra=239.11487 dec=-30.86528 radius=2.00"}
# 4419 237.49054166666664 -30.299944444444446
# Bad Request:{"error":"No object found ra=237.49054 dec=-30.29994 radius=2.00"}
# 4420 239.31374999999997 -30.810277777777777
# Bad Request:{"error":"No object found ra=239.31375 dec=-30.81028 radius=2.00"}
# 4421 238.27312499999996 -30.098277777777778
# Bad Request:{"error":"No object found ra=238.27312 dec=-30.09828 radius=2.00"}
# 4422 228.930875 -30.303944444444443
# {'object': 'ZTF21abhyrea', 'separation': 0.10713549607296907}
# 4423 122.01574999999997 34.88261111111111
# {'object': 'ZTF19acdjjbv', 'separation': 0.10927448865021139}
# 4424 126.9274583333333 34.821333333333335
# Bad Request:{"error":"No object found ra=126.92746 dec=34.82133 radius=2.00"}
# 4425 117.99308333333332 53.94647222222222
# Bad Request:{"error":"No object found ra=117.99308 dec=53.94647 radius=2.00"}
# 4426 112.27604166666664 55.673833333333334
# {'object': 'ZTF20abahuik', 'separation': 0.06498288783868554}
# 4427 123.45604166666665 53.01763888888889
# Bad Request:{"error":"No object found ra=123.45604 dec=53.01764 radius=2.00"}
# 4428 100.41370833333333 52.8935
# Bad Request:{"error":"No object found ra=100.41371 dec=52.89350 radius=2.00"}
# 4429 101.90858333333333 56.144666666666666
# {'object': 'ZTF21acbdczl', 'separation': 0.03281690890998135}
# 4430 118.09770833333333 37.34575
# {'object': 'ZTF22aaahgwc', 'separation': 0.07616043773078464}
# 4431 109.86412499999999 47.53883333333333
# {'object': 'ZTF21aarucpz', 'separation': 0.18397916777057285}
# 4432 105.00245833333332 57.09308333333333
# Bad Request:{"error":"No object found ra=105.00246 dec=57.09308 radius=2.00"}
# 4433 108.98424999999999 45.51880555555555
# {'object': 'ZTF22aaahgtt', 'separation': 0.05692359314684845}
# 4434 104.64754166666665 51.39238888888889
# {'object': 'ZTF23aaanxbm', 'separation': 0.17201096116113473}
# 4435 118.29879166666665 35.44208333333333
# {'object': 'ZTF17aacxkaq', 'separation': 0.1496302559839091}
# 4436 130.992 42.84355555555556
# {'object': 'ZTF18aaqjfit', 'separation': 0.246960221940488}
# 4437 122.22387499999998 35.84825
# {'object': 'ZTF17aadewid', 'separation': 0.14264879106167183}
# 4438 121.30775 40.84016666666667
# {'object': 'ZTF20aahcybq', 'separation': 0.2072107056435451}
# 4439 125.34891666666664 45.69316666666666
# {'object': 'ZTF18aaaxlfa', 'separation': 0.25349159247247915}
# 4440 110.00674999999998 52.57255555555556
# {'object': 'ZTF18achushg', 'separation': 1.2437276551230396}
# 4441 121.22583333333331 37.130916666666664
# Bad Request:{"error":"No object found ra=121.22583 dec=37.13092 radius=2.00"}
# 4442 127.28504166666664 48.44408333333333
# Bad Request:{"error":"No object found ra=127.28504 dec=48.44408 radius=2.00"}
# 4443 125.08079166666666 47.79197222222222
# {'object': 'ZTF18aakabcf', 'separation': 0.22609138427231398}
# 4444 118.38329166666664 37.966861111111115
# {'object': 'ZTF18aawvzcg', 'separation': 0.4236644722746193}
# 4445 111.55083333333333 46.4345
# Bad Request:{"error":"No object found ra=111.55083 dec=46.43450 radius=2.00"}
# 4446 135.06945833333333 34.657694444444445
# {'object': 'ZTF18adoezmg', 'separation': 0.2671014444020161}
# 4447 123.63154166666665 42.266555555555556
# {'object': 'ZTF20aaoqqyf', 'separation': 0.36713585150503186}
# 4448 121.75458333333333 55.79411111111111
# Bad Request:{"error":"No object found ra=121.75458 dec=55.79411 radius=2.00"}
# 4449 116.19141666666665 40.230250000000005
# {'object': 'ZTF19adbtjfs', 'separation': 0.5515351322102973}
# 4450 94.93687499999999 60.988083333333336
# {'object': 'ZTF18acpuhto', 'separation': 0.5200992843896728}
# 4451 121.41241666666666 35.68194444444444
# {'object': 'ZTF20aasylce', 'separation': 0.1654605396630443}
# 4452 106.02254166666665 50.569611111111115
# Bad Request:{"error":"No object found ra=106.02254 dec=50.56961 radius=2.00"}
# 4453 110.57920833333331 46.81766666666667
# {'object': 'ZTF19abtsows', 'separation': 0.03713827038732537}
# 4454 127.66049999999998 40.79419444444444
# {'object': 'ZTF18acponib', 'separation': 0.3446392239533609}
# 4455 126.29791666666664 35.22413888888889
# Bad Request:{"error":"No object found ra=126.29792 dec=35.22414 radius=2.00"}
# 4456 101.98866666666666 59.80313888888889
# Bad Request:{"error":"No object found ra=101.98867 dec=59.80314 radius=2.00"}
# 4457 104.73545833333333 50.82633333333334
# {'object': 'ZTF18aagqeeo', 'separation': 0.2097707775601078}
# 4458 105.11366666666665 55.49761111111111
# {'object': 'ZTF18acusatr', 'separation': 0.14198499597055647}
# 4459 110.03074999999998 45.26986111111111
# {'object': 'ZTF18aabrbjr', 'separation': 0.18604713150562882}
# 4460 110.53070833333331 59.29972222222222
# {'object': 'ZTF18abyskuw', 'separation': 0.25192150704083116}
# 4461 128.427625 45.15697222222222
# Bad Request:{"error":"No object found ra=128.42763 dec=45.15697 radius=2.00"}
# 4462 109.50204166666664 56.48902777777778
# {'object': 'ZTF18abtnfxg', 'separation': 0.1623481512933209}
# 4463 143.59745833333332 40.63591666666667
# {'object': 'ZTF18aadfuxg', 'separation': 0.31359606943653096}
# 4464 129.46254166666665 38.5035
# {'object': 'ZTF18aacvbng', 'separation': 0.2609471962282113}
# 4465 135.0689583333333 43.02175
# {'object': 'ZTF18aajyerc', 'separation': 0.3542765199529607}
# 4466 140.62191666666666 33.12877777777778
# {'object': 'ZTF17aaclmvx', 'separation': 0.3303782341078564}
# 4467 124.58366666666664 44.23191666666667
# {'object': 'ZTF22abedept', 'separation': 0.09117726946060709}
# 4468 116.92758333333332 41.317
# {'object': 'ZTF18abrqfjs', 'separation': 0.14198499597055647}
# 4469 102.06979166666665 55.27372222222222
# {'object': 'ZTF18abxwiqz', 'separation': 0.03912035193911381}
# 4470 116.46020833333333 56.25780555555556
# {'object': 'ZTF21aceejop', 'separation': 0.05197904098331289}
# 4471 278.80341666666664 38.33452777777778
# {'object': 'ZTF18aammpul', 'separation': 0.10477274199770496}
# 4472 287.2149583333333 43.008694444444444
# {'object': 'ZTF18acaxfpa', 'separation': 0.23736356894054825}
# 4473 275.299875 38.79533333333333
# {'object': 'ZTF18aabenub', 'separation': 0.2579432040332415}
# 4474 277.19649999999996 35.82477777777778
# {'object': 'ZTF18aakyvxh', 'separation': 0.1549038115925152}
# 4475 287.016375 31.39863888888889
# Bad Request:{"error":"No object found ra=287.01637 dec=31.39864 radius=2.00"}
# 4476 288.9462083333333 41.51686111111111
# Bad Request:{"error":"No object found ra=288.94621 dec=41.51686 radius=2.00"}
# 4477 285.38112499999994 42.91466666666666
# {'object': 'ZTF18abddimk', 'separation': 0.3355983405310907}
# 4478 287.7475833333333 28.944083333333335
# {'object': 'ZTF18abgrsxw', 'separation': 0.22586145722841355}
# 4479 289.3603333333333 37.17816666666666
# Bad Request:{"error":"No object found ra=289.36033 dec=37.17817 radius=2.00"}
# 4480 291.26604166666664 36.383583333333334
# {'object': 'ZTF18aazfxfm', 'separation': 0.37400618486989146}
# 4481 289.6868333333333 29.577972222222222
# {'object': 'ZTF18abmmjpl', 'separation': 0.269530809602106}
# 4482 277.36699999999996 28.47694444444444
# {'object': 'ZTF20acbafxl', 'separation': 0.2753904830488268}
# 4483 287.84329166666663 33.84561111111111
# {'object': 'ZTF18abgjrmo', 'separation': 0.1489341503623425}
# 4484 286.6610416666667 33.14980555555555
# Bad Request:{"error":"No object found ra=286.66104 dec=33.14981 radius=2.00"}
# 4485 282.21320833333334 41.66627777777778
# {'object': 'ZTF19accvbkv', 'separation': 1.598612961446309}
# 4486 285.0627916666666 42.54494444444444
# Bad Request:{"error":"No object found ra=285.06279 dec=42.54494 radius=2.00"}
# 4487 291.00370833333324 42.28325
# {'object': 'ZTF19aaziqbb', 'separation': 0.17288745581022788}
# 4488 285.840875 35.34627777777778
# {'object': 'ZTF18aceghfd', 'separation': 0.24176047702914036}
# 4489 283.0683333333333 31.25997222222222
# {'object': 'ZTF20abfchms', 'separation': 0.09023995681932896}
# 4490 284.4052083333333 38.29244444444444
# Bad Request:{"error":"No object found ra=284.40521 dec=38.29244 radius=2.00"}
# 4491 287.57233333333335 38.59880555555556
# {'object': 'ZTF19aapbjki', 'separation': 0.35115626000616607}
# 4492 280.40579166666663 39.137388888888886
# {'object': 'ZTF21aaopqyt', 'separation': 0.8902049174209927}
# 4493 291.785625 40.47405555555556
# Bad Request:{"error":"No object found ra=291.78562 dec=40.47406 radius=2.00"}
# 4494 286.5057083333333 26.404916666666665
# {'object': 'ZTF21ackmndd', 'separation': 1.694147742591202}
# 4495 285.0949166666666 32.35469444444445
# {'object': 'ZTF18aasiynn', 'separation': 0.1319137476764062}
# 4496 283.32537499999995 28.613666666666667
# {'object': 'ZTF18abhjntj', 'separation': 0.08595054254839903}
# 4497 283.88349999999997 38.675999999999995
# {'object': 'ZTF19aapbjiq', 'separation': 0.14297953296418087}
# 4498 286.99775 39.57061111111111
# Bad Request:{"error":"No object found ra=286.99775 dec=39.57061 radius=2.00"}
# 4499 289.6585833333333 39.73727777777778
# {'object': 'ZTF18abmmajs', 'separation': 0.07247406842872718}

# %%
# Get ZTF counterparts for remaining objects.
pt2 = get_ZTFcounterparts(AAVSO_CVS_2[4500:].reset_index(drop=True), 'ra', 'dec', radius=2)

# Save the dataframe to a csv file.
pt2.to_csv('../processed_data/AAVSOCVsZTFxmatch_21032023_4500_last.csv', index=False)
# Out:
# 0 280.4559166666666 38.84433333333334
# {'object': 'ZTF18ablwuyy', 'separation': 0.1296746985467178}
# 1 277.4248333333333 26.47833333333333
# {'object': 'ZTF19aaviqnb', 'separation': 0.015367925632528692}
# 2 277.6334166666666 42.68772222222222
# {'object': 'ZTF20abazeye', 'separation': 0.05133899320044929}
# 3 281.5805416666666 33.81194444444444
# {'object': 'ZTF18adjchby', 'separation': 0.1740854304640344}
# 4 287.7330416666666 28.976916666666664
# {'object': 'ZTF22aapnsco', 'separation': 0.14711528264918566}
# 5 274.575625 31.34263888888889
# {'object': 'ZTF18abjsdwy', 'separation': 0.11630991943417657}
# 6 288.59475 36.45605555555556
# {'object': 'ZTF18admgggc', 'separation': 0.0573369870537101}
# 7 275.0129166666666 45.58683333333334
# {'object': 'ZTF18abguobu', 'separation': 0.36517502759605935}
# 8 273.92137499999995 47.45127777777778
# {'object': 'ZTF18aanijwl', 'separation': 1.0509818617522533}
# 9 284.7604583333333 40.73013888888889
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 10 273.86829166666666 31.241666666666667
# {'object': 'ZTF18adixesd', 'separation': 0.19041349790304157}
# 11 280.36329166666667 27.378083333333333
# {'object': 'ZTF19aaoeazu', 'separation': 0.2733072266969}
# 12 291.5077916666666 42.39422222222222
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 13 290.73795833333327 42.07508333333334
# {'object': 'ZTF18abddipi', 'separation': 0.6533519549166378}
# 14 273.682375 39.61258333333333
# {'object': 'ZTF18aagrgoi', 'separation': 0.4168533893308558}
# 15 285.47554166666663 41.283
# {'object': 'ZTF19abowkak', 'separation': 0.19783481106793271}
# 16 278.33124999999995 26.87752777777778
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 17 291.2503333333333 43.00222222222222
# {'object': 'ZTF19aaviryr', 'separation': 0.020846068559187744}
# 18 288.39354166666664 37.38952777777778
# {'object': 'ZTF19abolxsr', 'separation': 0.32317983949860596}
# 19 284.40374999999995 32.14330555555556
# {'object': 'ZTF18aapmrow', 'separation': 0.08281586765041472}
# 20 287.2132916666666 46.062888888888885
# {'object': 'ZTF18abmsxzs', 'separation': 0.0794983847602452}
# 21 281.5779999999999 28.96872222222222
# {'object': 'ZTF18acbbuxh', 'separation': 0.13173458998450321}
# 22 290.35616666666664 34.241305555555556
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 23 289.88516666666663 35.37883333333333
# {'object': 'ZTF18abojtmy', 'separation': 0.5923652605293489}
# 24 281.35374999999993 31.948583333333335
# {'object': 'ZTF18aanvpoj', 'separation': 0.13319656956960332}
# 25 274.390375 40.06077777777777
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 26 285.8041666666667 38.52597222222222
# {'object': 'ZTF21abvevwh', 'separation': 0.15899676952049335}
# 27 280.60849999999994 33.785888888888884
# {'object': 'ZTF18aammafs', 'separation': 0.22677976670033234}
# 28 290.1287916666666 27.725888888888885
# {'object': 'ZTF18aayupbw', 'separation': 0.1915018665887784}
# 29 289.1475416666666 26.36475
# {'object': 'ZTF19abgluei', 'separation': 0.04292028050148413}
# 30 281.31737499999997 44.43863888888889
# {'object': 'ZTF19abhhjcc', 'separation': 0.1623481512933209}
# 31 291.9033749999999 40.20755555555556
# {'object': 'ZTF19acnvejn', 'separation': 0.006147170253011476}
# 32 281.03391666666664 36.04138888888889
# {'object': 'ZTF18abgofjq', 'separation': 0.03394885733931309}
# 33 285.20874999999995 40.83791666666667
# {'object': 'ZTF19aamvcyx', 'separation': 0.26858280538067436}
# 34 276.865375 37.69608333333333
# {'object': 'ZTF21abwqhhc', 'separation': 0.05975732465810063}
# 35 288.71020833333336 25.974777777777778
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 36 285.16929166666665 33.53236111111111
# {'object': 'ZTF22aabomdq', 'separation': 0.4566937944057441}
# 37 283.2532083333333 45.45236111111112
# {'object': 'ZTF18aapgtye', 'separation': 0.2716951896712046}
# 38 291.51758333333333 39.598222222222226
# {'object': 'ZTF18abcommb', 'separation': 0.176296298864435}
# 39 289.7203333333333 26.29325
# {'object': 'ZTF18aasnnsv', 'separation': 0.05975732465810063}
# 40 274.0390833333333 31.278305555555555
# {'object': 'ZTF18aawrgzh', 'separation': 0.2784267783425022}
# 41 277.30625 31.106722222222224
# {'object': 'ZTF18aaqznkg', 'separation': 1.7407077801928748}
# 42 277.83599999999996 30.326527777777777
# {'object': 'ZTF18aakytes', 'separation': 0.842145498299114}
# 43 280.08075 27.666138888888888
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 44 280.33916666666664 34.27941666666666
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 45 280.42116666666664 32.721444444444444
# {'object': 'ZTF19aapbjec', 'separation': 1.49452108870763}
# 46 281.1120833333333 36.86119444444444
# {'object': 'ZTF18aammzjo', 'separation': 0.26404225118435865}
# 47 282.1813333333333 29.914166666666667
# {'object': 'ZTF18abcysbr', 'separation': 0.8608014003604609}
# 48 282.6927083333333 27.345555555555553
# {'object': 'ZTF18abkodaw', 'separation': 0.03394885733931309}
# 49 283.8809166666667 37.269416666666665
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 50 284.100625 40.05327777777777
# {'object': 'ZTF18abgydpk', 'separation': 0.21785626881526254}
# 51 284.98816666666664 35.70675
# {'object': 'ZTF18aammeiw', 'separation': 0.5294244804234247}
# 52 285.1201666666666 31.443555555555555
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 53 285.33849999999995 47.284277777777774
# {'object': 'ZTF18abmiwau', 'separation': 0.9461651287776682}
# 54 286.31699999999995 47.392805555555555
# {'object': 'ZTF18abjkhgu', 'separation': 0.3994714834011774}
# 55 287.18716666666666 25.746472222222224
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 56 287.4865833333333 38.59302777777778
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 57 287.98679166666665 40.51711111111111
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 58 288.2009166666666 37.82616666666667
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 59 289.66962499999994 42.351083333333335
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 60 290.3087083333333 40.888305555555554
# {'object': 'ZTF19aausxbj', 'separation': 0.08120316508520119}
# 61 288.4425833333333 31.94238888888889
# {'object': 'ZTF18admejrl', 'separation': 0.08003134079382204}
# 62 288.6165 33.681888888888885
# {'object': 'ZTF18abgjryr', 'separation': 0.12861402179706408}
# 63 280.18791666666664 28.90497222222222
# {'object': 'ZTF18acbwiyt', 'separation': 0.21861380618719783}
# 64 281.13216666666665 41.78655555555555
# {'object': 'ZTF18aanvqfu', 'separation': 0.251414754380917}
# 65 283.145125 30.040861111111113
# {'object': 'ZTF18aasjdpy', 'separation': 0.2575583643969012}
# 66 285.70733333333334 38.78547222222222
# {'object': 'ZTF19abadpzm', 'separation': 0.08178278104315855}
# 67 289.0048333333333 28.355694444444445
# {'object': 'ZTF18ablybbf', 'separation': 0.30072482121955174}
# 68 282.8212083333333 35.68958333333333
# {'object': 'ZTF18aaowtej', 'separation': 0.06313954841150077}
# 69 289.4832916666667 33.52141666666667
# {'object': 'ZTF18abgjrxl', 'separation': 0.15970816801488258}
# 70 274.0371666666666 37.86547222222222
# {'object': 'ZTF18aajsyek', 'separation': 0.09542974489540394}
# 71 277.441 32.264833333333335
# {'object': 'ZTF18adixfki', 'separation': 0.040192340882424626}
# 72 277.7197083333333 26.920833333333334
# {'object': 'ZTF18abjtjhe', 'separation': 0.2775942570501427}
# 73 278.9127083333333 41.27608333333333
# {'object': 'ZTF18aagrglo', 'separation': 0.09973771895808016}
# 74 280.6621666666666 26.613111111111113
# {'object': 'ZTF18abfsesp', 'separation': 0.058559661605455685}
# 75 281.8549583333333 30.173805555555557
# {'object': 'ZTF18aaxuihk', 'separation': 0.07985408400743979}
# 76 283.48391666666663 28.37763888888889
# {'object': 'ZTF18abhjntr', 'separation': 0.09210504397604916}
# 77 284.4380416666666 27.76488888888889
# {'object': 'ZTF18abbmmxa', 'separation': 0.08484431185274943}
# 78 288.3525416666666 36.99277777777778
# {'object': 'ZTF18abvvrre', 'separation': 0.03948091580029215}
# 79 291.42808333333335 30.961388888888887
# {'object': 'ZTF18abdptrg', 'separation': 0.06831384348548562}
# 80 280.83549999999997 29.213583333333332
# {'object': 'ZTF18abbxjgd', 'separation': 0.30319635936345357}
# 81 280.698125 26.579944444444443
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 82 283.52 29.448416666666667
# {'object': 'ZTF19abhcrvd', 'separation': 0.05287995798829358}
# 83 287.5729583333333 28.91727777777778
# {'object': 'ZTF18acbwkhg', 'separation': 0.22183109584802477}
# 84 279.1046666666667 41.58013888888889
# {'object': 'ZTF18aaubpxj', 'separation': 0.06893332678413484}
# 85 289.0689166666666 38.969611111111114
# {'object': 'ZTF18abwutne', 'separation': 0.29615073293746186}
# 86 275.64849999999996 41.803805555555556
# {'object': 'ZTF18aalataf', 'separation': 0.30445563436923423}
# 87 286.4861666666666 45.41788888888889
# {'object': 'ZTF18adjccrf', 'separation': 0.02129442240198382}
# 88 288.3046666666666 45.635416666666664
# {'object': 'ZTF18aapyuru', 'separation': 0.028503255876644134}
# 89 286.75416666666666 35.83097222222222
# {'object': 'ZTF18adjgvfo', 'separation': 0.0965125306499585}
# 90 282.63695833333327 39.73052777777778
# {'object': 'ZTF18aarqtiv', 'separation': 0.09825862756793816}
# 91 289.7203333333333 26.29325
# {'object': 'ZTF18aasnnsv', 'separation': 0.05975732465810063}
# 92 278.01237499999996 33.148666666666664
# {'object': 'ZTF18adkuefc', 'separation': 0.09883380493481624}
# 93 288.87287499999996 31.66447222222222
# {'object': 'ZTF18abgxyfz', 'separation': 0.09987969443060293}
# 94 282.6948333333333 27.670916666666667
# {'object': 'ZTF18adlabhm', 'separation': 0.03281690890998135}
# 95 286.51533333333333 26.963
# {'object': 'ZTF18abikcnz', 'separation': 0.08020820585106313}
# 96 290.62741666666665 40.880250000000004
# {'object': 'ZTF18abkxflz', 'separation': 0.09236110519845102}
# 97 289.4835 30.226138888888887
# {'object': 'ZTF18admodwh', 'separation': 0.1555732085146629}
# 98 283.244375 26.755277777777778
# {'object': 'ZTF18admpwlr', 'separation': 0.0573369870537101}
# 99 290.8805 43.48116666666667
# {'object': 'ZTF18abrxrms', 'separation': 0.01894685119314915}
# 100 279.40774999999996 32.827000000000005
# {'object': 'ZTF18abvvtfp', 'separation': 0.06520058656518987}
# 101 287.9979583333333 31.951416666666667
# {'object': 'ZTF18abvvyro', 'separation': 0.03134454107348264}
# 102 291.18183333333326 33.84652777777778
# {'object': 'ZTF18acaxgen', 'separation': 0.25436586436496894}
# 103 283.9755416666667 26.287000000000003
# {'object': 'ZTF18acbwkjw', 'separation': 0.07484668889949171}
# 104 288.96324999999996 32.704750000000004
# {'object': 'ZTF18acxgwpj', 'separation': 0.06447206552566812}
# 105 288.4559166666666 36.74041666666667
# {'object': 'ZTF19aaumqle', 'separation': 0.07008852456384168}
# 106 290.64145833333333 38.90947222222222
# {'object': 'ZTF19abagvei', 'separation': 0.015057430481893489}
# 107 283.5805416666666 31.08897222222222
# {'object': 'ZTF19abgbyqo', 'separation': 0.07732983809896667}
# 108 283.36087499999996 43.399388888888886
# {'object': 'ZTF19abggtjk', 'separation': 0.15789375058357247}
# 109 287.69599999999997 43.15383333333333
# {'object': 'ZTF19abvxjqh', 'separation': 0.04007464709862265}
# 110 283.986 36.17308333333333
# {'object': 'ZTF19acmdqbm', 'separation': 0.02883278423304283}
# 111 288.2964999999999 44.49144444444445
# {'object': 'ZTF20aauadsw', 'separation': 0.02783249707536029}
# 112 282.95729166666666 32.51108333333333
# {'object': 'ZTF20aaurern', 'separation': 0.04225480949130896}
# 113 287.5309583333333 35.94394444444444
# {'object': 'ZTF20abazbfr', 'separation': 0.04681545389005153}
# 114 285.2402916666667 30.556444444444445
# {'object': 'ZTF21abbxesi', 'separation': 0.08865575018495997}
# 115 284.52237499999995 28.73352777777778
# {'object': 'ZTF21abrthyb', 'separation': 0.04898488628739321}
# 116 278.68787499999996 26.305111111111113
# {'object': 'ZTF21abytufi', 'separation': 0.07042468248551517}
# 117 286.78575 29.653499999999998
# {'object': 'ZTF22abazqjm', 'separation': 0.14501329673346414}
# 118 309.9676666666666 -30.80161111111111
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 119 320.2912083333333 -27.593166666666665
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 120 316.7635833333333 -30.618194444444445
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 121 309.18854166666665 -30.26372222222222
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 122 307.2314999999999 -30.067416666666666
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 123 308.20304166666665 -29.922972222222224
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 124 115.51720833333333 -9.374416666666667
# {'object': 'ZTF19aadlcxi', 'separation': 0.12139688557211425}
# 125 96.25729166666666 -2.799611111111111
# {'object': 'ZTF18actaaed', 'separation': 0.08660749892891886}
# 126 99.08895833333331 -3.862888888888889
# {'object': 'ZTF18adasrny', 'separation': 0.07208196058260738}
# 127 112.99358333333332 -4.847638888888889
# {'object': 'ZTF18acucsxw', 'separation': 0.29723332174476624}
# 128 119.00129166666666 -2.854277777777778
# {'object': 'ZTF18acrxnze', 'separation': 0.21391799191916913}
# 129 118.89774999999999 -10.330555555555556
# {'object': 'ZTF20aalztwm', 'separation': 0.7896482252245693}
# 130 112.46862499999999 -10.166
# {'object': 'ZTF18acrvdrm', 'separation': 0.09210504397604916}
# 131 100.86179166666666 -2.861388888888889
# {'object': 'ZTF19adgiafx', 'separation': 0.3917223651795274}
# 132 101.67712499999999 -1.6719444444444442
# {'object': 'ZTF18acyuwnl', 'separation': 0.09302356575281205}
# 133 106.89987499999998 -9.211527777777777
# {'object': 'ZTF18acpvmnu', 'separation': 0.2564003798016386}
# 134 95.52849999999998 -5.5192499999999995
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 135 118.92641666666665 -11.260277777777778
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 136 117.45820833333332 -7.026888888888889
# {'object': 'ZTF19acymuht', 'separation': 0.19555345700075502}
# 137 109.08787499999998 -3.224
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 138 117.34037499999998 -3.3261666666666665
# {'object': 'ZTF18acrvdwc', 'separation': 0.07421292059957296}
# 139 120.87075 -10.855416666666667
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 140 116.12020833333332 -3.1173888888888888
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 141 118.08008333333332 -5.613777777777777
# {'object': 'ZTF21achjcyb', 'separation': 0.03649680122576089}
# 142 106.71179166666666 -9.825055555555556
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 143 101.12141666666666 -4.132305555555555
# {'object': 'ZTF18acveeev', 'separation': 0.08758369443144357}
# 144 111.56345833333333 -10.393027777777776
# {'object': 'ZTF18acrvfdx', 'separation': 0.2541057575040744}
# 145 117.16254166666664 -10.826277777777777
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 146 119.70187499999999 -11.247666666666666
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 147 119.36879166666665 -1.7528611111111112
# {'object': 'ZTF18acrxnfr', 'separation': 0.24825741108157656}
# 148 106.15662499999999 6.020361111111111
# {'object': 'ZTF18acuxkzq', 'separation': 0.07175356725475868}
# 149 94.76012499999999 -9.95661111111111
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 150 110.14995833333332 -1.7599722222222223
# {'object': 'ZTF20acnzcmp', 'separation': 0.06577759415396581}
# 151 121.9965 -10.757722222222222
# {'object': 'ZTF19aapcmry', 'separation': 0.050410544209887324}
# 152 89.72366666666666 -9.720444444444444
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 153 120.55895833333332 -9.364305555555555
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 154 103.14983333333332 -7.989472222222222
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 155 118.66795833333332 -8.22311111111111
# {'object': 'ZTF18adaylew', 'separation': 0.1470831719246628}
# 156 98.03345833333331 6.63725
# {'object': 'ZTF21aatigej', 'separation': 0.10006868172245564}
# 157 90.12904166666665 -10.86888888888889
# {'object': 'ZTF20aaoopvl', 'separation': 0.8616240999948971}
# 158 90.15662499999999 -8.162472222222222
# {'object': 'ZTF18acwfxej', 'separation': 0.15648140775645877}
# 159 122.6727083333333 -1.189888888888889
# {'object': 'ZTF19aaiqndq', 'separation': 0.13000211449415364}
# 160 89.89754166666665 -8.181972222222221
# {'object': 'ZTF18adaisil', 'separation': 0.7029444407392663}
# 161 92.10354166666666 -9.308416666666668
# {'object': 'ZTF21acgrvmu', 'separation': 0.5082208092084638}
# 162 97.09887499999999 0.9770555555555556
# {'object': 'ZTF18abyyqqb', 'separation': 0.19361146790042125}
# 163 119.62149999999998 -5.082916666666667
# {'object': 'ZTF17aabwlhh', 'separation': 0.10979197136459347}
# 164 102.16941666666665 8.46211111111111
# {'object': 'ZTF18abzkood', 'separation': 0.1692705678259497}
# 165 101.14524999999999 2.519861111111111
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 166 97.50699999999999 -8.880305555555555
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 167 102.79241666666665 -0.2706388888888889
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 168 96.50637499999999 -3.9230555555555555
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 169 99.71074999999998 1.9888611111111112
# {'object': 'ZTF18acclkfa', 'separation': 0.14314461734310752}
# 170 101.08974999999998 -8.498
# {'object': 'ZTF18acpvluf', 'separation': 0.04379184721572153}
# 171 108.79958333333332 -4.621555555555556
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 172 106.39587499999999 9.437472222222222
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 173 108.12408333333332 -0.7053888888888888
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 174 120.52458333333333 -3.9919444444444445
# {'object': 'ZTF18acqxpga', 'separation': 0.14386873821634075}
# 175 106.20783333333333 7.053694444444444
# {'object': 'ZTF18accvefv', 'separation': 0.5967506219305538}
# 176 109.04304166666665 -1.5139444444444445
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 177 114.40204166666665 -11.023555555555557
# {'object': 'ZTF18acrvdnx', 'separation': 0.1586994122946084}
# 178 121.28216666666667 -9.528027777777778
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 179 96.05420833333334 8.93625
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 180 96.06170833333333 -1.5880277777777778
# {'object': 'ZTF18acruoof', 'separation': 0.1008679274877701}
# 181 118.87404166666666 -8.965277777777777
# {'object': 'ZTF18adaylcx', 'separation': 0.13241409963992828}
# 182 100.67908333333332 2.3353055555555557
# {'object': 'ZTF18acexert', 'separation': 0.2546813512767391}
# 183 99.79941666666666 3.14075
# {'object': 'ZTF17aabgjnc', 'separation': 0.2110951153495388}
# 184 95.59979166666665 8.748027777777777
# {'object': 'ZTF18abzikwz', 'separation': 0.016551762454990755}
# 185 102.999 -7.56825
# {'object': 'ZTF19actnosk', 'separation': 0.06613566753525078}
# 186 107.45137499999998 -6.413388888888889
# {'object': 'ZTF18adatmxj', 'separation': 0.05717198818772674}
# 187 117.03612499999998 -10.02963888888889
# {'object': 'ZTF19aamrvqa', 'separation': 0.2195624307092823}
# 188 121.65295833333332 -4.015694444444445
# {'object': 'ZTF19aaeqcty', 'separation': 0.23805903942875214}
# 189 119.04479166666665 -2.3550833333333334
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 190 110.83345833333333 -1.6234166666666667
# {'object': 'ZTF19accsxgq', 'separation': 0.1317704410097919}
# 191 111.791 -9.867277777777778
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 192 114.39074999999998 -10.246694444444444
# {'object': 'ZTF20acvkabi', 'separation': 0.1632765257019977}
# 193 109.31033333333332 -1.6599444444444444
# {'object': 'ZTF18acrkvpr', 'separation': 0.0850111641512821}
# 194 110.39291666666665 -7.353833333333333
# {'object': 'ZTF21aanbcfm', 'separation': 0.23027286639812075}
# 195 108.37508333333332 -4.369
# {'object': 'ZTF20aaukvjg', 'separation': 0.30412965633598665}
# 196 117.77645833333332 -7.946472222222223
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 197 113.06362499999997 -11.026055555555557
# {'object': 'ZTF18acrvcwv', 'separation': 0.10853716476745308}
# 198 93.836 -6.048916666666667
# {'object': 'ZTF18aczbnnt', 'separation': 0.0592014304859646}
# 199 109.61787499999998 -1.7089999999999999
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 200 110.16374999999998 -3.8327777777777774
# {'object': 'ZTF19acxycqu', 'separation': 0.2798988271130917}
# 201 109.71562499999999 -7.3077499999999995
# {'object': 'ZTF18acrvcyq', 'separation': 0.04269960921678703}
# 202 102.79629166666665 0.2465
# {'object': 'ZTF17aaasaaf', 'separation': 0.21312160366244917}
# 203 96.58391666666665 -1.3799166666666667
# {'object': 'ZTF19aanvlpy', 'separation': 0.13400972140967}
# 204 116.61187499999998 -1.6196666666666666
# {'object': 'ZTF18acrveuj', 'separation': 0.3693677009465288}
# 205 96.21804166666666 9.694861111111111
# {'object': 'ZTF18aaoaqgg', 'separation': 0.24257967582963835}
# 206 102.12308333333331 2.2019444444444445
# {'object': 'ZTF19acyscvr', 'separation': 0.1507310714463209}
# 207 102.23074999999999 -5.929583333333333
# {'object': 'ZTF18acuxeey', 'separation': 0.15863987396488421}
# 208 104.83820833333333 10.495277777777776
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 209 110.09145833333332 -4.752527777777778
# {'object': 'ZTF18actlaoz', 'separation': 0.37615960786153174}
# 210 118.51229166666666 -1.2324166666666667
# {'object': 'ZTF18acvvexv', 'separation': 0.12294340506023133}
# 211 106.24762499999999 -1.2042777777777778
# {'object': 'ZTF18actbmog', 'separation': 0.35575337148619895}
# 212 106.06283333333332 -3.726527777777778
# {'object': 'ZTF18acpvnog', 'separation': 0.1882680657682074}
# 213 119.08441666666666 -10.173416666666666
# {'object': 'ZTF19aaeqlmr', 'separation': 0.03701086599678818}
# 214 99.08366666666664 8.251944444444444
# {'object': 'ZTF18aabgqgw', 'separation': 0.10142830917469038}
# 215 101.56599999999999 1.494
# {'object': 'ZTF17aaaufly', 'separation': 0.031793411765598106}
# 216 104.63879166666666 9.976166666666666
# {'object': 'ZTF17aaaihbs', 'separation': 0.04236644722745456}
# 217 105.98533333333332 7.9743611111111115
# {'object': 'ZTF18acnaydb', 'separation': 0.13159108820989995}
# 218 106.03220833333332 7.792222222222222
# {'object': 'ZTF19aakpxyi', 'separation': 0.14000846572438447}
# 219 106.24633333333333 8.407805555555555
# {'object': 'ZTF18aczwyjo', 'separation': 0.09869032486167868}
# 220 112.19866666666665 -9.171944444444444
# {'object': 'ZTF17aabtchb', 'separation': 0.2088681452423444}
# 221 106.31024999999998 8.485444444444443
# {'object': 'ZTF17aabswnq', 'separation': 0.010647211200991907}
# 222 97.42229166666665 -1.6503055555555555
# {'object': 'ZTF18acewivc', 'separation': 0.056423522608648496}
# 223 106.34441666666665 -2.790694444444444
# {'object': 'ZTF17aaagsht', 'separation': 0.08114497577992465}
# 224 101.68895833333332 10.83361111111111
# {'object': 'ZTF18abscyxd', 'separation': 0.10845009121571776}
# 225 101.56445833333332 -5.175055555555556
# {'object': 'ZTF18acewjdj', 'separation': 0.05270100668662734}
# 226 110.30220833333333 -8.289638888888888
# {'object': 'ZTF18acuxxkf', 'separation': 0.09128082119126618}
# 227 103.78320833333332 -1.9364444444444444
# {'object': 'ZTF18actbmen', 'separation': 0.15370998910358494}
# 228 106.92683333333332 -2.034472222222222
# {'object': 'ZTF17aaaieal', 'separation': 0.09408384144737701}
# 229 95.419125 8.122388888888889
# {'object': 'ZTF17aaanrgp', 'separation': 0.05774742169176652}
# 230 95.895875 7.969694444444444
# {'object': 'ZTF17aabgnha', 'separation': 0.22684224333498115}
# 231 96.04820833333333 -3.486138888888889
# {'object': 'ZTF18acruois', 'separation': 0.08649835269912905}
# 232 96.993375 8.100388888888888
# {'object': 'ZTF18aaoaqfc', 'separation': 0.2264045448420136}
# 233 97.70574999999998 5.073166666666666
# {'object': 'ZTF18acbzhkr', 'separation': 0.2010791915337786}
# 234 100.27658333333332 -4.89061111111111
# {'object': 'ZTF17aaavwfg', 'separation': 0.09478410298627858}
# 235 100.75970833333332 -5.75775
# {'object': 'ZTF18acgrzrx', 'separation': 0.035044262281920716}
# 236 101.70862499999998 5.325916666666666
# {'object': 'ZTF17aaavwhr', 'separation': 0.14611656886720129}
# 237 102.25399999999999 8.068194444444444
# {'object': 'ZTF18aablmgk', 'separation': 0.08195586648765812}
# 238 103.57791666666665 -6.139333333333334
# {'object': 'ZTF18acrbyzz', 'separation': 0.04506760465038747}
# 239 103.687 6.685805555555556
# {'object': 'ZTF17aabgmpl', 'separation': 0.1779231504066314}
# 240 103.96129166666667 -5.9021944444444445
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 241 104.42399999999998 10.003333333333334
# {'object': 'ZTF17aaaihbr', 'separation': 0.21232222829599925}
# 242 107.81254166666665 1.2371666666666667
# {'object': 'ZTF18adayxpp', 'separation': 0.11318140756552698}
# 243 109.99741666666665 -1.6468333333333334
# {'object': 'ZTF18achcjts', 'separation': 0.22447694932079434}
# 244 110.21379166666665 -2.5043055555555553
# {'object': 'ZTF18achcrmr', 'separation': 0.15306330492347528}
# 245 112.07416666666666 -5.005305555555555
# {'object': 'ZTF17aaailpd', 'separation': 0.15798347144539213}
# 246 112.01187499999999 -3.279722222222222
# {'object': 'ZTF17aaailvv', 'separation': 0.05152267533713223}
# 247 102.29783333333332 10.3895
# {'object': 'ZTF18aaaekak', 'separation': 0.15044877390522993}
# 248 100.94412499999999 -10.92611111111111
# {'object': 'ZTF18acwdrfb', 'separation': 0.0804434210359432}
# 249 110.01683333333332 -7.424138888888889
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 250 101.37045833333333 0.3871388888888889
# {'object': 'ZTF17aaatddi', 'separation': 0.08102847180630277}
# 251 96.992125 11.845222222222223
# {'object': 'ZTF18acrgiyy', 'separation': 0.15191721123523586}
# 252 103.69058333333334 7.094111111111111
# {'object': 'ZTF17aaagsrn', 'separation': 0.07872218967736848}
# 253 100.66454166666665 3.687777777777778
# {'object': 'ZTF17aaagsrt', 'separation': 0.18356792575249775}
# 254 96.09591666666665 8.522611111111113
# {'object': 'ZTF17aaaguld', 'separation': 0.049464671354798574}
# 255 113.29466666666664 -1.385
# {'object': 'ZTF17aaailsw', 'separation': 0.048109216942493954}
# 256 113.96354166666664 -5.605888888888889
# {'object': 'ZTF17aaapids', 'separation': 0.0659926713300308}
# 257 109.24195833333333 -9.581527777777778
# {'object': 'ZTF17aabrpgv', 'separation': 0.06038636646241154}
# 258 95.77483333333333 -9.3535
# {'object': 'ZTF17aabwggo', 'separation': 0.03450090747740618}
# 259 121.74749999999999 -6.852916666666666
# {'object': 'ZTF17aabwjvw', 'separation': 0.1754637578016382}
# 260 95.99099999999999 8.189638888888888
# {'object': 'ZTF18abttpes', 'separation': 0.10226312415320772}
# 261 98.54104166666664 7.028666666666666
# {'object': 'ZTF18abxbjlt', 'separation': 0.03490921645288209}
# 262 105.79116666666665 1.0578333333333334
# {'object': 'ZTF18aceeloz', 'separation': 0.1767779105341954}
# 263 108.20062499999999 -0.48355555555555557
# {'object': 'ZTF18acnnxav', 'separation': 0.05197904098331289}
# 264 107.86783333333332 -3.4374722222222225
# {'object': 'ZTF18acnnxrd', 'separation': 0.2142930353528496}
# 265 95.65362499999998 -3.9940555555555557
# {'object': 'ZTF18acrunov', 'separation': 0.1636233080941516}
# 266 120.54679166666664 -5.094083333333333
# {'object': 'ZTF18acrxody', 'separation': 0.34225995466970033}
# 267 117.37324999999998 -5.8493055555555555
# {'object': 'ZTF18actrvcq', 'separation': 0.19954646353277194}
# 268 96.96833333333333 -8.726833333333333
# {'object': 'ZTF18acuargf', 'separation': 0.05358978784323291}
# 269 108.80412499999998 -6.710638888888889
# {'object': 'ZTF18acuxvld', 'separation': 0.11955416482375152}
# 270 94.27854166666665 -6.3148888888888886
# {'object': 'ZTF18adatmlr', 'separation': 0.12787739476630777}
# 271 103.03629166666666 6.968166666666667
# {'object': 'ZTF18adbkglv', 'separation': 0.05287995798829358}
# 272 101.81654166666667 -4.999388888888889
# {'object': 'ZTF19aaaimpx', 'separation': 0.06268908214696546}
# 273 115.83404166666665 -7.066083333333333
# {'object': 'ZTF19aaeqmcr', 'separation': 0.05234126864783112}
# 274 97.68483333333332 -6.044861111111111
# {'object': 'ZTF19aampokl', 'separation': 0.11073440900542623}
# 275 120.38524999999998 -7.460666666666667
# {'object': 'ZTF19aanejiy', 'separation': 0.43164998809896643}
# 276 119.87474999999999 -5.39138888888889
# {'object': 'ZTF19acrbzdn', 'separation': 0.047714872447701645}
# 277 112.07745833333333 -4.851444444444444
# {'object': 'ZTF21aaoiaer', 'separation': 0.10413966827438699}
# 278 121.41816666666665 -7.434611111111112
# {'object': 'ZTF22abuzpzz', 'separation': 0.04135085876868576}
# 279 115.53433333333332 -10.825694444444444
# {'object': 'ZTF19aaedrbh', 'separation': 0.10044558957918039}
# 280 279.6672083333333 9.373000000000001
# {'object': 'ZTF18abijuhx', 'separation': 0.2018060850403284}
# 281 265.1897916666666 -29.27627777777778
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 282 268.160375 7.551222222222222
# {'object': 'ZTF18abffzyg', 'separation': 0.4866563705882556}
# 283 262.72320833333333 10.284027777777778
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 284 256.2595416666666 -18.991666666666667
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 285 257.41925 -20.767277777777778
# {'object': 'ZTF18abnopzu', 'separation': 0.1091447346104041}
# 286 260.0736666666666 -16.778555555555556
# {'object': 'ZTF18acavhal', 'separation': 0.03887811832869965}
# 287 260.3885 -18.719305555555554
# {'object': 'ZTF18abeoxti', 'separation': 0.08230094534646676}
# 288 271.07191666666665 4.728944444444444
# {'object': 'ZTF20abbvaow', 'separation': 0.5698247777936819}
# 289 270.4531666666666 7.013722222222222
# {'object': 'ZTF18abzukns', 'separation': 0.19591543693107577}
# 290 253.32737499999996 -16.29838888888889
# {'object': 'ZTF21aamxkha', 'separation': 0.43369146556039834}
# 291 252.6359583333333 -24.44977777777778
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 292 257.217 1.4487777777777777
# {'object': 'ZTF21abawduv', 'separation': 0.017112997733483057}
# 293 248.306875 -12.759722222222223
# {'object': 'ZTF19aamwseh', 'separation': 0.1761086497438131}
# 294 256.68724999999995 0.6793888888888888
# {'object': 'ZTF19aavmtuv', 'separation': 0.4019704146614181}
# 295 252.41912499999998 -17.836
# {'object': 'ZTF18abcsjbm', 'separation': 0.33473867973375765}
# 296 274.5009583333333 7.011666666666667
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 297 256.7298333333333 -15.147333333333332
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 298 248.74741666666662 -20.371972222222222
# {'object': 'ZTF19aaetfzn', 'separation': 0.27784937543598853}
# 299 272.729875 7.6786111111111115
# {'object': 'ZTF19aazxpgk', 'separation': 1.1314551101387105}
# 300 264.88874999999996 -2.1404444444444444
# {'object': 'ZTF19aadoqfu', 'separation': 0.17173613919114}
# 301 259.007125 8.83311111111111
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 302 260.5751666666667 9.096416666666666
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 303 259.904625 4.52325
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 304 264.14016666666663 -1.0134444444444444
# {'object': 'ZTF19aasfdai', 'separation': 0.5334507828625359}
# 305 264.8515833333333 5.013805555555556
# {'object': 'ZTF19aapwppz', 'separation': 0.06038636646241154}
# 306 271.73404166666666 6.176444444444445
# {'object': 'ZTF18abltirl', 'separation': 0.49908625050826244}
# 307 257.26491666666664 -6.521861111111111
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 308 263.46591666666666 1.4123055555555555
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 309 264.56679166666663 5.631722222222223
# {'object': 'ZTF18abmpafl', 'separation': 0.0638832672059517}
# 310 258.50875 -18.9995
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 311 252.98270833333333 -16.35152777777778
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 312 271.08058333333327 13.3605
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 313 263.25066666666663 -9.352444444444444
# {'object': 'ZTF19aaqaqto', 'separation': 0.08523312579317822}
# 314 273.65479166666665 7.515555555555555
# {'object': 'ZTF19abiaxtv', 'separation': 1.318191827568895}
# 315 270.69062499999995 10.029694444444445
# {'object': 'ZTF18abgqccb', 'separation': 0.7958745860869402}
# 316 269.9985 7.451833333333333
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 317 254.60437499999995 -27.45363888888889
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 318 249.6426666666666 -12.608472222222222
# {'object': 'ZTF19aadhatx', 'separation': 0.257448304553803}
# 319 257.0614166666666 -19.099194444444443
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 320 267.864125 3.2585555555555556
# {'object': 'ZTF18abbkjbx', 'separation': 0.05402869597475124}
# 321 249.37425 -20.566305555555555
# {'object': 'ZTF19aadunzw', 'separation': 0.22523319048365428}
# 322 258.8399583333333 6.0078611111111115
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 323 272.11658333333327 0.5916666666666667
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 324 273.2468333333333 4.420111111111112
# {'object': 'ZTF18abucowm', 'separation': 0.06927509053893549}
# 325 280.1067083333333 11.775916666666667
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 326 256.96349999999995 -0.3738888888888889
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 327 276.52204166666667 7.654527777777778
# {'object': 'ZTF18abjkrwj', 'separation': 0.06995360908828425}
# 328 255.83037499999998 -29.87313888888889
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 329 263.16116666666665 0.5363888888888889
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 330 268.444125 -0.02186111111111111
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 331 267.75166666666667 6.423388888888889
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 332 249.7870416666666 -17.597944444444444
# {'object': 'ZTF19aatmoqr', 'separation': 1.2081379180366223}
# 333 266.40425 -11.634833333333333
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 334 272.4602916666666 8.612166666666667
# {'object': 'ZTF18adkyrtm', 'separation': 0.16659852102218975}
# 335 258.06929166666663 -8.820611111111111
# {'object': 'ZTF19abdsvvl', 'separation': 0.34035011509823476}
# 336 271.63820833333335 12.731166666666667
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 337 264.7799166666666 4.24525
# {'object': 'ZTF18abmbdgo', 'separation': 0.1278404519965736}
# 338 273.53299999999996 14.324194444444444
# {'object': 'ZTF19aargcuk', 'separation': 0.14231728052509196}
# 339 262.10195833333324 -17.733972222222224
# {'object': 'ZTF19aaqanmd', 'separation': 0.10499791470961241}
# 340 266.30729166666663 11.706333333333333
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 341 272.76216666666664 10.338333333333335
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 342 255.94299999999998 -10.214277777777777
# {'object': 'ZTF21aadrxrx', 'separation': 0.9699632778862007}
# 343 258.848375 -25.490583333333333
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 344 270.81362499999994 8.418999999999999
# {'object': 'ZTF21abcypjh', 'separation': 0.13460758955684962}
# 345 253.97025 -11.225833333333334
# {'object': 'ZTF19aadhajp', 'separation': 0.18834331781268934}
# 346 265.2146666666667 14.014027777777779
# {'object': 'ZTF21aboyiaf', 'separation': 0.20390173922012866}
# 347 271.48599999999993 8.473083333333333
# {'object': 'ZTF18abrlrma', 'separation': 0.19263313183707703}
# 348 259.1910416666666 -28.79577777777778
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 349 254.5015833333333 -12.781194444444445
# {'object': 'ZTF19aadhchq', 'separation': 0.10849363672689462}
# 350 254.61712499999993 -26.496583333333334
# {'object': 'ZTF21aazexuq', 'separation': 0.16488860383600892}
# 351 258.80249999999995 -29.63711111111111
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 352 262.19087499999995 3.7269444444444444
# {'object': 'ZTF22aarqpev', 'separation': 0.1058938175908518}
# 353 254.9117916666667 -3.973027777777778
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 354 245.81779166666664 -14.212472222222221
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 355 250.19554166666668 -3.4728611111111114
# {'object': 'ZTF19aaafowr', 'separation': 0.03739177688238208}
# 356 270.6095 0.9271111111111111
# {'object': 'ZTF18admkvng', 'separation': 0.1952875786221886}
# 357 257.2710833333333 -17.606055555555557
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 358 256.537875 -23.72186111111111
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 359 271.895 10.591055555555556
# {'object': 'ZTF19acszwgx', 'separation': 0.21307727259516512}
# 360 256.0428749999999 2.348138888888889
# {'object': 'ZTF19aaphirz', 'separation': 0.08693411542025344}
# 361 269.3628333333333 9.200694444444444
# {'object': 'ZTF18abyluab', 'separation': 0.03924090800898984}
# 362 262.4833333333333 0.6986111111111111
# {'object': 'ZTF21acdelny', 'separation': 0.09352995798495006}
# 363 250.7245416666666 -5.285833333333334
# {'object': 'ZTF19aanpgdu', 'separation': 0.12359481616075993}
# 364 261.8292916666666 -2.536833333333333
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 365 255.11004166666666 9.753777777777778
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 366 267.37562499999996 4.300916666666667
# {'object': 'ZTF22abaeves', 'separation': 0.01267271612591058}
# 367 267.14462499999996 7.630277777777779
# {'object': 'ZTF18abcysbo', 'separation': 0.14088289654274208}
# 368 272.0159166666666 4.21425
# {'object': 'ZTF18abmdfws', 'separation': 0.014416392116521405}
# 369 244.71145833333333 -5.419027777777778
# {'object': 'ZTF19aazwqxm', 'separation': 0.0792603651099872}
# 370 246.73666666666665 -0.4301666666666667
# {'object': 'ZTF19abafxil', 'separation': 0.8136645427079817}
# 371 254.5740833333333 2.944055555555556
# {'object': 'ZTF19aawpqrj', 'separation': 0.2947117800864204}
# 372 248.38183333333333 -2.0695555555555556
# {'object': 'ZTF19aayfuhh', 'separation': 0.5523310294891187}
# 373 253.74954166666663 -6.861722222222222
# {'object': 'ZTF19aasewea', 'separation': 0.8748980443371588}
# 374 255.31587499999995 -2.6995833333333334
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 375 253.29741666666663 -10.955833333333333
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 376 254.2036666666666 9.605
# {'object': 'ZTF19aarpptk', 'separation': 0.16437216009851086}
# 377 261.8903333333333 13.086833333333335
# {'object': 'ZTF18abfzzuo', 'separation': 0.25421726446073395}
# 378 250.9766666666666 -13.256972222222222
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 379 248.29741666666666 -1.1920833333333334
# {'object': 'ZTF21acczyyk', 'separation': 0.25823603024251385}
# 380 254.73374999999993 -0.9009444444444444
# {'object': 'ZTF19aageled', 'separation': 1.6815713158814058}
# 381 261.31487500000003 7.546972222222222
# {'object': 'ZTF22aaaupdw', 'separation': 0.17845331591544705}
# 382 258.69354166666665 6.384361111111112
# {'object': 'ZTF18admfrvg', 'separation': 0.7913869944151933}
# 383 254.4243333333333 -4.262194444444445
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 384 249.59887499999994 -9.288777777777778
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 385 254.42074999999997 -5.940361111111112
# {'object': 'ZTF19aacmasi', 'separation': 0.02714516883960072}
# 386 260.45349999999996 -5.286888888888889
# {'object': 'ZTF19aatmmgy', 'separation': 0.45563761416795673}
# 387 259.1667083333333 11.47938888888889
# {'object': 'ZTF19aaxsinb', 'separation': 0.15560356722478005}
# 388 256.95954166666667 -5.555916666666667
# {'object': 'ZTF19aaselhh', 'separation': 0.7902043303314612}
# 389 254.43924999999996 -4.734861111111111
# {'object': 'ZTF19aacksnj', 'separation': 0.03649680122576089}
# 390 255.0214583333333 -11.071388888888889
# {'object': 'ZTF19aadotsj', 'separation': 0.15584622400724274}
# 391 253.3829583333333 -5.165638888888889
# {'object': 'ZTF19aacmato', 'separation': 1.0767598262188942}
# 392 263.85412499999995 -4.4005
# {'object': 'ZTF19aalbzof', 'separation': 0.4388989160157502}
# 393 255.62779166666667 7.939694444444445
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 394 265.6174583333333 -28.243361111111113
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 395 265.9074166666666 -26.27883333333333
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 396 265.4167916666666 -27.29388888888889
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 397 264.7789583333333 -28.56475
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 398 264.20070833333335 -29.61088888888889
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 399 269.09324999999995 2.9678055555555556
# {'object': 'ZTF18abmbdyk', 'separation': 0.15887789341451306}
# 400 271.71358333333336 6.844138888888889
# {'object': 'ZTF19aaymxhe', 'separation': 0.23078510813623512}
# 401 270.38137499999993 2.40175
# {'object': 'ZTF18abeepxu', 'separation': 0.05944030743673969}
# 402 261.583875 6.271916666666667
# {'object': 'ZTF18adlzzzq', 'separation': 0.12956537603307644}
# 403 256.95641666666666 -20.44088888888889
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 404 257.4425416666666 -14.798777777777778
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 405 262.8666666666666 -18.136166666666668
# {'object': 'ZTF19abaqenr', 'separation': 0.19968843897836244}
# 406 274.762 9.928527777777777
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 407 260.3455833333333 -1.057027777777778
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 408 254.26254166666666 4.539916666666667
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 409 250.02766666666665 -16.500777777777778
# {'object': 'ZTF19aavybbf', 'separation': 0.0531472551824958}
# 410 251.78116666666668 -23.05963888888889
# {'object': 'ZTF19abagagw', 'separation': 0.19184687087467595}
# 411 264.1242083333333 -27.692083333333333
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 412 253.89895833333333 -25.483166666666666
# {'object': 'ZTF20aaxctyi', 'separation': 0.27908762243039403}
# 413 266.53212499999995 5.494583333333334
# {'object': 'ZTF19aadypwc', 'separation': 0.10584920254038156}
# 414 247.71983333333333 -21.77472222222222
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 415 262.0594583333333 -22.621000000000002
# {'object': 'ZTF19aawqhuk', 'separation': 0.016263883756242367}
# 416 261.79404166666666 5.832722222222222
# {'object': 'ZTF20aauonhf', 'separation': 0.06306469414877369}
# 417 264.6451666666666 1.420638888888889
# {'object': 'ZTF19abcpiag', 'separation': 0.21648602161277194}
# 418 269.990375 2.3623611111111114
# {'object': 'ZTF18abpbojh', 'separation': 0.276520189568209}
# 419 255.704 -17.075416666666666
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 420 258.72808333333336 -16.746277777777777
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 421 267.081375 1.9048333333333332
# {'object': 'ZTF18abgmgdi', 'separation': 0.7077926679825699}
# 422 273.7065833333333 0.1857222222222222
# {'object': 'ZTF20abqweoz', 'separation': 0.08649835269912905}
# 423 267.614 -2.10725
# {'object': 'ZTF19aayfibi', 'separation': 0.10184657201794019}
# 424 252.75529166666666 10.553083333333333
# {'object': 'ZTF18adkqvdi', 'separation': 0.09916778446956678}
# 425 262.9735833333333 5.536666666666666
# {'object': 'ZTF19aawpsau', 'separation': 0.11659384991282254}
# 426 273.9829166666666 2.7287777777777777
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 427 262.74454166666663 12.739138888888888
# {'object': 'ZTF21aaigevp', 'separation': 0.4892409959831792}
# 428 255.59924999999998 1.2377500000000001
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 429 262.167 -5.279166666666667
# {'object': 'ZTF20abcuzti', 'separation': 0.14507842734385934}
# 430 257.7817083333333 -28.033166666666666
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 431 246.01958333333326 -5.316194444444444
# {'object': 'ZTF20abdrhks', 'separation': 0.2057925342436975}
# 432 261.0186666666666 -23.31163888888889
# {'object': 'ZTF19abuerkg', 'separation': 0.3695978127127678}
# 433 268.7775 0.06686111111111111
# {'object': 'ZTF20acksipn', 'separation': 0.08137748335039655}
# 434 272.58762499999995 0.6566666666666667
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 435 261.86770833333327 -21.67886111111111
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 436 266.1537083333333 8.777222222222223
# {'object': 'ZTF18ablxcht', 'separation': 0.14478510887103885}
# ...
# {'object': 'ZTF18aakzoph', 'separation': 0.05124690524613072}
# 3843 275.4255 23.755333333333333
# {'object': 'ZTF18abmmjki', 'separation': 0.12802505924364038}
# 3844 244.78791666666666 13.862666666666666
# {'object': 'ZTF18abavrhi', 'separation': 0.15651159030235745}
# 3845 164.7350833333333 -29.244666666666667
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 3846 182.2055833333333 -30.69338888888889
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 3847 342.73070833333327 54.449777777777776
# {'object': 'ZTF18aazwdps', 'separation': 0.020387857251673143}
# 3848 340.44133333333326 56.375
# {'object': 'ZTF17aaaedrn', 'separation': 0.11561747110526471}
# 3849 336.62404166666664 39.21911111111111
# {'object': 'ZTF18abmoeer', 'separation': 0.06380928540092848}
# 3850 333.24158333333327 49.11233333333333
# {'object': 'ZTF18abgpmcd', 'separation': 0.11824318070915876}
# 3851 340.44154166666664 50.562444444444445
# {'object': 'ZTF18adlyqgq', 'separation': 0.04620611615091964}
# 3852 158.66666666666666 28.296944444444446
# {'object': 'ZTF17aabtrxp', 'separation': 0.7975050227426665}
# 3853 112.17820833333333 53.627611111111115
# {'object': 'ZTF18adonnra', 'separation': 0.1640269609213435}
# 3854 279.080875 43.2505
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 3855 284.033625 45.627805555555554
# {'object': 'ZTF18adjddex', 'separation': 0.10147486796033024}
# 3856 283.5977083333333 32.634972222222224
# {'object': 'ZTF18adjgvev', 'separation': 0.09641459807207321}
# 3857 97.47458333333333 -3.5856944444444445
# {'object': 'ZTF18acewnmo', 'separation': 0.36153514577619655}
# 3858 110.26179166666665 -5.989111111111111
# {'object': 'ZTF18achznqd', 'separation': 0.06775843716852098}
# 3859 97.36720833333332 2.131388888888889
# {'object': 'ZTF18abwlbjr', 'separation': 0.06520058656518987}
# 3860 107.01579166666666 -9.1625
# {'object': 'ZTF18acrvrbl', 'separation': 0.18525841532855264}
# 3861 268.9065833333333 9.100027777777777
# {'object': 'ZTF18abjedws', 'separation': 0.13963686581153087}
# 3862 280.09675 9.057055555555555
# {'object': 'ZTF18absmxfm', 'separation': 0.16176521170437555}
# 3863 93.70308333333332 9.574388888888889
# {'object': 'ZTF20aarfjgo', 'separation': 0.08902791988790466}
# 3864 83.14337499999999 -7.5737499999999995
# {'object': 'ZTF17aaakhci', 'separation': 0.0923099497776348}
# 3865 84.38745833333333 6.693194444444445
# {'object': 'ZTF18abwkvae', 'separation': 0.18881921763888176}
# 3866 79.16425 -10.53725
# {'object': 'ZTF19aamnudr', 'separation': 0.14471984625385287}
# 3867 342.05091666666664 13.32025
# {'object': 'ZTF18admqaga', 'separation': 0.1829751460660363}
# 3868 33.46233333333333 58.381194444444446
# {'object': 'ZTF17aaarlwe', 'separation': 0.13946762945579197}
# 3869 46.715291666666666 53.72661111111111
# {'object': 'ZTF19aakwlhx', 'separation': 0.3206561046779013}
# 3870 31.992874999999998 48.575388888888895
# {'object': 'ZTF19acicjxs', 'separation': 0.8571060126416304}
# 3871 29.62995833333333 54.184194444444444
# {'object': 'ZTF18abmewgx', 'separation': 0.02783249707536029}
# 3872 43.044 52.490500000000004
# {'object': 'ZTF18abjvcdq', 'separation': 0.23078510813623512}
# 3873 23.813125 54.318694444444446
# {'object': 'ZTF17aabpiiv', 'separation': 0.20925223972752363}
# 3874 118.56487499999999 -24.326777777777778
# {'object': 'ZTF19aaakuza', 'separation': 0.38018148377737115}
# 3875 113.94158333333331 -18.16188888888889
# {'object': 'ZTF17aabwlhf', 'separation': 0.22449799041840074}
# 3876 128.287875 -17.531416666666665
# {'object': 'ZTF19aamofdr', 'separation': 0.11659384991282254}
# 3877 135.34179166666667 -27.826472222222222
# {'object': 'ZTF21aawlntc', 'separation': 0.4961817471796507}
# 3878 294.4522083333333 16.844305555555554
# {'object': 'ZTF18aaxujwc', 'separation': 0.08473289445490957}
# 3879 297.66749999999996 18.422027777777778
# {'object': 'ZTF18abdkuny', 'separation': 0.06677536110049964}
# 3880 288.6192083333333 -12.959027777777777
# {'object': 'ZTF18abctcnk', 'separation': 0.18502880348820722}
# 3881 275.9456666666666 -16.500944444444446
# {'object': 'ZTF18abstqob', 'separation': 0.06022972192757415}
# 3882 284.4869999999999 -11.1915
# {'object': 'ZTF18adkprfh', 'separation': 0.03912035193911381}
# 3883 275.4531666666667 5.635694444444444
# {'object': 'ZTF18abfjdrn', 'separation': 0.10110179732985679}
# 3884 264.00775 -12.472805555555556
# {'object': 'ZTF19aafnpkc', 'separation': 0.1906118453504678}
# 3885 81.56629166666666 19.152749999999997
# {'object': 'ZTF17aadepqh', 'separation': 0.035044262281920716}
# 3886 89.45154166666666 25.030388888888886
# {'object': 'ZTF17aaczptk', 'separation': 0.1056258446157252}
# 3887 24.154166666666665 32.01111111111111
# {'object': 'ZTF18admdwxv', 'separation': 0.22426642976841554}
# 3888 203.91983333333332 5.122972222222222
# {'object': 'ZTF18acwywfz', 'separation': 0.3204645494205509}
# 3889 314.4377916666666 25.50713888888889
# {'object': 'ZTF18abtoupn', 'separation': 0.11565831811982483}
# 3890 314.7352916666666 23.88525
# {'object': 'ZTF18absnrin', 'separation': 0.17392255617564067}
# 3891 314.53749999999997 25.592416666666665
# {'object': 'ZTF18absnrzk', 'separation': 0.1512628627038502}
# 3892 290.40708333333333 23.007083333333334
# {'object': 'ZTF18aasnqbc', 'separation': 0.09107359999051536}
# 3893 301.3930416666666 23.121805555555557
# {'object': 'ZTF18abnbpcl', 'separation': 0.078361352683707}
# 3894 290.7827083333333 24.586138888888886
# {'object': 'ZTF18aauemog', 'separation': 0.18302676833989906}
# 3895 79.55970833333332 29.686944444444446
# {'object': 'ZTF19aakvpme', 'separation': 0.223992458554263}
# 3896 294.66712499999994 30.50788888888889
# {'object': 'ZTF18abdkhjm', 'separation': 0.20220359465971963}
# 3897 294.87249999999995 51.612944444444445
# {'object': 'ZTF18abcnxvd', 'separation': 0.16907512133194016}
# 3898 296.19391666666667 31.195888888888888
# {'object': 'ZTF18abdkwtw', 'separation': 0.04368385236028549}
# 3899 283.928375 22.230777777777774
# {'object': 'ZTF18abeymdp', 'separation': 0.04681545389005153}
# 3900 160.21349999999998 15.192694444444445
# {'object': 'ZTF18aaaqvfx', 'separation': 0.2488085669692533}
# 3901 297.11562499999997 -13.292694444444445
# {'object': 'ZTF18abuduzu', 'separation': 0.1205770226472754}
# 3902 126.30491666666664 73.1108611111111
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 3903 15.287124999999998 43.3905
# {'object': 'ZTF19acyycev', 'separation': 0.11655333076306275}
# 3904 5.4416666666666655 40.069972222222226
# {'object': 'ZTF17aaaenhs', 'separation': 0.13277033945408004}
# 3905 345.9765 52.33741666666667
# {'object': 'ZTF18aazwdho', 'separation': 0.2752703937497765}
# 3906 347.04624999999993 52.85988888888889
# {'object': 'ZTF18abcpdil', 'separation': 0.09912014200490521}
# 3907 294.61595833333325 6.045861111111111
# {'object': 'ZTF18abjtkzh', 'separation': 0.24127153813724178}
# 3908 303.26670833333327 15.59613888888889
# {'object': 'ZTF20abnrdev', 'separation': 0.167785094925133}
# 3909 293.32491666666664 13.952361111111111
# {'object': 'ZTF18abacgoo', 'separation': 0.2661092891500972}
# 3910 289.4191666666667 2.072138888888889
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 3911 295.5815416666666 -8.503666666666666
# {'object': 'ZTF18abvbgny', 'separation': 0.3296339446183778}
# 3912 295.4909583333333 -6.100972222222222
# {'object': 'ZTF18acaphgx', 'separation': 0.06154849419344735}
# 3913 98.17695833333332 30.93513888888889
# {'object': 'ZTF17aacptlo', 'separation': 0.09592343543733538}
# 3914 95.94633333333333 38.17538888888889
# {'object': 'ZTF18aaaarks', 'separation': 0.07260430046265569}
# 3915 85.38916666666667 38.936249999999994
# {'object': 'ZTF17aaahels', 'separation': 0.03557932013127233}
# 3916 78.22516666666665 31.04425
# {'object': 'ZTF17aaacqrw', 'separation': 0.47687146208942666}
# 3917 88.04741666666666 29.511805555555554
# {'object': 'ZTF17aadekbz', 'separation': 0.32619123569315916}
# 3918 108.519375 70.07177777777777
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 3919 82.81258333333332 57.15633333333333
# {'object': 'ZTF18acvvqao', 'separation': 0.2676490917097788}
# 3920 101.32174999999998 -16.85963888888889
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 3921 111.50708333333333 4.144111111111112
# {'object': 'ZTF17aaapjig', 'separation': 0.08332760805675334}
# 3922 4.562166666666666 66.30380555555556
# {'object': 'ZTF18actxcav', 'separation': 0.19016527266662764}
# 3923 349.1148749999999 59.805055555555555
# {'object': 'ZTF17aabungh', 'separation': 0.10831934964773314}
# 3924 0.14670833333333333 60.90122222222222
# {'object': 'ZTF17aaaeecv', 'separation': 0.1937577922452027}
# 3925 46.307624999999994 62.83947222222223
# {'object': 'ZTF18abyciqm', 'separation': 0.17386823084051073}
# 3926 41.856958333333324 72.87788888888888
# {'object': 'ZTF18acsywun', 'separation': 0.06613566753525078}
# 3927 347.60862499999996 66.55877777777778
# {'object': 'ZTF17aabumpu', 'separation': 0.1323784229318471}
# 3928 4.828791666666666 73.41402777777779
# {'object': 'ZTF18acpsudi', 'separation': 0.21826782962034424}
# 3929 342.8400833333333 66.56302777777778
# {'object': 'ZTF17aaajxht', 'separation': 0.33651195569647185}
# 3930 310.2727083333333 70.64025000000001
# {'object': 'ZTF19achwafv', 'separation': 0.0965614596927214}
# 3931 330.0698749999999 69.81730555555555
# {'object': 'ZTF18abvyppa', 'separation': 0.09128082119126618}
# 3932 307.7688749999999 47.36675
# {'object': 'ZTF17aabukie', 'separation': 0.08704271523201526}
# 3933 309.6295416666666 30.817194444444443
# {'object': 'ZTF18aaxpmoi', 'separation': 0.1326991679992451}
# 3934 316.94262499999996 43.56375
# {'object': 'ZTF18aaxysiv', 'separation': 0.19351385686931138}
# 3935 313.14975 30.621222222222222
# {'object': 'ZTF18ablvwig', 'separation': 0.1503859691544635}
# 3936 292.6716666666666 40.87361111111111
# {'object': 'ZTF18admodkx', 'separation': 0.0525214456648347}
# 3937 297.01533333333333 35.677638888888886
# {'object': 'ZTF18aaxumau', 'separation': 0.0750357755727688}
# 3938 299.003625 45.387861111111114
# {'object': 'ZTF18abueavt', 'separation': 0.010647211200991907}
# 3939 313.5415833333333 48.03461111111111
# {'object': 'ZTF18aayekxk', 'separation': 0.06913858776485064}
# 3940 292.8714583333333 45.98502777777778
# {'object': 'ZTF18abcorld', 'separation': 1.5984888581506846}
# 3941 302.5053333333333 33.425638888888884
# {'object': 'ZTF18aaxplvd', 'separation': 0.3292181292157301}
# 3942 316.3987083333333 45.546416666666666
# {'object': 'ZTF18aaztied', 'separation': 0.10105506666069525}
# 3943 307.6594583333333 50.90797222222222
# {'object': 'ZTF18aaztiva', 'separation': 0.1268389300545441}
# 3944 313.479875 46.91083333333333
# {'object': 'ZTF18aazvzgu', 'separation': 0.23863375095343634}
# 3945 296.7084583333333 34.921527777777776
# {'object': 'ZTF18adkoarp', 'separation': 0.14698679766166173}
# 3946 288.769125 43.80836111111111
# {'object': 'ZTF18abddipv', 'separation': 0.036237034214363445}
# 3947 318.4196666666666 39.91411111111111
# {'object': 'ZTF18abvbsbr', 'separation': 0.1519483004018839}
# 3948 309.1184166666667 20.324055555555557
# {'object': 'ZTF18adqqrtm', 'separation': 0.061240749794244945}
# 3949 294.037625 61.022083333333335
# {'object': 'ZTF19aamqtwx', 'separation': 0.07402173199357664}
# 3950 66.17129166666668 -20.119944444444446
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 3951 96.62774999999999 17.393
# {'object': 'ZTF17aacmmsq', 'separation': 0.09122906001829698}
# 3952 99.12066666666665 14.543694444444444
# {'object': 'ZTF18aaaanla', 'separation': 0.13280591087855056}
# 3953 251.04170833333333 25.250527777777776
# {'object': 'ZTF18adqwodi', 'separation': 0.1190791132833387}
# 3954 271.90774999999996 37.53927777777778
# {'object': 'ZTF18aamkhqj', 'separation': 0.1217465652754849}
# 3955 260.78454166666666 39.41536111111111
# {'object': 'ZTF18aalejee', 'separation': 0.1844151075903504}
# 3956 282.2149583333333 14.449833333333334
# {'object': 'ZTF18aawvbtq', 'separation': 0.12500085930271648}
# 3957 255.25412499999993 15.670083333333332
# {'object': 'ZTF18abeajkh', 'separation': 0.03899942320484046}
# 3958 334.7944583333333 35.76375
# {'object': 'ZTF18abxrjhk', 'separation': 0.1857930727615375}
# 3959 333.1928333333333 52.532777777777774
# {'object': 'ZTF18aaznghv', 'separation': 0.09897707701525106}
# 3960 152.50437499999998 16.044944444444447
# {'object': 'ZTF17aabtokj', 'separation': 0.43074077750644585}
# 3961 283.94791666666663 40.38344444444444
# {'object': 'ZTF18abgitdz', 'separation': 0.2243085494851487}
# 3962 107.89058333333332 0.8685277777777778
# {'object': 'ZTF17aaanqyh', 'separation': 0.19869248045499924}
# 3963 272.0669583333333 5.675111111111112
# {'object': 'ZTF18abimokb', 'separation': 0.32565501070676695}
# 3964 278.0525416666667 6.3694444444444445
# {'object': 'ZTF18aaxytlc', 'separation': 0.19730884447643823}
# 3965 255.60141666666667 -26.74775
# {'object': 'ZTF18abndzqf', 'separation': 0.026439978994146733}
# 3966 87.67320833333332 9.305444444444445
# {'object': 'ZTF18aabgcoy', 'separation': 0.06077621148263561}
# 3967 81.94841666666666 -9.46361111111111
# {'object': 'ZTF17aaakhmk', 'separation': 0.03517878969512636}
# 3968 94.08174999999999 7.2756388888888885
# {'object': 'ZTF18abzpfxo', 'separation': 0.41213556146885727}
# 3969 85.34541666666667 9.514388888888888
# {'object': 'ZTF18acnaphb', 'separation': 0.10035149532941397}
# 3970 88.92804166666666 7.567194444444445
# {'object': 'ZTF18aaaamoh', 'separation': 0.18300095902321714}
# 3971 355.09874999999994 12.628250000000001
# {'object': 'ZTF18abskynw', 'separation': 0.05394120005341208}
# 3972 325.9774999999999 12.749388888888888
# {'object': 'ZTF18abecurw', 'separation': 0.1152901739982107}
# 3973 26.979249999999993 51.42611111111111
# {'object': 'ZTF18abflsdk', 'separation': 0.5100484636207558}
# 3974 116.63016666666665 -12.952499999999999
# {'object': 'ZTF19aadqbef', 'separation': 0.29793172418985947}
# 3975 113.47574999999998 -15.76063888888889
# {'object': 'ZTF17aabwliz', 'separation': 0.14595484599654163}
# 3976 114.57945833333332 -20.76563888888889
# {'object': 'ZTF18adaihdy', 'separation': 0.06447206552566812}
# 3977 120.25616666666666 -13.794333333333332
# {'object': 'ZTF19aalivui', 'separation': 0.1655746897557274}
# 3978 287.587125 20.305722222222222
# {'object': 'ZTF18aavefrt', 'separation': 0.16865554473678626}
# 3979 296.36629166666665 19.148722222222222
# {'object': 'ZTF18aawboie', 'separation': 0.28055620384327584}
# 3980 287.33758333333327 20.66472222222222
# {'object': 'ZTF18aawuhuo', 'separation': 0.10792617466740385}
# 3981 284.10516666666666 -19.273027777777777
# {'object': 'ZTF18abineju', 'separation': 0.16605895224802938}
# 3982 272.8535833333333 -14.926138888888888
# {'object': 'ZTF18adnhxuq', 'separation': 0.7277065737667558}
# 3983 65.56345833333333 29.799583333333334
# {'object': 'ZTF18aabffpk', 'separation': 0.08207105398861769}
# 3984 302.2545416666666 24.910833333333333
# {'object': 'ZTF18adkcywy', 'separation': 0.04589841384146782}
# 3985 295.41637499999996 21.766222222222222
# {'object': 'ZTF18aavyouk', 'separation': 0.8703294679819504}
# 3986 306.29741666666666 25.09311111111111
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 3987 291.80379166666665 26.959166666666665
# {'object': 'ZTF18abdfrfw', 'separation': 0.1520104596601198}
# 3988 303.75741666666664 26.66022222222222
# {'object': 'ZTF18abnudna', 'separation': 0.18126336362573475}
# 3989 106.02008333333332 -3.847388888888889
# {'object': 'ZTF19acymjkg', 'separation': 0.2753390226198904}
# 3990 282.6529166666666 -21.39136111111111
# {'object': 'ZTF19adjkdiw', 'separation': 0.16600205351336333}
# 3991 269.41237499999994 -29.768
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 3992 269.38725 -30.71944444444444
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 3993 296.90883333333335 27.313277777777778
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.
# 3994 272.46287499999994 -19.73108333333333
# Request limit exceeded. Either wait an hour, or see API documentation to increase your limits.

# %%
# Load the two csv files.
pt1 = pd.read_csv('../processed_data/AAVSOCVsZTFxmatch_21032023_0_4499.csv')
pt2 = pd.read_csv('../processed_data/AAVSOCVsZTFxmatch_21032023_4500_last.csv')

# Concatenate the two dataframes.
AAVSO_CVS_3 = pd.concat([pt1, pt2], ignore_index=True)

# Refine AAVSO VSX CVs to those with ZTF counterparts; reset index.
AAVSO_CVS_3 = AAVSO_CVS_3[AAVSO_CVS_3['Xmatch_obj'].notna()].reset_index(drop=True)
AAVSO_CVS_3
# Out:
#                           Name         AUID                   Coords Const  \
# 0                  ASASSN-19dp  000-BMZ-678  02 22 59.02 +43 39 13.1   And
# 1                    BMAM-V789  000-BNS-414  02 33 58.15 +41 37 26.3   And
# 2     CSS 091026:002637+242916           --  00 26 37.06 +24 29 15.7   And
# 3                   MGAB-V3453           --  00 35 53.37 +43 33 41.5   And
# 4                   MGAB-V3769           --  23 34 33.16 +40 25 50.2   And
# ...                        ...          ...                      ...   ...
# 5680                    FY Vul  000-BCH-627  19 41 39.93 +21 45 58.4   Vul
# 5681                 MGAB-V796           --  19 27 12.91 +26 57 33.0   Vul
# 5682              ZTF18abnudna           --  20 15 01.78 +26 39 36.8   Vul
# 5683                 V0838 Mon  000-BBM-355  07 04 04.82 -03 50 50.6   Mon
# 5684                 V4332 Sgr  000-BCD-402  18 50 36.70 -21 23 28.9   Sgr
#
#          Type     Period             Mag          ra        dec    Xmatch_obj  \
# 0          AM         --   16.5 - 20.9 g   35.745917  43.653639  ZTF18abryuah
# 1          AM  0.0714789   18.5 - 21.7 r   38.492292  41.623972  ZTF18abtrvgp
# 2          AM         --    17.1 - 21 CV    6.654417  24.487694  ZTF17aaaehby
# 3          AM         --   18.2 - 20.9 r    8.972375  43.561528  ZTF18abgjgiq
# 4          AM         --   18.8 - 20.8 r  353.638167  40.430611  ZTF18abumlux
# ...       ...        ...             ...         ...        ...           ...
# 5680   UGZ/IW         --  13.4 - 15.9: V  295.416375  21.766222  ZTF18aavyouk
# 5681   UGZ/IW         --   18.5 - 21.1 g  291.803792  26.959167  ZTF18abdfrfw
# 5682   UGZ/IW         --   18.6 - 20.4 r  303.757417  26.660222  ZTF18abnudna
# 5683  V838MON         --   6.7 - 16.05 V  106.020083  -3.847389  ZTF19acymjkg
# 5684  V838MON         --    8.0 - 19.8 V  282.652917 -21.391361  ZTF19adjkdiw
#
#       separation
# 0       0.378550
# 1       0.134256
# 2       0.308769
# 3       0.522473
# 4       0.031042
# ...          ...
# 5680    0.870329
# 5681    0.152010
# 5682    0.181263
# 5683    0.275339
# 5684    0.166002
#
# [5685 rows x 11 columns]

# %% [markdown]
# ### 3.4 Inspect resultant dataframe and remove duplicates
#
# Remove duplicated cross matches;
# Save dataframe to csv

# %%
# Display duplicates - those AAVSO_VSX targets with the same ZTF counterparts.
AAVSO_CVS_3[AAVSO_CVS_3.Xmatch_obj.duplicated(keep=False)]
# Out:
#               Name         AUID                   Coords Const Type Period  \
# 1916  ZTF18abacprn           --  21 36 22.64 +63 09 48.5   Cep   UG     --
# 1921  ZTF18abbogxd  000-BNZ-280  21 36 22.64 +63 09 48.5   Cep   UG     --
# 3142        KLK-51  000-BNZ-706  19 18 52.88 +26 17 35.7   Lyr   UG     --
# 3184  ZTF18aasnnsv           --  19 18 52.88 +26 17 35.7   Lyr   UG     --
#
#                 Mag          ra        dec    Xmatch_obj  separation
# 1916  16.2 - 21.5 g  324.094333  63.163472  ZTF18abacprn    0.294503
# 1921  16.5 - 20.6 g  324.094333  63.163472  ZTF18abacprn    0.294503
# 3142  16.8 - 21.2 r  289.720333  26.293250  ZTF18aasnnsv    0.059757
# 3184   16.9 - 22: g  289.720333  26.293250  ZTF18aasnnsv    0.059757

# %%
# Drop selected duplicates and a particular object that has no light curve data (a pain in the arse).
AAVSO_CVS_4 = AAVSO_CVS_3.drop([1916,3142], axis=0).reset_index(drop=True)
AAVSO_CVS_4
# Out:
#                           Name         AUID                   Coords Const  \
# 0                  ASASSN-19dp  000-BMZ-678  02 22 59.02 +43 39 13.1   And
# 1                    BMAM-V789  000-BNS-414  02 33 58.15 +41 37 26.3   And
# 2     CSS 091026:002637+242916           --  00 26 37.06 +24 29 15.7   And
# 3                   MGAB-V3453           --  00 35 53.37 +43 33 41.5   And
# 4                   MGAB-V3769           --  23 34 33.16 +40 25 50.2   And
# ...                        ...          ...                      ...   ...
# 5678                    FY Vul  000-BCH-627  19 41 39.93 +21 45 58.4   Vul
# 5679                 MGAB-V796           --  19 27 12.91 +26 57 33.0   Vul
# 5680              ZTF18abnudna           --  20 15 01.78 +26 39 36.8   Vul
# 5681                 V0838 Mon  000-BBM-355  07 04 04.82 -03 50 50.6   Mon
# 5682                 V4332 Sgr  000-BCD-402  18 50 36.70 -21 23 28.9   Sgr
#
#          Type     Period             Mag          ra        dec    Xmatch_obj  \
# 0          AM         --   16.5 - 20.9 g   35.745917  43.653639  ZTF18abryuah
# 1          AM  0.0714789   18.5 - 21.7 r   38.492292  41.623972  ZTF18abtrvgp
# 2          AM         --    17.1 - 21 CV    6.654417  24.487694  ZTF17aaaehby
# 3          AM         --   18.2 - 20.9 r    8.972375  43.561528  ZTF18abgjgiq
# 4          AM         --   18.8 - 20.8 r  353.638167  40.430611  ZTF18abumlux
# ...       ...        ...             ...         ...        ...           ...
# 5678   UGZ/IW         --  13.4 - 15.9: V  295.416375  21.766222  ZTF18aavyouk
# 5679   UGZ/IW         --   18.5 - 21.1 g  291.803792  26.959167  ZTF18abdfrfw
# 5680   UGZ/IW         --   18.6 - 20.4 r  303.757417  26.660222  ZTF18abnudna
# 5681  V838MON         --   6.7 - 16.05 V  106.020083  -3.847389  ZTF19acymjkg
# 5682  V838MON         --    8.0 - 19.8 V  282.652917 -21.391361  ZTF19adjkdiw
#
#       separation
# 0       0.378550
# 1       0.134256
# 2       0.308769
# 3       0.522473
# 4       0.031042
# ...          ...
# 5678    0.870329
# 5679    0.152010
# 5680    0.181263
# 5681    0.275339
# 5682    0.166002
#
# [5683 rows x 11 columns]

# %%
# Save dataframe to csv.
AAVSO_CVS_4.to_csv('../processed_data/AAVSOCVsZTFxmatch_21032023.csv', index=False)

# %% [markdown]
# ### Add sources from bright transient survey.

# %%
# Load the csv file.
df_ZTF_CVs = pd.read_csv('../processed_data/AAVSOCVsZTFxmatch_21032023.csv')

# Load the csv file for BTS.
bts_cvs = pd.read_csv('../processed_data/BTS_novae.csv')
bts_cvs

# Sources in BTS not present in the df_ZTF_CVs dataframe.
new_novae = bts_cvs[~bts_cvs['ZTFID'].isin(df_ZTF_CVs['Xmatch_obj'])].copy()

# Combine the RA and Dec columns into a single column like in the df_ZTF_CVs dataframe.
new_novae['RA_Dec'] = new_novae['RA'].astype(str) + ' ' + new_novae['Dec'].astype(str)

# Convert the RA_Dec column into a ra and dec in degrees.
new_novae['ra'] = new_novae['RA_Dec'].apply(lambda x: SkyCoord(x, unit=(u.hourangle, u.deg)).ra.deg)
new_novae['dec'] = new_novae['RA_Dec'].apply(lambda x: SkyCoord(x, unit=(u.hourangle, u.deg)).dec.deg)

# Rename columns.
new_novae.rename(columns={'ZTFID':'Xmatch_obj', 'IAUID':'AUID', 'RA_Dec':'Coords'}, inplace=True)
new_novae['Type'] = 'N'

# Add new_novae dataframe to df_ZTF_CVs.
df_ZTF_CVs = pd.concat([df_ZTF_CVs, new_novae[['Xmatch_obj','AUID','ra','dec', 'Coords','Type']]], ignore_index=True)

# Save dataframe to csv.
df_ZTF_CVs.to_csv('../processed_data/AAVSOCVsZTFxmatch_21032023_BTS.csv', index=False)

pd.options.display.max_rows = 10
df_ZTF_CVs
# Out:
#                           Name         AUID                   Coords Const  \
# 0                  ASASSN-19dp  000-BMZ-678  02 22 59.02 +43 39 13.1   And
# 1                    BMAM-V789  000-BNS-414  02 33 58.15 +41 37 26.3   And
# 2     CSS 091026:002637+242916           --  00 26 37.06 +24 29 15.7   And
# 3                   MGAB-V3453           --  00 35 53.37 +43 33 41.5   And
# 4                   MGAB-V3769           --  23 34 33.16 +40 25 50.2   And
# ...                        ...          ...                      ...   ...
# 5706                       NaN    AT2022qzf  00:42:09.42 +41:15:31.2   NaN
# 5707                       NaN    AT2022ubf  00:42:30.04 +41:56:12.5   NaN
# 5708                       NaN    AT2022yax  00:43:45.84 +41:15:58.6   NaN
# 5709                       NaN    AT2022zzj  00:41:25.72 +40:44:23.3   NaN
# 5710                       NaN    AT2023bji  05:43:48.25 +62:58:41.6   NaN
#
#      Type     Period            Mag          ra        dec    Xmatch_obj  \
# 0      AM         --  16.5 - 20.9 g   35.745917  43.653639  ZTF18abryuah
# 1      AM  0.0714789  18.5 - 21.7 r   38.492292  41.623972  ZTF18abtrvgp
# 2      AM         --   17.1 - 21 CV    6.654417  24.487694  ZTF17aaaehby
# 3      AM         --  18.2 - 20.9 r    8.972375  43.561528  ZTF18abgjgiq
# 4      AM         --  18.8 - 20.8 r  353.638167  40.430611  ZTF18abumlux
# ...   ...        ...            ...         ...        ...           ...
# 5706    N        NaN            NaN   10.539250  41.258667  ZTF22aazmooy
# 5707    N        NaN            NaN   10.625167  41.936806  ZTF22abfxmpc
# 5708    N        NaN            NaN   10.941000  41.266278  ZTF22abnrgno
# 5709    N        NaN            NaN   10.357167  40.739806  ZTF22abtltcw
# 5710    N        NaN            NaN   85.951042  62.978222  ZTF23aabvpgb
#
#       separation
# 0       0.378550
# 1       0.134256
# 2       0.308769
# 3       0.522473
# 4       0.031042
# ...          ...
# 5706         NaN
# 5707         NaN
# 5708         NaN
# 5709         NaN
# 5710         NaN
#
# [5711 rows x 11 columns]

# %% [markdown]
# ## 4.0 Organise subtypes
#
# ### 4.1 Display CV types
#
# See https://www.aavso.org/vsx/index.php?view=about.vartypes for the variable types.

# %%
# Load the csv file.
df_ZTF_CVs = pd.read_csv('../processed_data/AAVSOCVsZTFxmatch_21032023_BTS.csv')
pd.options.display.max_rows=None

# Display the different types.
df_ZTF_CVs.Type.value_counts()
# Out:
# UG                    3765
# UGSU                   537
# CV                     288
# NL/VY                  125
# UGSS                   117
# AM                     100
# UGZ                     91
# UGZ/IW                  81
# NL+E                    72
# UG+E                    71
# UGWZ                    60
# NL                      51
# N                       39
# UGSU+E                  37
# DQ                      35
# UGER                    29
# AM+E                    25
# CV+E                    21
# UGSU/IBWD               19
# UG/IBWD                 16
# UGSS+E                  14
# UG/DQ                   13
# NB                      11
# NL/VY+E                 10
# UGZ+E                    7
# NR                       6
# UGWZ+ZZ/GWLIB            4
# UGWZ+E                   4
# UGSU/IBWD+E              4
# NA+UG                    4
# DQ+E                     4
# IBWD+E                   3
# NR+E                     3
# NC                       3
# N+E                      3
# NA+E                     3
# UG/IBWD+E                2
# V838MON                  2
# IBWD                     2
# NA/DQ+UG                 2
# EA+NL                    2
# NA+NL/VY                 2
# NA+EA                    2
# NC+M                     1
# AM+ELL                   1
# CBSS+E                   1
# E+NL                     1
# UGWZ/DQ+E+ZZ/GWLIB       1
# E/WD+NL                  1
# UGWZ+ZZ                  1
# UGWZ+E+ZZ/GWLIB          1
# UGWZ+E+ZZ                1
# EA/WD+NL                 1
# UGSU/DQ                  1
# NC+EA+SR                 1
# NA/AM+E                  1
# UGSS+ZZ                  1
# NA/DQ                    1
# NA/VY                    1
# NB+E                     1
# NB+UG                    1
# NB/DQ+EA                 1
# UG+EA                    1
# NC+E                     1
# NC+SR                    1
# Name: Type, dtype: int64

# %% [markdown]
# ### 4.2 Label main CV types and subclasses
#
# **Overarching class**
#
# (CV) Cataclysmic Variable
#
# **Subclasses**
#
# (N) Novae
# * (NA) Fast novae
# * (NB) Slow novae
# * (NC) Very slow novae
# * (NR) Recurrent novae
#
# (UG) Dwarf Nova
# * (UGSS) SS-Cyg
# * (UGSU) SU-UMa
#     * (UGWZ) WZ Sge
#     * (UGER) ER UMa
# * (UGZ) Z Cam
#     * (UGZ/IW) IW And
#
# (IBWD) AM CVn - also includes (UGSU/IBWD; UG/IBWD)
#
# (DQ) DQ Herculis - Intermediate Polars
#
# (AM) AM Herculis - Polars
#
# (NL) Nova-likes
# * (VY) VY Scl
#
#
# ### 4.2.1 Label main CV types

# %%
# Remove non-CV types
df_ZTF_CVs = df_ZTF_CVs[~df_ZTF_CVs.Type.isin(['V838MON', 'CBSS+E'])].reset_index(drop=True)

# Dataframe of eclipsing systems as defined by the AAVSO VSX.
Eclipsing = df_ZTF_CVs[(df_ZTF_CVs['Type'].str.contains('E', na=False)) &
                       (~df_ZTF_CVs['Type'].str.contains('UGER', na=False)) & 
                       (~df_ZTF_CVs['Type'].str.contains('ELL', na=False))
                       ]

# List of eclipsing system types.
Ecl_Nms = Eclipsing['Type'].value_counts().index.to_list()

# Label eclipsing systems.
df_ZTF_CVs.loc[(df_ZTF_CVs['Type'].isin(Ecl_Nms)), 'Eclipsing'] = 1
df_ZTF_CVs.loc[(~df_ZTF_CVs['Type'].isin(Ecl_Nms)), 'Eclipsing'] = 0


# Label CV main types

# (N) Novae (Classical/Recurrent)
Nov = df_ZTF_CVs[(df_ZTF_CVs['Type'].str.contains('N', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('NL', na=False))
                ]

Nov_Nms = Nov['Type'].value_counts().index.to_list()
df_ZTF_CVs.loc[(df_ZTF_CVs['Type'].isin(Nov_Nms)), 'CV_Types'] = 'nova'


# (DN) Dwarf Novae
DN = df_ZTF_CVs[(df_ZTF_CVs['Type'].str.contains('UG', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('IBWD', na=False)) & 
                (~df_ZTF_CVs['Type'].str.contains('DQ', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('NA', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('NB', na=False))
                ]

DN_Nms = DN['Type'].value_counts().index.to_list()
df_ZTF_CVs.loc[(df_ZTF_CVs['Type'].isin(DN_Nms)), 'CV_Types'] = 'dwarf_nova'

# (NL) Nova-likes
NL = df_ZTF_CVs[(df_ZTF_CVs['Type'].str.contains('NL', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('IBWD', na=False)) & 
                (~df_ZTF_CVs['Type'].str.contains('DQ', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('NA', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('NB', na=False))
                ]

NL_Nms = NL['Type'].value_counts().index.to_list()
df_ZTF_CVs.loc[(df_ZTF_CVs['Type'].isin(NL_Nms)), 'CV_Types'] = 'nova_like'

# (AM) AM Her
AM = df_ZTF_CVs[(df_ZTF_CVs['Type'].str.contains('AM', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('IBWD', na=False)) & 
                (~df_ZTF_CVs['Type'].str.contains('NA', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('NB', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('NC', na=False))
                ]

AM_Nms = AM['Type'].value_counts().index.to_list()
df_ZTF_CVs.loc[(df_ZTF_CVs['Type'].isin(AM_Nms)), 'CV_Types'] = 'polar'

# (DQ) DQ Her
DQ = df_ZTF_CVs[(df_ZTF_CVs['Type'].str.contains('DQ', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('IBWD', na=False)) & 
                (~df_ZTF_CVs['Type'].str.contains('NA', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('NB', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('NC', na=False))
                ]

DQ_Nms = DQ['Type'].value_counts().index.to_list()
df_ZTF_CVs.loc[(df_ZTF_CVs['Type'].isin(DQ_Nms)), 'CV_Types'] = 'intermediate_polar'

# (IBWD) AM CVn
IBWD = df_ZTF_CVs[(df_ZTF_CVs['Type'].str.contains('IBWD', na=False)) &
                  (~df_ZTF_CVs['Type'].str.contains('NA', na=False)) &
                  (~df_ZTF_CVs['Type'].str.contains('NB', na=False)) &
                  (~df_ZTF_CVs['Type'].str.contains('NC', na=False))
                 ]

IBWD_Nms = IBWD['Type'].value_counts().index.to_list()
df_ZTF_CVs.loc[(df_ZTF_CVs['Type'].isin(IBWD_Nms)), 'CV_Types'] = 'AMCVn'

# Additional (NA)) Nova
df_ZTF_CVs.loc[(df_ZTF_CVs['Type'].isin(['NA+NL/VY'])), 'CV_Types'] = 'nova'

# Display value counts for CV types.
df_ZTF_CVs.CV_Types.value_counts()
# Out:
# dwarf_nova            4822
# nova_like              263
# polar                  126
# nova                    88
# intermediate_polar      54
# AMCVn                   46
# Name: CV_Types, dtype: int64

# %% [markdown]
# ### 4.2.2 Label CV subclasses and subsubclasses

# %%
# Label subclasses

# (dwarf_nova) Dwarf Nova subclasses and subsubclasses

df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['dwarf_nova'])) & (df_ZTF_CVs.Type.str.contains('UGSS', na=False)), 'CV_subtypes'] = 'dwarf_nova_U_Gem'

df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['dwarf_nova'])) & (df_ZTF_CVs.Type.str.contains('UGSU', na=False)), 'CV_subtypes'] = 'dwarf_nova_SU_Uma'
df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['dwarf_nova'])) & (df_ZTF_CVs.Type.str.contains('UGWZ', na=False)), 'CV_subtypes'] = 'dwarf_nova_SU_Uma'
df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['dwarf_nova'])) & (df_ZTF_CVs.Type.str.contains('UGER', na=False)), 'CV_subtypes'] = 'dwarf_nova_SU_Uma'

df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['dwarf_nova'])) & (df_ZTF_CVs.Type.str.contains('UGWZ', na=False)), 'CV_subsubtypes'] = 'dwarf_nova_SU_Uma_WZ_Sge'
df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['dwarf_nova'])) & (df_ZTF_CVs.Type.str.contains('UGER', na=False)), 'CV_subsubtypes'] = 'dwarf_nova_SU_Uma_ER_Uma'

df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['dwarf_nova'])) & (df_ZTF_CVs.Type.str.contains('UGZ', na=False)), 'CV_subtypes'] = 'dwarf_nova_Z_Cam'
df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['dwarf_nova'])) & (df_ZTF_CVs.Type.str.contains('UGZ/IW', na=False)), 'CV_subsubtypes'] = 'dwarf_nova_Z_Cam_IW_And'


# (N) Nova subclasses
df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['nova'])) & (df_ZTF_CVs.Type.str.contains('NA', na=False)), 'CV_subtypes'] = 'nova_fast'
df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['nova'])) & (df_ZTF_CVs.Type.str.contains('NB', na=False)), 'CV_subtypes'] = 'nova_slow'
df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['nova'])) & (df_ZTF_CVs.Type.str.contains('NC', na=False)), 'CV_subtypes'] = 'nova_very_slow'
df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['nova'])) & (df_ZTF_CVs.Type.str.contains('NR', na=False)), 'CV_subtypes'] = 'nova_recurrent'


# (NL) Nova-like subclasses
df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['nova_like'])) & (df_ZTF_CVs.Type.str.contains('VY', na=False)), 'CV_subtypes'] = 'nova_like_VY_Scl'

# Display dataframe
pd.options.display.max_rows = 50
df_ZTF_CVs
# Out:
#                           Name         AUID                   Coords Const  \
# 0                  ASASSN-19dp  000-BMZ-678  02 22 59.02 +43 39 13.1   And
# 1                    BMAM-V789  000-BNS-414  02 33 58.15 +41 37 26.3   And
# 2     CSS 091026:002637+242916           --  00 26 37.06 +24 29 15.7   And
# 3                   MGAB-V3453           --  00 35 53.37 +43 33 41.5   And
# 4                   MGAB-V3769           --  23 34 33.16 +40 25 50.2   And
# ...                        ...          ...                      ...   ...
# 5703                       NaN    AT2022qzf  00:42:09.42 +41:15:31.2   NaN
# 5704                       NaN    AT2022ubf  00:42:30.04 +41:56:12.5   NaN
# 5705                       NaN    AT2022yax  00:43:45.84 +41:15:58.6   NaN
# 5706                       NaN    AT2022zzj  00:41:25.72 +40:44:23.3   NaN
# 5707                       NaN    AT2023bji  05:43:48.25 +62:58:41.6   NaN
#
#      Type     Period            Mag          ra        dec    Xmatch_obj  \
# 0      AM         --  16.5 - 20.9 g   35.745917  43.653639  ZTF18abryuah
# 1      AM  0.0714789  18.5 - 21.7 r   38.492292  41.623972  ZTF18abtrvgp
# 2      AM         --   17.1 - 21 CV    6.654417  24.487694  ZTF17aaaehby
# 3      AM         --  18.2 - 20.9 r    8.972375  43.561528  ZTF18abgjgiq
# 4      AM         --  18.8 - 20.8 r  353.638167  40.430611  ZTF18abumlux
# ...   ...        ...            ...         ...        ...           ...
# 5703    N        NaN            NaN   10.539250  41.258667  ZTF22aazmooy
# 5704    N        NaN            NaN   10.625167  41.936806  ZTF22abfxmpc
# 5705    N        NaN            NaN   10.941000  41.266278  ZTF22abnrgno
# 5706    N        NaN            NaN   10.357167  40.739806  ZTF22abtltcw
# 5707    N        NaN            NaN   85.951042  62.978222  ZTF23aabvpgb
#
#       separation  Eclipsing CV_Types CV_subtypes CV_subsubtypes
# 0       0.378550        0.0    polar         NaN            NaN
# 1       0.134256        0.0    polar         NaN            NaN
# 2       0.308769        0.0    polar         NaN            NaN
# 3       0.522473        0.0    polar         NaN            NaN
# 4       0.031042        0.0    polar         NaN            NaN
# ...          ...        ...      ...         ...            ...
# 5703         NaN        0.0     nova         NaN            NaN
# 5704         NaN        0.0     nova         NaN            NaN
# 5705         NaN        0.0     nova         NaN            NaN
# 5706         NaN        0.0     nova         NaN            NaN
# 5707         NaN        0.0     nova         NaN            NaN
#
# [5708 rows x 15 columns]

# %% [markdown]
# ### 4.2.3 Save dataframe to csv.

# %%
# Save dataframe to csv
df_ZTF_CVs.to_csv('../processed_data/AAVSOCVsZTFxmatch_21032023_BTS_labelled.csv', index=False)

# %%
#
