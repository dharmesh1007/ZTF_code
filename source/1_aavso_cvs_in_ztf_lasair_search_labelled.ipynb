# %% [markdown]
# # Build Dataset
#
# We focus on objects classified as CV within AAVSO VSX. This resource is the most up-to-date catalogue of transients/variable stars available online. The resource also includes subtypes that are going to be important for this work.

# %% [markdown]
# ## 1. Imports

# %%
import os
import lasair
import pandas as pd
from astropy import units as u
from astropy.coordinates import SkyCoord

# %% [markdown]
# ## 2. Generate list of CVs from those catalogued in AAVSO VSX
#
# ### 2.1 Load csv of CVs and suspected CVs
#
# See https://www.aavso.org/vsx/. From this link, I dowloaded a list of targets classified as CV by AAVSO. The variability types are detailed in https://www.aavso.org/vsx/index.php?view=about.vartypes.

# %%
date = '08092023'
AAVSO_CVS = pd.read_csv(f"../processed_data/AAVSOCVsraw_{date}.csv")
print(f'Number of examples: {AAVSO_CVS.shape[0]}')

# Convert coordinates to ra and dec.
AAVSO_CVS['ra'] = AAVSO_CVS.apply(lambda x: SkyCoord(f'{x["Coords"]}', unit=(u.hourangle, u.deg), equinox='J2000').ra.deg, axis=1)
AAVSO_CVS['dec'] = AAVSO_CVS.apply(lambda x: SkyCoord(f'{x["Coords"]}', unit=(u.hourangle, u.deg), equinox='J2000').dec.deg, axis=1)

AAVSO_CVS.head()
# Out:
# Number of examples: 15895
# WARNING: IllegalSecondWarning: 'second' was found  to be '60.0', which is not in range [0,60). Treating as 0 sec, +1 min [astropy.coordinates.angle_formats]
# WARNING: IllegalSecondWarning: 'second' was found  to be '60.0', which is not in range [0,60). Treating as 0 sec, +1 min [astropy.coordinates.angle_formats]
#      Name         AUID                   Coords Const  Type    Period  \
# 0  RX And  000-BBC-342  01 04 35.54 +41 17 57.8   And   UGZ  0.209893
# 1  AR And  000-BBD-275  01 45 03.27 +37 56 33.2   And  UGSS     0.163
# 2  BV And  000-BCT-512  23 27 02.09 +50 07 13.0   And    UG      (45)
# 3  DX And  000-BCR-612  23 29 46.68 +43 45 04.0   And  UGSS  0.440502
# 4  FN And  000-BBC-497  01 11 57.60 +35 17 24.3   And  UGSS        --
#
#              Mag          ra        dec
# 0  10.3 - 14.8 V   16.148083  41.299389
# 1  11.0 - 17.6 V   26.263625  37.942556
# 2  15.3 - 18.5 V  351.758708  50.120278
# 3  11.0 - 15.5 V  352.444500  43.751111
# 4  12.9 - 19.3 V   17.990000  35.290083

# %% [markdown]
# ### 2.2 Identify those observable by ZTF.
#
# Perform some processing to acquire the coordinates in degree format; select only those observable by ZTF (greater than -31 degree declination); inspect the subtypes.

# %%
pd.options.display.max_rows = 10

# Select those observable with ZTF.
AAVSO_CVS_1 = AAVSO_CVS.copy()[AAVSO_CVS['dec']>-31]
AAVSO_CVS_1 = AAVSO_CVS_1.reset_index(drop=True)
AAVSO_CVS_1
# Out:
#                Name         AUID                   Coords Const  Type  \
# 0            RX And  000-BBC-342  01 04 35.54 +41 17 57.8   And   UGZ
# 1            AR And  000-BBD-275  01 45 03.27 +37 56 33.2   And  UGSS
# 2            BV And  000-BCT-512  23 27 02.09 +50 07 13.0   And    UG
# 3            DX And  000-BCR-612  23 29 46.68 +43 45 04.0   And  UGSS
# 4            FN And  000-BBC-497  01 11 57.60 +35 17 24.3   And  UGSS
# ...             ...          ...                      ...   ...   ...
# 11553  ZTF20abmbcza           --  20 22 34.43 +21 02 09.6   Vul   UG:
# 11554  ZTF20abopngr           --  20 52 57.13 +26 18 08.2   Vul    UG
# 11555  ZTF21acatkss           --  20 48 37.96 +27 03 18.8   Vul    UG
# 11556  ZTF22abmlesb  000-BPL-654  20 51 42.53 +26 30 48.0   Vul    UG
# 11557  ZTF23aaiurvg  000-BPQ-022  21 16 41.18 +20 40 00.3   Vul   UG:
#
#          Period            Mag          ra        dec
# 0      0.209893  10.3 - 14.8 V   16.148083  41.299389
# 1         0.163  11.0 - 17.6 V   26.263625  37.942556
# 2          (45)  15.3 - 18.5 V  351.758708  50.120278
# 3      0.440502  11.0 - 15.5 V  352.444500  43.751111
# 4            --  12.9 - 19.3 V   17.990000  35.290083
# ...         ...            ...         ...        ...
# 11553        --   17.2 - 23: r  305.643458  21.036000
# 11554        --  17.2 - 23.7 r  313.238042  26.302278
# 11555        --  18.2 - 22.3 r  312.158167  27.055222
# 11556        --   15.8 - <23 g  312.927208  26.513333
# 11557        --   17.2 - <23 g  319.171583  20.666750
#
# [11558 rows x 9 columns]

# %% [markdown]
# ### 2.3 Inspect CV subtypes

# %%
pd.options.display.max_rows = None

# Display subtypes.
print(f'Number of CVs observable with ZTF: {AAVSO_CVS_1.shape[0]}')
AAVSO_CVS_1.Type.value_counts()
# Out:
# Number of CVs observable with ZTF: 11558
# Type
# UG                    5774
# UG:                   1520
# UGSU                   754
# CV                     608
# UGSU:                  275
# UGWZ                   164
# AM                     151
# NL/VY                  149
# CV:                    139
# UGSS                   127
# UGZ                     93
# UGZ/IW                  91
# UG+E                    88
# NL+E                    80
# UG|SN                   79
# NL                      78
# SN|UG                   74
# UGWZ:                   69
# UGSU+E                  51
# DQ                      48
# N                       46
# UGZ:                    43
# NL/VY:                  40
# AM:                     38
# AM+E                    37
# NL:                     37
# NB                      32
# N:                      29
# UGER                    28
# CV+E                    26
# UGZ/IW:                 26
# UGSU/IBWD               26
# UG/IBWD                 23
# UGSS:                   19
# UG+E:                   18
# UGSS+E                  18
# IBWD                    16
# UG/DQ                   13
# NL/VY+E                 13
# DQ:                     12
# UG/IBWD:                12
# CV|QSO                  11
# UGSU/IBWD:              11
# NA:                     11
# UG+VY                   10
# UGER:                    9
# UGER+UGZ                 9
# NA+E                     9
# NR                       9
# UGZ/IW+E                 9
# IBWD+E                   8
# UGZ+E                    7
# UGZ+VY                   7
# UGSU:+E                  7
# CV+E:                    7
# NA+UG                    6
# UGWZ+ZZ/GWLIB            6
# UG/DQ:                   6
# UGWZ+E                   6
# SN|UG:                   6
# LMXB|CV+EA               6
# UG+VY:                   5
# NB:                      5
# V838MON                  5
# DQ+E                     5
# NC                       4
# UG+NL/VY                 4
# NB+E                     4
# UG|QSO                   4
# NC:                      4
# UGSU/IBWD+E              4
# AM:+E                    4
# NL:+E                    4
# AGN|UG                   3
# UG:+E                    3
# NC+M                     3
# UG|AGN                   3
# NA/DQ:                   3
# UG+ELL                   3
# N+E                      3
# AM|DQ                    3
# UGSU:/IBWD               3
# UG|YSO                   3
# UGSU+E:                  3
# UG/IBWD|UGWZ             3
# UG/DQ+E                  3
# NR+E                     3
# NR:                      3
# UGSS|UGZ/IW:             2
# AGN|CV                   2
# V838MON:                 2
# LMXB|CV                  2
# NA+UG:                   2
# UGZ/IW+VY                2
# DQ|AM                    2
# AM+E:                    2
# UG/IBWD+E                2
# EA+NL                    2
# IBWD:                    2
# UGSS+ELL                 2
# CV|LMXB                  2
# NA+NL/VY                 2
# YSO|CV                   2
# NA+E:                    2
# NA/DQ                    2
# NA/DQ+UG                 2
# UGZ/IW:+VY               2
# EA/WD+NL                 2
# UGSU/DQ                  2
# NB+UG                    2
# UGWZ/IBWD                2
# CV+ZZ/GWLIB              2
# UG+R                     2
# UGWZ+E+ZZ/GWLIB          2
# NA+EA                    2
# DQ|LMXB                  1
# UG/DQ:+E                 1
# CV|LMXB|RS:              1
# UV|UG                    1
# E+DQ:                    1
# LMXB|CV+ELL              1
# YSO|UG                   1
# NL/VY+E:                 1
# UGZ/IW+UGER              1
# N|NL                     1
# BY|LMXB|CV               1
# UGWZ/DQ+E+ZZ/GWLIB       1
# NB/AM                    1
# UGWZ:/IBWD:              1
# NC+SR                    1
# UGZ/DQ:                  1
# NR+LB                    1
# NL:+E:                   1
# CV|YSO                   1
# CV:+E                    1
# UGZ:+NL/VY:              1
# DCEP|CV                  1
# UG:+NL/VY:               1
# UGZ//IW:|NL:             1
# UGZ:+E                   1
# UGSS+ZZ:                 1
# N:+UG+E                  1
# N+ELL                    1
# UGSU+UGZ/IW              1
# UGSU/DQ+E                1
# UG:+E:                   1
# UG|Microlens             1
# UGSU+UGZ                 1
# UGER+UGZ+E               1
# UG:+EW                   1
# LMXB|UG+E                1
# CBSS+E                   1
# NC+EA+SR                 1
# XP                       1
# NR:+ELL                  1
# NA+ELL                   1
# ROT|CV|LMXB              1
# LMXB/XN|UGWZ|NR          1
# UG:|AGN:                 1
# UGWZ+E+ZZ                1
# CBSS/V+E                 1
# NB/DQ                    1
# AM+ELL                   1
# E/WD+NL                  1
# UGZ+UGSU+VY              1
# DQ+E:                    1
# UGSS+ZZ                  1
# UGZ:+VY                  1
# UGZ:/DQ                  1
# NB+EA                    1
# UG:|UV:                  1
# UGWZ|SN                  1
# NL+UGZ                   1
# NC+E                     1
# NR+ZAND+M                1
# AM|DQ:                   1
# NR+ELL                   1
# UG:+ZZ/GWLIB             1
# CV|AGN                   1
# N+CBSS:                  1
# UGWZ+ZZ                  1
# UGZ/IW+UGSU              1
# AM:+E:                   1
# UGZ/IW+E:                1
# NL|UGZ:                  1
# EA+CV:                   1
# NB+E:                    1
# NA+UGZ/IW                1
# UG|SN:                   1
# UGZ|NL                   1
# UGWZ:|N                  1
# NL+E:                    1
# NA+UGZ/DQ:               1
# UG+EA                    1
# UGZ+N                    1
# UGWZ:+E                  1
# UGSU/IBWD+UGZ            1
# UG+NL/VY:                1
# UV+CV                    1
# UG:/DQ                   1
# NA/AM+E                  1
# NL+ZZ:                   1
# UGWZ/IBWD:               1
# NA+UGSS                  1
# UGER/IBWD+UGZ            1
# UG+ELL+ROT               1
# E+NL                     1
# NA:+UGER+NL              1
# CV+R                     1
# IBWD+ZZB:                1
# UG|QSO:                  1
# UGER+UGZ:                1
# NA/VY                    1
# UGSS+EW                  1
# QSO|CV                   1
# UGZ+E:                   1
# NB/DQ+EA                 1
# UG|Microlens:            1
# N:+E                     1
# UGZ+NL:                  1
# NA+ZAND:+E:              1
# UGSS/DQ:                 1
# UGWZ+E:                  1
# UGZ+VY+E                 1
# CV+R:                    1
# NL|UG                    1
# UGZ+NL                   1
# UGSU+ELL                 1
# UG|N                     1
# UG|YSO:                  1
# YSO|UGZ:                 1
# Name: count, dtype: int64

# %% [markdown]
# ### 2.4 Refine subtypes
#
# A colon ( : ) after the variability type -or any other field- means the value/classification is uncertain.
#
# A pipe character ( | ) between two different types signifies a logical OR; the classification is uncertain and all possible types are indicated. An example of this is ELL|DSCT, where the star may be an ellipsoidal binary system or a DSCT-type pulsating variable with half the given period.

# %%
pd.options.display.max_rows=50

# Remove objects with uncertain classification and or have several possible types (:, |). 
AAVSO_CVS_2 = AAVSO_CVS_1[(AAVSO_CVS_1['Type'].str.contains(':', regex=True)==False)]
AAVSO_CVS_2 = AAVSO_CVS_2[(AAVSO_CVS_2['Type'].str.contains('\|', regex=True)==False)]
AAVSO_CVS_2 = AAVSO_CVS_2.reset_index(drop=True)

# Inspect dataframe for different CV transient types.
# Eclipsing = AAVSO_CVS_2[(AAVSO_CVS_2.Type.str.contains('E', regex=True)==True) & (AAVSO_CVS_2.Type!='UGER')]
# Eclipsing.Type.value_counts()
AAVSO_CVS_2
# Out:
#               Name         AUID                   Coords Const  Type  \
# 0           RX And  000-BBC-342  01 04 35.54 +41 17 57.8   And   UGZ
# 1           AR And  000-BBD-275  01 45 03.27 +37 56 33.2   And  UGSS
# 2           BV And  000-BCT-512  23 27 02.09 +50 07 13.0   And    UG
# 3           DX And  000-BCR-612  23 29 46.68 +43 45 04.0   And  UGSS
# 4           FN And  000-BBC-497  01 11 57.60 +35 17 24.3   And  UGSS
# ...            ...          ...                      ...   ...   ...
# 8731  ZTF19abasmma           --  19 54 27.43 +24 51 26.6   Vul    UG
# 8732  ZTF19abxzumq           --  20 54 29.51 +26 30 42.3   Vul    UG
# 8733  ZTF20abopngr           --  20 52 57.13 +26 18 08.2   Vul    UG
# 8734  ZTF21acatkss           --  20 48 37.96 +27 03 18.8   Vul    UG
# 8735  ZTF22abmlesb  000-BPL-654  20 51 42.53 +26 30 48.0   Vul    UG
#
#         Period            Mag          ra        dec
# 0     0.209893  10.3 - 14.8 V   16.148083  41.299389
# 1        0.163  11.0 - 17.6 V   26.263625  37.942556
# 2         (45)  15.3 - 18.5 V  351.758708  50.120278
# 3     0.440502  11.0 - 15.5 V  352.444500  43.751111
# 4           --  12.9 - 19.3 V   17.990000  35.290083
# ...        ...            ...         ...        ...
# 8731        --  17.5 - 21.6 g  298.614292  24.857389
# 8732        --   15.3 - <23 g  313.622958  26.511750
# 8733        --  17.2 - 23.7 r  313.238042  26.302278
# 8734        --  18.2 - 22.3 r  312.158167  27.055222
# 8735        --   15.8 - <23 g  312.927208  26.513333
#
# [8736 rows x 9 columns]

# %% [markdown]
# ## 3. Coordinate cross match AAVSO VSX CVs with ZTF targets within Lasair
#
# ### 3.1 Define Lasair token and create cache

# %%
# Tokens required for Lasair database access via the API: https://lasair-iris.roe.ac.uk/api.
# Starter token - Ten attempts per hour
starterToken = '4b762569bb349bd8d60f1bc7da3f39dbfaefff9a'
# User token - 100 queries an hour
token = '4607a33defa78fa20bef98791680574b6cc13b23'

if not os.path.exists('../cacheLasairXmatch'):
    os.makedirs('../cacheLasairXmatch')

# %% [markdown]
# ### 3.2 Crossmatch with Lasair to obtain ZTF counterparts

# %%
def get_ZTFcounterparts(df, racol, deccol, radius):
    # Make a copy of the dataframe.
    df = df.copy()
    
    # Initialise Lasair client.
    L = lasair.lasair_client(token, cache='../cacheLasairXmatch')

    # Loop through the AAVSO CVs list to identify ZTF counterparts.
    for count, (ra, dec) in enumerate(zip(df[racol], df[deccol]), start=0):
        print(count, ra, dec)

        try:
            # Performs a cone search of ZTF objects within Lasair that are within x arccseconds of the coordinated given. 
            c = L.cone(ra=ra, dec=dec, radius=radius, requestType='nearest')
            print(c)

            # Append ZTF object ID and separation from coordinated given into new columns using pd.DataFrame.at().
            df.at[count, 'Xmatch_obj']=c['object']
            df.at[count, 'separation']=c['separation']

        # Print the error that caused the except pathway to be triggered. 
        except Exception as e:
            print(e)
            pass

    return df

# %%
# Get ZTF counterparts for first 5000 objects.
pt1 = get_ZTFcounterparts(AAVSO_CVS_2[0:4500].reset_index(drop=True), 'ra', 'dec', radius=2)

# Save the dataframe to a csv file.
pt1.to_csv(f'../processed_data/AAVSOCVsZTFxmatch_{date}_0_4499.csv', index=False)
# Out:
# 0 16.148083333333332 41.299388888888885
# Bad Request:{"error":"No object found ra=16.14808 dec=41.29939 radius=2.00"}
# 1 26.263624999999998 37.94255555555555
# {'object': 'ZTF19acgtoku', 'separation': 0.27532186700614003}
# 2 351.7587083333333 50.12027777777778
# {'object': 'ZTF17aabuphg', 'separation': 0.04368385236028549}
# 3 352.4445 43.75111111111111
# Bad Request:{"error":"No object found ra=352.44450 dec=43.75111 radius=2.00"}
# 4 17.99 35.29008333333333
# Bad Request:{"error":"No object found ra=17.99000 dec=35.29008 radius=2.00"}
# 5 18.883999999999997 37.626555555555555
# {'object': 'ZTF18aabfcyi', 'separation': 0.3907323425164502}
# 6 36.47929166666666 37.56813888888889
# {'object': 'ZTF18aabfoia', 'separation': 0.05305830573909658}
# 7 7.8994583333333335 43.81827777777778
# HTTPSConnectionPool(host='lasair-ztf.lsst.ac.uk', port=443): Max retries exceeded with url: /api/cone/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1404c2350>: Failed to establish a new connection: [Errno 12] Cannot allocate memory'))
# 8 10.230749999999999 43.41652777777777
# {'object': 'ZTF18abgjgma', 'separation': 0.18126336362573475}
# 9 15.287124999999998 43.3905
# {'object': 'ZTF19acyycev', 'separation': 0.11655333076306275}
# 10 16.766166666666663 42.72002777777778
# {'object': 'ZTF18abgopgb', 'separation': 0.117280533642637}
# 11 34.307916666666664 40.69155555555555
# {'object': 'ZTF18admvlto', 'separation': 0.17060474072414752}
# 12 38.82491666666666 41.23394444444445
# {'object': 'ZTF18adnxjie', 'separation': 0.6071400449452153}
# 13 10.464458333333331 26.62252777777778
# {'object': 'ZTF21acbalhp', 'separation': 0.8503394186931251}
# 14 8.042791666666666 41.96952777777778
# {'object': 'ZTF22aahofcd', 'separation': 0.7836738024829346}
# 15 10.062624999999999 43.097
# {'object': 'ZTF17aaaduzw', 'separation': 0.2639348951111328}
# 16 34.93370833333333 40.45619444444445
# Bad Request:{"error":"No object found ra=34.93371 dec=40.45619 radius=2.00"}
# 17 346.1559166666666 49.45663888888889
# {'object': 'ZTF20actpowx', 'separation': 0.31638524446408595}
# 18 37.37320833333333 40.04438888888889
# Bad Request:{"error":"No object found ra=37.37321 dec=40.04439 radius=2.00"}
# 19 10.10158333333333 41.06755555555556
# {'object': 'ZTF23aaknvmk', 'separation': 0.1319853426600633}
# 20 7.524208333333333 26.290666666666667
# {'object': 'ZTF20abrwsis', 'separation': 0.061240749794244945}
# 21 4.958041666666666 21.947805555555554
# {'object': 'ZTF18abpumun', 'separation': 0.4068525889490733}
# 22 2.7802499999999997 30.543333333333337
# Bad Request:{"error":"No object found ra=2.78025 dec=30.54333 radius=2.00"}
# 23 353.50604166666665 39.361361111111115
# {'object': 'ZTF23aaaswqx', 'separation': 1.5046792413753711}
# 24 30.105999999999998 44.17197222222222
# Bad Request:{"error":"No object found ra=30.10600 dec=44.17197 radius=2.00"}
# 25 10.610416666666666 42.260194444444444
# Bad Request:{"error":"No object found ra=10.61042 dec=42.26019 radius=2.00"}
# 26 13.832749999999997 46.215833333333336
# {'object': 'ZTF18admoxby', 'separation': 0.21435915137294065}
# 27 35.56870833333333 41.38311111111111
# Bad Request:{"error":"No object found ra=35.56871 dec=41.38311 radius=2.00"}
# 28 356.239625 43.52286111111111
# {'object': 'ZTF17aaaenex', 'separation': 0.28827869134978407}
# 29 11.606875 41.12061111111111
# {'object': 'ZTF18abumtyr', 'separation': 0.25416151709751245}
# 30 22.416916666666665 38.70291666666667
# Bad Request:{"error":"No object found ra=22.41692 dec=38.70292 radius=2.00"}
# 31 349.90029166666665 36.78333333333333
# {'object': 'ZTF18abnzbxh', 'separation': 0.6088026578781295}
# 32 9.612624999999998 25.157083333333333
# {'object': 'ZTF18abnzlcm', 'separation': 0.6293273440069824}
# 33 21.960749999999994 38.13663888888889
# {'object': 'ZTF18abtlrqu', 'separation': 0.3284855908594489}
# 34 27.56745833333333 37.93861111111111
# {'object': 'ZTF18aabfaxr', 'separation': 0.06268908214696546}
# 35 354.4967083333333 43.1475
# {'object': 'ZTF18admipph', 'separation': 0.21134110793989833}
# 36 356.2603333333333 34.49
# {'object': 'ZTF17aabouaj', 'separation': 0.09034458289136163}
# 37 20.152874999999995 49.400055555555554
# {'object': 'ZTF18aabfarp', 'separation': 0.10709139831597723}
# 38 350.33824999999996 38.13225
# {'object': 'ZTF17aabuuke', 'separation': 0.18170581918838835}
# 39 0.5932083333333332 42.70375
# {'object': 'ZTF18admewcz', 'separation': 0.33743709548838347}
# 40 358.00491666666665 44.84955555555556
# {'object': 'ZTF18abiwzlg', 'separation': 0.26963593766029414}
# 41 352.48025 44.93713888888889
# Bad Request:{"error":"No object found ra=352.48025 dec=44.93714 radius=2.00"}
# 42 39.21083333333333 40.233361111111115
# {'object': 'ZTF18acakfsn', 'separation': 0.11983040851726198}
# 43 31.2515 46.09388888888889
# {'object': 'ZTF17aaaewmi', 'separation': 0.17261402932912123}
# 44 10.442958333333332 35.626777777777775
# {'object': 'ZTF19aavftba', 'separation': 0.12217259241420132}
# 45 24.898416666666662 35.644666666666666
# {'object': 'ZTF18abmewej', 'separation': 0.27242438760640864}
# 46 357.5653333333333 33.350972222222225
# Bad Request:{"error":"No object found ra=357.56533 dec=33.35097 radius=2.00"}
# 47 17.593 47.331583333333334
# {'object': 'ZTF18acbxzuc', 'separation': 0.07516156908198952}
# 48 355.60925 32.805527777777776
# {'object': 'ZTF18abtyrpb', 'separation': 0.13337376343479088}
# 49 27.906791666666667 45.65452777777778
# Bad Request:{"error":"No object found ra=27.90679 dec=45.65453 radius=2.00"}
# 50 9.149291666666667 21.857166666666668
# Bad Request:{"error":"No object found ra=9.14929 dec=21.85717 radius=2.00"}
# 51 23.281541666666666 41.12186111111111
# {'object': 'ZTF18adikuzj', 'separation': 0.12930993073961242}
# 52 9.752291666666666 27.22936111111111
# {'object': 'ZTF18achawna', 'separation': 0.18513088835307065}
# 53 26.96870833333333 45.94541666666667
# Bad Request:{"error":"No object found ra=26.96871 dec=45.94542 radius=2.00"}
# 54 37.60183333333333 45.121722222222225
# {'object': 'ZTF19adfblgz', 'separation': 0.16062239452235852}
# 55 350.53862499999997 39.83552777777778
# Bad Request:{"error":"No object found ra=350.53862 dec=39.83553 radius=2.00"}
# 56 36.546083333333335 38.69291666666666
# Bad Request:{"error":"No object found ra=36.54608 dec=38.69292 radius=2.00"}
# 57 17.470166666666664 47.95311111111111
# Bad Request:{"error":"No object found ra=17.47017 dec=47.95311 radius=2.00"}
# 58 349.37466666666666 52.33902777777778
# {'object': 'ZTF18aazndpb', 'separation': 0.6796446650340882}
# 59 353.744375 40.269194444444445
# Bad Request:{"error":"No object found ra=353.74437 dec=40.26919 radius=2.00"}
# 60 358.7149583333333 43.96619444444445
# {'object': 'ZTF19aaeyvgl', 'separation': 0.29127793974800437}
# 61 35.74591666666666 43.653638888888885
# {'object': 'ZTF18adnatie', 'separation': 0.20067945468799261}
# 62 348.57370833333334 52.93227777777778
# Bad Request:{"error":"No object found ra=348.57371 dec=52.93228 radius=2.00"}
# 63 23.570375 42.27941666666666
# {'object': 'ZTF19acprlbl', 'separation': 0.0368830215180689}
# 64 13.029791666666666 43.871833333333335
# {'object': 'ZTF19abjqekj', 'separation': 0.6659331987139664}
# 65 11.971874999999999 39.01594444444444
# Bad Request:{"error":"No object found ra=11.97187 dec=39.01594 radius=2.00"}
# 66 350.0770833333333 49.32947222222223
# {'object': 'ZTF19aceiizg', 'separation': 0.07775623665739964}
# 67 32.80837499999999 42.93558333333333
# {'object': 'ZTF18acpsekl', 'separation': 0.03281690890998135}
# 68 24.71645833333333 46.58052777777778
# Bad Request:{"error":"No object found ra=24.71646 dec=46.58053 radius=2.00"}
# 69 352.8615833333333 47.614583333333336
# {'object': 'ZTF19abajklf', 'separation': 0.08207105398861769}
# 70 39.23920833333333 41.443638888888884
# {'object': 'ZTF21aaadtpw', 'separation': 0.18032281517833432}
# 71 12.732833333333332 35.982083333333335
# {'object': 'ZTF21abhrevv', 'separation': 0.5260681356990796}
# 72 345.675 44.71555555555556
# {'object': 'ZTF21abpvsig', 'separation': 0.03450090747740618}
# 73 349.1512083333333 50.03122222222222
# {'object': 'ZTF18abwijpp', 'separation': 0.32891669335589774}
# 74 7.226624999999999 43.19558333333333
# {'object': 'ZTF18aboslis', 'separation': 0.6923553244089943}
# 75 0.3248333333333333 39.47380555555556
# {'object': 'ZTF22abjfseq', 'separation': 0.03011486096378699}
# 76 346.8147916666666 49.37577777777778
# {'object': 'ZTF18acugwxc', 'separation': 0.30977712880797315}
# 77 0.34349999999999997 48.28272222222222
# {'object': 'ZTF17aaaenol', 'separation': 0.1767779105341954}
# 78 3.4753749999999997 44.89055555555556
# Bad Request:{"error":"No object found ra=3.47537 dec=44.89056 radius=2.00"}
# 79 5.985291666666667 42.7855
# Bad Request:{"error":"No object found ra=5.98529 dec=42.78550 radius=2.00"}
# 80 10.788416666666667 41.283944444444444
# {'object': 'ZTF23aaaairl', 'separation': 0.11442656502932465}
# 81 350.3454583333333 44.39738888888889
# {'object': 'ZTF22abfwxsk', 'separation': 0.061008922779964565}
# 82 354.09887499999996 44.64308333333333
# {'object': 'ZTF18acrckdd', 'separation': 0.02496992360765051}
# 83 11.356208333333331 39.84791666666667
# Bad Request:{"error":"No object found ra=11.35621 dec=39.84792 radius=2.00"}
# 84 33.11745833333333 46.89255555555555
# Bad Request:{"error":"No object found ra=33.11746 dec=46.89256 radius=2.00"}
# 85 33.85945833333333 43.275444444444446
# {'object': 'ZTF22abznxxk', 'separation': 0.10814478168635025}
# 86 359.85108333333335 45.901916666666665
# Bad Request:{"error":"No object found ra=359.85108 dec=45.90192 radius=2.00"}
# 87 354.74662499999994 41.57625
# {'object': 'ZTF18acswudf', 'separation': 0.1459224799143172}
# 88 23.170749999999995 50.156416666666665
# {'object': 'ZTF19abgzjjo', 'separation': 0.038142188343107786}
# 89 4.0616666666666665 46.50338888888889
# {'object': 'ZTF18abolkgw', 'separation': 0.27648602385614085}
# 90 3.4268333333333327 28.919222222222224
# {'object': 'ZTF20acmjgyw', 'separation': 0.4203851042645014}
# 91 3.626833333333333 43.2385
# {'object': 'ZTF22abgglcz', 'separation': 0.0823583179190298}
# 92 357.0442083333333 41.792027777777776
# {'object': 'ZTF18admipox', 'separation': 0.11864197840358848}
# 93 33.89525 49.334472222222225
# {'object': 'ZTF18abnzpcu', 'separation': 0.43890967795815405}
# 94 346.728625 50.23375
# {'object': 'ZTF18abosjyg', 'separation': 0.11715964661483098}
# 95 38.49229166666666 41.62397222222222
# {'object': 'ZTF18abtrvgp', 'separation': 0.13425622485012198}
# 96 3.2566666666666664 41.34422222222222
# {'object': 'ZTF18abtcgjs', 'separation': 0.3129024387755184}
# 97 10.100624999999997 33.69252777777778
# Bad Request:{"error":"No object found ra=10.10062 dec=33.69253 radius=2.00"}
# 98 11.607791666666666 38.33994444444445
# {'object': 'ZTF19aaaanyo', 'separation': 0.09873817471896851}
# 99 8.749833333333331 27.60552777777778
# {'object': 'ZTF18aczower', 'separation': 1.0870719210156319}
# 100 11.25120833333333 22.452027777777776
# {'object': 'ZTF19aayijpg', 'separation': 0.5495188573313078}
# 101 353.13558333333333 39.220888888888894
# {'object': 'ZTF19aadweee', 'separation': 0.9949162296133238}
# 102 347.40849999999995 37.12083333333334
# {'object': 'ZTF18abxznky', 'separation': 0.20262363720170956}
# 103 352.63274999999993 40.60166666666667
# Bad Request:{"error":"No object found ra=352.63275 dec=40.60167 radius=2.00"}
# 104 3.9093333333333327 26.61577777777778
# {'object': 'ZTF17aaaemzh', 'separation': 0.7216840709851688}
# 105 12.030041666666666 26.77311111111111
# {'object': 'ZTF18abnzljz', 'separation': 0.8824722692847762}
# 106 351.8177916666666 41.53022222222222
# {'object': 'ZTF18abxmbfq', 'separation': 0.4099291540321481}
# 107 6.654416666666666 24.487694444444447
# {'object': 'ZTF17aaaehby', 'separation': 0.29018941085666805}
# 108 2.439458333333333 40.491
# Bad Request:{"error":"No object found ra=2.43946 dec=40.49100 radius=2.00"}
# 109 2.5804999999999993 41.08186111111112
# {'object': 'ZTF18admewpb', 'separation': 0.13054598291751152}
# 110 8.015125 31.752916666666668
# {'object': 'ZTF18ablmdrf', 'separation': 0.1579236632011722}
# 111 352.0907083333333 36.532111111111114
# Bad Request:{"error":"No object found ra=352.09071 dec=36.53211 radius=2.00"}
# 112 4.618166666666665 21.922055555555556
# Bad Request:{"error":"No object found ra=4.61817 dec=21.92206 radius=2.00"}
# 113 36.15179166666666 37.33927777777778
# {'object': 'ZTF18abwjzpq', 'separation': 0.14386873821634075}
# 114 2.9929166666666664 31.92888888888889
# {'object': 'ZTF18acajlmn', 'separation': 0.38161997323073893}
# 115 3.414958333333333 33.35641666666667
# Bad Request:{"error":"No object found ra=3.41496 dec=33.35642 radius=2.00"}
# 116 6.735791666666667 28.825833333333332
# {'object': 'ZTF19aavkbfk', 'separation': 0.06417834160389728}
# 117 8.266416666666666 38.018138888888885
# {'object': 'ZTF19abqkusj', 'separation': 0.5620040108096319}
# 118 355.6769166666666 34.225
# {'object': 'ZTF20abtntaq', 'separation': 0.8363427886244569}
# 119 4.967666666666665 43.65038888888889
# Bad Request:{"error":"No object found ra=4.96767 dec=43.65039 radius=2.00"}
# 120 3.1402916666666663 37.83711111111111
# HTTPSConnectionPool(host='lasair-ztf.lsst.ac.uk', port=443): Max retries exceeded with url: /api/cone/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1400dea70>: Failed to establish a new connection: [Errno 12] Cannot allocate memory'))
# 121 7.732541666666665 23.296111111111113
# {'object': 'ZTF18acdyzuo', 'separation': 0.3028378329140288}
# 122 30.72854166666666 40.617777777777775
# Bad Request:{"error":"No object found ra=30.72854 dec=40.61778 radius=2.00"}
# 123 13.447166666666664 40.930166666666665
# {'object': 'ZTF17aaawcro', 'separation': 0.13607341415045102}
# 124 345.10541666666666 41.52222222222222
# Bad Request:{"error":"No object found ra=345.10542 dec=41.52222 radius=2.00"}
# 125 10.773458333333332 37.058972222222216
# {'object': 'ZTF18abgyipb', 'separation': 0.5304227899807479}
# 126 11.540875 35.261
# Bad Request:{"error":"No object found ra=11.54087 dec=35.26100 radius=2.00"}
# 127 2.2955416666666664 30.052305555555556
# {'object': 'ZTF18abcvkft', 'separation': 0.1394337575355703}
# 128 31.00458333333333 43.692361111111104
# {'object': 'ZTF18aabfwba', 'separation': 0.17768405983895086}
# 129 353.38008333333335 40.366055555555555
# {'object': 'ZTF20abpdvcy', 'separation': 0.2658251360640899}
# 130 14.768041666666663 46.24666666666667
# {'object': 'ZTF20abgbycw', 'separation': 0.18369653778099335}
# 131 33.321583333333336 46.11208333333334
# {'object': 'ZTF20accexlw', 'separation': 0.1539556304734037}
# 132 5.4416666666666655 40.069972222222226
# {'object': 'ZTF17aaaenhs', 'separation': 0.15899676952049335}
# 133 5.451833333333332 35.08088888888889
# {'object': 'ZTF18abvklaz', 'separation': 0.1290173739604257}
# 134 27.171041666666664 36.563916666666664
# {'object': 'ZTF17aaaxiye', 'separation': 0.0737660430361381}
# 135 10.084291666666664 37.43436111111111
# {'object': 'ZTF19adepqtz', 'separation': 0.05912159035457878}
# 136 30.636708333333328 38.803777777777775
# Bad Request:{"error":"No object found ra=30.63671 dec=38.80378 radius=2.00"}
# 137 11.491999999999999 26.029722222222222
# Bad Request:{"error":"No object found ra=11.49200 dec=26.02972 radius=2.00"}
# 138 357.0564583333333 35.830555555555556
# {'object': 'ZTF18ablvioz', 'separation': 0.28021928021524883}
# 139 17.858291666666666 34.85127777777778
# {'object': 'ZTF23aazkytm', 'separation': 0.25693406859112916}
# 140 347.1264166666666 43.71361111111111
# {'object': 'ZTF18abpdjxr', 'separation': 0.0872053613693065}
# 141 9.120624999999999 39.170361111111106
# {'object': 'ZTF18abryewg', 'separation': 0.20013736344491717}
# 142 355.8805833333333 47.72116666666667
# Bad Request:{"error":"No object found ra=355.88058 dec=47.72117 radius=2.00"}
# 143 26.126791666666666 46.55288888888889
# {'object': 'ZTF18adbdhvb', 'separation': 0.050969643129182965}
# 144 35.105124999999994 45.799388888888885
# Bad Request:{"error":"No object found ra=35.10512 dec=45.79939 radius=2.00"}
# 145 38.33083333333333 45.20741666666667
# {'object': 'ZTF18acpsefo', 'separation': 0.06684606028504596}
# 146 348.9045 50.10463888888889
# {'object': 'ZTF18abumcmz', 'separation': 0.18392781280299297}
# 147 34.41145833333333 45.840944444444446
# Bad Request:{"error":"No object found ra=34.41146 dec=45.84094 radius=2.00"}
# 148 33.452 46.499138888888886
# {'object': 'ZTF20abpqbgi', 'separation': 0.038389065925870894}
# 149 345.7224583333333 52.48072222222223
# Bad Request:{"error":"No object found ra=345.72246 dec=52.48072 radius=2.00"}
# 150 8.898791666666666 46.397888888888886
# {'object': 'ZTF17aaakpyj', 'separation': 0.13054598291751152}
# 151 7.177208333333333 31.305416666666666
# {'object': 'ZTF18abmnwus', 'separation': 0.12294340506023133}
# 152 355.8844166666666 45.656749999999995
# {'object': 'ZTF20abmbzpi', 'separation': 0.5363207888324542}
# 153 10.658458333333332 41.14480555555556
# Bad Request:{"error":"No object found ra=10.65846 dec=41.14481 radius=2.00"}
# 154 10.718208333333331 41.27022222222222
# {'object': 'ZTF20aakdppm', 'separation': 0.47293277412912793}
# 155 10.731916666666665 41.236583333333336
# {'object': 'ZTF19abfqlzi', 'separation': 0.37525440963217177}
# 156 10.740541666666665 41.13666666666666
# {'object': 'ZTF20acozbod', 'separation': 0.2668714513951517}
# 157 11.086624999999998 41.386361111111114
# {'object': 'ZTF22aazdzyj', 'separation': 0.050690864503642435}
# 158 10.388208333333331 41.17011111111111
# Bad Request:{"error":"No object found ra=10.38821 dec=41.17011 radius=2.00"}
# 159 10.872833333333332 41.28708333333333
# Bad Request:{"error":"No object found ra=10.87283 dec=41.28708 radius=2.00"}
# 160 11.370041666666665 41.90275
# {'object': 'ZTF18aceikre', 'separation': 0.10354834849678171}
# 161 10.841333333333333 41.34011111111111
# Bad Request:{"error":"No object found ra=10.84133 dec=41.34011 radius=2.00"}
# 162 10.810416666666665 41.565888888888885
# Bad Request:{"error":"No object found ra=10.81042 dec=41.56589 radius=2.00"}
# 163 11.036333333333332 41.72686111111111
# Bad Request:{"error":"No object found ra=11.03633 dec=41.72686 radius=2.00"}
# 164 10.597791666666664 41.13966666666666
# {'object': 'ZTF20abgdyqe', 'separation': 1.25032596725454}
# 165 10.706749999999998 41.28113888888889
# Bad Request:{"error":"No object found ra=10.70675 dec=41.28114 radius=2.00"}
# 166 4.7804166666666665 40.57344444444445
# Bad Request:{"error":"No object found ra=4.78042 dec=40.57344 radius=2.00"}
# 167 5.206249999999999 28.005666666666666
# Bad Request:{"error":"No object found ra=5.20625 dec=28.00567 radius=2.00"}
# 168 6.098624999999999 45.79130555555555
# Bad Request:{"error":"No object found ra=6.09862 dec=45.79131 radius=2.00"}
# 169 9.907874999999999 41.50725
# Bad Request:{"error":"No object found ra=9.90787 dec=41.50725 radius=2.00"}
# 170 14.420791666666664 44.51708333333333
# {'object': 'ZTF23aaixkbd', 'separation': 0.6198134183754649}
# 171 15.21533333333333 37.32702777777778
# Bad Request:{"error":"No object found ra=15.21533 dec=37.32703 radius=2.00"}
# 172 18.915416666666665 38.29730555555555
# {'object': 'ZTF18aabfvvr', 'separation': 0.9619192107194025}
# 173 26.21033333333333 45.54508333333333
# {'object': 'ZTF19aakpkto', 'separation': 0.8141114182505926}
# 174 26.68604166666666 48.44713888888889
# {'object': 'ZTF18acajudm', 'separation': 0.18084594599945358}
# 175 27.10458333333333 43.114444444444445
# {'object': 'ZTF18aboszbk', 'separation': 1.113953076235493}
# 176 33.507041666666666 41.70477777777778
# {'object': 'ZTF19abicwdn', 'separation': 0.09533069998558762}
# 177 33.69862499999999 48.314611111111105
# {'object': 'ZTF18abtrvxg', 'separation': 0.7442519946358398}
# 178 36.86904166666666 48.22977777777778
# {'object': 'ZTF17aaafhrl', 'separation': 0.01683471906199563}
# 179 38.52524999999999 38.69511111111111
# Bad Request:{"error":"No object found ra=38.52525 dec=38.69511 radius=2.00"}
# 180 38.56016666666666 45.718611111111116
# Bad Request:{"error":"No object found ra=38.56017 dec=45.71861 radius=2.00"}
# 181 345.453 41.318083333333334
# {'object': 'ZTF17aabutck', 'separation': 0.17007788207902258}
# 182 347.6044166666666 38.01025
# {'object': 'ZTF18acbxphq', 'separation': 0.23379459171648062}
# 183 349.5995833333333 45.89969444444444
# Bad Request:{"error":"No object found ra=349.59958 dec=45.89969 radius=2.00"}
# 184 349.821125 48.52061111111111
# {'object': 'ZTF19abfqpeh', 'separation': 0.11659384991282254}
# 185 350.0931666666666 44.72522222222222
# {'object': 'ZTF19aaprxbe', 'separation': 0.3922043962056498}
# 186 350.25179166666663 49.77063888888889
# {'object': 'ZTF18abncell', 'separation': 0.15263065994969185}
# 187 358.76379166666663 42.00277777777778
# {'object': 'ZTF19aacbptg', 'separation': 0.06268908214696546}
# 188 359.1374583333333 39.33027777777778
# Bad Request:{"error":"No object found ra=359.13746 dec=39.33028 radius=2.00"}
# 189 345.13899999999995 49.760416666666664
# {'object': 'ZTF18ablwmzw', 'separation': 0.13255671045093254}
# 190 345.5516666666666 47.23166666666667
# {'object': 'ZTF18adlysmz', 'separation': 0.06491015934601692}
# 191 349.8771666666666 51.838166666666666
# {'object': 'ZTF17aabpjjg', 'separation': 0.1612973431563068}
# 192 351.61199999999997 49.105000000000004
# {'object': 'ZTF18abmrryd', 'separation': 0.12428082410955378}
# 193 353.0725833333333 46.569944444444445
# {'object': 'ZTF18abmrscy', 'separation': 0.07622243239935735}
# 194 359.0978333333333 41.46563888888889
# {'object': 'ZTF18abnyxce', 'separation': 0.06705771060975486}
# 195 349.5300833333333 52.556888888888885
# {'object': 'ZTF17aaawqgg', 'separation': 0.2828700394846955}
# 196 36.81620833333333 43.627833333333335
# {'object': 'ZTF18aaadsir', 'separation': 0.2926369421798144}
# 197 3.616916666666666 40.71808333333333
# {'object': 'ZTF18abvzqzi', 'separation': 0.24236539139238458}
# 198 8.972375 43.561527777777776
# {'object': 'ZTF18abgjgiq', 'separation': 0.36830477010696466}
# 199 15.412749999999997 36.07416666666667
# {'object': 'ZTF18abumskz', 'separation': 0.2379796599535781}
# 200 23.722999999999995 47.67944444444444
# Bad Request:{"error":"No object found ra=23.72300 dec=47.67944 radius=2.00"}
# 201 36.602125 39.26875
# {'object': 'ZTF18abnvefg', 'separation': 0.08876224361696693}
# 202 352.6197083333333 45.522666666666666
# {'object': 'ZTF19adejevd', 'separation': 0.013745490554998244}
# 203 346.023875 47.36977777777778
# {'object': 'ZTF18admepgd', 'separation': 0.09533069998558762}
# 204 347.99499999999995 43.71052777777778
# {'object': 'ZTF18abwiiqj', 'separation': 0.29678802812881633}
# 205 353.6381666666666 40.43061111111111
# {'object': 'ZTF18abumlux', 'separation': 0.8024824107240528}
# 206 353.90920833333325 37.53977777777778
# {'object': 'ZTF18abtbrvv', 'separation': 0.1585207302199773}
# 207 27.802791666666664 36.135416666666664
# {'object': 'ZTF17aaaaznz', 'separation': 0.10175377329979327}
# 208 346.3704166666666 52.6545
# {'object': 'ZTF18abdgqzr', 'separation': 0.06691668477414191}
# 209 27.01825 43.458333333333336
# {'object': 'ZTF18aabflzr', 'separation': 0.06131783069296557}
# 210 27.233166666666662 44.946666666666665
# {'object': 'ZTF18admgvhl', 'separation': 0.06373521772024685}
# 211 27.354291666666665 45.100861111111115
# {'object': 'ZTF17aaaewmp', 'separation': 0.04281008704495006}
# 212 21.308666666666667 48.09777777777778
# {'object': 'ZTF18aaadwtg', 'separation': 0.1755983055998017}
# 213 36.36012499999999 38.54725
# Bad Request:{"error":"No object found ra=36.36012 dec=38.54725 radius=2.00"}
# 214 355.8534166666666 42.14475
# {'object': 'ZTF18admjqhq', 'separation': 0.3165345039168688}
# 215 357.5702916666666 46.98938888888889
# {'object': 'ZTF18abgtzzh', 'separation': 0.11752193465341257}
# 216 355.15654166666667 42.59102777777778
# {'object': 'ZTF19abzpkss', 'separation': 0.1223271435100406}
# 217 10.64333333333333 40.74055555555556
# Bad Request:{"error":"No object found ra=10.64333 dec=40.74056 radius=2.00"}
# 218 12.432999999999998 40.56055555555555
# {'object': 'ZTF18abxzyss', 'separation': 0.030581785877509732}
# 219 34.806999999999995 42.41730555555555
# Bad Request:{"error":"No object found ra=34.80700 dec=42.41731 radius=2.00"}
# 220 22.858624999999996 36.04436111111111
# Bad Request:{"error":"No object found ra=22.85862 dec=36.04436 radius=2.00"}
# 221 3.1314166666666665 28.003083333333333
# HTTPSConnectionPool(host='lasair-ztf.lsst.ac.uk', port=443): Max retries exceeded with url: /api/cone/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1405f66b0>: Failed to establish a new connection: [Errno 12] Cannot allocate memory'))
# 222 4.802416666666666 22.12586111111111
# Bad Request:{"error":"No object found ra=4.80242 dec=22.12586 radius=2.00"}
# 223 7.2956666666666665 32.6905
# Bad Request:{"error":"No object found ra=7.29567 dec=32.69050 radius=2.00"}
# 224 12.207791666666667 33.475833333333334
# {'object': 'ZTF19abpegku', 'separation': 0.1611508556652244}
# 225 13.591249999999999 33.804361111111106
# Bad Request:{"error":"No object found ra=13.59125 dec=33.80436 radius=2.00"}
# 226 353.80045833333327 49.904694444444445
# Bad Request:{"error":"No object found ra=353.80046 dec=49.90469 radius=2.00"}
# 227 356.10887499999995 47.011916666666664
# Bad Request:{"error":"No object found ra=356.10887 dec=47.01192 radius=2.00"}
# 228 16.952083333333334 47.199777777777776
# Bad Request:{"error":"No object found ra=16.95208 dec=47.19978 radius=2.00"}
# 229 0.12229166666666666 38.19594444444444
# {'object': 'ZTF22abdsaqa', 'separation': 0.2755962286756202}
# 230 3.329333333333333 42.29494444444444
# {'object': 'ZTF18adaabii', 'separation': 0.11301435004633005}
# 231 14.790541666666664 34.64325
# {'object': 'ZTF19acyfeuy', 'separation': 0.16425717431312087}
# 232 24.233041666666665 41.01261111111111
# {'object': 'ZTF18achmbdv', 'separation': 0.04517229144568054}
# 233 24.495583333333332 49.8515
# {'object': 'ZTF22abcqztw', 'separation': 0.3184981732127243}
# 234 26.30733333333333 41.83491666666667
# Bad Request:{"error":"No object found ra=26.30733 dec=41.83492 radius=2.00"}
# 235 29.966916666666663 41.5545
# {'object': 'ZTF22abeuaan', 'separation': 0.03394885733931309}
# 236 31.061875 40.89275
# {'object': 'ZTF20abfxibv', 'separation': 0.5694682252679545}
# 237 34.926249999999996 37.59838888888889
# {'object': 'ZTF22abqxowa', 'separation': 0.18472221039690667}
# 238 21.715083333333332 50.21630555555556
# {'object': 'ZTF21achratu', 'separation': 0.045588634730303265}
# 239 34.83245833333332 46.395833333333336
# Bad Request:{"error":"No object found ra=34.83246 dec=46.39583 radius=2.00"}
# 240 21.39683333333333 36.77386111111111
# {'object': 'ZTF17aabulce', 'separation': 0.021733528855063206}
# 241 8.573749999999999 43.76091666666667
# {'object': 'ZTF17aabumcd', 'separation': 0.18876917941946889}
# 242 32.51008333333333 43.801138888888886
# {'object': 'ZTF19aabgcjq', 'separation': 0.3081719363470238}
# 243 347.5465416666666 51.25311111111111
# {'object': 'ZTF18aazndjw', 'separation': 0.1541089575012193}
# 244 345.9765 52.33741666666667
# {'object': 'ZTF18aazwdho', 'separation': 0.19258408457165133}
# 245 347.4847916666666 51.861805555555556
# {'object': 'ZTF18abcjxhg', 'separation': 0.17394971248093155}
# 246 347.04624999999993 52.85988888888889
# {'object': 'ZTF18abcpdil', 'separation': 0.31044731317218116}
# 247 348.5143333333333 52.37127777777778
# {'object': 'ZTF18abhqaxd', 'separation': 0.05394120005341208}
# 248 1.9137916666666666 45.680749999999996
# {'object': 'ZTF18abiuzar', 'separation': 0.17107476520972206}
# 249 5.198291666666666 33.10180555555556
# {'object': 'ZTF18abmjoue', 'separation': 0.5929072379538268}
# 250 2.4555416666666665 29.862250000000003
# {'object': 'ZTF18abmneqb', 'separation': 0.7091127922304066}
# 251 350.65283333333326 48.475
# {'object': 'ZTF18abmrryp', 'separation': 0.16605895224802938}
# 252 21.544749999999997 50.28780555555555
# {'object': 'ZTF18abmrusw', 'separation': 0.13094338408918513}
# 253 4.626416666666666 43.95461111111111
# {'object': 'ZTF18abnndda', 'separation': 0.14880723585240516}
# 254 11.316083333333331 42.17425
# {'object': 'ZTF18abnuzzt', 'separation': 0.10091474481565083}
# 255 9.147833333333331 45.93311111111111
# {'object': 'ZTF18adnhalc', 'separation': 0.12045944385514959}
# 256 345.18137499999995 38.804249999999996
# {'object': 'ZTF18abtbrfb', 'separation': 0.22151146968540336}
# 257 30.46458333333333 42.15266666666667
# {'object': 'ZTF18abtrvrj', 'separation': 0.012294340506022955}
# 258 355.5127916666666 40.14094444444444
# {'object': 'ZTF18abuurtt', 'separation': 0.4347466377976084}
# 259 31.91 40.896
# {'object': 'ZTF18abwjyqu', 'separation': 0.03851191125081615}
# 260 17.618166666666667 34.83244444444445
# {'object': 'ZTF18abwxaix', 'separation': 0.10673796039381804}
# 261 37.91258333333333 49.235083333333336
# {'object': 'ZTF18abzsdju', 'separation': 0.08715117971675114}
# 262 11.838999999999999 34.01247222222222
# {'object': 'ZTF18acayqvh', 'separation': 0.006147170253011476}
# 263 9.063499999999998 38.85883333333334
# {'object': 'ZTF18accbuhi', 'separation': 0.06570574531313042}
# 264 351.28075 36.60813888888889
# {'object': 'ZTF18accqjow', 'separation': 0.044646402842828406}
# 265 353.17674999999997 44.45747222222222
# {'object': 'ZTF18acfqtql', 'separation': 0.08790668395201665}
# 266 30.63591666666666 43.287055555555554
# {'object': 'ZTF18acmwtvp', 'separation': 0.10892813440762747}
# 267 35.91524999999999 47.17338888888889
# {'object': 'ZTF18acmwuum', 'separation': 0.05206983413719308}
# 268 349.501 50.451638888888894
# {'object': 'ZTF19aaprxdz', 'separation': 0.17110237349929255}
# 269 345.73758333333336 51.21380555555556
# {'object': 'ZTF19aavantx', 'separation': 0.28914579529958195}
# 270 25.763958333333335 36.84436111111111
# {'object': 'ZTF19aawteif', 'separation': 0.14044636167015703}
# 271 38.057624999999994 48.34280555555556
# {'object': 'ZTF19aaywash', 'separation': 0.14817103270017312}
# 272 350.339 45.387027777777774
# {'object': 'ZTF19abctpiu', 'separation': 0.10377617792181568}
# 273 10.334375 41.82775
# {'object': 'ZTF19abfvpjh', 'separation': 0.02783249707536029}
# 274 346.2257916666666 48.700833333333335
# {'object': 'ZTF19abpnpcy', 'separation': 0.05498196221999314}
# 275 13.685291666666664 46.64925
# {'object': 'ZTF19adffwii', 'separation': 0.22652968785194275}
# 276 351.8348333333333 41.584
# {'object': 'ZTF19acmdxbp', 'separation': 0.08310055693158978}
# 277 1.4344999999999999 36.82930555555556
# {'object': 'ZTF19aczlxwf', 'separation': 0.6826127414838467}
# 278 35.49012499999999 46.00747222222222
# {'object': 'ZTF20abzcokk', 'separation': 0.0696151764834874}
# 279 33.581833333333336 43.98738888888889
# {'object': 'ZTF21abujmgh', 'separation': 0.08131941878121234}
# 280 7.889708333333332 25.043750000000003
# {'object': 'ZTF22aajuldx', 'separation': 0.13333834349964635}
# 281 354.039125 48.564611111111105
# {'object': 'ZTF22abnabxg', 'separation': 0.06563381781996291}
# 282 153.44129166666664 -27.96611111111111
# Bad Request:{"error":"No object found ra=153.44129 dec=-27.96611 radius=2.00"}
# 283 144.05683333333332 -27.903055555555554
# {'object': 'ZTF19aanwfuw', 'separation': 1.1601878025572347}
# 284 143.26908333333333 -30.664805555555553
# Bad Request:{"error":"No object found ra=143.26908 dec=-30.66481 radius=2.00"}
# 285 145.8750833333333 -28.477416666666667
# Bad Request:{"error":"No object found ra=145.87508 dec=-28.47742 radius=2.00"}
# 286 149.63679166666665 -27.830861111111112
# {'object': 'ZTF21aarayzx', 'separation': 0.05506780452397416}
# 287 149.22345833333333 -30.56041666666667
# Bad Request:{"error":"No object found ra=149.22346 dec=-30.56042 radius=2.00"}
# 288 143.20183333333333 -25.669305555555557
# Bad Request:{"error":"No object found ra=143.20183 dec=-25.66931 radius=2.00"}
# 289 144.41766666666666 -28.996555555555556
# Bad Request:{"error":"No object found ra=144.41767 dec=-28.99656 radius=2.00"}
# 290 154.19933333333333 -28.802833333333336
# Bad Request:{"error":"No object found ra=154.19933 dec=-28.80283 radius=2.00"}
# 291 145.08949999999996 -28.472388888888887
# Bad Request:{"error":"No object found ra=145.08950 dec=-28.47239 radius=2.00"}
# 292 149.5135 -29.594555555555555
# Bad Request:{"error":"No object found ra=149.51350 dec=-29.59456 radius=2.00"}
# 293 146.5915 -29.093666666666664
# Bad Request:{"error":"No object found ra=146.59150 dec=-29.09367 radius=2.00"}
# 294 142.927125 -30.21697222222222
# Bad Request:{"error":"No object found ra=142.92712 dec=-30.21697 radius=2.00"}
# 295 147.6894583333333 -30.022666666666666
# Bad Request:{"error":"No object found ra=147.68946 dec=-30.02267 radius=2.00"}
# 296 151.52520833333332 -30.76975
# Bad Request:{"error":"No object found ra=151.52521 dec=-30.76975 radius=2.00"}
# 297 144.23637499999998 -25.927472222222224
# Bad Request:{"error":"No object found ra=144.23637 dec=-25.92747 radius=2.00"}
# 298 149.744125 -28.36491666666667
# Bad Request:{"error":"No object found ra=149.74412 dec=-28.36492 radius=2.00"}
# 299 145.49379166666665 -25.118083333333335
# Bad Request:{"error":"No object found ra=145.49379 dec=-25.11808 radius=2.00"}
# 300 155.0775 -30.009722222222223
# Bad Request:{"error":"No object found ra=155.07750 dec=-30.00972 radius=2.00"}
# 301 145.86362499999998 -27.343888888888888
# {'object': 'ZTF19aapkrcg', 'separation': 0.7188641876848997}
# 302 332.27399999999994 -3.771583333333333
# {'object': 'ZTF18achfxrt', 'separation': 0.35037522352584366}
# 303 318.0385416666666 -8.826888888888888
# {'object': 'ZTF18abskpen', 'separation': 0.18087206282333146}
# 304 322.6025833333333 -2.9882222222222223
# {'object': 'ZTF18abvbbvs', 'separation': 0.11667484599755658}
# 305 351.3299583333333 -8.305305555555556
# {'object': 'ZTF19abxierc', 'separation': 0.5290228433846389}
# 306 353.5249999999999 -22.812
# {'object': 'ZTF18accqmuj', 'separation': 0.13209266237639378}
# 307 334.48074999999994 -8.351055555555556
# {'object': 'ZTF18abxehba', 'separation': 0.14585772620360074}
# 308 335.1122083333333 2.0148055555555557
# {'object': 'ZTF19actbity', 'separation': 0.2130994392815809}
# 309 316.99245833333333 -5.294611111111111
# {'object': 'ZTF18abrymfz', 'separation': 1.27221179729947}
# 310 334.1149166666666 -20.456694444444445
# {'object': 'ZTF18acxhody', 'separation': 1.5042773723479745}
# 311 311.91416666666663 0.14452777777777778
# {'object': 'ZTF22abvnhig', 'separation': 0.0915907739378327}
# 312 312.5744166666666 -5.6074722222222215
# Bad Request:{"error":"No object found ra=312.57442 dec=-5.60747 radius=2.00"}
# 313 314.8119583333333 -6.205694444444444
# {'object': 'ZTF18abvceiu', 'separation': 0.08178278104315855}
# 314 315.05883333333327 0.7461111111111111
# {'object': 'ZTF18abmefme', 'separation': 0.25878418630455163}
# 315 316.20808333333326 1.0960555555555556
# Bad Request:{"error":"No object found ra=316.20808 dec=1.09606 radius=2.00"}
# 316 322.84324999999995 -0.6602777777777779
# Bad Request:{"error":"No object found ra=322.84325 dec=-0.66028 radius=2.00"}
# 317 333.832625 -0.5490833333333334
# {'object': 'ZTF18accgkmi', 'separation': 0.5338667841667593}
# 318 339.6826249999999 1.1390833333333332
# {'object': 'ZTF18abvpodm', 'separation': 0.20773433953124631}
# 319 349.0150833333333 -5.452472222222222
# {'object': 'ZTF18absgnqy', 'separation': 0.15699372187272664}
# 320 311.2038333333333 -4.991333333333333
# {'object': 'ZTF18abvcedz', 'separation': 0.053677856576176644}
# 321 326.72229166666665 -2.3056666666666663
# {'object': 'ZTF19abisjkc', 'separation': 0.46469110574878286}
# 322 313.2196666666666 -2.6646944444444443
# Bad Request:{"error":"No object found ra=313.21967 dec=-2.66469 radius=2.00"}
# 323 316.8863333333333 -9.949805555555557
# {'object': 'ZTF18acavnti', 'separation': 0.17143332617507587}
# 324 316.59825 -4.548055555555555
# Bad Request:{"error":"No object found ra=316.59825 dec=-4.54806 radius=2.00"}
# 325 318.78324999999995 1.954222222222222
# {'object': 'ZTF18abtpmlk', 'separation': 0.19608413221523938}
# 326 311.2327916666666 -11.864694444444444
# {'object': 'ZTF21abnddcs', 'separation': 0.7256134973129456}
# 327 341.5772083333333 -6.490444444444445
# Bad Request:{"error":"No object found ra=341.57721 dec=-6.49044 radius=2.00"}
# 328 319.14912499999997 -7.819611111111111
# Bad Request:{"error":"No object found ra=319.14912 dec=-7.81961 radius=2.00"}
# 329 340.74183333333326 -19.764305555555556
# {'object': 'ZTF19aazdbyq', 'separation': 0.7719656444923019}
# 330 354.92083333333323 -18.001833333333334
# Bad Request:{"error":"No object found ra=354.92083 dec=-18.00183 radius=2.00"}
# 331 323.7664166666666 -0.6915277777777777
# Bad Request:{"error":"No object found ra=323.76642 dec=-0.69153 radius=2.00"}
# 332 333.52095833333334 -9.072055555555556
# {'object': 'ZTF23aaqurnk', 'separation': 0.2718516110311667}
# 333 315.7915 -7.22025
# Bad Request:{"error":"No object found ra=315.79150 dec=-7.22025 radius=2.00"}
# 334 310.33 -1.71275
# Bad Request:{"error":"No object found ra=310.33000 dec=-1.71275 radius=2.00"}
# 335 318.0109583333333 -6.276888888888889
# {'object': 'ZTF18abmmszc', 'separation': 0.3010701753066696}
# 336 354.150875 -5.66313888888889
# Bad Request:{"error":"No object found ra=354.15087 dec=-5.66314 radius=2.00"}
# 337 319.7045 -3.1145
# Bad Request:{"error":"No object found ra=319.70450 dec=-3.11450 radius=2.00"}
# 338 327.95691666666664 -3.4924166666666667
# {'object': 'ZTF18acswton', 'separation': 0.04671444955687334}
# 339 330.19795833333325 2.1313055555555556
# Bad Request:{"error":"No object found ra=330.19796 dec=2.13131 radius=2.00"}
# 340 319.425625 -2.3745833333333333
# {'object': 'ZTF18admohws', 'separation': 0.37599633050689846}
# 341 332.239625 -9.08075
# {'object': 'ZTF19actbcij', 'separation': 0.10901482613198037}
# 342 351.9745416666666 -5.805638888888889
# {'object': 'ZTF19acxgtsx', 'separation': 1.908023124741742}
# 343 320.24320833333326 -5.937444444444445
# Bad Request:{"error":"No object found ra=320.24321 dec=-5.93744 radius=2.00"}
# 344 311.3424999999999 -1.8933333333333333
# {'object': 'ZTF20abewxfh', 'separation': 0.09086590621962061}
# 345 312.1209583333333 -6.069166666666667
# {'object': 'ZTF20abyfgpv', 'separation': 0.06691668477414191}
# 346 319.1438333333333 -1.886861111111111
# {'object': 'ZTF21aaxwqem', 'separation': 0.09878600139879855}
# 347 330.09124999999995 -7.3573055555555555
# {'object': 'ZTF21abiplqz', 'separation': 0.11724025181639552}
# 348 315.6275833333333 -2.2889166666666667
# {'object': 'ZTF21ackmlco', 'separation': 0.10142830917469038}
# 349 314.42075 -0.7775555555555556
# Bad Request:{"error":"No object found ra=314.42075 dec=-0.77756 radius=2.00"}
# 350 324.8651249999999 1.4832222222222224
# {'object': 'ZTF19abffmdf', 'separation': 0.17924562401106114}
# 351 320.47341666666665 -9.697333333333333
# {'object': 'ZTF22abtegkn', 'separation': 0.03238222867278257}
# 352 323.4994583333333 -4.002194444444444
# {'object': 'ZTF23aajadma', 'separation': 0.08660749892891886}
# 353 323.65983333333327 -5.888166666666666
# {'object': 'ZTF18acswsyt', 'separation': 0.052431434552130146}
# 354 321.47945833333335 -3.401638888888889
# Bad Request:{"error":"No object found ra=321.47946 dec=-3.40164 radius=2.00"}
# 355 314.4065 -14.4685
# {'object': 'ZTF18abntqth', 'separation': 0.24378393816751948}
# 356 310.2921666666666 -4.634055555555555
# Bad Request:{"error":"No object found ra=310.29217 dec=-4.63406 radius=2.00"}
# 357 321.34079166666663 -10.44111111111111
# {'object': 'ZTF18absuuph', 'separation': 0.5113987547591966}
# 358 342.0979166666666 -9.349777777777778
# Bad Request:{"error":"No object found ra=342.09792 dec=-9.34978 radius=2.00"}
# 359 312.3184999999999 -3.292611111111111
# {'object': 'ZTF18adhmijj', 'separation': 0.5096686289101656}
# 360 323.6345833333333 -1.344472222222222
# {'object': 'ZTF18abtjakn', 'separation': 0.8384523899615987}
# 361 316.768875 1.7377500000000001
# Bad Request:{"error":"No object found ra=316.76887 dec=1.73775 radius=2.00"}
# 362 314.88716666666664 -9.271194444444445
# {'object': 'ZTF18abvwpum', 'separation': 0.20759786672146666}
# 363 317.1567083333333 -10.86336111111111
# Bad Request:{"error":"No object found ra=317.15671 dec=-10.86336 radius=2.00"}
# 364 317.7417083333333 -12.911333333333333
# Bad Request:{"error":"No object found ra=317.74171 dec=-12.91133 radius=2.00"}
# 365 315.18308333333334 -0.8699166666666667
# {'object': 'ZTF18adoyjth', 'separation': 0.6427027452829333}
# 366 337.51237499999996 -14.97638888888889
# Bad Request:{"error":"No object found ra=337.51237 dec=-14.97639 radius=2.00"}
# 367 329.12674999999996 -3.3326388888888885
# {'object': 'ZTF18abudxrk', 'separation': 0.043139823010599314}
# 368 318.96220833333325 -0.12127777777777778
# {'object': 'ZTF19acopfng', 'separation': 0.06907023521451247}
# 369 338.5769583333333 -3.9250833333333333
# {'object': 'ZTF19abjoabu', 'separation': 0.4741297711693066}
# 370 332.86966666666666 -3.0875000000000004
# {'object': 'ZTF18aceihff', 'separation': 0.7888402782907169}
# 371 341.2724583333333 1.26325
# {'object': 'ZTF18actxlqb', 'separation': 0.6678031247975011}
# 372 328.10699999999997 -1.4806111111111113
# {'object': 'ZTF19acpnbji', 'separation': 0.38398908014469285}
# 373 317.1934999999999 -3.8421944444444445
# {'object': 'ZTF18abtjmpx', 'separation': 0.29069356522765755}
# 374 325.304625 -3.5130833333333333
# {'object': 'ZTF19abhiady', 'separation': 1.1772673632153656}
# 375 310.74499999999995 -0.5648333333333334
# {'object': 'ZTF19aavhqxe', 'separation': 0.5211789037947586}
# 376 311.3447083333333 -1.1678333333333335
# Bad Request:{"error":"No object found ra=311.34471 dec=-1.16783 radius=2.00"}
# 377 353.30412499999994 -15.962305555555554
# {'object': 'ZTF19actspxg', 'separation': 0.43900652356781605}
# 378 338.05899999999997 -16.19377777777778
# Bad Request:{"error":"No object found ra=338.05900 dec=-16.19378 radius=2.00"}
# 379 323.60004166666664 -7.986277777777778
# Bad Request:{"error":"No object found ra=323.60004 dec=-7.98628 radius=2.00"}
# 380 309.9070833333333 -4.4855
# Bad Request:{"error":"No object found ra=309.90708 dec=-4.48550 radius=2.00"}
# 381 310.89962499999996 -5.8878611111111105
# Bad Request:{"error":"No object found ra=310.89962 dec=-5.88786 radius=2.00"}
# 382 312.94262499999996 -3.9740833333333336
# Bad Request:{"error":"No object found ra=312.94262 dec=-3.97408 radius=2.00"}
# 383 349.74075 -6.046333333333333
# {'object': 'ZTF18abxqdlm', 'separation': 1.1078473139352503}
# 384 333.0008333333333 -13.999888888888888
# Bad Request:{"error":"No object found ra=333.00083 dec=-13.99989 radius=2.00"}
# 385 312.0378333333333 0.9776666666666667
# Bad Request:{"error":"No object found ra=312.03783 dec=0.97767 radius=2.00"}
# 386 334.35041666666666 -19.664749999999998
# {'object': 'ZTF19aazcclj', 'separation': 0.6480018463537439}
# 387 315.06674999999996 -2.716111111111111
# Bad Request:{"error":"No object found ra=315.06675 dec=-2.71611 radius=2.00"}
# 388 314.5333333333333 -0.8323333333333334
# {'object': 'ZTF20acqjfjn', 'separation': 0.6443102478505718}
# 389 332.81624999999997 -18.14388888888889
# {'object': 'ZTF19abcezre', 'separation': 0.1401770491276854}
# 390 333.25683333333325 -21.923583333333333
# {'object': 'ZTF19aboyaow', 'separation': 0.12143578859685014}
# 391 331.2160416666666 -2.1332222222222224
# {'object': 'ZTF22acajswb', 'separation': 0.37425868704885}
# 392 310.69516666666664 -9.897416666666667
# Bad Request:{"error":"No object found ra=310.69517 dec=-9.89742 radius=2.00"}
# 393 322.0255416666666 2.5390277777777777
# {'object': 'ZTF20acnwkbh', 'separation': 0.2082793365487806}
# 394 332.3991666666666 -0.22577777777777777
# Bad Request:{"error":"No object found ra=332.39917 dec=-0.22578 radius=2.00"}
# 395 310.82574999999997 -7.164472222222223
# Bad Request:{"error":"No object found ra=310.82575 dec=-7.16447 radius=2.00"}
# 396 314.27212499999996 -7.407166666666667
# {'object': 'ZTF19aawflnr', 'separation': 0.30734314434075233}
# 397 334.00858333333326 -12.18211111111111
# {'object': 'ZTF19abdbsrm', 'separation': 0.23500367368972896}
# 398 357.3399166666666 -17.67463888888889
# {'object': 'ZTF23aazneeg', 'separation': 0.19246141172362724}
# 399 311.2733333333333 -7.838527777777777
# Bad Request:{"error":"No object found ra=311.27333 dec=-7.83853 radius=2.00"}
# 400 340.64995833333325 -11.470305555555555
# {'object': 'ZTF18abvpkml', 'separation': 0.10691482540392508}
# 401 332.0313333333333 2.2720277777777778
# Bad Request:{"error":"No object found ra=332.03133 dec=2.27203 radius=2.00"}
# 402 345.3110833333333 -6.721611111111112
# Bad Request:{"error":"No object found ra=345.31108 dec=-6.72161 radius=2.00"}
# 403 313.31920833333334 -10.942527777777778
# Bad Request:{"error":"No object found ra=313.31921 dec=-10.94253 radius=2.00"}
# 404 330.7632083333333 -13.751472222222223
# {'object': 'ZTF19abcefyc', 'separation': 0.46118118064351454}
# 405 336.90145833333327 -17.95411111111111
# Bad Request:{"error":"No object found ra=336.90146 dec=-17.95411 radius=2.00"}
# 406 337.07433333333324 -14.949111111111112
# Bad Request:{"error":"No object found ra=337.07433 dec=-14.94911 radius=2.00"}
# 407 315.544125 2.1113055555555555
# {'object': 'ZTF19abjfnky', 'separation': 0.21850574735691577}
# 408 332.30841666666663 -10.901833333333334
# {'object': 'ZTF18abvbppu', 'separation': 0.233309204497291}
# 409 354.91145833333326 -5.551472222222222
# {'object': 'ZTF18accqcwt', 'separation': 0.1375579580989225}
# 410 353.8005833333333 -3.597805555555556
# Bad Request:{"error":"No object found ra=353.80058 dec=-3.59781 radius=2.00"}
# 411 330.8425833333333 -13.215027777777777
# HTTPSConnectionPool(host='lasair-ztf.lsst.ac.uk', port=443): Max retries exceeded with url: /api/cone/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1404c2920>: Failed to establish a new connection: [Errno 12] Cannot allocate memory'))
# 412 317.0859583333333 -13.81925
# {'object': 'ZTF18acbdbhx', 'separation': 0.18074144096558975}
# 413 330.4266666666666 -5.657888888888889
# Bad Request:{"error":"No object found ra=330.42667 dec=-5.65789 radius=2.00"}
# 414 315.16570833333327 -2.8266388888888887
# {'object': 'ZTF21ackmkwt', 'separation': 0.10788240010682507}
# 415 320.8067083333333 -2.246638888888889
# Bad Request:{"error":"No object found ra=320.80671 dec=-2.24664 radius=2.00"}
# 416 327.2106666666666 -2.1064722222222225
# {'object': 'ZTF19acgkbla', 'separation': 0.08550976762993295}
# 417 311.68033333333324 -0.10836111111111112
# {'object': 'ZTF18abvvtdv', 'separation': 0.18708516533439462}
# 418 311.8365 0.002138888888888889
# {'object': 'ZTF19aatvkpb', 'separation': 0.10966282961666672}
# 419 312.074375 -6.179083333333334
# {'object': 'ZTF18accwxfq', 'separation': 0.6158762107358791}
# 420 312.11629166666665 0.8358055555555556
# {'object': 'ZTF18abwvggo', 'separation': 0.3596882610423953}
# 421 314.8827083333333 -7.088027777777778
# {'object': 'ZTF19aazijkf', 'separation': 0.14595484599654163}
# 422 316.1377916666666 -6.9214722222222225
# Bad Request:{"error":"No object found ra=316.13779 dec=-6.92147 radius=2.00"}
# 423 319.21779166666664 1.6956666666666667
# Bad Request:{"error":"No object found ra=319.21779 dec=1.69567 radius=2.00"}
# 424 334.5585833333333 -0.9802222222222222
# {'object': 'ZTF19abqkqvy', 'separation': 0.7799157909790414}
# 425 338.66637499999996 0.6909166666666667
# {'object': 'ZTF18abvpojw', 'separation': 0.11923767409030472}
# 426 344.4565416666666 -8.374416666666667
# Bad Request:{"error":"No object found ra=344.45654 dec=-8.37442 radius=2.00"}
# 427 344.6299166666666 -9.825472222222222
# Bad Request:{"error":"No object found ra=344.62992 dec=-9.82547 radius=2.00"}
# 428 357.90891666666664 -8.584138888888889
# {'object': 'ZTF20acmzfky', 'separation': 0.10775096972287282}
# 429 354.5936666666666 -20.831166666666668
# Bad Request:{"error":"No object found ra=354.59367 dec=-20.83117 radius=2.00"}
# 430 311.85129166666667 -10.982277777777778
# {'object': 'ZTF18abskpyo', 'separation': 0.09251440174410128}
# 431 323.5876666666666 -2.2771666666666666
# {'object': 'ZTF18acswtgb', 'separation': 0.6531205672587839}
# 432 343.15437499999996 -5.3213888888888885
# {'object': 'ZTF18acxhphf', 'separation': 0.10063351413931969}
# 433 319.5922083333333 -9.462694444444443
# {'object': 'ZTF21abwrujq', 'separation': 0.09542974489540394}
# 434 313.61299999999994 -13.267027777777779
# {'object': 'ZTF22abfokjh', 'separation': 0.11192239835090023}
# 435 299.3282083333333 -9.322527777777777
# {'object': 'ZTF18abobptn', 'separation': 1.7017255944689027}
# 436 283.0148333333333 -1.4775555555555557
# {'object': 'ZTF18abnpmfj', 'separation': 0.22327432906889977}
# 437 289.99249999999995 -7.182
# {'object': 'ZTF18abctavz', 'separation': 0.2055628806354509}
# 438 291.5450833333333 -10.25838888888889
# {'object': 'ZTF18abnowur', 'separation': 0.20322883264100808}
# 439 292.85749999999996 -6.427388888888889
# Bad Request:{"error":"No object found ra=292.85750 dec=-6.42739 radius=2.00"}
# 440 284.0084583333333 -3.322333333333333
# Bad Request:{"error":"No object found ra=284.00846 dec=-3.32233 radius=2.00"}
# 441 289.1588333333333 0.12705555555555556
# {'object': 'ZTF18abnozzo', 'separation': 0.9484338680324373}
# 442 293.4735 14.296138888888889
# {'object': 'ZTF18abacgon', 'separation': 0.977632011398223}
# 443 298.27779166666664 12.983527777777777
# {'object': 'ZTF18abmfybu', 'separation': 0.06670458698299724}
# 444 289.30699999999996 1.7226944444444445
# {'object': 'ZTF19aaoocmr', 'separation': 0.0851222173196633}
# 445 291.6435833333333 7.603833333333333
# {'object': 'ZTF18ababqov', 'separation': 0.12252005822303325}
# ...
# Bad Request:{"error":"No object found ra=134.00929 dec=-10.44411 radius=2.00"}
# 4356 157.18279166666665 -16.21758333333333
# {'object': 'ZTF18adakztt', 'separation': 0.23150034239931372}
# 4357 192.03508333333332 -26.66622222222222
# Bad Request:{"error":"No object found ra=192.03508 dec=-26.66622 radius=2.00"}
# 4358 127.77683333333333 -5.711638888888889
# {'object': 'ZTF18acwwlsk', 'separation': 0.12163011707545245}
# 4359 151.72833333333332 -14.427166666666666
# {'object': 'ZTF22abxlizh', 'separation': 0.1780027758974854}
# 4360 149.44870833333331 -13.328083333333334
# Bad Request:{"error":"No object found ra=149.44871 dec=-13.32808 radius=2.00"}
# 4361 159.70554166666665 -20.360166666666668
# Bad Request:{"error":"No object found ra=159.70554 dec=-20.36017 radius=2.00"}
# 4362 133.11975 2.0174166666666666
# Bad Request:{"error":"No object found ra=133.11975 dec=2.01742 radius=2.00"}
# 4363 144.7123333333333 -10.73786111111111
# Bad Request:{"error":"No object found ra=144.71233 dec=-10.73786 radius=2.00"}
# 4364 143.08499999999998 -16.125222222222224
# Bad Request:{"error":"No object found ra=143.08500 dec=-16.12522 radius=2.00"}
# 4365 208.16195833333333 -24.602083333333336
# {'object': 'ZTF20adcaqqn', 'separation': 0.24166276838956413}
# 4366 161.91029166666664 -17.36025
# Bad Request:{"error":"No object found ra=161.91029 dec=-17.36025 radius=2.00"}
# 4367 165.66641666666663 -27.07336111111111
# {'object': 'ZTF20aayhujl', 'separation': 0.16135590091578042}
# 4368 135.00841666666665 -15.472222222222223
# {'object': 'ZTF18aczddtb', 'separation': 0.0718851046103637}
# 4369 192.5143333333333 -22.792333333333335
# Bad Request:{"error":"No object found ra=192.51433 dec=-22.79233 radius=2.00"}
# 4370 139.43762499999997 -19.102305555555557
# {'object': 'ZTF21aamofzb', 'separation': 0.1179632201387773}
# 4371 146.1070833333333 -18.548333333333336
# Bad Request:{"error":"No object found ra=146.10708 dec=-18.54833 radius=2.00"}
# 4372 130.634 -13.230611111111111
# {'object': 'ZTF20aaqwhhx', 'separation': 0.188593941100955}
# 4373 212.07108333333332 -27.189
# Bad Request:{"error":"No object found ra=212.07108 dec=-27.18900 radius=2.00"}
# 4374 128.31904166666666 -11.636805555555554
# Bad Request:{"error":"No object found ra=128.31904 dec=-11.63681 radius=2.00"}
# 4375 137.35841666666667 -11.43613888888889
# Bad Request:{"error":"No object found ra=137.35842 dec=-11.43614 radius=2.00"}
# 4376 162.75949999999997 -29.83736111111111
# Bad Request:{"error":"No object found ra=162.75950 dec=-29.83736 radius=2.00"}
# 4377 125.90412499999998 -5.404527777777778
# Bad Request:{"error":"No object found ra=125.90412 dec=-5.40453 radius=2.00"}
# 4378 130.304 -3.3222777777777774
# Bad Request:{"error":"No object found ra=130.30400 dec=-3.32228 radius=2.00"}
# 4379 214.03591666666665 -24.806194444444444
# Bad Request:{"error":"No object found ra=214.03592 dec=-24.80619 radius=2.00"}
# 4380 213.45924999999997 -29.88975
# Bad Request:{"error":"No object found ra=213.45925 dec=-29.88975 radius=2.00"}
# 4381 141.5850833333333 3.76175
# {'object': 'ZTF18aczejci', 'separation': 0.15623973748443157}
# 4382 209.00758333333332 -23.749000000000002
# Bad Request:{"error":"No object found ra=209.00758 dec=-23.74900 radius=2.00"}
# 4383 191.13620833333331 -23.955666666666666
# Bad Request:{"error":"No object found ra=191.13621 dec=-23.95567 radius=2.00"}
# 4384 128.85675 -8.084805555555556
# Bad Request:{"error":"No object found ra=128.85675 dec=-8.08481 radius=2.00"}
# 4385 129.167625 -4.218388888888889
# Bad Request:{"error":"No object found ra=129.16762 dec=-4.21839 radius=2.00"}
# 4386 131.50145833333335 -17.01163888888889
# Bad Request:{"error":"No object found ra=131.50146 dec=-17.01164 radius=2.00"}
# 4387 137.25204166666666 4.817583333333333
# Bad Request:{"error":"No object found ra=137.25204 dec=4.81758 radius=2.00"}
# 4388 159.73637499999998 -26.93713888888889
# {'object': 'ZTF19aanjvmj', 'separation': 1.3696952000300013}
# 4389 163.87087499999996 -25.94788888888889
# Bad Request:{"error":"No object found ra=163.87087 dec=-25.94789 radius=2.00"}
# 4390 185.50545833333334 -27.25713888888889
# {'object': 'ZTF21aajvkwg', 'separation': 1.3553290676397114}
# 4391 191.2344583333333 -27.175222222222224
# Bad Request:{"error":"No object found ra=191.23446 dec=-27.17522 radius=2.00"}
# 4392 194.73874999999998 -28.692083333333333
# Bad Request:{"error":"No object found ra=194.73875 dec=-28.69208 radius=2.00"}
# 4393 200.3707083333333 -28.211694444444444
# Bad Request:{"error":"No object found ra=200.37071 dec=-28.21169 radius=2.00"}
# 4394 209.88816666666665 -29.529333333333334
# Bad Request:{"error":"No object found ra=209.88817 dec=-29.52933 radius=2.00"}
# 4395 222.73395833333333 -25.92413888888889
# Bad Request:{"error":"No object found ra=222.73396 dec=-25.92414 radius=2.00"}
# 4396 133.22983333333332 -8.05175
# {'object': 'ZTF18acwxhax', 'separation': 0.038756433778799795}
# 4397 146.46254166666665 -19.733611111111113
# {'object': 'ZTF18aalurns', 'separation': 1.3875254020892998}
# 4398 151.894375 -20.292361111111113
# {'object': 'ZTF18aaqphee', 'separation': 0.1701611787367364}
# 4399 126.70116666666665 -0.010499999999999999
# Bad Request:{"error":"No object found ra=126.70117 dec=-0.01050 radius=2.00"}
# 4400 127.88504166666665 3.2390833333333333
# Bad Request:{"error":"No object found ra=127.88504 dec=3.23908 radius=2.00"}
# 4401 134.78824999999998 5.615138888888889
# {'object': 'ZTF17aaaizfe', 'separation': 0.14660066705329736}
# 4402 136.01454166666664 3.917
# Bad Request:{"error":"No object found ra=136.01454 dec=3.91700 radius=2.00"}
# 4403 136.61770833333333 5.449166666666667
# {'object': 'ZTF18aabjifc', 'separation': 0.09714668601834851}
# 4404 143.15916666666664 1.1506944444444445
# {'object': 'ZTF19aaaehud', 'separation': 0.10949040367728383}
# 4405 145.91449999999998 -18.69525
# {'object': 'ZTF21aaabnps', 'separation': 0.3019005424179831}
# 4406 224.6767083333333 -26.976249999999997
# {'object': 'ZTF20abfxvkw', 'separation': 0.13014736829867343}
# 4407 214.70658333333333 -24.55125
# {'object': 'ZTF19aaysjcu', 'separation': 0.7255939682123428}
# 4408 140.92249999999999 -21.969305555555554
# {'object': 'ZTF20aaobxzx', 'separation': 0.04157868891592844}
# 4409 153.07237499999997 -18.40308333333333
# {'object': 'ZTF19aaeduol', 'separation': 0.045692127791370045}
# 4410 185.33474999999996 -30.42275
# Bad Request:{"error":"No object found ra=185.33475 dec=-30.42275 radius=2.00"}
# 4411 144.99754166666665 -20.546833333333336
# {'object': 'ZTF19aankird', 'separation': 0.06527299145875494}
# 4412 175.78195833333334 -29.14075
# Bad Request:{"error":"No object found ra=175.78196 dec=-29.14075 radius=2.00"}
# 4413 187.40837499999998 -29.281666666666666
# Bad Request:{"error":"No object found ra=187.40837 dec=-29.28167 radius=2.00"}
# 4414 217.32816666666662 -28.449722222222224
# Bad Request:{"error":"No object found ra=217.32817 dec=-28.44972 radius=2.00"}
# 4415 141.71079166666667 -9.859555555555556
# Bad Request:{"error":"No object found ra=141.71079 dec=-9.85956 radius=2.00"}
# 4416 220.7248333333333 -27.281333333333333
# Bad Request:{"error":"No object found ra=220.72483 dec=-27.28133 radius=2.00"}
# 4417 161.23416666666662 -29.145138888888887
# Bad Request:{"error":"No object found ra=161.23417 dec=-29.14514 radius=2.00"}
# 4418 210.79512499999998 -24.02636111111111
# {'object': 'ZTF20aavhtln', 'separation': 0.15432335941399722}
# 4419 212.89791666666665 -28.474361111111108
# Bad Request:{"error":"No object found ra=212.89792 dec=-28.47436 radius=2.00"}
# 4420 129.28475 -15.171277777777776
# Bad Request:{"error":"No object found ra=129.28475 dec=-15.17128 radius=2.00"}
# 4421 223.04554166666665 -29.451944444444443
# Bad Request:{"error":"No object found ra=223.04554 dec=-29.45194 radius=2.00"}
# 4422 157.88808333333333 -24.57286111111111
# Bad Request:{"error":"No object found ra=157.88808 dec=-24.57286 radius=2.00"}
# 4423 129.33429166666667 -6.045472222222222
# {'object': 'ZTF18achzhtm', 'separation': 0.360226274830734}
# 4424 139.7644583333333 -9.014388888888888
# Bad Request:{"error":"No object found ra=139.76446 dec=-9.01439 radius=2.00"}
# 4425 123.31545833333332 -11.007416666666666
# {'object': 'ZTF18aczdngc', 'separation': 0.31014286344397596}
# 4426 128.12324999999998 -9.232333333333333
# {'object': 'ZTF17aabwjvv', 'separation': 0.14563086147714502}
# 4427 142.96487499999998 -4.176694444444445
# {'object': 'ZTF18acpeevn', 'separation': 0.3355561136242824}
# 4428 140.901875 -20.624805555555557
# {'object': 'ZTF18acdvwvx', 'separation': 0.03751788778638425}
# 4429 125.85449999999999 -0.3487222222222222
# {'object': 'ZTF18acnnpzr', 'separation': 0.09835472404818456}
# 4430 133.76470833333332 -13.564333333333334
# {'object': 'ZTF18acvwfyd', 'separation': 0.08009033921008678}
# 4431 141.9050833333333 -8.091444444444445
# {'object': 'ZTF18acvwgbr', 'separation': 0.08389254746256476}
# 4432 132.655 4.7325
# {'object': 'ZTF18aczehur', 'separation': 0.16138517182775194}
# 4433 133.01725000000002 -18.787222222222223
# {'object': 'ZTF18adayxxz', 'separation': 0.14400000534056065}
# 4434 136.23799999999997 -15.657833333333334
# {'object': 'ZTF19aaaojkv', 'separation': 0.12252005822303325}
# 4435 160.46995833333332 -20.47297222222222
# {'object': 'ZTF19aachvbn', 'separation': 0.20773433953124631}
# 4436 132.2795833333333 -15.424055555555555
# {'object': 'ZTF19aarsljl', 'separation': 0.1485530815493045}
# 4437 206.95725 -26.977527777777777
# {'object': 'ZTF20aavhqhx', 'separation': 0.2768445535384541}
# 4438 123.43799999999999 3.6225555555555555
# {'object': 'ZTF20aaydouq', 'separation': 0.029799513415632597}
# 4439 335.59237499999995 50.39447222222222
# {'object': 'ZTF20aciaalo', 'separation': 0.08189821198422445}
# 4440 333.92124999999993 55.61702777777778
# {'object': 'ZTF18abcjzao', 'separation': 0.5778503524090481}
# 4441 342.44575 53.28883333333333
# {'object': 'ZTF18abchhxd', 'separation': 0.5472966908140365}
# 4442 339.84399999999994 51.54288888888889
# {'object': 'ZTF17aabvgst', 'separation': 0.1823545389212186}
# 4443 342.6620416666666 55.24780555555556
# {'object': 'ZTF18abasxdk', 'separation': 0.4347575025250914}
# 4444 333.4553333333333 55.47402777777778
# HTTPSConnectionPool(host='lasair-ztf.lsst.ac.uk', port=443): Max retries exceeded with url: /api/cone/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1400de0b0>: Failed to establish a new connection: [Errno 12] Cannot allocate memory'))
# 4445 335.7694166666666 52.68283333333333
# {'object': 'ZTF18aaznfkp', 'separation': 0.07763464747174283}
# 4446 331.4169583333333 51.64969444444444
# {'object': 'ZTF18abcksma', 'separation': 0.10030441510382042}
# 4447 341.02425 43.75897222222222
# {'object': 'ZTF18abgtfuk', 'separation': 0.016263883756242367}
# 4448 343.4350416666666 35.898472222222225
# Bad Request:{"error":"No object found ra=343.43504 dec=35.89847 radius=2.00"}
# 4449 341.80108333333334 46.30416666666667
# {'object': 'ZTF18abmnorl', 'separation': 0.09008278986668167}
# 4450 338.75474999999994 56.43336111111111
# {'object': 'ZTF18abmndpu', 'separation': 0.1534639545495462}
# 4451 335.79029166666663 43.65508333333333
# {'object': 'ZTF18abmjivl', 'separation': 0.15441515481782028}
# 4452 336.7798333333333 55.63333333333333
# {'object': 'ZTF18ablvntg', 'separation': 0.07522438695261373}
# 4453 339.82458333333324 38.052305555555556
# {'object': 'ZTF18abvioui', 'separation': 0.06417834160389728}
# 4454 333.5157083333333 37.58130555555556
# {'object': 'ZTF18acarunx', 'separation': 0.06491015934601692}
# 4455 338.44866666666667 48.583083333333335
# {'object': 'ZTF18admgidx', 'separation': 1.8520180419099137}
# 4456 333.6677083333333 51.09363888888889
# {'object': 'ZTF19acgfyqs', 'separation': 0.05179697723308924}
# 4457 342.7800833333333 53.837611111111116
# {'object': 'ZTF19achufoh', 'separation': 0.051430916269940744}
# 4458 331.42141666666663 42.35388888888889
# {'object': 'ZTF19abyyujh', 'separation': 0.07811986874221438}
# 4459 334.08883333333324 38.52591666666667
# Bad Request:{"error":"No object found ra=334.08883 dec=38.52592 radius=2.00"}
# 4460 336.71554166666664 46.15902777777777
# {'object': 'ZTF19abngskg', 'separation': 0.1410504348306745}
# 4461 334.6525833333333 40.82230555555556
# Bad Request:{"error":"No object found ra=334.65258 dec=40.82231 radius=2.00"}
# 4462 335.91283333333325 51.89469444444445
# {'object': 'ZTF18abckbdo', 'separation': 0.07775623665739964}
# 4463 344.0388333333333 52.6185
# {'object': 'ZTF18abccukx', 'separation': 0.14524112609112086}
# 4464 340.23112499999996 52.70605555555556
# {'object': 'ZTF17aaaeczb', 'separation': 0.11166889315936794}
# 4465 334.7944583333333 35.76375
# {'object': 'ZTF18abxrjhk', 'separation': 0.0909178741427821}
# 4466 342.73070833333327 54.449777777777776
# {'object': 'ZTF18aazwdps', 'separation': 0.020387857251673143}
# 4467 342.39266666666657 37.93161111111111
# {'object': 'ZTF18abyzkeq', 'separation': 0.28819675442082043}
# 4468 339.593625 42.599250000000005
# {'object': 'ZTF18abnytem', 'separation': 0.4358209319247798}
# 4469 336.0993333333333 51.50944444444445
# {'object': 'ZTF18abnnidi', 'separation': 0.050128656384820176}
# 4470 334.62304166666667 39.81038888888889
# {'object': 'ZTF18abscetf', 'separation': 0.2451750132999207}
# 4471 337.1393333333333 50.67113888888888
# {'object': 'ZTF18abnunsl', 'separation': 0.1398734527077123}
# 4472 343.1069166666666 42.486333333333334
# {'object': 'ZTF18abmjipb', 'separation': 0.08394883230449698}
# 4473 342.4350416666666 54.94158333333333
# Bad Request:{"error":"No object found ra=342.43504 dec=54.94158 radius=2.00"}
# 4474 335.16895833333325 44.06483333333333
# {'object': 'ZTF18abasynv', 'separation': 0.15041737480775658}
# 4475 331.2112083333333 40.144
# {'object': 'ZTF18admuwqu', 'separation': 0.21272229146969115}
# 4476 339.07979166666667 51.205083333333334
# {'object': 'ZTF18abcjzta', 'separation': 0.06563381781996291}
# 4477 335.3715833333333 36.388
# {'object': 'ZTF19aaeuydl', 'separation': 0.10217070377811158}
# 4478 337.1966666666666 53.952194444444444
# {'object': 'ZTF20abxrwqs', 'separation': 0.25192150704083116}
# 4479 338.36349999999993 36.07027777777778
# Bad Request:{"error":"No object found ra=338.36350 dec=36.07028 radius=2.00"}
# 4480 340.50112499999994 48.308861111111106
# Bad Request:{"error":"No object found ra=340.50112 dec=48.30886 radius=2.00"}
# 4481 336.33525 56.67472222222222
# {'object': 'ZTF17aaaedpk', 'separation': 0.20271686179242598}
# 4482 335.756625 42.82277777777778
# {'object': 'ZTF18abmjinj', 'separation': 0.13355072220100103}
# 4483 340.46225 37.20561111111111
# Bad Request:{"error":"No object found ra=340.46225 dec=37.20561 radius=2.00"}
# 4484 331.4251666666666 47.72813888888889
# Bad Request:{"error":"No object found ra=331.42517 dec=47.72814 radius=2.00"}
# 4485 339.02104166666663 53.84055555555556
# {'object': 'ZTF20aauoahz', 'separation': 0.12401449416354807}
# 4486 337.28987499999994 52.35788888888889
# {'object': 'ZTF19aastacp', 'separation': 0.035843854034733974}
# 4487 343.54362499999996 48.726083333333335
# Bad Request:{"error":"No object found ra=343.54362 dec=48.72608 radius=2.00"}
# 4488 333.0958749999999 42.72552777777778
# {'object': 'ZTF19aazlbeb', 'separation': 0.3615874020669625}
# 4489 333.04962499999993 49.49297222222222
# {'object': 'ZTF18abgpmce', 'separation': 0.06373521772024685}
# 4490 342.00737499999997 51.53919444444444
# Bad Request:{"error":"No object found ra=342.00737 dec=51.53919 radius=2.00"}
# 4491 331.40412499999996 46.31472222222222
# {'object': 'ZTF18abcvgsz', 'separation': 0.367521620079991}
# 4492 336.67604166666666 43.39363888888889
# {'object': 'ZTF18admgjgb', 'separation': 0.04303019177108041}
# 4493 335.7637083333333 41.42916666666667
# Bad Request:{"error":"No object found ra=335.76371 dec=41.42917 radius=2.00"}
# 4494 336.01124999999996 43.39497222222222
# {'object': 'ZTF18admdsxu', 'separation': 0.1338333695482856}
# 4495 331.7229166666666 38.41938888888889
# {'object': 'ZTF22aaonsgo', 'separation': 0.06366106386416576}
# 4496 343.09937499999995 49.933305555555556
# {'object': 'ZTF22aasytdx', 'separation': 0.12378575527685497}
# 4497 331.2743333333333 37.734833333333334
# {'object': 'ZTF19aaprgqb', 'separation': 0.034773646168101156}
# 4498 335.18091666666663 43.75958333333333
# {'object': 'ZTF23aaaaqfh', 'separation': 0.07967643287746771}
# 4499 343.9505833333333 46.565666666666665
# Bad Request:{"error":"No object found ra=343.95058 dec=46.56567 radius=2.00"}

# %%
# Get ZTF counterparts for remaining objects.
pt2 = get_ZTFcounterparts(AAVSO_CVS_2[4500:].reset_index(drop=True), 'ra', 'dec', radius=2)

# Save the dataframe to a csv file.
pt2.to_csv(f'../processed_data/AAVSOCVsZTFxmatch_{date}_4500_last.csv', index=False)
# Out:
# 0 334.20970833333325 46.778166666666664
# Bad Request:{"error":"No object found ra=334.20971 dec=46.77817 radius=2.00"}
# 1 331.81224999999995 52.36108333333333
# {'object': 'ZTF18abburnj', 'separation': 0.05179697723308924}
# 2 331.6160833333333 37.78172222222222
# {'object': 'ZTF18abxywka', 'separation': 0.32027287959399287}
# 3 333.2184166666666 46.854305555555555
# {'object': 'ZTF18ablsaka', 'separation': 0.37816340207815263}
# 4 334.85874999999993 39.91008333333333
# Bad Request:{"error":"No object found ra=334.85875 dec=39.91008 radius=2.00"}
# 5 338.314625 39.59430555555556
# Bad Request:{"error":"No object found ra=338.31462 dec=39.59431 radius=2.00"}
# 6 339.1384583333333 37.77272222222222
# {'object': 'ZTF18abvwidj', 'separation': 0.3476549513947395}
# 7 341.96441666666664 36.72202777777778
# {'object': 'ZTF18abmnmuw', 'separation': 0.0792007484297882}
# 8 342.46370833333333 40.63408333333333
# {'object': 'ZTF22aasolik', 'separation': 1.2144979063535606}
# 9 342.5402916666666 50.236444444444444
# Bad Request:{"error":"No object found ra=342.54029 dec=50.23644 radius=2.00"}
# 10 343.4615833333333 36.742916666666666
# Bad Request:{"error":"No object found ra=343.46158 dec=36.74292 radius=2.00"}
# 11 344.06087499999995 38.13758333333333
# {'object': 'ZTF19aceiomh', 'separation': 0.6518537131969906}
# 12 344.1352916666666 35.71058333333334
# {'object': 'ZTF18ablvjse', 'separation': 0.6876112098019247}
# 13 331.27920833333326 45.03333333333333
# {'object': 'ZTF18abtwhyo', 'separation': 0.17013341771546725}
# 14 331.5453333333333 50.52425
# {'object': 'ZTF18abcxmlo', 'separation': 0.42712881643955547}
# 15 331.59004166666665 51.06336111111111
# {'object': 'ZTF18aazwgov', 'separation': 0.24337671020937374}
# 16 333.7115416666667 36.94255555555555
# {'object': 'ZTF17aabrhvu', 'separation': 0.14175193332737931}
# 17 335.04870833333325 53.806777777777775
# {'object': 'ZTF18abajwbu', 'separation': 0.08484431185274943}
# 18 336.2753333333333 41.83869444444445
# {'object': 'ZTF18abmeirl', 'separation': 0.03924090800898984}
# 19 336.36083333333335 49.79269444444444
# {'object': 'ZTF18abbogcm', 'separation': 0.1513877185754622}
# 20 336.9396666666666 45.52097222222222
# {'object': 'ZTF18aazgbwk', 'separation': 0.0659926713300308}
# 21 337.29737499999993 43.31594444444444
# {'object': 'ZTF19abyxsbo', 'separation': 0.11259562185580593}
# 22 339.028 49.383805555555554
# {'object': 'ZTF18abmroqu', 'separation': 0.1549038115925152}
# 23 339.6142083333333 46.72866666666667
# {'object': 'ZTF17aabutsz', 'separation': 0.15786383229802042}
# 24 340.44133333333326 56.375
# {'object': 'ZTF17aaaedrn', 'separation': 0.009220755379517215}
# 25 340.5079999999999 56.478388888888894
# {'object': 'ZTF18abgpmxr', 'separation': 0.2134095311356606}
# 26 342.30683333333326 51.33441666666667
# {'object': 'ZTF18abblxwa', 'separation': 0.23995626915046128}
# 27 343.34695833333325 50.06411111111111
# {'object': 'ZTF18acsxbdw', 'separation': 0.1495671075295314}
# 28 344.24116666666663 55.56158333333333
# {'object': 'ZTF18abcxmen', 'separation': 0.05944030743673969}
# 29 334.56770833333326 40.88488888888889
# {'object': 'ZTF18abscevg', 'separation': 0.11832304777717034}
# 30 330.612875 40.23597222222222
# {'object': 'ZTF18abolzdh', 'separation': 0.1448177291505721}
# 31 336.62404166666664 39.21911111111111
# {'object': 'ZTF18abmoeer', 'separation': 0.257448304553803}
# 32 329.57537499999995 42.08825
# {'object': 'ZTF18abuelzu', 'separation': 0.07453047840694374}
# 33 333.24154166666665 49.11233333333333
# {'object': 'ZTF18abgpmcd', 'separation': 0.03960037421489392}
# 34 333.8426666666667 49.54230555555555
# {'object': 'ZTF17aabpimd', 'separation': 0.023000604984937438}
# 35 335.93704166666663 45.0415
# {'object': 'ZTF18abzonnp', 'separation': 0.11401302350657791}
# 36 335.9534583333333 39.71925
# {'object': 'ZTF18abvjznu', 'separation': 0.2973763102286338}
# 37 337.66049999999996 52.0055
# {'object': 'ZTF18adlfsud', 'separation': 0.05498196221999314}
# 38 337.6635416666666 43.328388888888895
# {'object': 'ZTF18abxelbg', 'separation': 0.04042670054145869}
# 39 338.057375 44.09316666666667
# {'object': 'ZTF19aaprwuu', 'separation': 0.2000429367524966}
# 40 338.6644583333333 51.96791666666667
# {'object': 'ZTF18abtkgmo', 'separation': 0.0659926713300308}
# 41 340.5268333333333 41.87891666666667
# {'object': 'ZTF18abvzjxh', 'separation': 0.4812983076203637}
# 42 342.0785833333333 37.661944444444444
# Bad Request:{"error":"No object found ra=342.07858 dec=37.66194 radius=2.00"}
# 43 342.4652083333333 51.38055555555555
# {'object': 'ZTF18abdehpv', 'separation': 0.16631475566371798}
# 44 344.0259583333333 54.78872222222222
# {'object': 'ZTF17aabvfbw', 'separation': 0.06927509053893549}
# 45 334.4399583333333 53.54241666666667
# {'object': 'ZTF18abajwcd', 'separation': 0.1573243302489469}
# 46 334.46541666666667 52.7025
# {'object': 'ZTF18abcdcfr', 'separation': 0.09959554109683501}
# 47 333.16837499999997 51.87419444444444
# {'object': 'ZTF18abajvqd', 'separation': 0.0702231808350775}
# 48 333.9556666666666 47.350388888888894
# {'object': 'ZTF18abajtog', 'separation': 0.1697999314404665}
# 49 337.49666666666667 52.25213888888889
# {'object': 'ZTF17aaaedcz', 'separation': 0.055153513221013466}
# 50 339.78787499999993 37.74861111111111
# Bad Request:{"error":"No object found ra=339.78787 dec=37.74861 radius=2.00"}
# 51 343.967375 38.68288888888889
# Bad Request:{"error":"No object found ra=343.96738 dec=38.68289 radius=2.00"}
# 52 337.9240416666666 40.40072222222222
# {'object': 'ZTF18abumfjv', 'separation': 0.10035149532941397}
# 53 343.76395833333333 54.63869444444445
# {'object': 'ZTF17aabpkjj', 'separation': 0.02360865532517176}
# 54 340.44154166666664 50.562444444444445
# {'object': 'ZTF18adlyqgq', 'separation': 0.014084936497102967}
# 55 337.90608333333324 40.49536111111111
# Bad Request:{"error":"No object found ra=337.90608 dec=40.49536 radius=2.00"}
# 56 333.0184999999999 42.97852777777778
# {'object': 'ZTF22aaynsxc', 'separation': 0.13244976673812128}
# 57 336.2037083333333 48.17938888888889
# {'object': 'ZTF23abamchj', 'separation': 0.018441510759034434}
# 58 331.0972083333333 50.272527777777775
# {'object': 'ZTF18abaszqn', 'separation': 0.22388699574011403}
# 59 337.1127916666666 49.821250000000006
# Bad Request:{"error":"No object found ra=337.11279 dec=49.82125 radius=2.00"}
# 60 331.49054166666656 36.058611111111105
# {'object': 'ZTF17aaaehyg', 'separation': 0.3264228439486248}
# 61 333.1928333333333 52.532777777777774
# {'object': 'ZTF18aaznghv', 'separation': 0.056674109434187846}
# 62 331.7364583333333 51.09847222222223
# {'object': 'ZTF18aazwgpb', 'separation': 0.07305828443359949}
# 63 339.16220833333335 55.056444444444445
# {'object': 'ZTF18abajsxx', 'separation': 0.05179697723308924}
# 64 338.4002083333333 51.627583333333334
# {'object': 'ZTF18abaqipz', 'separation': 0.20220359465971963}
# 65 341.2537083333333 56.525166666666664
# {'object': 'ZTF18abblwnw', 'separation': 0.12635388456827565}
# 66 332.54675 44.939166666666665
# {'object': 'ZTF18abboeaw', 'separation': 0.04065970939060597}
# 67 337.6322916666666 36.69072222222222
# {'object': 'ZTF18abbugzp', 'separation': 0.04214287602450665}
# 68 335.6970416666667 51.68113888888889
# {'object': 'ZTF18abckbdn', 'separation': 0.04898488628739321}
# 69 344.24125 55.894888888888886
# Bad Request:{"error":"No object found ra=344.24125 dec=55.89489 radius=2.00"}
# 70 335.37604166666665 49.95752777777778
# {'object': 'ZTF18abdbozw', 'separation': 0.23223371385325423}
# 71 342.967375 52.49297222222222
# {'object': 'ZTF18abeddmj', 'separation': 0.019919108219366818}
# 72 336.64145833333333 47.82269444444445
# {'object': 'ZTF18abhesko', 'separation': 0.035044262281920716}
# 73 335.8382916666666 47.297888888888885
# {'object': 'ZTF18adlilmt', 'separation': 0.051614271276706127}
# 74 334.38191666666665 46.992472222222226
# {'object': 'ZTF18abmnbne', 'separation': 0.08966233114260247}
# 75 335.38145833333334 41.80166666666666
# {'object': 'ZTF18admjqlw', 'separation': 0.21986340745196023}
# 76 333.9640416666666 51.286249999999995
# {'object': 'ZTF18abnulqf', 'separation': 0.10682642950174842}
# 77 341.12808333333334 47.10925
# {'object': 'ZTF18admqfrd', 'separation': 0.03394885733931309}
# 78 340.30470833333334 49.996027777777776
# {'object': 'ZTF18admqfyj', 'separation': 0.1513253035167073}
# 79 341.7045833333333 43.26808333333333
# {'object': 'ZTF18admuxcg', 'separation': 0.01894685119314915}
# 80 344.3525416666666 48.11647222222222
# {'object': 'ZTF18aboshpo', 'separation': 0.22632107772587115}
# 81 335.71037499999994 53.542361111111106
# {'object': 'ZTF18abpuhwf', 'separation': 0.25337976616346886}
# 82 331.68287499999997 39.02022222222222
# {'object': 'ZTF18absksnc', 'separation': 0.007528715240946743}
# 83 337.9227916666666 36.84825
# {'object': 'ZTF18abtizrj', 'separation': 0.4633474178109571}
# 84 342.4529166666666 50.88183333333333
# {'object': 'ZTF18abulsfu', 'separation': 0.1355168743370438}
# 85 343.5264999999999 49.08266666666667
# {'object': 'ZTF18abumesx', 'separation': 0.02534543225182117}
# 86 343.83916666666664 53.6455
# {'object': 'ZTF18abvburn', 'separation': 0.013745490554998244}
# 87 343.0983333333333 50.82030555555556
# {'object': 'ZTF18abvubjc', 'separation': 0.1388906833880882}
# 88 333.8025833333333 43.879805555555556
# {'object': 'ZTF18abwcqlc', 'separation': 0.09782502523263605}
# 89 342.10825 38.919333333333334
# {'object': 'ZTF18acehgym', 'separation': 0.09719529582174988}
# 90 338.2845833333333 46.54719444444444
# {'object': 'ZTF18acuhrvm', 'separation': 0.1279143268666493}
# 91 340.91458333333327 36.77736111111111
# {'object': 'ZTF19aaaheft', 'separation': 0.08394883230449698}
# 92 332.71395833333327 41.358472222222225
# {'object': 'ZTF19aaahelh', 'separation': 0.11251168921510282}
# 93 330.13974999999994 37.64688888888889
# {'object': 'ZTF19aassvxn', 'separation': 0.09261645847865663}
# 94 337.1767499999999 43.229416666666665
# {'object': 'ZTF19aawevyv', 'separation': 0.29835947993661815}
# 95 335.0067083333332 45.43805555555555
# {'object': 'ZTF19abjklri', 'separation': 0.11655333076306275}
# 96 338.41999999999996 45.306749999999994
# {'object': 'ZTF19abzirup', 'separation': 0.14701892943549874}
# 97 338.99783333333323 46.464194444444445
# {'object': 'ZTF19acarefd', 'separation': 0.05684055357944761}
# 98 337.5225416666666 38.172666666666665
# {'object': 'ZTF21acahxze', 'separation': 0.0425888448039677}
# 99 147.75612499999997 11.875333333333334
# {'object': 'ZTF18aakapxk', 'separation': 0.3922525667285784}
# 100 174.34270833333332 1.8162777777777779
# {'object': 'ZTF19aaaenxw', 'separation': 0.6630756827741443}
# 101 160.21349999999998 15.192694444444445
# {'object': 'ZTF18aaaqvfx', 'separation': 0.14988258374490745}
# 102 169.31633333333332 17.961583333333333
# {'object': 'ZTF18aabpoqs', 'separation': 0.3292468229996532}
# 103 153.8945 9.078333333333333
# {'object': 'ZTF18aaarims', 'separation': 0.47553239259673247}
# 104 144.6540833333333 7.248638888888889
# {'object': 'ZTF17aaajeks', 'separation': 0.39625414727437086}
# 105 146.643625 13.849388888888889
# {'object': 'ZTF17aabhicw', 'separation': 0.03557932013127233}
# 106 155.44354166666665 23.823999999999998
# Bad Request:{"error":"No object found ra=155.44354 dec=23.82400 radius=2.00"}
# 107 157.7525 20.476
# Bad Request:{"error":"No object found ra=157.75250 dec=20.47600 radius=2.00"}
# 108 164.48454166666662 9.387444444444444
# {'object': 'ZTF18aabbkmg', 'separation': 0.07683962816264389}
# 109 157.00033333333332 21.80377777777778
# {'object': 'ZTF17aaajhzf', 'separation': 0.7824311867754903}
# 110 171.4820833333333 -0.27702777777777776
# {'object': 'ZTF18acvwayb', 'separation': 1.5157979547700202}
# 111 168.7063333333333 -0.31552777777777774
# Bad Request:{"error":"No object found ra=168.70633 dec=-0.31553 radius=2.00"}
# 112 161.09175 18.582833333333333
# Bad Request:{"error":"No object found ra=161.09175 dec=18.58283 radius=2.00"}
# 113 143.28908333333334 10.467277777777777
# Bad Request:{"error":"No object found ra=143.28908 dec=10.46728 radius=2.00"}
# 114 166.5333333333333 -3.771611111111111
# Bad Request:{"error":"No object found ra=166.53333 dec=-3.77161 radius=2.00"}
# 115 156.33704166666664 16.196305555555554
# {'object': 'ZTF18aaadgen', 'separation': 0.6637591927327768}
# 116 141.9479583333333 31.96838888888889
# {'object': 'ZTF19acqdbad', 'separation': 0.22460316633910066}
# 117 164.1992083333333 20.807222222222222
# {'object': 'ZTF19aacgush', 'separation': 0.5641347598319967}
# 118 149.45187499999997 7.4695277777777775
# Bad Request:{"error":"No object found ra=149.45187 dec=7.46953 radius=2.00"}
# 119 176.0774583333333 24.18052777777778
# Bad Request:{"error":"No object found ra=176.07746 dec=24.18053 radius=2.00"}
# 120 152.50437499999998 16.044944444444447
# {'object': 'ZTF17aabtokj', 'separation': 0.6025402849926074}
# 121 147.10329166666665 20.725888888888885
# Bad Request:{"error":"No object found ra=147.10329 dec=20.72589 radius=2.00"}
# 122 163.95866666666666 9.939055555555555
# Bad Request:{"error":"No object found ra=163.95867 dec=9.93906 radius=2.00"}
# 123 158.32199999999997 7.355138888888889
# {'object': 'ZTF19aatfwbt', 'separation': 0.6858572809521988}
# 124 164.6497083333333 12.013472222222223
# Bad Request:{"error":"No object found ra=164.64971 dec=12.01347 radius=2.00"}
# 125 164.646375 5.785083333333334
# {'object': 'ZTF19adhzuso', 'separation': 0.8224410707556137}
# 126 167.57899999999998 -5.371611111111111
# {'object': 'ZTF19aacyjjz', 'separation': 0.8036528838385002}
# 127 159.41104166666665 12.713944444444444
# Bad Request:{"error":"No object found ra=159.41104 dec=12.71394 radius=2.00"}
# 128 161.04754166666663 21.21858333333333
# Bad Request:{"error":"No object found ra=161.04754 dec=21.21858 radius=2.00"}
# 129 157.40299999999996 19.11213888888889
# Bad Request:{"error":"No object found ra=157.40300 dec=19.11214 radius=2.00"}
# 130 156.56716666666665 19.345694444444444
# {'object': 'ZTF17aaajhyv', 'separation': 1.1872714710709604}
# 131 171.9529583333333 -5.710083333333333
# Bad Request:{"error":"No object found ra=171.95296 dec=-5.71008 radius=2.00"}
# 132 171.2903333333333 23.17663888888889
# {'object': 'ZTF19acmxbpa', 'separation': 0.03662599384648257}
# 133 153.1410833333333 7.781055555555556
# {'object': 'ZTF17aaajhgk', 'separation': 0.22432960637789495}
# 134 168.66524999999996 -2.7921388888888887
# {'object': 'ZTF19aapseww', 'separation': 0.08742175217685152}
# 135 171.581 8.780833333333334
# Bad Request:{"error":"No object found ra=171.58100 dec=8.78083 radius=2.00"}
# 136 166.80662499999997 13.560027777777778
# Bad Request:{"error":"No object found ra=166.80662 dec=13.56003 radius=2.00"}
# 137 152.9788333333333 14.19225
# {'object': 'ZTF21aambeym', 'separation': 0.8408488571128914}
# 138 168.14929166666664 0.47050000000000003
# {'object': 'ZTF20acoumqb', 'separation': 0.4407246712176219}
# 139 169.218625 1.2433611111111111
# {'object': 'ZTF19aanhffu', 'separation': 0.09528113892167872}
# 140 149.64970833333334 28.18186111111111
# {'object': 'ZTF18aauhben', 'separation': 0.19699738596422764}
# 141 172.51274999999998 28.11327777777778
# Bad Request:{"error":"No object found ra=172.51275 dec=28.11328 radius=2.00"}
# 142 151.6213333333333 22.445583333333335
# Bad Request:{"error":"No object found ra=151.62133 dec=22.44558 radius=2.00"}
# 143 141.23308333333333 13.347888888888889
# Bad Request:{"error":"No object found ra=141.23308 dec=13.34789 radius=2.00"}
# 144 152.98674999999997 19.228194444444444
# Bad Request:{"error":"No object found ra=152.98675 dec=19.22819 radius=2.00"}
# 145 170.66145833333331 -5.663694444444444
# {'object': 'ZTF19aadtgii', 'separation': 0.15120039610498406}
# 146 159.26912499999997 10.040027777777778
# Bad Request:{"error":"No object found ra=159.26912 dec=10.04003 radius=2.00"}
# 147 163.43866666666665 13.64561111111111
# Bad Request:{"error":"No object found ra=163.43867 dec=13.64561 radius=2.00"}
# 148 168.90487499999998 5.167000000000001
# {'object': 'ZTF20abbdcrp', 'separation': 1.2184274509274131}
# 149 166.827125 21.886166666666668
# Bad Request:{"error":"No object found ra=166.82712 dec=21.88617 radius=2.00"}
# 150 153.53891666666664 12.863972222222221
# {'object': 'ZTF18accnfln', 'separation': 0.2902545122396198}
# 151 170.554625 14.439388888888889
# {'object': 'ZTF18aamqtld', 'separation': 1.3748445517868653}
# 152 145.87329166666666 10.499277777777777
# {'object': 'ZTF19aalvizg', 'separation': 0.32301902804249166}
# 153 148.28416666666664 14.976777777777778
# {'object': 'ZTF17aaajhib', 'separation': 0.5530147558419221}
# 154 142.041 7.191805555555556
# {'object': 'ZTF21aaqvwgo', 'separation': 0.3014778109960427}
# 155 143.08720833333334 13.522833333333335
# Bad Request:{"error":"No object found ra=143.08721 dec=13.52283 radius=2.00"}
# 156 143.90612499999997 16.330805555555557
# {'object': 'ZTF18aabjqhl', 'separation': 0.24990723214430272}
# 157 144.9418333333333 6.869305555555556
# {'object': 'ZTF19aaipqno', 'separation': 0.21010826495195378}
# 158 145.01074999999997 27.828333333333333
# {'object': 'ZTF18aassdgz', 'separation': 0.20262363720170956}
# 159 146.49266666666665 29.38116666666667
# {'object': 'ZTF19aacwwsa', 'separation': 1.0194947967744983}
# 160 151.314125 19.1855
# {'object': 'ZTF17aaapome', 'separation': 0.27945971687437804}
# 161 151.74341666666663 23.6235
# {'object': 'ZTF18aaadmzu', 'separation': 0.6753219801552172}
# 162 153.5898333333333 6.649388888888889
# {'object': 'ZTF20aaicimz', 'separation': 1.0684720911243466}
# 163 157.94991666666667 8.873472222222222
# {'object': 'ZTF18aabopru', 'separation': 0.1556339200129796}
# 164 165.06133333333332 13.2645
# {'object': 'ZTF18aabszen', 'separation': 0.28038779263664626}
# 165 144.26545833333333 16.95986111111111
# Bad Request:{"error":"No object found ra=144.26546 dec=16.95986 radius=2.00"}
# 166 158.13424999999998 21.61713888888889
# {'object': 'ZTF18aaoawyk', 'separation': 0.2886880271583688}
# 167 156.72208333333333 20.248916666666666
# {'object': 'ZTF22abvfvks', 'separation': 0.05717198818772674}
# 168 150.53108333333333 33.85005555555556
# {'object': 'ZTF17aacwmyu', 'separation': 0.03971947335362735}
# 169 158.52441666666664 31.133222222222223
# Bad Request:{"error":"No object found ra=158.52442 dec=31.13322 radius=2.00"}
# 170 166.41570833333333 25.107944444444446
# {'object': 'ZTF17aaajlfw', 'separation': 0.5925805167834245}
# 171 163.62675 30.10288888888889
# {'object': 'ZTF18adkctvd', 'separation': 0.6767333713049787}
# 172 156.61454166666664 38.75075
# {'object': 'ZTF17aabtvrf', 'separation': 0.8856299673366957}
# 173 141.661375 36.40069444444444
# {'object': 'ZTF17aackrzg', 'separation': 0.853970059899906}
# 174 154.947 33.96488888888889
# {'object': 'ZTF17aacldol', 'separation': 0.8870954534690849}
# 175 162.60829166666667 33.469833333333334
# Bad Request:{"error":"No object found ra=162.60829 dec=33.46983 radius=2.00"}
# 176 149.03799999999998 37.983555555555554
# {'object': 'ZTF18aabkhrv', 'separation': 0.36095982727735904}
# 177 142.87812499999998 33.94755555555555
# {'object': 'ZTF18aceyuwr', 'separation': 0.06069844278605647}
# 178 160.68812499999999 37.305499999999995
# {'object': 'ZTF18aceyzdu', 'separation': 0.29957602129317706}
# 179 163.39066666666662 28.842666666666666
# {'object': 'ZTF17aacmiwg', 'separation': 0.05872076139156606}
# 180 163.67941666666664 28.842416666666665
# Bad Request:{"error":"No object found ra=163.67942 dec=28.84242 radius=2.00"}
# 181 164.47599999999997 27.99652777777778
# Bad Request:{"error":"No object found ra=164.47600 dec=27.99653 radius=2.00"}
# 182 164.77112499999998 27.465416666666666
# Bad Request:{"error":"No object found ra=164.77112 dec=27.46542 radius=2.00"}
# 183 158.66666666666666 28.296944444444446
# {'object': 'ZTF17aabtrxp', 'separation': 0.7975050227426665}
# 184 154.34666666666664 37.89536111111111
# {'object': 'ZTF19acymwir', 'separation': 0.2658962028040481}
# 185 90.1385 -27.15511111111111
# Bad Request:{"error":"No object found ra=90.13850 dec=-27.15511 radius=2.00"}
# 186 89.74183333333332 -23.423944444444444
# {'object': 'ZTF23aabmsvn', 'separation': 1.1914058063882595}
# 187 81.35808333333333 -21.487194444444444
# {'object': 'ZTF17aaazpbo', 'separation': 0.23510414984707953}
# 188 78.27745833333333 -26.33111111111111
# {'object': 'ZTF20acgjzeh', 'separation': 0.39603952400309855}
# 189 87.04875 -18.247083333333336
# Bad Request:{"error":"No object found ra=87.04875 dec=-18.24708 radius=2.00"}
# 190 75.77879166666666 -13.801805555555557
# Bad Request:{"error":"No object found ra=75.77879 dec=-13.80181 radius=2.00"}
# 191 91.73074999999999 -20.155277777777776
# Bad Request:{"error":"No object found ra=91.73075 dec=-20.15528 radius=2.00"}
# 192 79.268875 -25.517611111111112
# {'object': 'ZTF18acwevfv', 'separation': 0.1995227911365166}
# 193 90.51987499999998 -12.330833333333333
# {'object': 'ZTF19aaiqzky', 'separation': 0.048791651268727206}
# 194 83.76812499999998 -11.431666666666667
# {'object': 'ZTF20aasajit', 'separation': 0.07472036528388723}
# 195 89.76549999999999 -11.711972222222222
# Bad Request:{"error":"No object found ra=89.76550 dec=-11.71197 radius=2.00"}
# 196 77.12633333333333 -19.19772222222222
# {'object': 'ZTF21acinvoq', 'separation': 0.056674109434187846}
# 197 74.26583333333332 -26.835305555555554
# Bad Request:{"error":"No object found ra=74.26583 dec=-26.83531 radius=2.00"}
# 198 74.2905 -22.92227777777778
# Bad Request:{"error":"No object found ra=74.29050 dec=-22.92228 radius=2.00"}
# 199 82.89429166666666 -12.817277777777777
# {'object': 'ZTF18acrwnwq', 'separation': 0.0797949109100159}
# 200 84.93733333333333 -17.400944444444445
# {'object': 'ZTF17aabwfnh', 'separation': 0.24827643682487627}
# 201 92.09945833333333 -15.599083333333335
# {'object': 'ZTF18acrukts', 'separation': 0.18472221039690667}
# 202 78.21941666666666 -12.63738888888889
# Bad Request:{"error":"No object found ra=78.21942 dec=-12.63739 radius=2.00"}
# 203 75.54062499999999 -15.800583333333334
# {'object': 'ZTF21acgzwzr', 'separation': 0.038018148377731785}
# 204 91.36841666666665 -18.31191666666667
# {'object': 'ZTF22abgheca', 'separation': 0.2794428142392959}
# 205 79.08612499999998 -16.559944444444444
# {'object': 'ZTF18acuauty', 'separation': 0.45106367082380766}
# 206 91.25679166666664 -24.630083333333335
# {'object': 'ZTF18acyuqzg', 'separation': 0.34040562355739834}
# 207 81.45004166666666 -12.963138888888889
# {'object': 'ZTF18actabky', 'separation': 0.21149749971092546}
# 208 76.74674999999998 -16.99211111111111
# Bad Request:{"error":"No object found ra=76.74675 dec=-16.99211 radius=2.00"}
# 209 81.94337499999999 -13.882222222222223
# {'object': 'ZTF19aadmluu', 'separation': 0.186275488111672}
# 210 83.92424999999999 -11.621305555555557
# {'object': 'ZTF19aagzyqe', 'separation': 0.24774316371520758}
# 211 85.75529166666665 -16.669972222222224
# {'object': 'ZTF18acrwlyl', 'separation': 0.10082108841977538}
# 212 86.79637499999998 -19.42366666666667
# {'object': 'ZTF19aakvlvn', 'separation': 0.31669860806566064}
# 213 83.48174999999999 -20.788972222222224
# Bad Request:{"error":"No object found ra=83.48175 dec=-20.78897 radius=2.00"}
# 214 86.800625 -17.7065
# {'object': 'ZTF18acuwutx', 'separation': 0.9191098817519509}
# 215 92.60641666666666 -16.483083333333333
# {'object': 'ZTF19aaefxss', 'separation': 0.20793888080455764}
# 216 89.36925 -13.717972222222222
# Bad Request:{"error":"No object found ra=89.36925 dec=-13.71797 radius=2.00"}
# 217 80.50304166666666 -16.417555555555555
# {'object': 'ZTF18acnmdao', 'separation': 0.4851885584791966}
# 218 80.87345833333333 -16.172333333333334
# Bad Request:{"error":"No object found ra=80.87346 dec=-16.17233 radius=2.00"}
# 219 86.79883333333332 -16.005916666666668
# Bad Request:{"error":"No object found ra=86.79883 dec=-16.00592 radius=2.00"}
# 220 78.33070833333333 -22.4905
# Bad Request:{"error":"No object found ra=78.33071 dec=-22.49050 radius=2.00"}
# 221 90.366875 -20.549083333333336
# {'object': 'ZTF19abxvlze', 'separation': 0.16018067842017655}
# 222 93.05812499999999 -18.33213888888889
# Bad Request:{"error":"No object found ra=93.05812 dec=-18.33214 radius=2.00"}
# 223 81.56033333333332 -18.32208333333333
# Bad Request:{"error":"No object found ra=81.56033 dec=-18.32208 radius=2.00"}
# 224 82.92187499999999 -14.19963888888889
# {'object': 'ZTF22abpyjrz', 'separation': 0.071621788323969}
# 225 88.76054166666665 -23.75175
# Bad Request:{"error":"No object found ra=88.76054 dec=-23.75175 radius=2.00"}
# 226 79.25958333333332 -26.718138888888888
# {'object': 'ZTF19aabaqng', 'separation': 0.2249603966558507}
# 227 87.38387499999997 -21.924833333333336
# Bad Request:{"error":"No object found ra=87.38387 dec=-21.92483 radius=2.00"}
# 228 88.31537499999997 -26.813055555555557
# {'object': 'ZTF19aamfvdm', 'separation': 0.21327668983356624}
# 229 89.11720833333334 -17.395222222222223
# Bad Request:{"error":"No object found ra=89.11721 dec=-17.39522 radius=2.00"}
# 230 85.36999999999999 -25.45422222222222
# {'object': 'ZTF18adbcyjj', 'separation': 0.32024338174639694}
# 231 75.48320833333332 -13.273694444444445
# {'object': 'ZTF22aabhpei', 'separation': 0.12728502379989592}
# 232 229.98087499999997 -25.006972222222224
# {'object': 'ZTF19aatyrrf', 'separation': 1.5772823138324725}
# 233 234.06658333333328 -8.652083333333334
# Bad Request:{"error":"No object found ra=234.06658 dec=-8.65208 radius=2.00"}
# 234 220.92462499999996 -17.930500000000002
# {'object': 'ZTF18acyyiea', 'separation': 1.0228067458370105}
# 235 227.44404166666664 -21.796222222222223
# Bad Request:{"error":"No object found ra=227.44404 dec=-21.79622 radius=2.00"}
# 236 236.1640416666666 -11.467888888888888
# {'object': 'ZTF19aatmqvx', 'separation': 0.8569847633095801}
# 237 239.49737499999998 -4.404333333333334
# {'object': 'ZTF19acekpoy', 'separation': 1.653805877188954}
# 238 232.75945833333333 -8.458722222222221
# {'object': 'ZTF18abcigqi', 'separation': 0.4934803403473061}
# 239 233.00154166666664 -28.565805555555556
# Bad Request:{"error":"No object found ra=233.00154 dec=-28.56581 radius=2.00"}
# 240 217.69187499999998 -12.215472222222221
# Bad Request:{"error":"No object found ra=217.69187 dec=-12.21547 radius=2.00"}
# 241 233.30916666666664 -29.217499999999998
# Bad Request:{"error":"No object found ra=233.30917 dec=-29.21750 radius=2.00"}
# 242 229.48104166666664 -22.098666666666666
# Bad Request:{"error":"No object found ra=229.48104 dec=-22.09867 radius=2.00"}
# 243 225.39445833333332 -22.05536111111111
# {'object': 'ZTF19aavydev', 'separation': 0.2935716294349389}
# 244 234.36974999999998 -20.051472222222223
# Bad Request:{"error":"No object found ra=234.36975 dec=-20.05147 radius=2.00"}
# 245 225.57904166666663 -15.796944444444444
# Bad Request:{"error":"No object found ra=225.57904 dec=-15.79694 radius=2.00"}
# 246 219.41333333333333 -9.219333333333333
# {'object': 'ZTF19aaciqvu', 'separation': 0.015970816801487864}
# 247 221.91199999999998 -17.152305555555554
# Bad Request:{"error":"No object found ra=221.91200 dec=-17.15231 radius=2.00"}
# 248 219.1462083333333 -24.032277777777775
# Bad Request:{"error":"No object found ra=219.14621 dec=-24.03228 radius=2.00"}
# 249 237.7392083333333 -12.677472222222221
# Bad Request:{"error":"No object found ra=237.73921 dec=-12.67747 radius=2.00"}
# 250 238.97374999999997 -13.057083333333335
# {'object': 'ZTF20abfqsik', 'separation': 0.07896183160058466}
# 251 234.17241666666663 -23.247972222222224
# {'object': 'ZTF22aasluxi', 'separation': 0.13786665356827163}
# 252 228.99754166666662 -27.822055555555554
# Bad Request:{"error":"No object found ra=228.99754 dec=-27.82206 radius=2.00"}
# 253 226.96162499999997 -10.97488888888889
# {'object': 'ZTF20aayitwt', 'separation': 0.1947789848212328}
# 254 222.98137499999999 -14.971916666666667
# {'object': 'ZTF21abbvorw', 'separation': 0.1623190540350366}
# 255 233.8447083333333 -10.050055555555556
# {'object': 'ZTF21abmemav', 'separation': 0.04180527745425577}
# 256 238.6895833333333 -14.33313888888889
# Bad Request:{"error":"No object found ra=238.68958 dec=-14.33314 radius=2.00"}
# 257 231.01895833333333 -20.478194444444444
# {'object': 'ZTF22aabzkfa', 'separation': 0.02697060002670598}
# 258 222.54308333333333 -24.783333333333335
# Bad Request:{"error":"No object found ra=222.54308 dec=-24.78333 radius=2.00"}
# 259 227.1697083333333 -29.162166666666664
# Bad Request:{"error":"No object found ra=227.16971 dec=-29.16217 radius=2.00"}
# 260 234.42679166666665 -22.60452777777778
# Bad Request:{"error":"No object found ra=234.42679 dec=-22.60453 radius=2.00"}
# 261 230.53779166666666 -3.7831944444444443
# {'object': 'ZTF19aadttiw', 'separation': 0.04538094055342241}
# 262 219.82141666666666 -18.0775
# {'object': 'ZTF21abexegc', 'separation': 0.03713827038732537}
# 263 239.4534166666666 -14.479666666666667
# {'object': 'ZTF19aackzkr', 'separation': 0.06872745277499152}
# 264 219.55249999999998 -14.206444444444443
# {'object': 'ZTF19aapymxy', 'separation': 0.18904422572384563}
# 265 239.1290833333333 -8.077944444444444
# Bad Request:{"error":"No object found ra=239.12908 dec=-8.07794 radius=2.00"}
# 266 231.6050833333333 -14.695833333333333
# {'object': 'ZTF19aanpgdw', 'separation': 0.3893881800396303}
# 267 220.1589583333333 -22.236027777777778
# Bad Request:{"error":"No object found ra=220.15896 dec=-22.23603 radius=2.00"}
# 268 225.97474999999997 -22.11975
# {'object': 'ZTF19aapzvoj', 'separation': 0.8323799686520578}
# 269 235.9755833333333 -14.629305555555556
# {'object': 'ZTF19aarxpzx', 'separation': 0.05650717502316449}
# 270 231.40766666666661 -7.944833333333333
# Bad Request:{"error":"No object found ra=231.40767 dec=-7.94483 radius=2.00"}
# 271 237.84304166666664 -4.430611111111111
# Bad Request:{"error":"No object found ra=237.84304 dec=-4.43061 radius=2.00"}
# 272 223.9777083333333 -11.331861111111111
# Bad Request:{"error":"No object found ra=223.97771 dec=-11.33186 radius=2.00"}
# 273 229.65025 -5.800833333333333
# Bad Request:{"error":"No object found ra=229.65025 dec=-5.80083 radius=2.00"}
# 274 225.20541666666665 -8.74636111111111
# {'object': 'ZTF18acwyzll', 'separation': 0.3138520232530763}
# 275 220.71674999999996 -22.84436111111111
# {'object': 'ZTF23aacvldt', 'separation': 0.16548908456788244}
# 276 221.22099999999998 -13.188416666666667
# {'object': 'ZTF19aaedwjy', 'separation': 0.1751404213638685}
# 277 224.4552083333333 -24.683111111111113
# Bad Request:{"error":"No object found ra=224.45521 dec=-24.68311 radius=2.00"}
# 278 220.6083333333333 -11.591138888888889
# {'object': 'ZTF19aavxoyu', 'separation': 0.7103772715645427}
# 279 216.47779166666663 -22.63525
# Bad Request:{"error":"No object found ra=216.47779 dec=-22.63525 radius=2.00"}
# 280 229.30862499999998 -7.170722222222222
# Bad Request:{"error":"No object found ra=229.30862 dec=-7.17072 radius=2.00"}
# 281 236.73008333333334 -12.248444444444443
# {'object': 'ZTF19aanxolm', 'separation': 0.05411605043110572}
# 282 234.71429166666664 -5.570138888888889
# Bad Request:{"error":"No object found ra=234.71429 dec=-5.57014 radius=2.00"}
# 283 234.19141666666664 -22.49727777777778
# {'object': 'ZTF19aaxlgob', 'separation': 0.2239502793883577}
# 284 230.36279166666662 -11.322194444444444
# {'object': 'ZTF19aatmqlm', 'separation': 0.26441765418865554}
# 285 234.1132083333333 -16.157027777777778
# {'object': 'ZTF19aanoxtr', 'separation': 0.5321475732198342}
# 286 239.3762083333333 -18.795055555555557
# {'object': 'ZTF19aadaefn', 'separation': 0.2925723709208245}
# 287 215.7105 -22.308027777777777
# Bad Request:{"error":"No object found ra=215.71050 dec=-22.30803 radius=2.00"}
# 288 227.95624999999998 -22.063972222222223
# {'object': 'ZTF23aaleepz', 'separation': 0.07427654077465105}
# 289 218.43949999999998 -18.442583333333335
# Bad Request:{"error":"No object found ra=218.43950 dec=-18.44258 radius=2.00"}
# 290 230.8833333333333 -10.233222222222222
# {'object': 'ZTF19abgplbp', 'separation': 0.09523155206486117}
# 291 231.04762499999998 -16.365472222222223
# Bad Request:{"error":"No object found ra=231.04762 dec=-16.36547 radius=2.00"}
# 292 229.95391666666666 -27.87777777777778
# Bad Request:{"error":"No object found ra=229.95392 dec=-27.87778 radius=2.00"}
# 293 239.83116666666663 -7.738111111111111
# Bad Request:{"error":"No object found ra=239.83117 dec=-7.73811 radius=2.00"}
# 294 234.81520833333332 -12.024638888888889
# Bad Request:{"error":"No object found ra=234.81521 dec=-12.02464 radius=2.00"}
# 295 225.01499999999996 -21.285861111111114
# Bad Request:{"error":"No object found ra=225.01500 dec=-21.28586 radius=2.00"}
# 296 218.26029166666666 -24.29127777777778
# Bad Request:{"error":"No object found ra=218.26029 dec=-24.29128 radius=2.00"}
# 297 223.72991666666664 -22.06913888888889
# Bad Request:{"error":"No object found ra=223.72992 dec=-22.06914 radius=2.00"}
# 298 226.325 -14.659638888888889
# {'object': 'ZTF18adbioao', 'separation': 0.44801654738790814}
# 299 227.9452083333333 -28.904249999999998
# Bad Request:{"error":"No object found ra=227.94521 dec=-28.90425 radius=2.00"}
# 300 229.85674999999998 -18.51725
# Bad Request:{"error":"No object found ra=229.85675 dec=-18.51725 radius=2.00"}
# 301 231.64824999999996 -21.905388888888886
# {'object': 'ZTF19aatyrpj', 'separation': 0.20889075858569459}
# 302 232.77175 -26.076999999999998
# Bad Request:{"error":"No object found ra=232.77175 dec=-26.07700 radius=2.00"}
# 303 233.8322083333333 -6.507944444444444
# {'object': 'ZTF19aaczyyy', 'separation': 0.3084323914343013}
# 304 238.92854166666663 -19.19661111111111
# {'object': 'ZTF19aaqrlqb', 'separation': 1.2006353569919161}
# 305 239.60737499999996 -3.9575
# {'object': 'ZTF19aatnfzx', 'separation': 0.38239895433566823}
# 306 235.93091666666663 -8.31713888888889
# Bad Request:{"error":"No object found ra=235.93092 dec=-8.31714 radius=2.00"}
# 307 234.6367083333333 -15.288527777777778
# {'object': 'ZTF20aaazrxx', 'separation': 0.1059384138520795}
# 308 224.06216666666663 -12.145111111111111
# Bad Request:{"error":"No object found ra=224.06217 dec=-12.14511 radius=2.00"}
# 309 226.80670833333332 -13.737194444444444
# {'object': 'ZTF21abfzmnx', 'separation': 0.1926821666175167}
# 310 229.3323333333333 -22.96488888888889
# Bad Request:{"error":"No object found ra=229.33233 dec=-22.96489 radius=2.00"}
# 311 223.83729166666663 -1.8134166666666667
# {'object': 'ZTF18acwyzvb', 'separation': 0.22994443283264912}
# 312 231.61391666666665 -23.02872222222222
# Bad Request:{"error":"No object found ra=231.61392 dec=-23.02872 radius=2.00"}
# 313 233.27549999999997 -23.592944444444445
# Bad Request:{"error":"No object found ra=233.27550 dec=-23.59294 radius=2.00"}
# 314 234.53412499999996 -18.633777777777777
# {'object': 'ZTF19aauxexa', 'separation': 0.4654223913824712}
# 315 234.18849999999998 -14.428777777777777
# {'object': 'ZTF19aamwqtq', 'separation': 0.20496457701604873}
# 316 220.13779166666663 -15.756416666666667
# {'object': 'ZTF18acyygqo', 'separation': 0.15807314138248363}
# 317 235.18554166666664 -18.94825
# Bad Request:{"error":"No object found ra=235.18554 dec=-18.94825 radius=2.00"}
# 318 227.48854166666663 -23.81625
# {'object': 'ZTF20abistfy', 'separation': 0.049750321494718634}
# 319 220.53274999999996 -17.973055555555554
# Bad Request:{"error":"No object found ra=220.53275 dec=-17.97306 radius=2.00"}
# 320 232.71937499999999 -4.099805555555555
# {'object': 'ZTF20aareovl', 'separation': 0.2078025423258165}
# 321 233.95941666666664 -21.453277777777778
# Bad Request:{"error":"No object found ra=233.95942 dec=-21.45328 radius=2.00"}
# 322 234.00729166666665 -16.71633333333333
# {'object': 'ZTF19aaaqqaj', 'separation': 0.5303070111728413}
# 323 234.487 -24.670694444444447
# Bad Request:{"error":"No object found ra=234.48700 dec=-24.67069 radius=2.00"}
# 324 217.23820833333332 -16.609833333333334
# {'object': 'ZTF19aapymzi', 'separation': 1.6599977715876126}
# 325 227.6747083333333 -9.074083333333332
# {'object': 'ZTF18adbafkf', 'separation': 0.053677856576176644}
# 326 238.79649999999995 -13.648249999999999
# {'object': 'ZTF19aabzwkh', 'separation': 0.5562679621651047}
# 327 230.89749999999995 -10.190722222222222
# {'object': 'ZTF19aanycxa', 'separation': 0.15884816048762887}
# 328 237.4425833333333 -10.593583333333333
# {'object': 'ZTF19aaseplf', 'separation': 0.3006148526251193}
# 329 233.7567083333333 -16.448166666666665
# {'object': 'ZTF19aatysfx', 'separation': 0.08785293482809704}
# 330 231.9060833333333 -20.884777777777778
# {'object': 'ZTF19aauymhu', 'separation': 0.613070452013449}
# 331 223.45529166666662 -4.1219166666666665
# {'object': 'ZTF22aaflcke', 'separation': 0.05420326410643417}
# 332 225.292625 -6.843388888888889
# {'object': 'ZTF22aalwamk', 'separation': 0.19980667478656602}
# 333 239.11487499999998 -30.86527777777778
# Bad Request:{"error":"No object found ra=239.11487 dec=-30.86528 radius=2.00"}
# 334 237.49054166666664 -30.299944444444446
# Bad Request:{"error":"No object found ra=237.49054 dec=-30.29994 radius=2.00"}
# 335 239.31374999999997 -30.810277777777777
# Bad Request:{"error":"No object found ra=239.31375 dec=-30.81028 radius=2.00"}
# 336 234.65916666666664 -30.597277777777776
# Bad Request:{"error":"No object found ra=234.65917 dec=-30.59728 radius=2.00"}
# 337 238.27312499999996 -30.098277777777778
# Bad Request:{"error":"No object found ra=238.27312 dec=-30.09828 radius=2.00"}
# 338 228.930875 -30.303944444444443
# {'object': 'ZTF21abhyrea', 'separation': 0.1682910655340137}
# 339 125.65020833333332 51.09016666666667
# {'object': 'ZTF18aaagbzp', 'separation': 0.37773848520280073}
# 340 135.78704166666668 41.29655555555556
# {'object': 'ZTF18aadfmdc', 'separation': 0.3561116795516601}
# 341 125.21283333333332 49.575500000000005
# Bad Request:{"error":"No object found ra=125.21283 dec=49.57550 radius=2.00"}
# 342 116.38308333333332 45.64158333333333
# {'object': 'ZTF18aaeaftr', 'separation': 1.437527954125565}
# 343 118.16854166666666 36.47313888888889
# {'object': 'ZTF18abztpda', 'separation': 0.145728132463039}
# 344 118.67929166666666 50.12475
# {'object': 'ZTF18aabjfsq', 'separation': 0.1918961065667158}
# 345 121.14258333333332 51.06372222222222
# {'object': 'ZTF18aacsfxc', 'separation': 1.9176018535348158}
# 346 123.34137499999999 45.469277777777776
# {'object': 'ZTF18adqyesq', 'separation': 0.30155613930181396}
# 347 126.04054166666666 49.523472222222225
# Bad Request:{"error":"No object found ra=126.04054 dec=49.52347 radius=2.00"}
# 348 133.55841666666666 39.093722222222226
# {'object': 'ZTF18aaadlpa', 'separation': 0.967989026594893}
# 349 136.21716666666666 44.04911111111111
# Bad Request:{"error":"No object found ra=136.21717 dec=44.04911 radius=2.00"}
# 350 132.80599999999998 34.74686111111111
# {'object': 'ZTF18adooaph', 'separation': 0.5292460127020472}
# 351 108.97454166666665 58.26847222222222
# {'object': 'ZTF18aabhkoo', 'separation': 0.11039263532293267}
# 352 118.22899999999998 53.092000000000006
# Bad Request:{"error":"No object found ra=118.22900 dec=53.09200 radius=2.00"}
# 353 122.01574999999997 34.88261111111111
# {'object': 'ZTF19acdjjbv', 'separation': 0.10927448865021139}
# 354 98.37816666666666 59.31330555555555
# {'object': 'ZTF18abztcib', 'separation': 0.19639703902679362}
# 355 99.82341666666666 57.38625
# {'object': 'ZTF19aamfzhw', 'separation': 0.03134454107348264}
# 356 110.803 50.83555555555556
# {'object': 'ZTF21acqbdvg', 'separation': 0.1167962348072196}
# 357 126.9274583333333 34.821333333333335
# Bad Request:{"error":"No object found ra=126.92746 dec=34.82133 radius=2.00"}
# 358 109.98449999999998 46.821250000000006
# Bad Request:{"error":"No object found ra=109.98450 dec=46.82125 radius=2.00"}
# 359 138.23587499999996 42.720777777777776
# {'object': 'ZTF18aasslfa', 'separation': 1.6708716629824636}
# 360 102.45804166666665 55.69463888888889
# {'object': 'ZTF19aaadfxf', 'separation': 0.2043414075562294}
# 361 99.74420833333332 59.064416666666666
# {'object': 'ZTF20aagqrbx', 'separation': 0.3068047685087614}
# 362 117.99308333333332 53.94647222222222
# Bad Request:{"error":"No object found ra=117.99308 dec=53.94647 radius=2.00"}
# 363 112.27604166666664 55.673833333333334
# {'object': 'ZTF20abahuik', 'separation': 0.06498288783868554}
# 364 123.45604166666665 53.01763888888889
# Bad Request:{"error":"No object found ra=123.45604 dec=53.01764 radius=2.00"}
# 365 100.41370833333333 52.8935
# Bad Request:{"error":"No object found ra=100.41371 dec=52.89350 radius=2.00"}
# 366 101.90858333333333 56.144666666666666
# {'object': 'ZTF21acbdczl', 'separation': 0.03281690890998135}
# 367 118.09770833333333 37.34575
# {'object': 'ZTF22aaahgwc', 'separation': 0.07616043773078464}
# 368 109.86412499999999 47.53883333333333
# {'object': 'ZTF21aarucpz', 'separation': 0.18397916777057285}
# 369 105.00245833333332 57.09308333333333
# Bad Request:{"error":"No object found ra=105.00246 dec=57.09308 radius=2.00"}
# 370 108.98424999999999 45.51880555555555
# {'object': 'ZTF22aaahgtt', 'separation': 0.05692359314684845}
# 371 104.64754166666665 51.39238888888889
# {'object': 'ZTF23aaanxbm', 'separation': 0.17201096116113473}
# 372 106.94566666666665 52.536249999999995
# Bad Request:{"error":"No object found ra=106.94567 dec=52.53625 radius=2.00"}
# 373 118.29879166666665 35.44208333333333
# {'object': 'ZTF17aacxkaq', 'separation': 0.1532483502921843}
# 374 130.992 42.84355555555556
# {'object': 'ZTF18aaqjfit', 'separation': 0.327477478027405}
# 375 122.22387499999998 35.84825
# {'object': 'ZTF17aadewid', 'separation': 0.0894513606593337}
# 376 121.30775 40.84016666666667
# {'object': 'ZTF20aahcybq', 'separation': 0.2072107056435451}
# 377 125.34891666666664 45.69316666666666
# {'object': 'ZTF18aaaxlfa', 'separation': 0.25349159247247915}
# 378 110.00674999999998 52.57255555555556
# {'object': 'ZTF18achushg', 'separation': 1.2437276551230396}
# 379 121.22583333333331 37.130916666666664
# Bad Request:{"error":"No object found ra=121.22583 dec=37.13092 radius=2.00"}
# 380 127.28504166666664 48.44408333333333
# Bad Request:{"error":"No object found ra=127.28504 dec=48.44408 radius=2.00"}
# 381 125.08087499999999 47.792027777777776
# {'object': 'ZTF18aakabcf', 'separation': 0.12665259393211079}
# 382 118.38329166666664 37.966861111111115
# {'object': 'ZTF18aawvzcg', 'separation': 0.030581785877509732}
# 383 111.55083333333333 46.4345
# Bad Request:{"error":"No object found ra=111.55083 dec=46.43450 radius=2.00"}
# 384 135.06945833333333 34.657694444444445
# {'object': 'ZTF18adoezmg', 'separation': 0.18287185780148846}
# 385 116.00199999999998 41.91775
# {'object': 'ZTF18aaacggd', 'separation': 0.48681164103029806}
# 386 118.57804166666666 38.207
# Bad Request:{"error":"No object found ra=118.57804 dec=38.20700 radius=2.00"}
# 387 123.63154166666665 42.266555555555556
# {'object': 'ZTF20aaoqqyf', 'separation': 0.36713585150503186}
# 388 121.75458333333333 55.79411111111111
# {'object': 'ZTF20aazrimq', 'separation': 0.37084813854729093}
# 389 116.19141666666665 40.230250000000005
# {'object': 'ZTF19adbtjfs', 'separation': 0.5515351322102973}
# 390 94.93687499999999 60.988083333333336
# {'object': 'ZTF18acpuhto', 'separation': 0.5200992843896728}
# 391 113.67799999999998 50.70825
# {'object': 'ZTF18abykrbg', 'separation': 0.5740861354893025}
# 392 121.41241666666666 35.68194444444444
# {'object': 'ZTF20aasylce', 'separation': 0.1654605396630443}
# 393 135.45870833333333 37.912305555555555
# Bad Request:{"error":"No object found ra=135.45871 dec=37.91231 radius=2.00"}
# 394 106.02254166666665 50.569611111111115
# Bad Request:{"error":"No object found ra=106.02254 dec=50.56961 radius=2.00"}
# 395 105.31579166666664 50.38933333333333
# {'object': 'ZTF18acgmwpt', 'separation': 0.2633615902905519}
# 396 110.57920833333331 46.81766666666667
# {'object': 'ZTF19abtsows', 'separation': 0.03713827038732537}
# 397 127.66049999999998 40.79419444444444
# {'object': 'ZTF18acponib', 'separation': 0.37038932563576255}
# 398 126.29791666666664 35.22413888888889
# Bad Request:{"error":"No object found ra=126.29792 dec=35.22414 radius=2.00"}
# 399 101.58166666666665 50.763666666666666
# {'object': 'ZTF18aaaeyfq', 'separation': 0.26404225118435865}
# 400 101.98866666666666 59.80313888888889
# Bad Request:{"error":"No object found ra=101.98867 dec=59.80314 radius=2.00"}
# 401 105.11366666666665 55.49761111111111
# {'object': 'ZTF18acusatr', 'separation': 0.01267271612591058}
# 402 110.03074999999998 45.26986111111111
# {'object': 'ZTF18aabrbjr', 'separation': 0.17478946525355868}
# 403 112.45275 59.64011111111111
# {'object': 'ZTF18abuqhmk', 'separation': 1.1604768282543212}
# 404 113.35616666666665 37.62916666666667
# {'object': 'ZTF19aarhrcv', 'separation': 0.36425549970750076}
# 405 110.53070833333331 59.29972222222222
# {'object': 'ZTF18abyskuw', 'separation': 0.25192150704083116}
# 406 105.22991666666665 53.42419444444444
# {'object': 'ZTF17aaairls', 'separation': 0.3831023819192669}
# 407 128.427625 45.15697222222222
# Bad Request:{"error":"No object found ra=128.42763 dec=45.15697 radius=2.00"}
# 408 109.50204166666664 56.48902777777778
# {'object': 'ZTF18adnluuy', 'separation': 0.19593954514957976}
# 409 143.59745833333332 40.63591666666667
# {'object': 'ZTF18aadfuxg', 'separation': 0.6674281432755308}
# 410 109.80049999999999 48.976305555555555
# {'object': 'ZTF18aaawjmk', 'separation': 0.09719529582174988}
# 411 99.22937499999998 55.96130555555556
# {'object': 'ZTF18aabhjpn', 'separation': 0.4095602638300697}
# 412 113.03383333333332 41.50241666666667
# Bad Request:{"error":"No object found ra=113.03383 dec=41.50242 radius=2.00"}
# 413 116.82 42.81361111111111
# {'object': 'ZTF18aaabbbv', 'separation': 0.13704192042363078}
# 414 119.64633333333332 48.42322222222222
# Bad Request:{"error":"No object found ra=119.64633 dec=48.42322 radius=2.00"}
# 415 120.56412499999998 40.17975
# {'object': 'ZTF18aaclrfn', 'separation': 0.7586713904484685}
# 416 121.79308333333333 48.88322222222222
# {'object': 'ZTF18acrgvys', 'separation': 0.25678695488391157}
# 417 122.28499999999998 38.23502777777778
# {'object': 'ZTF18aaameuf', 'separation': 0.255218634759518}
# 418 124.045125 45.502833333333335
# {'object': 'ZTF18aacktzu', 'separation': 0.038142188343107786}
# 419 129.46254166666665 38.5035
# {'object': 'ZTF18aacvbng', 'separation': 0.2609471962282113}
# 420 130.6172083333333 46.39288888888889
# {'object': 'ZTF20aaoqryb', 'separation': 0.21143048883116}
# 421 135.0689583333333 43.02175
# {'object': 'ZTF18aajyerc', 'separation': 0.852148358389612}
# 422 135.58904166666665 38.32827777777778
# Bad Request:{"error":"No object found ra=135.58904 dec=38.32828 radius=2.00"}
# 423 135.96141666666665 33.009972222222224
# {'object': 'ZTF18aallweb', 'separation': 0.3289597725327024}
# 424 140.62191666666666 33.12877777777778
# {'object': 'ZTF17aacmhee', 'separation': 0.25494087088100265}
# 425 114.15258333333331 41.85602777777778
# {'object': 'ZTF21ackwqjy', 'separation': 0.11888061487348062}
# 426 124.58366666666664 44.23191666666667
# {'object': 'ZTF22abedept', 'separation': 0.09117726946060709}
# 427 112.17820833333333 53.627611111111115
# {'object': 'ZTF18adonnra', 'separation': 0.12920029957896276}
# 428 116.92758333333332 41.317
# {'object': 'ZTF18abrqfjs', 'separation': 0.1723949759041594}
# 429 102.06979166666665 55.27372222222222
# {'object': 'ZTF18abxwiqz', 'separation': 0.12378575527685497}
# 430 116.46020833333333 56.25780555555556
# {'object': 'ZTF21aceejop', 'separation': 0.05197904098331289}
# 431 281.1112083333333 37.99775
# {'object': 'ZTF18aakzfjo', 'separation': 0.31096419363624855}
# 432 283.17241666666666 26.75872222222222
# {'object': 'ZTF19abpcizw', 'separation': 0.08506670885773181}
# 433 284.6851666666666 30.25927777777778
# Bad Request:{"error":"No object found ra=284.68517 dec=30.25928 radius=2.00"}
# 434 278.80341666666664 38.33452777777778
# {'object': 'ZTF18aammpul', 'separation': 0.1518239055382967}
# 435 286.817875 44.01905555555555
# {'object': 'ZTF19aarlhma', 'separation': 1.0855587645890954}
# 436 281.16324999999995 43.37444444444444
# {'object': 'ZTF18aakzafr', 'separation': 0.2516588737801734}
# 437 284.88737499999996 42.40333333333333
# Bad Request:{"error":"No object found ra=284.88737 dec=42.40333 radius=2.00"}
# 438 287.2149583333333 43.008694444444444
# {'object': 'ZTF18acaxfpa', 'separation': 0.2406049867461076}
# 439 275.299875 38.79533333333333
# {'object': 'ZTF18aabenub', 'separation': 0.30916660963195286}
# 440 277.19649999999996 35.82477777777778
# {'object': 'ZTF18aakyvxh', 'separation': 0.24661570623412704}
# 441 287.016375 31.39863888888889
# Bad Request:{"error":"No object found ra=287.01637 dec=31.39864 radius=2.00"}
# 442 287.55841666666663 29.10386111111111
# {'object': 'ZTF18abbmmuf', 'separation': 0.2298417010968186}
# 443 285.0829166666667 44.46216666666667
# {'object': 'ZTF18adjcwdy', 'separation': 0.09835472404818456}
# 444 288.9462083333333 41.51686111111111
# Bad Request:{"error":"No object found ra=288.94621 dec=41.51686 radius=2.00"}
# 445 285.38112499999994 42.91466666666666
# {'object': 'ZTF18abddimk', 'separation': 0.22310502149644304}
# 446 290.1487083333333 37.74780555555556
# {'object': 'ZTF18adlczrp', 'separation': 0.5807693424406645}
# 447 287.7475833333333 28.944083333333335
# {'object': 'ZTF18abgrsxw', 'separation': 0.10445668474065462}
# 448 288.4933749999999 40.73577777777778
# {'object': 'ZTF21aciqyqo', 'separation': 0.03726523920347172}
# 449 289.3603333333333 37.17816666666666
# Bad Request:{"error":"No object found ra=289.36033 dec=37.17817 radius=2.00"}
# 450 288.09712499999995 40.83152777777778
# {'object': 'ZTF18abgisyo', 'separation': 0.20154845516271166}
# 451 286.330875 30.256777777777778
# ...
# 4081 316.83975 27.51988888888889
# {'object': 'ZTF17aabuvdv', 'separation': 0.10082108841977538}
# 4082 285.0185833333333 24.010555555555555
# {'object': 'ZTF18acapnsw', 'separation': 0.10110179732985679}
# 4083 297.29862499999996 29.111472222222222
# {'object': 'ZTF21aagtxml', 'separation': 0.13711083766229606}
# 4084 288.1599999999999 22.698
# {'object': 'ZTF18abyvkvb', 'separation': 0.07751286755759994}
# 4085 303.1667916666666 25.17402777777778
# {'object': 'ZTF20abylore', 'separation': 0.1849266622695551}
# 4086 302.9846666666666 23.03880555555556
# {'object': 'ZTF18abgocgu', 'separation': 0.15098155948192787}
# 4087 305.0671666666666 24.858611111111113
# {'object': 'ZTF18abxyvdr', 'separation': 0.057006511753288414}
# 4088 308.4 24.451527777777777
# {'object': 'ZTF18abikoki', 'separation': 0.10166088987258555}
# 4089 310.0297083333333 26.00883333333333
# {'object': 'ZTF18acswkeb', 'separation': 0.08584056100296872}
# 4090 301.2006666666666 23.857722222222225
# {'object': 'ZTF18adkbcsk', 'separation': 0.06154849419344735}
# 4091 296.40666666666664 28.092388888888888
# Bad Request:{"error":"No object found ra=296.40667 dec=28.09239 radius=2.00"}
# 4092 293.61024999999995 26.174666666666667
# Bad Request:{"error":"No object found ra=293.61025 dec=26.17467 radius=2.00"}
# 4093 306.42745833333333 26.345499999999998
# {'object': 'ZTF18abzpwqj', 'separation': 0.2554221362946856}
# 4094 308.99866666666657 22.324472222222223
# Bad Request:{"error":"No object found ra=308.99867 dec=22.32447 radius=2.00"}
# 4095 285.48825 22.939777777777778
# {'object': 'ZTF22aabbiok', 'separation': 0.11719995614522197}
# 4096 301.1785416666666 27.33986111111111
# {'object': 'ZTF18aaydaxi', 'separation': 0.0525214456648347}
# 4097 308.8962083333333 27.37697222222222
# {'object': 'ZTF19aaphrna', 'separation': 0.11309790965112564}
# 4098 311.797375 27.71561111111111
# {'object': 'ZTF18adlamuj', 'separation': 0.14354004521618074}
# 4099 290.64187499999997 27.53366666666667
# {'object': 'ZTF18aasnlwa', 'separation': 0.1291637351804439}
# 4100 307.96445833333325 27.47936111111111
# {'object': 'ZTF18ablpocf', 'separation': 0.07553769271063254}
# 4101 302.75516666666664 28.28977777777778
# {'object': 'ZTF18absdtap', 'separation': 0.21343166331421487}
# 4102 307.92695833333323 28.894055555555553
# {'object': 'ZTF20aavztpy', 'separation': 0.14902926531638838}
# 4103 310.4957916666666 21.977277777777775
# {'object': 'ZTF18abnblvc', 'separation': 0.09081390855801226}
# 4104 306.6984583333333 22.03838888888889
# {'object': 'ZTF19aabkaps', 'separation': 0.09806615210874374}
# 4105 304.477125 27.925416666666667
# {'object': 'ZTF18acgzfhz', 'separation': 0.1624063301704055}
# 4106 289.1551666666666 24.409416666666665
# {'object': 'ZTF21ablssud', 'separation': 0.09552868711471768}
# 4107 290.46079166666664 23.390249999999998
# {'object': 'ZTF18adkendn', 'separation': 0.051705704955597384}
# 4108 311.3046666666666 20.51775
# {'object': 'ZTF21acbqmnb', 'separation': 0.03134454107348264}
# 4109 300.6644583333333 21.78875
# {'object': 'ZTF21acdepkq', 'separation': 0.05394120005341208}
# 4110 313.28008333333327 26.119
# Bad Request:{"error":"No object found ra=313.28008 dec=26.11900 radius=2.00"}
# 4111 298.77987499999995 27.934083333333334
# {'object': 'ZTF19aausqxr', 'separation': 0.27513308465344183}
# 4112 305.35325 25.157277777777775
# {'object': 'ZTF19aclkbzu', 'separation': 0.13906062188721705}
# 4113 312.3625833333333 23.224249999999998
# {'object': 'ZTF20acynejt', 'separation': 0.06845199093393252}
# 4114 289.67299999999994 25.571166666666667
# {'object': 'ZTF22abdxlaq', 'separation': 0.02216393754623983}
# 4115 297.763375 28.755166666666668
# {'object': 'ZTF23aazddim', 'separation': 0.09205374625891155}
# 4116 302.98295833333333 28.30311111111111
# {'object': 'ZTF18aaxczhw', 'separation': 0.20343790390779143}
# 4117 284.71883333333324 23.231638888888888
# {'object': 'ZTF18adlvjlt', 'separation': 0.751024723752472}
# 4118 305.490375 21.488722222222222
# {'object': 'ZTF18abqkwgc', 'separation': 0.27597303060603967}
# 4119 306.81325 22.170972222222222
# {'object': 'ZTF18abjrdjs', 'separation': 0.1492509644841588}
# 4120 308.13933333333335 22.72447222222222
# {'object': 'ZTF18aboronz', 'separation': 0.03662599384648257}
# 4121 308.2884166666666 25.852305555555557
# Bad Request:{"error":"No object found ra=308.28842 dec=25.85231 radius=2.00"}
# 4122 309.8915416666666 26.156805555555554
# {'object': 'ZTF19aargbdq', 'separation': 0.6548467687773073}
# 4123 309.9065833333333 21.651666666666664
# {'object': 'ZTF18acxgvqt', 'separation': 0.2749785299639756}
# 4124 311.6163333333333 24.37188888888889
# {'object': 'ZTF18abiklxj', 'separation': 0.226904702767123}
# 4125 314.5707499999999 23.970166666666664
# {'object': 'ZTF18abvhzxn', 'separation': 1.0566518984640019}
# 4126 315.41849999999994 21.95883333333333
# {'object': 'ZTF18abortbw', 'separation': 0.07453047840694374}
# 4127 315.4237916666666 23.443833333333334
# {'object': 'ZTF18acascph', 'separation': 0.31249459067695917}
# 4128 315.8940416666667 23.69125
# {'object': 'ZTF18absnqxs', 'separation': 0.14817103270017312}
# 4129 316.5925833333333 25.355805555555555
# {'object': 'ZTF18abjrcju', 'separation': 0.2976938165226048}
# 4130 317.1002083333333 23.47472222222222
# {'object': 'ZTF18abjgzwo', 'separation': 0.46305169123081175}
# 4131 318.2447083333333 24.36261111111111
# Bad Request:{"error":"No object found ra=318.24471 dec=24.36261 radius=2.00"}
# 4132 318.34549999999996 26.113166666666668
# Bad Request:{"error":"No object found ra=318.34550 dec=26.11317 radius=2.00"}
# 4133 319.12804166666666 27.565833333333334
# {'object': 'ZTF18abwdnml', 'separation': 0.11748173559813925}
# 4134 319.5385 26.953833333333332
# {'object': 'ZTF18admbzze', 'separation': 0.35492922102997493}
# 4135 319.7295833333333 28.054277777777777
# Bad Request:{"error":"No object found ra=319.72958 dec=28.05428 radius=2.00"}
# 4136 320.71687499999996 27.539416666666668
# {'object': 'ZTF18abbrizh', 'separation': 0.08338427423675152}
# 4137 321.60054166666663 25.640777777777778
# {'object': 'ZTF18aazsdnv', 'separation': 0.3414032325383763}
# 4138 314.21258333333327 29.35825
# {'object': 'ZTF18abzqgvp', 'separation': 0.09572626475519212}
# 4139 314.6989166666666 22.121666666666666
# {'object': 'ZTF18ablpocl', 'separation': 0.15834184651031313}
# 4140 314.7352916666666 23.88525
# {'object': 'ZTF18absnrin', 'separation': 0.16941003441286714}
# 4141 315.4254166666666 23.099916666666665
# {'object': 'ZTF18achagoh', 'separation': 0.1682910655340137}
# 4142 315.4663749999999 28.29625
# {'object': 'ZTF18abmnvbe', 'separation': 0.10377617792181568}
# 4143 307.96545833333323 21.223388888888888
# {'object': 'ZTF21aaucnik', 'separation': 0.3161612231625681}
# 4144 311.61949999999996 22.570833333333333
# {'object': 'ZTF18abtovmq', 'separation': 0.11183796046762405}
# 4145 290.1329999999999 25.43338888888889
# {'object': 'ZTF18aazuokc', 'separation': 0.03912035193911381}
# 4146 303.3122916666666 23.722638888888888
# {'object': 'ZTF18aawltzy', 'separation': 0.16126805630301838}
# 4147 314.53749999999997 25.592416666666665
# {'object': 'ZTF18absnrzk', 'separation': 0.1459224799143172}
# 4148 311.1956666666666 26.888694444444443
# {'object': 'ZTF18abjhael', 'separation': 0.25757670313197356}
# 4149 305.50825 24.55363888888889
# {'object': 'ZTF18abkohpd', 'separation': 0.20981580724347718}
# 4150 284.7867083333333 23.706944444444442
# {'object': 'ZTF18ablvrie', 'separation': 0.23760224528937632}
# 4151 292.74862499999995 26.81511111111111
# {'object': 'ZTF18abcuqpc', 'separation': 0.2030893322246336}
# 4152 293.49291666666664 26.451416666666667
# {'object': 'ZTF18adjsorh', 'separation': 0.1106063676340173}
# 4153 311.7535 26.28275
# {'object': 'ZTF18aboqtqk', 'separation': 0.11305613756857386}
# 4154 313.71624999999995 24.81983333333333
# Bad Request:{"error":"No object found ra=313.71625 dec=24.81983 radius=2.00"}
# 4155 314.3043333333333 27.202166666666667
# {'object': 'ZTF18abzqgut', 'separation': 0.08287288374505188}
# 4156 298.1157916666666 28.747944444444446
# {'object': 'ZTF18aavekzi', 'separation': 0.0970493933689842}
# 4157 315.889375 22.799222222222223
# {'object': 'ZTF18absnqzf', 'separation': 0.22359143522084093}
# 4158 293.7958749999999 26.66622222222222
# {'object': 'ZTF18aauqlvx', 'separation': 0.01567227053674131}
# 4159 287.68041666666664 25.492194444444447
# {'object': 'ZTF18abgrtjd', 'separation': 0.1539863080926129}
# 4160 285.50304166666666 22.756527777777777
# {'object': 'ZTF18adlqbny', 'separation': 0.08982023381463296}
# 4161 305.99749999999995 23.05152777777778
# {'object': 'ZTF18absaqea', 'separation': 0.07943894670725507}
# 4162 298.23745833333334 22.68786111111111
# {'object': 'ZTF18aaxayyj', 'separation': 0.20791616393325973}
# 4163 304.28587500000003 26.33983333333333
# {'object': 'ZTF18aaxaacc', 'separation': 0.2627870347323329}
# 4164 290.40708333333333 23.007083333333334
# {'object': 'ZTF18aasnqbc', 'separation': 0.04389957639994919}
# 4165 310.69424999999995 23.81797222222222
# {'object': 'ZTF18abtovwx', 'separation': 0.2566949660022623}
# 4166 285.1160416666666 22.151666666666664
# {'object': 'ZTF18aaudxnf', 'separation': 0.06283959636637347}
# 4167 289.576875 24.37811111111111
# {'object': 'ZTF18aaueamh', 'separation': 0.0841735953099787}
# 4168 290.74562499999996 25.940277777777776
# {'object': 'ZTF18aauqkge', 'separation': 0.1519483004018839}
# 4169 290.7630833333333 24.865861111111112
# {'object': 'ZTF18aauqhds', 'separation': 0.14091642013549321}
# 4170 291.80379166666665 26.959166666666665
# {'object': 'ZTF18abdfrfw', 'separation': 0.06934324116096383}
# 4171 291.9089166666666 23.38475
# {'object': 'ZTF18abarhvx', 'separation': 0.06147170253011499}
# 4172 292.0820416666666 19.591805555555556
# {'object': 'ZTF18abbdjkb', 'separation': 0.40825495358131236}
# 4173 297.4329583333333 20.386333333333333
# {'object': 'ZTF18adjxlgz', 'separation': 0.062159412334093396}
# 4174 297.77345833333334 26.26833333333333
# {'object': 'ZTF18aayotjv', 'separation': 0.049939847215301106}
# 4175 297.8580416666667 22.411194444444444
# {'object': 'ZTF18aawbmgc', 'separation': 0.08960963508683553}
# 4176 297.9458333333333 27.31061111111111
# Bad Request:{"error":"No object found ra=297.94583 dec=27.31061 radius=2.00"}
# 4177 298.6029583333333 23.46013888888889
# {'object': 'ZTF18aazetql', 'separation': 0.16185278648930046}
# 4178 298.8289583333333 21.34997222222222
# {'object': 'ZTF18abhpmyy', 'separation': 0.07286406623151835}
# 4179 301.3930416666666 23.121805555555557
# {'object': 'ZTF18abnbpcl', 'separation': 0.038142188343107786}
# 4180 303.51366666666667 27.402388888888886
# {'object': 'ZTF18abdbcrk', 'separation': 0.11927728135732972}
# 4181 304.1049583333333 28.94302777777778
# {'object': 'ZTF18aaxanfj', 'separation': 0.1916990879248655}
# 4182 305.2800833333333 21.04963888888889
# {'object': 'ZTF18abmpkom', 'separation': 0.35352910030195134}
# 4183 307.0017083333333 23.450194444444445
# {'object': 'ZTF18abiknzw', 'separation': 0.2396016828928185}
# 4184 307.34566666666666 29.15758333333333
# {'object': 'ZTF18abhpyvf', 'separation': 0.24296879971759755}
# 4185 309.09770833333334 21.616694444444445
# {'object': 'ZTF18adlykis', 'separation': 0.03826582623086799}
# 4186 311.9208333333333 20.987416666666668
# {'object': 'ZTF18adlyjty', 'separation': 0.07195078311160212}
# 4187 312.0755833333333 27.147333333333332
# {'object': 'ZTF18abwdfpf', 'separation': 0.3130986206030865}
# 4188 312.26020833333325 21.87288888888889
# {'object': 'ZTF18abwdeue', 'separation': 0.03338768055024972}
# 4189 312.544 23.371472222222224
# {'object': 'ZTF18abyvbmj', 'separation': 0.14121777435426372}
# 4190 297.4472916666666 22.682166666666667
# {'object': 'ZTF18abpnawy', 'separation': 0.07049172170344192}
# 4191 298.70462499999996 19.529555555555554
# {'object': 'ZTF18aavzlyn', 'separation': 0.11103259799036573}
# 4192 305.2264583333333 25.13775
# Bad Request:{"error":"No object found ra=305.22646 dec=25.13775 radius=2.00"}
# 4193 310.5934166666666 27.203055555555554
# Bad Request:{"error":"No object found ra=310.59342 dec=27.20306 radius=2.00"}
# 4194 319.407 21.126638888888888
# {'object': 'ZTF18acbwstu', 'separation': 0.3277802374325168}
# 4195 305.03925 29.146361111111112
# {'object': 'ZTF19aaodnzd', 'separation': 0.06981843290576444}
# 4196 301.41258333333326 22.053055555555556
# Bad Request:{"error":"No object found ra=301.41258 dec=22.05306 radius=2.00"}
# 4197 320.1247916666666 21.292555555555555
# {'object': 'ZTF18abccncz', 'separation': 0.10814478168635025}
# 4198 304.384125 25.19922222222222
# {'object': 'ZTF18aazmncc', 'separation': 0.06085388079417717}
# 4199 315.3759166666666 21.81563888888889
# Bad Request:{"error":"No object found ra=315.37592 dec=21.81564 radius=2.00"}
# 4200 296.638 19.65736111111111
# {'object': 'ZTF18aayehyx', 'separation': 0.2250863425815457}
# 4201 316.74766666666665 24.107472222222224
# {'object': 'ZTF18acapszx', 'separation': 0.3943303110614597}
# 4202 293.4599583333333 23.48713888888889
# {'object': 'ZTF18aasnqfr', 'separation': 0.21822454398191757}
# 4203 290.7827083333333 24.586138888888886
# {'object': 'ZTF18aauemog', 'separation': 0.2546628040421606}
# 4204 290.579 25.388333333333332
# {'object': 'ZTF18aauethf', 'separation': 0.25047361626311626}
# 4205 298.62091666666663 19.810972222222222
# {'object': 'ZTF18aavzlyi', 'separation': 0.10267798640089938}
# 4206 303.1076666666666 23.605805555555555
# {'object': 'ZTF18aawluad', 'separation': 0.16628635249458187}
# 4207 303.7914583333333 26.55675
# {'object': 'ZTF18adkbevu', 'separation': 0.11330653906594962}
# 4208 292.28404166666667 27.01786111111111
# {'object': 'ZTF18aawurfo', 'separation': 0.17826793733733834}
# 4209 289.1009166666666 22.535333333333334
# {'object': 'ZTF18aaxdkhn', 'separation': 0.20673144680277467}
# 4210 298.91204166666665 29.13088888888889
# {'object': 'ZTF18aaxluzd', 'separation': 0.14024442574735468}
# 4211 296.1904583333333 26.858500000000003
# {'object': 'ZTF18aaxplqj', 'separation': 0.29661290845100186}
# 4212 301.9972916666666 22.470055555555554
# {'object': 'ZTF18aayelpj', 'separation': 0.13776383193539654}
# 4213 298.9052083333333 23.599416666666666
# {'object': 'ZTF18aaypfws', 'separation': 0.058236125087663335}
# 4214 299.81925 24.608777777777778
# {'object': 'ZTF18aazerxc', 'separation': 0.18482446460368435}
# 4215 297.66187499999995 21.281055555555554
# {'object': 'ZTF18abchfow', 'separation': 0.08950414990008045}
# 4216 287.247125 25.662694444444444
# {'object': 'ZTF18abcyzxp', 'separation': 0.16918683268957369}
# 4217 308.7450833333333 23.618972222222222
# {'object': 'ZTF18adlallm', 'separation': 0.027490981109996503}
# 4218 292.9902916666666 20.50883333333333
# {'object': 'ZTF18abikpuh', 'separation': 0.12049864953360188}
# 4219 304.8370416666666 25.250416666666666
# {'object': 'ZTF18abikqiu', 'separation': 0.21846250885894483}
# 4220 307.37787499999996 22.593416666666666
# {'object': 'ZTF18adqqszt', 'separation': 0.27219889222926374}
# 4221 312.55137499999995 28.893916666666666
# {'object': 'ZTF18abmnvsq', 'separation': 0.4986980664687509}
# 4222 303.75741666666664 26.66022222222222
# {'object': 'ZTF18abnudna', 'separation': 0.12255860472649538}
# 4223 308.7468333333333 24.60575
# {'object': 'ZTF18abnyktn', 'separation': 0.0592014304859646}
# 4224 319.10208333333327 26.83961111111111
# {'object': 'ZTF18aborthz', 'separation': 0.1651748192984847}
# 4225 285.4344166666666 22.133277777777778
# {'object': 'ZTF18abrwwzs', 'separation': 0.040891390521579064}
# 4226 311.5192083333333 22.748055555555556
# {'object': 'ZTF18absnibc', 'separation': 0.033669438123991285}
# 4227 306.55683333333326 22.82425
# {'object': 'ZTF18abuktge', 'separation': 0.13878862041039433}
# 4228 284.6389166666666 24.40922222222222
# {'object': 'ZTF18abwdpla', 'separation': 0.12217259241420132}
# 4229 306.0961666666666 24.069416666666665
# {'object': 'ZTF18abxyuzo', 'separation': 0.12945596119917718}
# 4230 308.8737916666666 25.762916666666666
# {'object': 'ZTF18abzpxiu', 'separation': 0.11651279752213503}
# 4231 298.6142916666666 24.85738888888889
# {'object': 'ZTF19abasmma', 'separation': 0.23788039836012395}
# 4232 313.62295833333326 26.51175
# {'object': 'ZTF19abxzumq', 'separation': 0.04908121850686596}
# 4233 313.2380416666666 26.30227777777778
# {'object': 'ZTF20abopngr', 'separation': 0.10096154043366118}
# 4234 312.15816666666666 27.055222222222223
# {'object': 'ZTF21acatkss', 'separation': 0.15232087546157186}
# 4235 312.9272083333333 26.513333333333332
# {'object': 'ZTF22abmlesb', 'separation': 0.08617008452173909}

# %%
# Load the two csv files.
pt1 = pd.read_csv(f'../processed_data/AAVSOCVsZTFxmatch_{date}_0_4499.csv')
pt2 = pd.read_csv(f'../processed_data/AAVSOCVsZTFxmatch_{date}_4500_last.csv')

# Concatenate the two dataframes.
AAVSO_CVS_3 = pd.concat([pt1, pt2], ignore_index=True)

# Refine AAVSO VSX CVs to those with ZTF counterparts; reset index.
AAVSO_CVS_3 = AAVSO_CVS_3[AAVSO_CVS_3['Xmatch_obj'].notna()].reset_index(drop=True)
AAVSO_CVS_3
# Out:
#               Name         AUID                   Coords Const   Type  \
# 0           AR And  000-BBD-275  01 45 03.27 +37 56 33.2   And   UGSS
# 1           BV And  000-BCT-512  23 27 02.09 +50 07 13.0   And     UG
# 2           FO And  000-BBC-590  01 15 32.16 +37 37 35.6   And   UGSU
# 3           FS And  000-BBD-866  02 25 55.03 +37 34 05.3   And     UG
# 4           HV And  000-BCT-527  00 40 55.38 +43 24 59.5   And  NL/VY
# ...            ...          ...                      ...   ...    ...
# 5900  ZTF19abasmma           --  19 54 27.43 +24 51 26.6   Vul     UG
# 5901  ZTF19abxzumq           --  20 54 29.51 +26 30 42.3   Vul     UG
# 5902  ZTF20abopngr           --  20 52 57.13 +26 18 08.2   Vul     UG
# 5903  ZTF21acatkss           --  20 48 37.96 +27 03 18.8   Vul     UG
# 5904  ZTF22abmlesb  000-BPL-654  20 51 42.53 +26 30 48.0   Vul     UG
#
#        Period              Mag          ra        dec    Xmatch_obj  \
# 0       0.163    11.0 - 17.6 V   26.263625  37.942556  ZTF19acgtoku
# 1        (45)    15.3 - 18.5 V  351.758708  50.120278  ZTF17aabuphg
# 2     0.07161    13.1 - 18.6 V   18.884000  37.626556  ZTF18aabfcyi
# 3          --    14.9 - 19.0 V   36.479292  37.568139  ZTF18aabfoia
# 4      0.1403  15.2 - 20.6 G g   10.230750  43.416528  ZTF18abgjgma
# ...       ...              ...         ...        ...           ...
# 5900       --    17.5 - 21.6 g  298.614292  24.857389  ZTF19abasmma
# 5901       --     15.3 - <23 g  313.622958  26.511750  ZTF19abxzumq
# 5902       --    17.2 - 23.7 r  313.238042  26.302278  ZTF20abopngr
# 5903       --    18.2 - 22.3 r  312.158167  27.055222  ZTF21acatkss
# 5904       --     15.8 - <23 g  312.927208  26.513333  ZTF22abmlesb
#
#       separation
# 0       0.275322
# 1       0.043684
# 2       0.390732
# 3       0.053058
# 4       0.181263
# ...          ...
# 5900    0.237880
# 5901    0.049081
# 5902    0.100962
# 5903    0.152321
# 5904    0.086170
#
# [5905 rows x 11 columns]

# %% [markdown]
# ### 3.4 Inspect resultant dataframe and remove duplicates
#
# Remove duplicated cross matches;
# Save dataframe to csv

# %%
# Display duplicates - those AAVSO_VSX targets with the same ZTF counterparts.
AAVSO_CVS_3[AAVSO_CVS_3.Xmatch_obj.duplicated(keep=False)]
# Out:
#               Name         AUID                   Coords Const Type Period  \
# 1704  ZTF18abacprn           --  21 36 22.64 +63 09 48.5   Cep   UG     --
# 1709  ZTF18abbogxd  000-BNZ-280  21 36 22.64 +63 09 48.5   Cep   UG     --
# 3744        KLK-51  000-BNZ-706  19 18 52.88 +26 17 35.7   Lyr   UG     --
# 3807  ZTF18aasnnsv           --  19 18 52.88 +26 17 35.7   Lyr   UG     --
#
#                 Mag          ra        dec    Xmatch_obj  separation
# 1704  16.2 - 21.5 g  324.094333  63.163472  ZTF18abacprn    0.246367
# 1709  16.5 - 20.6 g  324.094333  63.163472  ZTF18abacprn    0.246367
# 3744  16.8 - 21.2 r  289.720333  26.293250  ZTF18aasnnsv    0.071291
# 3807   16.9 - 22: g  289.720333  26.293250  ZTF18aasnnsv    0.071291

# %%
# Drop selected duplicates and a particular object that has no light curve data (a pain in the arse).
AAVSO_CVS_4 = AAVSO_CVS_3.drop([1709,3744], axis=0).reset_index(drop=True)
AAVSO_CVS_4
# Out:
#               Name         AUID                   Coords Const   Type  \
# 0           AR And  000-BBD-275  01 45 03.27 +37 56 33.2   And   UGSS
# 1           BV And  000-BCT-512  23 27 02.09 +50 07 13.0   And     UG
# 2           FO And  000-BBC-590  01 15 32.16 +37 37 35.6   And   UGSU
# 3           FS And  000-BBD-866  02 25 55.03 +37 34 05.3   And     UG
# 4           HV And  000-BCT-527  00 40 55.38 +43 24 59.5   And  NL/VY
# ...            ...          ...                      ...   ...    ...
# 5898  ZTF19abasmma           --  19 54 27.43 +24 51 26.6   Vul     UG
# 5899  ZTF19abxzumq           --  20 54 29.51 +26 30 42.3   Vul     UG
# 5900  ZTF20abopngr           --  20 52 57.13 +26 18 08.2   Vul     UG
# 5901  ZTF21acatkss           --  20 48 37.96 +27 03 18.8   Vul     UG
# 5902  ZTF22abmlesb  000-BPL-654  20 51 42.53 +26 30 48.0   Vul     UG
#
#        Period              Mag          ra        dec    Xmatch_obj  \
# 0       0.163    11.0 - 17.6 V   26.263625  37.942556  ZTF19acgtoku
# 1        (45)    15.3 - 18.5 V  351.758708  50.120278  ZTF17aabuphg
# 2     0.07161    13.1 - 18.6 V   18.884000  37.626556  ZTF18aabfcyi
# 3          --    14.9 - 19.0 V   36.479292  37.568139  ZTF18aabfoia
# 4      0.1403  15.2 - 20.6 G g   10.230750  43.416528  ZTF18abgjgma
# ...       ...              ...         ...        ...           ...
# 5898       --    17.5 - 21.6 g  298.614292  24.857389  ZTF19abasmma
# 5899       --     15.3 - <23 g  313.622958  26.511750  ZTF19abxzumq
# 5900       --    17.2 - 23.7 r  313.238042  26.302278  ZTF20abopngr
# 5901       --    18.2 - 22.3 r  312.158167  27.055222  ZTF21acatkss
# 5902       --     15.8 - <23 g  312.927208  26.513333  ZTF22abmlesb
#
#       separation
# 0       0.275322
# 1       0.043684
# 2       0.390732
# 3       0.053058
# 4       0.181263
# ...          ...
# 5898    0.237880
# 5899    0.049081
# 5900    0.100962
# 5901    0.152321
# 5902    0.086170
#
# [5903 rows x 11 columns]

# %%
# Save dataframe to csv.
AAVSO_CVS_4.to_csv(f'../processed_data/AAVSOCVsZTFxmatch_{date}.csv', index=False)

# %% [markdown]
# ### Add sources from bright transient survey.

# %%
# Load the csv file.
df_ZTF_CVs = pd.read_csv(f'../processed_data/AAVSOCVsZTFxmatch_{date}.csv')

# Load the csv file for BTS.
bts_cvs = pd.read_csv(f'../processed_data/BTS_novae_{date}.csv')

# Sources in BTS not present in the df_ZTF_CVs dataframe.
new_novae = bts_cvs[~bts_cvs['ZTFID'].isin(df_ZTF_CVs['Xmatch_obj'])].copy()

# Combine the RA and Dec columns into a single column like in the df_ZTF_CVs dataframe.
new_novae['RA_Dec'] = new_novae['RA'].astype(str) + ' ' + new_novae['Dec'].astype(str)

# Convert the RA_Dec column into a ra and dec in degrees.
new_novae['ra'] = new_novae['RA_Dec'].apply(lambda x: SkyCoord(x, unit=(u.hourangle, u.deg)).ra.deg)
new_novae['dec'] = new_novae['RA_Dec'].apply(lambda x: SkyCoord(x, unit=(u.hourangle, u.deg)).dec.deg)

# Rename columns.
new_novae.rename(columns={'ZTFID':'Xmatch_obj', 'IAUID':'AUID', 'RA_Dec':'Coords'}, inplace=True)
new_novae['Type'] = 'N'

# Add new_novae dataframe to df_ZTF_CVs.
df_ZTF_CVs = pd.concat([df_ZTF_CVs, new_novae[['Xmatch_obj','AUID','ra','dec', 'Coords','Type']]], ignore_index=True)

# Save dataframe to csv.
df_ZTF_CVs.to_csv(f'../processed_data/AAVSOCVsZTFxmatch_{date}_BTS.csv', index=False)

pd.options.display.max_rows = 10
df_ZTF_CVs
# Out:
#         Name         AUID                   Coords Const   Type   Period  \
# 0     AR And  000-BBD-275  01 45 03.27 +37 56 33.2   And   UGSS    0.163
# 1     BV And  000-BCT-512  23 27 02.09 +50 07 13.0   And     UG     (45)
# 2     FO And  000-BBC-590  01 15 32.16 +37 37 35.6   And   UGSU  0.07161
# 3     FS And  000-BBD-866  02 25 55.03 +37 34 05.3   And     UG       --
# 4     HV And  000-BCT-527  00 40 55.38 +43 24 59.5   And  NL/VY   0.1403
# ...      ...          ...                      ...   ...    ...      ...
# 5925     NaN    AT2022oyb  00:42:29.41 +41:15:43.2   NaN      N      NaN
# 5926     NaN    AT2022qzf  00:42:09.42 +41:15:31.2   NaN      N      NaN
# 5927     NaN    AT2022ubf  00:42:30.04 +41:56:12.5   NaN      N      NaN
# 5928     NaN    AT2022yax  00:43:45.84 +41:15:58.6   NaN      N      NaN
# 5929     NaN    AT2022zzj  00:41:25.72 +40:44:23.3   NaN      N      NaN
#
#                   Mag          ra        dec    Xmatch_obj  separation
# 0       11.0 - 17.6 V   26.263625  37.942556  ZTF19acgtoku    0.275322
# 1       15.3 - 18.5 V  351.758708  50.120278  ZTF17aabuphg    0.043684
# 2       13.1 - 18.6 V   18.884000  37.626556  ZTF18aabfcyi    0.390732
# 3       14.9 - 19.0 V   36.479292  37.568139  ZTF18aabfoia    0.053058
# 4     15.2 - 20.6 G g   10.230750  43.416528  ZTF18abgjgma    0.181263
# ...               ...         ...        ...           ...         ...
# 5925              NaN   10.622542  41.262000  ZTF22aatixbc         NaN
# 5926              NaN   10.539250  41.258667  ZTF22aazmooy         NaN
# 5927              NaN   10.625167  41.936806  ZTF22abfxmpc         NaN
# 5928              NaN   10.941000  41.266278  ZTF22abnrgno         NaN
# 5929              NaN   10.357167  40.739806  ZTF22abtltcw         NaN
#
# [5930 rows x 11 columns]

# %% [markdown]
# ## 4.0 Organise subtypes
#
# ### 4.1 Display CV types
#
# See https://www.aavso.org/vsx/index.php?view=about.vartypes for the variable types.

# %%
# Load the csv file.
df_ZTF_CVs = pd.read_csv(f'../processed_data/AAVSOCVsZTFxmatch_{date}_BTS.csv')
pd.options.display.max_rows=None

# Display the different types.
df_ZTF_CVs.Type.value_counts()
# Out:
# Type
# UG                    3855
# UGSU                   553
# CV                     286
# AM                     129
# NL/VY                  125
# UGSS                   113
# UGZ                     85
# UGZ/IW                  83
# NL+E                    78
# UG+E                    74
# UGWZ                    66
# NL                      56
# N                       41
# UGSU+E                  39
# DQ                      35
# AM+E                    32
# UGER                    27
# CV+E                    21
# UGSU/IBWD               20
# UGSS+E                  17
# UG/IBWD                 15
# UG/DQ                   13
# NB                      12
# NL/VY+E                 10
# UGZ/IW+E                 9
# UG+VY                    9
# UGER+UGZ                 9
# UGZ+E                    7
# NR                       6
# UGZ+VY                   6
# UGWZ+E                   5
# UGWZ+ZZ/GWLIB            4
# NA+E                     4
# NA+UG                    4
# UGSU/IBWD+E              4
# DQ+E                     4
# N+E                      3
# NC                       3
# NR+E                     3
# IBWD+E                   3
# UG+NL/VY                 3
# UGZ/IW+VY                2
# NA/DQ+UG                 2
# NA+NL/VY                 2
# UGSS+ELL                 2
# V838MON                  2
# UG/IBWD+E                2
# EA+NL                    2
# IBWD                     2
# NA+EA                    2
# UG+R                     2
# UGWZ/IBWD                2
# CBSS+E                   1
# CV+R                     1
# NB+E                     1
# NC+SR                    1
# UGWZ/DQ+E+ZZ/GWLIB       1
# UGZ/IW+UGER              1
# UGSS+ZZ                  1
# UGZ+UGSU+VY              1
# NA+UGZ/IW                1
# NL+UGZ                   1
# NC+M                     1
# NC+EA+SR                 1
# UGSU+UGZ/IW              1
# NB+UG                    1
# UGSU+UGZ                 1
# UGER+UGZ+E               1
# E/WD+NL                  1
# UGWZ+E+ZZ                1
# UGER/IBWD+UGZ            1
# UGWZ+ZZ                  1
# UG+ELL+ROT               1
# NC+E                     1
# NA/AM+E                  1
# UGSU/DQ                  1
# UGSU+ELL                 1
# UGZ+NL                   1
# UGZ+VY+E                 1
# UG+EA                    1
# NB/DQ+EA                 1
# NA+UGSS                  1
# NA/DQ                    1
# UGSS+EW                  1
# NA/VY                    1
# UGSU/IBWD+UGZ            1
# E+NL                     1
# UGWZ+E+ZZ/GWLIB          1
# EA/WD+NL                 1
# Name: count, dtype: int64

# %% [markdown]
# ### 4.2 Label main CV types and subclasses
#
# **Overarching class**
#
# (CV) Cataclysmic Variable
#
# **Subclasses**
#
# (N) Novae
# * (NA) Fast novae
# * (NB) Slow novae
# * (NC) Very slow novae
# * (NR) Recurrent novae
#
# (UG) Dwarf Nova
# * (UGSS) SS-Cyg
# * (UGSU) SU-UMa
#     * (UGWZ) WZ Sge
#     * (UGER) ER UMa
# * (UGZ) Z Cam
#     * (UGZ/IW) IW And
#
# (IBWD) AM CVn - also includes (UGSU/IBWD; UG/IBWD)
#
# (DQ) DQ Herculis - Intermediate Polars
#
# (AM) AM Herculis - Polars
#
# (NL) Nova-likes
# * (VY) VY Scl
#
#
# ### 4.2.1 Label main CV types

# %%
# Remove non-CV types
df_ZTF_CVs = df_ZTF_CVs[~df_ZTF_CVs.Type.isin(['V838MON', 'CBSS+E'])].reset_index(drop=True)

# Dataframe of eclipsing systems as defined by the AAVSO VSX.
Eclipsing = df_ZTF_CVs[(df_ZTF_CVs['Type'].str.contains('E', na=False)) &
                       (~df_ZTF_CVs['Type'].str.contains('UGER', na=False)) & 
                       (~df_ZTF_CVs['Type'].str.contains('ELL', na=False))
                       ]

# List of eclipsing system types.
Ecl_Nms = Eclipsing['Type'].value_counts().index.to_list()

# Label eclipsing systems.
df_ZTF_CVs.loc[(df_ZTF_CVs['Type'].isin(Ecl_Nms)), 'Eclipsing'] = 1
df_ZTF_CVs.loc[(~df_ZTF_CVs['Type'].isin(Ecl_Nms)), 'Eclipsing'] = 0


# Label CV main types

# (N) Novae (Classical/Recurrent)
Nov = df_ZTF_CVs[(df_ZTF_CVs['Type'].str.contains('N', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('NL', na=False))
                ]

Nov_Nms = Nov['Type'].value_counts().index.to_list()
df_ZTF_CVs.loc[(df_ZTF_CVs['Type'].isin(Nov_Nms)), 'CV_Types'] = 'nova'


# (DN) Dwarf Novae
DN = df_ZTF_CVs[(df_ZTF_CVs['Type'].str.contains('UG', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('IBWD', na=False)) & 
                (~df_ZTF_CVs['Type'].str.contains('DQ', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('NA', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('NB', na=False))
                ]

DN_Nms = DN['Type'].value_counts().index.to_list()
df_ZTF_CVs.loc[(df_ZTF_CVs['Type'].isin(DN_Nms)), 'CV_Types'] = 'dwarf_nova'

# (NL) Nova-likes
NL = df_ZTF_CVs[(df_ZTF_CVs['Type'].str.contains('NL', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('IBWD', na=False)) & 
                (~df_ZTF_CVs['Type'].str.contains('DQ', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('NA', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('NB', na=False))
                ]

NL_Nms = NL['Type'].value_counts().index.to_list()
df_ZTF_CVs.loc[(df_ZTF_CVs['Type'].isin(NL_Nms)), 'CV_Types'] = 'nova_like'

# (AM) AM Her
AM = df_ZTF_CVs[(df_ZTF_CVs['Type'].str.contains('AM', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('IBWD', na=False)) & 
                (~df_ZTF_CVs['Type'].str.contains('NA', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('NB', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('NC', na=False))
                ]

AM_Nms = AM['Type'].value_counts().index.to_list()
df_ZTF_CVs.loc[(df_ZTF_CVs['Type'].isin(AM_Nms)), 'CV_Types'] = 'polar'

# (DQ) DQ Her
DQ = df_ZTF_CVs[(df_ZTF_CVs['Type'].str.contains('DQ', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('IBWD', na=False)) & 
                (~df_ZTF_CVs['Type'].str.contains('NA', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('NB', na=False)) &
                (~df_ZTF_CVs['Type'].str.contains('NC', na=False))
                ]

DQ_Nms = DQ['Type'].value_counts().index.to_list()
df_ZTF_CVs.loc[(df_ZTF_CVs['Type'].isin(DQ_Nms)), 'CV_Types'] = 'intermediate_polar'

# (IBWD) AM CVn
IBWD = df_ZTF_CVs[(df_ZTF_CVs['Type'].str.contains('IBWD', na=False)) &
                  (~df_ZTF_CVs['Type'].str.contains('NA', na=False)) &
                  (~df_ZTF_CVs['Type'].str.contains('NB', na=False)) &
                  (~df_ZTF_CVs['Type'].str.contains('NC', na=False))
                 ]

IBWD_Nms = IBWD['Type'].value_counts().index.to_list()
df_ZTF_CVs.loc[(df_ZTF_CVs['Type'].isin(IBWD_Nms)), 'CV_Types'] = 'AMCVn'

# Additional (NA)) Nova
df_ZTF_CVs.loc[(df_ZTF_CVs['Type'].isin(['NA+NL/VY'])), 'CV_Types'] = 'nova'

# Display value counts for CV types.
df_ZTF_CVs.CV_Types.value_counts()
# Out:
# CV_Types
# dwarf_nova            4981
# nova_like              279
# polar                  161
# nova                    94
# intermediate_polar      54
# AMCVn                   50
# Name: count, dtype: int64

# %% [markdown]
# ### 4.2.2 Label CV subclasses and subsubclasses

# %%
# Label subclasses

# (dwarf_nova) Dwarf Nova subclasses and subsubclasses

df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['dwarf_nova'])) & (df_ZTF_CVs.Type.str.contains('UGSS', na=False)), 'CV_subtypes'] = 'dwarf_nova_U_Gem'

df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['dwarf_nova'])) & (df_ZTF_CVs.Type.str.contains('UGSU', na=False)), 'CV_subtypes'] = 'dwarf_nova_SU_Uma'
df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['dwarf_nova'])) & (df_ZTF_CVs.Type.str.contains('UGWZ', na=False)), 'CV_subtypes'] = 'dwarf_nova_SU_Uma'
df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['dwarf_nova'])) & (df_ZTF_CVs.Type.str.contains('UGER', na=False)), 'CV_subtypes'] = 'dwarf_nova_SU_Uma'

df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['dwarf_nova'])) & (df_ZTF_CVs.Type.str.contains('UGWZ', na=False)), 'CV_subsubtypes'] = 'dwarf_nova_SU_Uma_WZ_Sge'
df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['dwarf_nova'])) & (df_ZTF_CVs.Type.str.contains('UGER', na=False)), 'CV_subsubtypes'] = 'dwarf_nova_SU_Uma_ER_Uma'

df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['dwarf_nova'])) & (df_ZTF_CVs.Type.str.contains('UGZ', na=False)), 'CV_subtypes'] = 'dwarf_nova_Z_Cam'
df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['dwarf_nova'])) & (df_ZTF_CVs.Type.str.contains('UGZ/IW', na=False)), 'CV_subsubtypes'] = 'dwarf_nova_Z_Cam_IW_And'


# (N) Nova subclasses
df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['nova'])) & (df_ZTF_CVs.Type.str.contains('NA', na=False)), 'CV_subtypes'] = 'nova_fast'
df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['nova'])) & (df_ZTF_CVs.Type.str.contains('NB', na=False)), 'CV_subtypes'] = 'nova_slow'
df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['nova'])) & (df_ZTF_CVs.Type.str.contains('NC', na=False)), 'CV_subtypes'] = 'nova_very_slow'
df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['nova'])) & (df_ZTF_CVs.Type.str.contains('NR', na=False)), 'CV_subtypes'] = 'nova_recurrent'


# (NL) Nova-like subclasses
df_ZTF_CVs.loc[(df_ZTF_CVs.CV_Types.isin(['nova_like'])) & (df_ZTF_CVs.Type.str.contains('VY', na=False)), 'CV_subtypes'] = 'nova_like_VY_Scl'

# Display dataframe
pd.options.display.max_rows = 50
print(df_ZTF_CVs.CV_subtypes.value_counts())
print(df_ZTF_CVs.CV_subsubtypes.value_counts())
# Out:
# CV_subtypes
# dwarf_nova_SU_Uma    698
# dwarf_nova_Z_Cam     207
# nova_like_VY_Scl     138
# dwarf_nova_U_Gem     134
# nova_fast             19
# nova_slow             15
# nova_recurrent         9
# nova_very_slow         7
# Name: count, dtype: int64
# CV_subsubtypes
# dwarf_nova_Z_Cam_IW_And     96
# dwarf_nova_SU_Uma_WZ_Sge    78
# dwarf_nova_SU_Uma_ER_Uma    37
# Name: count, dtype: int64

# %% [markdown]
# ### 4.2.3 Save dataframe to csv.

# %%
# Save dataframe to csv
df_ZTF_CVs.to_csv(f'../processed_data/AAVSOCVsZTFxmatch_{date}_BTS_labelled.csv', index=False)

# %%
a = pd.read_csv('../processed_data/AAVSOCVsZTFxmatch_21032023_BTS_manual_labelled.csv')
a.columns
# Out:
# Index(['Name', 'AUID', 'Coords', 'Const', 'Type', 'Period', 'Mag', 'ra', 'dec',
#        'Xmatch_obj', 'separation', 'Eclipsing', 'CV_Types', 'CV_subtypes',
#        'CV_subsubtypes', 'eclipse_clear', 'Clarity', 'manual_label',
#        'Unnamed: 18'],
#       dtype='object')
