# %%
import pandas as pd
import os
import pandas as pd
from lcfunctions import download_alerce_lc, download_lasair_lc, display_lightcurve
from lcfunctions import alerce_clean, lasair_clean, load_lasair_lc
from raw_processing import label_schemes

# Load dataset
df_ZTF_CVs = pd.read_csv('../processed_data/AAVSOCVsZTFxmatch_21032023_BTS_manual_labelled.csv')
df_ZTF_CVs = label_schemes(df_ZTF_CVs.copy())
df_ZTF_CVs.head()
df_ZTF_CVs['labels_2'].value_counts()
# Out:
#         oid_ztf                 oid_aavso type_aavso          ra        dec  \
# 0  ZTF18abryuah               ASASSN-19dp         AM   35.745917  43.653639
# 1  ZTF18abtrvgp                 BMAM-V789         AM   38.492292  41.623972
# 2  ZTF17aaaehby  CSS 091026:002637+242916         AM    6.654417  24.487694
# 3  ZTF18abgjgiq                MGAB-V3453         AM    8.972375  43.561528
# 4  ZTF18abumlux                MGAB-V3769         AM  353.638167  40.430611
#
#    Eclipsing CV_Types CV_subtypes CV_subsubtypes  eclipse_clear manual_label  \
# 0          0    polar         NaN            NaN            0.0       AM_Her
# 1          0    polar         NaN            NaN            0.0       AM_Her
# 2          0    polar         NaN            NaN            0.0       AM_Her
# 3          0    polar         NaN            NaN            0.0       AM_Her
# 4          0    polar         NaN            NaN            0.0       AM_Her
#
#    Clarity labels_1 labels_2 labels_3  labels_4
# 0      1.0    polar    polar    polar  magnetic
# 1      1.0    polar    polar    polar  magnetic
# 2      1.0    polar    polar    polar  magnetic
# 3      1.0    polar    polar    polar  magnetic
# 4      1.0    polar    polar    polar  magnetic

# %%
date = '2023_03_25'

object = 'ZTF18aakynpt'

# Apply errorbars
error = False

if error == True:
        errColalerce1 = 'sigmapsf'
        errColalerce2 = 'sigmapsf_corr_revised'
        errCollasair1 = 'sigmapsf'
        errCollasair2 = 'dc_sigmag'
else:
    errColalerce1 = None
    errColalerce2 = None
    errCollasair1 = None
    errCollasair2 = None

display_start = 0
display_end = 20
label_scheme = 'labels_2'

# objlist = df_ZTF_CVs[df_ZTF_CVs[label_scheme].str.contains('DQ', na=False)]['Xmatch_obj'].iloc[display_start:display_end]
# objtype = df_ZTF_CVs[df_ZTF_CVs[label_scheme].str.contains('DQ', na=False)][label_scheme].iloc[display_start:display_end]
# name = df_ZTF_CVs[df_ZTF_CVs[label_scheme].str.contains('DQ', na=False)]['Name'].iloc[display_start:display_end]

class_list = ['dwarf_nova_Z_Cam']
print(f'Number of objects: {df_ZTF_CVs[df_ZTF_CVs[label_scheme].isin(class_list)].shape[0]}')

objlist = df_ZTF_CVs[df_ZTF_CVs[label_scheme].isin(class_list)]['oid_ztf'].iloc[display_start:display_end]
objtype = df_ZTF_CVs[df_ZTF_CVs[label_scheme].isin(class_list)][label_scheme].iloc[display_start:display_end]
name = df_ZTF_CVs[df_ZTF_CVs[label_scheme].isin(class_list)]['oid_aavso'].iloc[display_start:display_end]

i=0
for object, type, name in zip(objlist, objtype, name):

    print(i, object, type, name)
    
    # Display lasair difference magnitude and apparent magnitude light curves.
    lc_lasair = load_lasair_lc(object, path=f'../lightcurves_dataset/lasair_{date}')
    lc_lasair_appmag = lasair_clean(lc_lasair, limit=25, magerrlim=1)

    # print('Lasair difference magnitude')
    # display_lightcurve(lc_lasair,x='jd',y='magpsf',errorCol=errCollasair1)
    print('Lasair apparent magnitude')
    display_lightcurve(lc_lasair_appmag,x='jd',y='dc_mag',errorCol=errCollasair2)
    i+=1
# Out:
# Number of objects: 174
# 0 ZTF18aanvvqw dwarf_nova_Z_Cam MGAB-V240
# Lasair apparent magnitude
# 1 ZTF18aayotjv dwarf_nova_Z_Cam MGAB-V864
# Lasair apparent magnitude
# 2 ZTF18aawbmgc dwarf_nova_Z_Cam MGAB-V866
# Lasair apparent magnitude
# 3 ZTF18aabfaxr dwarf_nova_Z_Cam 1RXS J015017.0+375614
# Lasair apparent magnitude
# 4 ZTF17aaaewmi dwarf_nova_Z_Cam ASASSN-14gl
# Lasair apparent magnitude
# 5 ZTF19aawteif dwarf_nova_Z_Cam ZTF19aawteif
# Lasair apparent magnitude
# 6 ZTF19aaphtab dwarf_nova_Z_Cam MGAB-V3636
# Lasair apparent magnitude
# 7 ZTF18aazfbnj dwarf_nova_Z_Cam MGAB-V522
# Lasair apparent magnitude
# 8 ZTF18abinavv dwarf_nova_Z_Cam MGAB-V769
# Lasair apparent magnitude
# 9 ZTF18abcgont dwarf_nova_Z_Cam ZTF18abcgont
# Lasair apparent magnitude
# 10 ZTF18aabhjxp dwarf_nova_Z_Cam ZTF18aabhjxp
# Lasair apparent magnitude
# 11 ZTF19aadkhsj dwarf_nova_Z_Cam MGAB-V3488
# Lasair apparent magnitude
# 12 ZTF18aaakoxi dwarf_nova_Z_Cam MGAB-V613
# Lasair apparent magnitude
# 13 ZTF18aculoxl dwarf_nova_Z_Cam ATO J106.9922-25.2102
# Lasair apparent magnitude
# 14 ZTF20acrbeha dwarf_nova_Z_Cam NSV 3087
# Lasair apparent magnitude
# 15 ZTF17aabunpt dwarf_nova_Z_Cam 2MASS J23430113+5214305
# Lasair apparent magnitude
# 16 ZTF18abtscit dwarf_nova_Z_Cam BMAM-V362
# Lasair apparent magnitude
# 17 ZTF18abuxnlr dwarf_nova_Z_Cam BMAM-V490
# Lasair apparent magnitude
# 18 ZTF19aavvyrp dwarf_nova_Z_Cam BMAM-V784
# Lasair apparent magnitude
# 19 ZTF18abncpgs dwarf_nova_Z_Cam ZTF18abncpgs
# Lasair apparent magnitude
