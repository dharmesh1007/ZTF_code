# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from matplotlib import pyplot as plt
from sklearn import set_config

from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import ADASYN, RandomOverSampler
from sklearn.model_selection import train_test_split
from sklearn.metrics import balanced_accuracy_score, precision_score, recall_score, f1_score, make_scorer, roc_auc_score, confusion_matrix

from performance import plot_roc, plot_learning_curves
from lcfunctions import load_lasair_lc, lasair_clean
from raw_processing import label_schemes

from tensorflow.keras.utils import to_categorical
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
from sklearn.utils import class_weight

# %% [markdown]
# ### Generate dataset

# %%
label_scheme = 'labels_1'

pd.options.display.max_columns = None
                     
dataset = pd.read_csv('../processed_data/AAVSOCVsZTFxmatch_21032023_BTS_manual_labelled.csv')
dataset = label_schemes(dataset)

dataset = dataset[dataset[label_scheme].notna()].reset_index(drop=True)
print(dataset[label_scheme].value_counts())
dataset.columns
# Out:
# dwarf_nova_SU_UMa    572
# dwarf_nova_Z_Cam     174
# nova_like            144
# nova_like_VY_Scl     120
# dwarf_nova_U_Gem     116
# polar                114
# dwarf_nova_WZ_Sge     58
# int_polar             49
# AMCVn                 46
# nova                  46
# Name: labels_1, dtype: int64
# Index(['oid_ztf', 'oid_aavso', 'type_aavso', 'ra', 'dec', 'Eclipsing',
#        'CV_Types', 'CV_subtypes', 'CV_subsubtypes', 'eclipse_clear',
#        'manual_label', 'Clarity', 'labels_1', 'labels_2', 'labels_3',
#        'labels_4'],
#       dtype='object')

# %% [markdown]
# ### Dictionary of light curve information

# %%
# Create a dictionary of dictionary, where each sub-dictionary contains the light curve data for a given object

def lightcurve_dictionary(dataset, lc_folder = '../lightcurves_dataset/lasair_2023_03_25'):

    lightcurves = {}
    for obj in dataset['oid_ztf']:
        print(obj)
        # Load and process lasair light curve, the split into g and r bands
        lc_test = load_lasair_lc(oid=obj, path=lc_folder)
        lc_appmag_test = lasair_clean(lc_test, limit=25, magerrlim=1)
        df_lc = lc_appmag_test.copy()
        df_lc_g = df_lc[df_lc['fid'] == 1].reset_index(drop=True)
        df_lc_r = df_lc[df_lc['fid'] == 2].reset_index(drop=True)

        lightcurves[obj] = {'g_mag': df_lc_g['dc_mag'].values, 
                            'r_mag': df_lc_r['dc_mag'].values,
                            'g_jd': df_lc_g['jd'].values,
                            'r_jd': df_lc_r['jd'].values
                            }
    
    return lightcurves
    

lightcurves = lightcurve_dictionary(dataset)
# Out:
# ZTF18abryuah
# ZTF18abtrvgp
# ZTF17aaaehby
# ZTF18abgjgiq
# ZTF18abumlux
# ZTF18absgnqy
# ZTF18aaxdlbl
# ZTF18absgzlu
# ZTF18acegnyn
# ZTF18aaadtna
# ZTF18acywwfg
# ZTF17aabxrtj
# ZTF18aagqeuv
# ZTF18aahmxsl
# ZTF17aaarxou
# ZTF17aaairkd
# ZTF19aabiema
# ZTF18acnnsmq
# ZTF18abcrbmk
# ZTF18admxenl
# ZTF18abwiccd
# ZTF18abwpsyj
# ZTF18aaylcic
# ZTF18aagrcve
# ZTF20abragvw
# ZTF19abhpnxh
# ZTF18adlhiaq
# ZTF18aazucqe
# ZTF18abnbluc
# ZTF18aajqtnw
# ZTF18aapovzp
# ZTF18aainbrb
# ZTF18aauxwft
# ZTF18aaxcqso
# ZTF19abtsrif
# ZTF19acbzgog
# ZTF19acfsteg
# ZTF19acgfhfd
# ZTF19acnfsij
# ZTF19acqprad
# ZTF19acxrihd
# ZTF19adakuos
# ZTF20abqhsxb
# ZTF20abzbtgm
# ZTF20aceeeuz
# ZTF20acfucwr
# ZTF20acgigfo
# ZTF20acplkub
# ZTF21aaarlbp
# ZTF21abjiotr
# ZTF21acbcfmh
# ZTF21acbutpl
# ZTF21ackfkfz
# ZTF22aatixbc
# ZTF22aazmooy
# ZTF22abfxmpc
# ZTF22abnrgno
# ZTF22abtltcw
# ZTF23aabvpgb

# %% [markdown]
# ### Functions for obtaining different input representations

# %%
from scipy.signal import find_peaks

def getdiffs(array):
    if len(array):
        diffs = np.diff(array)
        return diffs
    else:
        return np.array([])

def backfilled_magnitudes(lightcurves, n_pts=500, backfill_value=np.nan):
    X_gmag = np.empty((0, n_pts))
    X_rmag = np.empty((0, n_pts))
    X_gjd = np.empty((0, n_pts))
    X_rjd = np.empty((0, n_pts))

    for obj in lightcurves.keys():
        for key in ['g_mag', 'r_mag', 'g_jd', 'r_jd']:
            lc = lightcurves[obj][key]

            if key == 'g_jd' or key == 'r_jd':
                try:
                    lc = (lc - lc[0])
                except:
                    lc = []

            if len(lc) < n_pts:
                lc = np.pad(lc, (n_pts-len(lc), 0), 'constant', constant_values=(backfill_value, backfill_value))
            elif len(lc) >= n_pts:
                lc = lc[-n_pts:]
            
            if key == 'g_mag':
                X_gmag = np.vstack((X_gmag, lc))
            elif key == 'r_mag':
                X_rmag = np.vstack((X_rmag, lc))
            elif key == 'g_jd':
                X_gjd = np.vstack((X_gjd, lc))
            elif key == 'r_jd':
                X_rjd = np.vstack((X_rjd, lc))
            
    return X_gmag, X_rmag, X_gjd, X_rjd


def dmdt(lightcurves, n_pts=500, backfill_value=np.nan):

    X_gdm = np.empty((0, n_pts))
    X_gdt = np.empty((0, n_pts))
    X_rdm = np.empty((0, n_pts))
    X_rdt = np.empty((0, n_pts))

    for obj in lightcurves.keys():
        for key in ['g_mag', 'r_mag', 'g_jd', 'r_jd']:
            lc = lightcurves[obj][key]

            if len(lc) > 0:
                diff = np.diff(lc)
                diff = np.insert(diff, 0, 0)
            elif len(lc) == 0:
                diff = np.array([])
            
            if len(diff) < n_pts:
                diff = np.pad(diff, (n_pts-len(diff), 0), 'constant', constant_values=(backfill_value, backfill_value))
                
            elif len(diff) >= n_pts:
                diff = diff[-n_pts:]
            
            if key == 'g_mag':
                X_gdm = np.vstack((X_gdm, diff))
            elif key == 'r_mag':
                X_rdm = np.vstack((X_rdm, diff))
            elif key == 'g_jd':
                X_gdt = np.vstack((X_gdt, diff))
            elif key == 'r_jd':
                X_rdt = np.vstack((X_rdt, diff))

    return X_gdm, X_rdm, X_gdt, X_rdt


def interpolated_lcs(lightcurves, interp_pts=1000, true_cadence=True, backfill_value=0, cadence=1):
        X_ginterp = np.empty((0, interp_pts))
        X_rinterp = np.empty((0, interp_pts))

    
        for obj in list(lightcurves.keys()):

            for magkey, timekey in zip(['g_mag', 'r_mag'], ['g_jd', 'r_jd']):
                mag = lightcurves[obj][magkey]
                time = lightcurves[obj][timekey]

                # Convert jd to days since first observation
                try:
                    time = (time - time[0])
                except:
                    time = []

                 # Interpolate the light curve to 1 day cadence or a set number of points
                try:
                    if true_cadence==True:
                        lc_interp = np.interp(np.arange(0, time[-1], cadence), time, mag)
                    elif true_cadence==False:
                        lc_interp = np.interp(np.arange(0, interp_pts, 1), time, mag)
                except:
                    lc_interp = np.array([])
                
                # Pad the light curve with zeros if it is shorter than the desired length, or trim it if it is longer
                if len(lc_interp) < interp_pts:
                    lc_interp = np.pad(lc_interp, (interp_pts-len(lc_interp), 0), 'constant', constant_values=(backfill_value, backfill_value))
                elif len(lc_interp) >= interp_pts:
                    lc_interp = lc_interp[-interp_pts:]
                
                # Append the interpolated light curve to the appropriate array
                if magkey == 'g_mag':
                    X_ginterp = np.vstack((X_ginterp, lc_interp))
                elif magkey == 'r_mag':
                    X_rinterp = np.vstack((X_rinterp, lc_interp))

        return X_ginterp, X_rinterp


def gminusr(lightcurves, n_pts=500, backfill_value=np.nan):

    clr = np.empty((0, n_pts))

    for obj in list(lightcurves.keys()):
        # print(obj)
        # df_g = pd.DataFrame(lightcurves[obj]['g_mag', 'g_jd'].copy())
        gmag = lightcurves[obj]['g_mag'].copy()
        gjd = lightcurves[obj]['g_jd'].copy()
        rmag = lightcurves[obj]['r_mag'].copy()
        rjd = lightcurves[obj]['r_jd'].copy()

        gjd = gjd.astype(int)
        rjd = rjd.astype(int)

        # Drop the duplicate jd and corresponding mag.
        g_jd_unique0 = np.unique(gjd, return_index=True)    # The unique function also returns the indices of unique values
        g_jd_unique = g_jd_unique0[0]                       # The unique jd values
        g_jd_unique_idx = g_jd_unique0[1]                   # The indices of the unique jd values can be used as a mask
        gmag_unique = gmag[g_jd_unique_idx]                 # The unique mag values

        r_jd_unique0 = np.unique(rjd, return_index=True)
        r_jd_unique = r_jd_unique0[0]
        r_jd_unique_idx = r_jd_unique0[1]
        rmag_unique = rmag[r_jd_unique_idx]

        # Get a boolean array of whether each g_jd_unique is in r_jd_unique. Use it as a mask to get gmag and rmag
        # values that were taken at the same time.
        gmask = np.in1d(g_jd_unique, r_jd_unique)
        gjd_inr = g_jd_unique[gmask]    
        # print(gjd_inr.shape)  
        gmag_inr = gmag_unique[gmask]  
        # print(gmag_inr.shape)        


        # Get a boolean array of whether each r_jd is in g_jd
        rmask = np.in1d(r_jd_unique, g_jd_unique)
        rjd_ing = r_jd_unique[rmask]
        # print(rjd_ing.shape)
        rmag_ing = rmag_unique[rmask]
        # print(rmag_ing.shape)

        clr_source = gmag_inr - rmag_ing

        if len(clr_source) < n_pts:
            clr_source = np.pad(clr_source, (n_pts-len(clr_source), 0), 'constant', constant_values=(backfill_value, backfill_value))
        elif len(clr_source) >= n_pts:
            clr_source = clr_source[-n_pts:]

        
        clr_source = clr_source.reshape(1, clr_source.shape[0])
        # print(clr_source.shape)
        clr = np.vstack((clr, clr_source))

    return clr

def dmdt_hist(lightcurves, bins, limit, dm=False, usepeaks=False):

    g_all = np.array([])
    r_all = np.array([])
    g_hist_all = np.empty((0, bins))
    r_hist_all = np.empty((0, bins))

    rand = np.random.randint(0, len(lightcurves))
    for obj in list(lightcurves.keys()):#[rand:rand+1]:
        lc = lightcurves[obj]
        lc_g = lc['g_mag']
        lc_r = lc['r_mag']
        lc_g_jd = lc['g_jd']
        lc_r_jd = lc['r_jd']

        if usepeaks == True:
            # Find the peaks and the troughs of lc_g and lc_r
            g_peaks, _ = find_peaks(-lc_g, prominence=(None,None))
            g_troughs, _ = find_peaks(lc_g, prominence=(None,None))
            r_peaks, _ = find_peaks(-lc_r, prominence=(None,None))
            r_troughs, _ = find_peaks(lc_r, prominence=(None,None))

            lc_g = lc_g[np.sort(np.concatenate((g_peaks, g_troughs)))]
            lc_r = lc_r[np.sort(np.concatenate((r_peaks, r_troughs)))]
            lc_g_jd = lc_g_jd[np.sort(np.concatenate((g_peaks, g_troughs)))]
            lc_r_jd = lc_r_jd[np.sort(np.concatenate((r_peaks, r_troughs)))]
        

        # Get the dm and dt arrays
        g_dm = getdiffs(lc_g)
        r_dm = getdiffs(lc_r)
        g_dt = getdiffs(lc_g_jd)
        r_dt = getdiffs(lc_r_jd)

        if dm == True:
            # Just use the dms
            g_processed = g_dm
            r_processed = r_dm
        else:
            # Get the dmdt arrays
            g_dmdt = g_dm / g_dt
            g_processed = np.nan_to_num(g_dmdt, nan=0)
            r_dmdt = r_dm / r_dt
            r_processed = np.nan_to_num(r_dmdt, nan=0)

        # Add the g and r processed arrays to the all arrays
        g_all = np.append(g_all, g_processed, axis=0)
        r_all = np.append(r_all, r_processed, axis=0)

        # Get the histograms. First clip the arrays to the limit.
        g_processed[g_processed > limit] = limit
        g_processed[g_processed < -limit] = -limit
        r_processed[r_processed > limit] = limit
        r_processed[r_processed < -limit] = -limit

        g_hist, g_bins = np.histogram(g_processed, bins=np.linspace(-limit, limit, bins+1))
        r_hist, r_bins = np.histogram(r_processed, bins=np.linspace(-limit, limit, bins+1))

        # print(g_hist)

        # Add the histogram to the array
        g_hist_all = np.vstack((g_hist_all, g_hist))
        r_hist_all = np.vstack((r_hist_all, r_hist))

        # # plot the peaks and troughs and indicate them
        # plt.figure(figsize=(20, 5))
        # plt.plot(lc_g_jd, lc_g, '.')
        # plt.plot(lc_g_jd[g_peaks], lc_g[g_peaks], "x")
        # plt.plot(lc_g_jd[g_troughs], lc_g[g_troughs], "x")
        # plt.gca().invert_yaxis()
        # plt.show()

        # plt.figure(figsize=(20, 5))
        # plt.plot(lc_g_peaksandtroughs_jd, lc_g_peaksandtroughs, '.')
        # plt.gca().invert_yaxis()
        # plt.show()

        # print(np.diff(lc_g_peaksandtroughs))

    return g_hist_all, r_hist_all, g_all, r_all

def multi_channel(array_list):
    reshaped_arrays = []
    for array in array_list:
        reshaped_arrays.append(np.reshape(array, (array.shape[0], array.shape[1], 1)))

    new_arrray = np.concatenate(reshaped_arrays, axis=2)
    return new_arrray

# %% [markdown]
# ### Obtain representation and reshape

# %%
# Get the representation.
X_g, X_r, X_gjd, X_rjd = backfilled_magnitudes(lightcurves=lightcurves, n_pts=2000, backfill_value=0.0)
X_g_hist, X_r_hist, a, b = dmdt_hist(lightcurves, bins=100, limit=10, dm=True, usepeaks=True)
X_g_int, X_r_int = interpolated_lcs(lightcurves, interp_pts=1000, true_cadence=True, backfill_value=0, cadence=1)

# show = np.random.randint(0, len(X_g))
# plt.plot(X_g_int[show], '.')
# plt.gca().invert_yaxis()

X_gr = multi_channel([X_g, X_r])
X_gr_hist = multi_channel([X_g_hist, X_r_hist])
# Reshape the arrays.
# X_g = X_g.reshape(X_g.shape[0], X_g.shape[1], -1)

X_variant = X_g_int.reshape(X_g_int.shape[0], X_g_int.shape[1], -1)
X_mulithead_1 = X_gr
X_multihead_2 = X_gr_hist

print(X_variant.shape, X_mulithead_1.shape, X_multihead_2.shape)
# Out:
# (1439, 1000, 1) (1439, 2000, 2) (1439, 100, 2)

# %% [markdown]
# ### Display representation

# %%
show = np.random.randint(0, len(X_g_int))
plt.plot(X_g_int[show], '.')
plt.gca().invert_yaxis()

# %% [markdown]
# ### Obtain training and test sets

# %%
multihead = False
random_state = 1

# Get the labels as names
y_names = dataset[label_scheme].to_numpy()
# Encode the labels
enc = LabelEncoder().fit(y_names)
y_num = enc.transform(y_names)
# One hot encode the labels
y = to_categorical(y_num)

if multihead == True:

    # Train, test, split for multi-input model.
    X_train1, X_test1, y_train1, y_test1 = train_test_split(X_mulithead_1, y, test_size=0.3, random_state=random_state)
    X_train2, X_test2, y_train2, y_test2 = train_test_split(X_multihead_2, y, test_size=0.3, random_state=random_state)

    # Train, validation, split for multi-input model.
    X_train1, X_val1, y_train1, y_val1 = train_test_split(X_train1, y_train1, test_size=0.3, random_state=random_state)
    X_train2, X_val2, y_train2, y_val2 = train_test_split(X_train2, y_train2, test_size=0.3, random_state=random_state)

    # Single y_train, y_val, y_test for multi-input model.
    y_train = y_train1
    y_val = y_val1
    y_test = y_test1

    # # Normalise the data.
    mean1 = np.mean(X_train1)
    std1 = np.std(X_train1)
    X_train1 = (X_train1 - mean1) / std1
    X_val1 = (X_val1 - mean1) / std1
    X_test1 = (X_test1 - mean1) / std1

    mean2 = np.mean(X_train2)
    std2 = np.std(X_train2)
    X_train2 = (X_train2 - mean2) / std2
    X_val2 = (X_val2 - mean2) / std2
    X_test2 = (X_test2 - mean2) / std2

    print(f'X_train1, X_val1, X_test1 shapes: {X_train1.shape} {X_val1.shape} {X_test1.shape}')
    print(f'X_train2, X_val2, X_test2 shapes: {X_train2.shape} {X_val2.shape}, {X_test2.shape}')

elif multihead == False:
    # Train, validation, split for single-input model.
    X_train, X_test, y_train, y_test = train_test_split(X_variant, y, test_size=0.3, stratify=y, random_state=random_state)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, stratify=y_train, random_state=random_state)

    # Normalise the data.
    mean = np.mean(X_train)
    std = np.std(X_train)
    X_train = (X_train - mean) / std
    X_val = (X_val - mean) / std
    X_test = (X_test - mean) / std

    print(f'X_train, X_val, X_test shapes: {X_train.shape} {X_val.shape} {X_test.shape}')


# Get the labels for each set as numbers.
y_train_labels = np.argmax(y_train, axis=1)

# Get the class weights for the training data.
class_weights = class_weight.compute_class_weight(class_weight='balanced', classes=np.unique(y_train_labels), y=y_train_labels)
class_weights_dict = dict(zip(np.unique(y_train_labels), class_weights))


# Use over/undersampling to balance the training data.
us = 360
os = 360
# Undersample the training data
class_dist_us = {enc.transform(['dwarf_nova_SU_UMa'])[0]:us}
# Oversample the training data
class_dist_os = {enc.transform(['dwarf_nova_SU_UMa'])[0]:os,
                enc.transform(['dwarf_nova_Z_Cam'])[0]:os,
                enc.transform(['dwarf_nova_U_Gem'])[0]:os,
                enc.transform(['nova_like_VY_Scl'])[0]:os,
                enc.transform(['polar'])[0]:os,
                enc.transform(['nova_like'])[0]:os,
                enc.transform(['nova'])[0]:os,
                enc.transform(['int_polar'])[0]:os,
                enc.transform(['AMCVn'])[0]:os
                }

undersample = RandomUnderSampler(sampling_strategy=class_dist_us, random_state=random_state)
oversample = RandomOverSampler(sampling_strategy=class_dist_os, random_state=random_state)

if multihead == True:
    X_train1_us, y_train1_us = undersample.fit_resample(X_train1.reshape(-1, X_train1.shape[1]*X_train1.shape[2]), y_train)
    X_train1_os, y_train1_os = oversample.fit_resample(X_train1_us, y_train1_us)
    X_train1_os = X_train1_os.reshape(-1, X_train1.shape[1], X_train1.shape[2])

    X_train2_us, y_train2_us = undersample.fit_resample(X_train2.reshape(-1, X_train2.shape[1]*X_train2.shape[2]), y_train)
    X_train2_os, y_train2_os = oversample.fit_resample(X_train2_us, y_train2_us)
    X_train2_os = X_train2_os.reshape(-1, X_train2.shape[1], X_train2.shape[2])

    print(f'X_train1_os, y_train1_os shapes: {X_train1_os.shape} {y_train1_os.shape}')
    print(f'X_train2_os, y_train2_os shapes: {X_train2_os.shape} {y_train2_os.shape}')

elif multihead == False:
    X_train_us, y_train_us = undersample.fit_resample(X_train.reshape(-1, X_train.shape[1]*X_train.shape[2]), y_train)
    X_train_os, y_train_os = oversample.fit_resample(X_train_us, y_train_us)
    X_train_os = X_train_os.reshape(-1, X_train.shape[1], X_train.shape[2])

    print(f'X_train_os, y_train_os shapes: {X_train_os.shape} {y_train_os.shape}')
# Out:
# X_train, X_val, X_test shapes: (906, 1000, 1) (101, 1000, 1) (432, 1000, 1)
# X_train_os, y_train_os shapes: (3277, 1000, 1) (3277, 10)

# %%
show = np.random.randint(0, len(X_train))
plt.plot(X_train[show], '.')
plt.gca().invert_yaxis()

# %% [markdown]
# ### Build model function

# %%
def get_model(X_train, learning_rate=0.001, ks=30):
    # inputs = keras.Input(shape=(X_train.shape[1], X_train.shape[2]))
    inputs = keras.Input(shape=(X_train.shape[1], X_train.shape[2]), name="input")
    # x = layers.BatchNormalization()(inputs)
    # x = layers.Conv1D(filters=8, kernel_size=ks, activation="ReLU", padding='same', name='Conv1D_1', kernel_regularizer=regularizers.l1_l2(l1=0.00, l2=0.00))(inputs)
    # x = layers.MaxPooling1D(pool_size=2, name='MaxPool_1')(x)
    # x = layers.Dropout(0.2)(x)
    # x = layers.Conv1D(filters=8, kernel_size=ks, activation="ReLU", padding='same', name='Conv1D_2', kernel_regularizer=regularizers.l1_l2(l1=0.00, l2=0.00))(x)
    # x = layers.MaxPooling1D(pool_size=2, name='MaxPool_2')(x)
    # x = layers.Dropout(0.2)(x)
    # x = layers.Conv1D(filters=8, kernel_size=ks, activation="ReLU", padding='same', name='Conv1D_3', kernel_regularizer=regularizers.l1_l2(l1=0.00, l2=0.00))(x)
    # x = layers.MaxPooling1D(pool_size=2, name='MaxPool_3')(x)
    # x = layers.Conv1D(filters=64, kernel_size=ks, activation="ReLU", padding='valid', name='Conv1D_4')(x)
    # x = layers.MaxPooling1D(pool_size=2, name='MaxPool_4')(x)
    # x = layers.Conv1D(filters=64, kernel_size=ks, activation="ReLU", padding='valid', name='Conv1D_5')(x)
    # x = layers.MaxPooling1D(pool_size=2, name='MaxPool_5')(x)
    # x = layers.GlobalAveragePooling1D()(x)
    # x = layers.Dropout(0.2)(x)
    x = layers.Flatten(name='Flatten')(inputs)
    x = layers.Dense(100, activation="ReLU", kernel_regularizer=regularizers.l1_l2(l1=0.00, l2=0.00), name='Dense1')(x)
    x = layers.Dense(100, activation="ReLU", kernel_regularizer=regularizers.l1_l2(l1=0.00, l2=0.00), name='Dense2')(x)
    outputs = layers.Dense(10, activation="softmax", name='Output')(x)
    model = keras.Model(inputs=inputs, outputs=outputs)
    model.summary()

    model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
                  loss="categorical_crossentropy",
                  metrics=["categorical_accuracy"])
    return model


def get_multiheadmodel(X_train_list, learning_rate=0.001):

    input1 = keras.Input(shape=(X_train_list[0].shape[1], X_train_list[0].shape[2]), name="input1")
    input2 = keras.Input(shape=(X_train_list[1].shape[1], X_train_list[1].shape[2]), name="input2")
    # input3 = keras.Input(shape=(X_train_list[2].shape[1], X_train_list[2].shape[2]), name="input3")

    x1 = layers.Conv1D(filters=64, kernel_size=10, activation="ReLU", padding='valid', name='i1Conv1')(input1)
    x1 = layers.MaxPooling1D(pool_size=2, name='i1MaxPool1')(x1)
    x1 = layers.Conv1D(filters=64, kernel_size=10, activation="ReLU", padding='valid', name='i1Conv12')(input1)
    x1 = layers.MaxPooling1D(pool_size=2, name='i1MaxPool2')(x1)
    x1 = layers.Flatten(name='i1Flatten')(x1)

    x2 = layers.Conv1D(filters=64, kernel_size=10, activation="ReLU", padding='valid')(input2)
    x2 = layers.MaxPooling1D(pool_size=2)(x2)
    x2 = layers.Conv1D(filters=64, kernel_size=10, activation="ReLU", padding='valid')(input2)
    x2 = layers.MaxPooling1D(pool_size=2)(x2)
    x2 = layers.Flatten()(x2)

    # x3 = layers.Conv1D(filters=64, kernel_size=10, activation="ReLU", padding='valid')(input3)
    # x3 = layers.MaxPooling1D(pool_size=2)(x3)
    # x3 = layers.Flatten()(x3)

    x = layers.Concatenate()([x1, x2])

    x = layers.Dense(100, activation="ReLU", kernel_regularizer=regularizers.l1_l2(l1=0.00, l2=0.0))(x)
    x = layers.Dense(100, activation="ReLU", kernel_regularizer=regularizers.l1_l2(l1=0.00, l2=0.0))(x)
    outputs = layers.Dense(10, activation="softmax")(x)

    model = keras.Model(inputs=[input1, input2], outputs=outputs)

    model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
                  loss="categorical_crossentropy",
                  metrics=["categorical_accuracy"])

    return model


# model = get_model(X_train, learning_rate=0.001, ks=10)
# model = get_multiheadmodel([X_train1, X_train2])

# keras.utils.plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### Fit model

# %%
if multihead == True:
    X_train_final = [X_train1, X_train2]
    y_train_final = y_train
    validation_data = ([X_val1, X_val2], y_val)
    test_data = ([X_test1, X_test2], y_test)

else:
    X_train_final = X_train_os
    y_train_final = y_train_os
    validation_data = (X_val, y_val)
    test_data = (X_test, y_test)

# history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_val, y_val), verbose=2)
def fit(model, x, y, validation_data, model_path, epochs=500, batch_size=32):
    callbacks= [keras.callbacks.EarlyStopping(monitor="val_categorical_accuracy",
                                                    mode='max',
                                                    patience=50,
                                                    ),
                                    ModelCheckpoint(model_path,
                                                    monitor="val_categorical_accuracy", 
                                                    mode="max",
                                                    save_best_only=True, 
                                                    verbose=0)]

    history = model.fit(x=x, 
                        y=y, 
                        epochs=epochs, 
                        batch_size=batch_size,
                        validation_data=validation_data,
                        class_weight=class_weights_dict,
                        callbacks= callbacks
            )
    
    plot_learning_curves(history, metric='categorical_accuracy')
    
    return history



def evaluate_val(x, y, validation_data, n_runs=1, multihead=True, epochs=100, batch_size=32):

    val_loss_list = []
    val_acc_list = []

    for i in range(n_runs):
        model_path = f'../results/model/NNCheckpoint{i}.hdf5'

        if multihead == True:
            model = get_multiheadmodel(x)
        else:
            model = get_model(x)
        
        fit(model, x, y, validation_data, model_path, epochs=epochs, batch_size=batch_size)
        best_model = load_model(model_path)
        val_loss, val_acc = best_model.evaluate(validation_data[0], validation_data[1])
        val_loss_list.append(val_loss)
        val_acc_list.append(val_acc)
    
    # Print the mean and std of the validation loss and accuracy
    print(f'Validation loss: {np.mean(val_loss_list):.4f} ± {np.std(val_loss_list):.4f}')
    print(f'Validation accuracy: {np.mean(val_acc_list):.4f} ± {np.std(val_acc_list):.4f}')

    # plot a boxplot of the validation loss and accuracy
    plt.figure(figsize=(5, 3))
    plt.subplot(1, 2, 1)
    plt.boxplot(val_loss_list)
    plt.title("Validation loss")
    plt.ylabel("Loss")
    plt.subplot(1, 2, 2)
    plt.boxplot(val_acc_list)
    plt.title("Validation accuracy")
    plt.ylabel("Accuracy")
    plt.tight_layout()
    plt.show()
    
    
    # Get the index of the best model
    best_model_index = val_acc_list.index(max(val_acc_list))
    overall_best_model = load_model(f'../results/model/NNCheckpoint{best_model_index}.hdf5')

    return val_loss_list, val_acc_list, overall_best_model

# %%
val_loss, val_acc, clf = evaluate_val(X_train_final,y_train_final,validation_data, n_runs=1, multihead=multihead, epochs=500, batch_size=128)
# Out:
# Model: "model_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 1000, 1)]         0
#
#  Flatten (Flatten)           (None, 1000)              0
#
#  Dense1 (Dense)              (None, 100)               100100
#
#  Dense2 (Dense)              (None, 100)               10100
#
#  Output (Dense)              (None, 10)                1010
#
# =================================================================
# Total params: 111210 (434.41 KB)
# Trainable params: 111210 (434.41 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/500
# 26/26 [==============================] - 0s 4ms/step - loss: 3.2798 - categorical_accuracy: 0.1666 - val_loss: 3.0389 - val_categorical_accuracy: 0.0693
# Epoch 2/500
# 26/26 [==============================] - 0s 2ms/step - loss: 3.0019 - categorical_accuracy: 0.2310 - val_loss: 3.0381 - val_categorical_accuracy: 0.0594
# Epoch 3/500
# 26/26 [==============================] - 0s 2ms/step - loss: 2.8597 - categorical_accuracy: 0.2444 - val_loss: 2.9932 - val_categorical_accuracy: 0.0792
# Epoch 4/500
# 26/26 [==============================] - 0s 2ms/step - loss: 2.7719 - categorical_accuracy: 0.2673 - val_loss: 2.9943 - val_categorical_accuracy: 0.0693
# Epoch 5/500
# 26/26 [==============================] - 0s 2ms/step - loss: 2.6675 - categorical_accuracy: 0.2792 - val_loss: 3.0437 - val_categorical_accuracy: 0.0693
# Epoch 6/500
# 26/26 [==============================] - 0s 2ms/step - loss: 2.6301 - categorical_accuracy: 0.2896 - val_loss: 2.9101 - val_categorical_accuracy: 0.0693
# Epoch 7/500
# 26/26 [==============================] - 0s 2ms/step - loss: 2.5129 - categorical_accuracy: 0.3152 - val_loss: 2.9892 - val_categorical_accuracy: 0.0990
# Epoch 8/500
# 26/26 [==============================] - 0s 2ms/step - loss: 2.4841 - categorical_accuracy: 0.3280 - val_loss: 3.0550 - val_categorical_accuracy: 0.0891
# Epoch 9/500
# 26/26 [==============================] - 0s 2ms/step - loss: 2.4189 - categorical_accuracy: 0.3329 - val_loss: 2.9894 - val_categorical_accuracy: 0.0792
# Epoch 10/500
# 26/26 [==============================] - 0s 2ms/step - loss: 2.3208 - categorical_accuracy: 0.3500 - val_loss: 2.8934 - val_categorical_accuracy: 0.0693
# Epoch 11/500
# 26/26 [==============================] - 0s 2ms/step - loss: 2.2398 - categorical_accuracy: 0.3598 - val_loss: 2.9764 - val_categorical_accuracy: 0.1089
# Epoch 12/500
# 26/26 [==============================] - 0s 2ms/step - loss: 2.2521 - categorical_accuracy: 0.3558 - val_loss: 2.8755 - val_categorical_accuracy: 0.0693
# Epoch 13/500
# 26/26 [==============================] - 0s 2ms/step - loss: 2.2074 - categorical_accuracy: 0.3686 - val_loss: 3.2842 - val_categorical_accuracy: 0.0792
# Epoch 14/500
# 26/26 [==============================] - 0s 2ms/step - loss: 2.1175 - categorical_accuracy: 0.3760 - val_loss: 3.0030 - val_categorical_accuracy: 0.0792
# Epoch 15/500
# 26/26 [==============================] - 0s 2ms/step - loss: 2.0129 - categorical_accuracy: 0.3991 - val_loss: 2.9391 - val_categorical_accuracy: 0.0891
# Epoch 16/500
# 26/26 [==============================] - 0s 2ms/step - loss: 2.0174 - categorical_accuracy: 0.3946 - val_loss: 2.8709 - val_categorical_accuracy: 0.1287
# Epoch 17/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.9611 - categorical_accuracy: 0.4123 - val_loss: 2.8809 - val_categorical_accuracy: 0.0891
# Epoch 18/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.9471 - categorical_accuracy: 0.4153 - val_loss: 3.3618 - val_categorical_accuracy: 0.0792
# Epoch 19/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.9154 - categorical_accuracy: 0.4260 - val_loss: 2.9397 - val_categorical_accuracy: 0.1188
# Epoch 20/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.8437 - categorical_accuracy: 0.4342 - val_loss: 2.9670 - val_categorical_accuracy: 0.0693
# Epoch 21/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.8126 - categorical_accuracy: 0.4529 - val_loss: 3.0045 - val_categorical_accuracy: 0.0891
# Epoch 22/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.7885 - categorical_accuracy: 0.4547 - val_loss: 3.3015 - val_categorical_accuracy: 0.1089
# Epoch 23/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.7933 - categorical_accuracy: 0.4614 - val_loss: 3.1407 - val_categorical_accuracy: 0.0792
# Epoch 24/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.7774 - categorical_accuracy: 0.4571 - val_loss: 2.9017 - val_categorical_accuracy: 0.1188
# Epoch 25/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.6685 - categorical_accuracy: 0.4843 - val_loss: 2.8497 - val_categorical_accuracy: 0.1188
# Epoch 26/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.6151 - categorical_accuracy: 0.4913 - val_loss: 3.2969 - val_categorical_accuracy: 0.0990
# Epoch 27/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.6366 - categorical_accuracy: 0.4947 - val_loss: 2.9257 - val_categorical_accuracy: 0.1386
# Epoch 28/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.7005 - categorical_accuracy: 0.4837 - val_loss: 3.1609 - val_categorical_accuracy: 0.1089
# Epoch 29/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.6645 - categorical_accuracy: 0.4925 - val_loss: 3.1247 - val_categorical_accuracy: 0.0990
# Epoch 30/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.5593 - categorical_accuracy: 0.5090 - val_loss: 2.9143 - val_categorical_accuracy: 0.1287
# Epoch 31/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.5181 - categorical_accuracy: 0.5221 - val_loss: 2.8934 - val_categorical_accuracy: 0.1485
# Epoch 32/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.5042 - categorical_accuracy: 0.5288 - val_loss: 3.0612 - val_categorical_accuracy: 0.1089
# Epoch 33/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.4702 - categorical_accuracy: 0.5276 - val_loss: 3.1559 - val_categorical_accuracy: 0.1188
# Epoch 34/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.4631 - categorical_accuracy: 0.5407 - val_loss: 3.1589 - val_categorical_accuracy: 0.1089
# Epoch 35/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.5277 - categorical_accuracy: 0.5233 - val_loss: 3.4446 - val_categorical_accuracy: 0.1188
# Epoch 36/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.6053 - categorical_accuracy: 0.5261 - val_loss: 3.2921 - val_categorical_accuracy: 0.1188
# Epoch 37/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.4600 - categorical_accuracy: 0.5319 - val_loss: 2.9858 - val_categorical_accuracy: 0.1386
# Epoch 38/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.4873 - categorical_accuracy: 0.5389 - val_loss: 3.3608 - val_categorical_accuracy: 0.0891
# Epoch 39/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.4615 - categorical_accuracy: 0.5502 - val_loss: 3.2308 - val_categorical_accuracy: 0.1287
# Epoch 40/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.4556 - categorical_accuracy: 0.5475 - val_loss: 3.1389 - val_categorical_accuracy: 0.1485
# Epoch 41/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.3275 - categorical_accuracy: 0.5624 - val_loss: 2.8381 - val_categorical_accuracy: 0.1584
# Epoch 42/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.3470 - categorical_accuracy: 0.5658 - val_loss: 3.1706 - val_categorical_accuracy: 0.1584
# Epoch 43/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.2984 - categorical_accuracy: 0.5755 - val_loss: 2.9541 - val_categorical_accuracy: 0.1485
# Epoch 44/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.2559 - categorical_accuracy: 0.5874 - val_loss: 2.9547 - val_categorical_accuracy: 0.1386
# Epoch 45/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.2400 - categorical_accuracy: 0.5914 - val_loss: 3.1731 - val_categorical_accuracy: 0.1287
# Epoch 46/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.2106 - categorical_accuracy: 0.5914 - val_loss: 2.9021 - val_categorical_accuracy: 0.1980
# Epoch 47/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.2588 - categorical_accuracy: 0.5777 - val_loss: 3.1817 - val_categorical_accuracy: 0.1287
# Epoch 48/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.2807 - categorical_accuracy: 0.5801 - val_loss: 3.3084 - val_categorical_accuracy: 0.1485
# Epoch 49/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.2467 - categorical_accuracy: 0.5899 - val_loss: 3.2917 - val_categorical_accuracy: 0.1584
# Epoch 50/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.2318 - categorical_accuracy: 0.5862 - val_loss: 2.9599 - val_categorical_accuracy: 0.1683
# Epoch 51/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.2801 - categorical_accuracy: 0.5960 - val_loss: 2.9350 - val_categorical_accuracy: 0.1980
# Epoch 52/500
# 26/26 [==============================] - 0s 3ms/step - loss: 1.1687 - categorical_accuracy: 0.6097 - val_loss: 2.9855 - val_categorical_accuracy: 0.1683
# Epoch 53/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.1697 - categorical_accuracy: 0.6201 - val_loss: 3.0381 - val_categorical_accuracy: 0.1584
# Epoch 54/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.1507 - categorical_accuracy: 0.6115 - val_loss: 3.3308 - val_categorical_accuracy: 0.1188
# Epoch 55/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.0983 - categorical_accuracy: 0.6332 - val_loss: 3.1561 - val_categorical_accuracy: 0.1584
# Epoch 56/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.0851 - categorical_accuracy: 0.6417 - val_loss: 3.1406 - val_categorical_accuracy: 0.1584
# Epoch 57/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.1598 - categorical_accuracy: 0.6259 - val_loss: 3.4064 - val_categorical_accuracy: 0.1584
# Epoch 58/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.1698 - categorical_accuracy: 0.6289 - val_loss: 3.1118 - val_categorical_accuracy: 0.1584
# Epoch 59/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.1006 - categorical_accuracy: 0.6283 - val_loss: 3.1054 - val_categorical_accuracy: 0.1881
# Epoch 60/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.0618 - categorical_accuracy: 0.6402 - val_loss: 3.0593 - val_categorical_accuracy: 0.1881
# Epoch 61/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.0088 - categorical_accuracy: 0.6546 - val_loss: 3.4198 - val_categorical_accuracy: 0.1485
# Epoch 62/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.9808 - categorical_accuracy: 0.6683 - val_loss: 3.2628 - val_categorical_accuracy: 0.1485
# Epoch 63/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.0535 - categorical_accuracy: 0.6451 - val_loss: 3.2708 - val_categorical_accuracy: 0.1683
# Epoch 64/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.0660 - categorical_accuracy: 0.6503 - val_loss: 3.2764 - val_categorical_accuracy: 0.1584
# Epoch 65/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.1055 - categorical_accuracy: 0.6482 - val_loss: 3.3201 - val_categorical_accuracy: 0.1485
# Epoch 66/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.2407 - categorical_accuracy: 0.6207 - val_loss: 3.1743 - val_categorical_accuracy: 0.1485
# Epoch 67/500
# 26/26 [==============================] - 0s 2ms/step - loss: 1.0788 - categorical_accuracy: 0.6570 - val_loss: 3.2325 - val_categorical_accuracy: 0.1683
# Epoch 68/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.9933 - categorical_accuracy: 0.6692 - val_loss: 3.1743 - val_categorical_accuracy: 0.1881
# Epoch 69/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.9594 - categorical_accuracy: 0.6793 - val_loss: 3.1595 - val_categorical_accuracy: 0.1485
# Epoch 70/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.9377 - categorical_accuracy: 0.6839 - val_loss: 3.3851 - val_categorical_accuracy: 0.1485
# Epoch 71/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.9277 - categorical_accuracy: 0.6802 - val_loss: 3.2494 - val_categorical_accuracy: 0.1485
# Epoch 72/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.8883 - categorical_accuracy: 0.6973 - val_loss: 3.3335 - val_categorical_accuracy: 0.1485
# Epoch 73/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.8894 - categorical_accuracy: 0.6985 - val_loss: 3.3202 - val_categorical_accuracy: 0.1386
# Epoch 74/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.9392 - categorical_accuracy: 0.6823 - val_loss: 3.1538 - val_categorical_accuracy: 0.1782
# Epoch 75/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.8956 - categorical_accuracy: 0.6930 - val_loss: 3.1515 - val_categorical_accuracy: 0.1584
# Epoch 76/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.8865 - categorical_accuracy: 0.6942 - val_loss: 3.2297 - val_categorical_accuracy: 0.1485
# Epoch 77/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.8785 - categorical_accuracy: 0.7022 - val_loss: 3.1870 - val_categorical_accuracy: 0.1386
# Epoch 78/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.8735 - categorical_accuracy: 0.7089 - val_loss: 3.2060 - val_categorical_accuracy: 0.2079
# Epoch 79/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.9545 - categorical_accuracy: 0.6930 - val_loss: 3.3078 - val_categorical_accuracy: 0.1683
# Epoch 80/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.8346 - categorical_accuracy: 0.7132 - val_loss: 3.3007 - val_categorical_accuracy: 0.1683
# Epoch 81/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.9378 - categorical_accuracy: 0.6973 - val_loss: 3.2255 - val_categorical_accuracy: 0.1683
# Epoch 82/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.9600 - categorical_accuracy: 0.6872 - val_loss: 3.2623 - val_categorical_accuracy: 0.1782
# Epoch 83/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.8385 - categorical_accuracy: 0.7107 - val_loss: 3.3877 - val_categorical_accuracy: 0.1683
# Epoch 84/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.7779 - categorical_accuracy: 0.7373 - val_loss: 3.2604 - val_categorical_accuracy: 0.1881
# Epoch 85/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.8160 - categorical_accuracy: 0.7241 - val_loss: 3.2321 - val_categorical_accuracy: 0.1980
# Epoch 86/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.8719 - categorical_accuracy: 0.7086 - val_loss: 3.1569 - val_categorical_accuracy: 0.1782
# Epoch 87/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.8267 - categorical_accuracy: 0.7254 - val_loss: 3.3274 - val_categorical_accuracy: 0.1980
# Epoch 88/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.7706 - categorical_accuracy: 0.7309 - val_loss: 3.2407 - val_categorical_accuracy: 0.2178
# Epoch 89/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.8010 - categorical_accuracy: 0.7351 - val_loss: 3.4421 - val_categorical_accuracy: 0.2079
# Epoch 90/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.7716 - categorical_accuracy: 0.7357 - val_loss: 3.4539 - val_categorical_accuracy: 0.1584
# Epoch 91/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.7474 - categorical_accuracy: 0.7379 - val_loss: 3.2693 - val_categorical_accuracy: 0.1683
# Epoch 92/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.7412 - categorical_accuracy: 0.7440 - val_loss: 3.0896 - val_categorical_accuracy: 0.2574
# Epoch 93/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.6858 - categorical_accuracy: 0.7620 - val_loss: 3.3722 - val_categorical_accuracy: 0.2079
# Epoch 94/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.7419 - categorical_accuracy: 0.7339 - val_loss: 3.4367 - val_categorical_accuracy: 0.1782
# Epoch 95/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.7217 - categorical_accuracy: 0.7598 - val_loss: 3.3464 - val_categorical_accuracy: 0.1683
# Epoch 96/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.6953 - categorical_accuracy: 0.7598 - val_loss: 3.3539 - val_categorical_accuracy: 0.1980
# Epoch 97/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.6627 - categorical_accuracy: 0.7632 - val_loss: 3.4246 - val_categorical_accuracy: 0.1782
# Epoch 98/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.6595 - categorical_accuracy: 0.7644 - val_loss: 3.3184 - val_categorical_accuracy: 0.1881
# Epoch 99/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.6143 - categorical_accuracy: 0.7763 - val_loss: 3.5277 - val_categorical_accuracy: 0.1881
# Epoch 100/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.6077 - categorical_accuracy: 0.7815 - val_loss: 3.5499 - val_categorical_accuracy: 0.1584
# Epoch 101/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.6227 - categorical_accuracy: 0.7754 - val_loss: 3.5851 - val_categorical_accuracy: 0.1683
# Epoch 102/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.6394 - categorical_accuracy: 0.7794 - val_loss: 3.3402 - val_categorical_accuracy: 0.1980
# Epoch 103/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.6828 - categorical_accuracy: 0.7678 - val_loss: 3.6419 - val_categorical_accuracy: 0.1881
# Epoch 104/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.6841 - categorical_accuracy: 0.7632 - val_loss: 3.3179 - val_categorical_accuracy: 0.1782
# Epoch 105/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.6168 - categorical_accuracy: 0.7797 - val_loss: 3.7693 - val_categorical_accuracy: 0.1782
# Epoch 106/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.6817 - categorical_accuracy: 0.7708 - val_loss: 3.6404 - val_categorical_accuracy: 0.1782
# Epoch 107/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.6917 - categorical_accuracy: 0.7708 - val_loss: 3.6239 - val_categorical_accuracy: 0.1881
# Epoch 108/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.6474 - categorical_accuracy: 0.7818 - val_loss: 3.6209 - val_categorical_accuracy: 0.1782
# Epoch 109/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.6391 - categorical_accuracy: 0.7693 - val_loss: 3.5500 - val_categorical_accuracy: 0.1485
# Epoch 110/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5934 - categorical_accuracy: 0.7867 - val_loss: 3.6057 - val_categorical_accuracy: 0.1881
# Epoch 111/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.6269 - categorical_accuracy: 0.7693 - val_loss: 3.6050 - val_categorical_accuracy: 0.1881
# Epoch 112/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.6045 - categorical_accuracy: 0.7830 - val_loss: 3.8423 - val_categorical_accuracy: 0.1683
# Epoch 113/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5619 - categorical_accuracy: 0.7946 - val_loss: 3.7468 - val_categorical_accuracy: 0.1980
# Epoch 114/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5693 - categorical_accuracy: 0.8041 - val_loss: 4.0073 - val_categorical_accuracy: 0.1980
# Epoch 115/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.6058 - categorical_accuracy: 0.7852 - val_loss: 3.7670 - val_categorical_accuracy: 0.1485
# Epoch 116/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5469 - categorical_accuracy: 0.7962 - val_loss: 3.6229 - val_categorical_accuracy: 0.1584
# Epoch 117/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5966 - categorical_accuracy: 0.7788 - val_loss: 3.7356 - val_categorical_accuracy: 0.1683
# Epoch 118/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5762 - categorical_accuracy: 0.7971 - val_loss: 4.0298 - val_categorical_accuracy: 0.1485
# Epoch 119/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5321 - categorical_accuracy: 0.7965 - val_loss: 3.6806 - val_categorical_accuracy: 0.1881
# Epoch 120/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5125 - categorical_accuracy: 0.8227 - val_loss: 3.8268 - val_categorical_accuracy: 0.1980
# Epoch 121/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5673 - categorical_accuracy: 0.7998 - val_loss: 3.7838 - val_categorical_accuracy: 0.2079
# Epoch 122/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5290 - categorical_accuracy: 0.8056 - val_loss: 3.6305 - val_categorical_accuracy: 0.2178
# Epoch 123/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5355 - categorical_accuracy: 0.8102 - val_loss: 3.8584 - val_categorical_accuracy: 0.2178
# Epoch 124/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5568 - categorical_accuracy: 0.7955 - val_loss: 3.7816 - val_categorical_accuracy: 0.2079
# Epoch 125/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5406 - categorical_accuracy: 0.8105 - val_loss: 3.8316 - val_categorical_accuracy: 0.1485
# Epoch 126/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5340 - categorical_accuracy: 0.8093 - val_loss: 3.8749 - val_categorical_accuracy: 0.1881
# Epoch 127/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5325 - categorical_accuracy: 0.8126 - val_loss: 3.8752 - val_categorical_accuracy: 0.2277
# Epoch 128/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5175 - categorical_accuracy: 0.8145 - val_loss: 3.9485 - val_categorical_accuracy: 0.1188
# Epoch 129/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4928 - categorical_accuracy: 0.8181 - val_loss: 4.0175 - val_categorical_accuracy: 0.1980
# Epoch 130/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4816 - categorical_accuracy: 0.8270 - val_loss: 3.7881 - val_categorical_accuracy: 0.1881
# Epoch 131/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4791 - categorical_accuracy: 0.8279 - val_loss: 3.9350 - val_categorical_accuracy: 0.2079
# Epoch 132/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5451 - categorical_accuracy: 0.8090 - val_loss: 4.1278 - val_categorical_accuracy: 0.2970
# Epoch 133/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5270 - categorical_accuracy: 0.8071 - val_loss: 3.7903 - val_categorical_accuracy: 0.1881
# Epoch 134/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4741 - categorical_accuracy: 0.8276 - val_loss: 3.8725 - val_categorical_accuracy: 0.2079
# Epoch 135/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4701 - categorical_accuracy: 0.8239 - val_loss: 4.0347 - val_categorical_accuracy: 0.2277
# Epoch 136/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4720 - categorical_accuracy: 0.8251 - val_loss: 3.8790 - val_categorical_accuracy: 0.2277
# Epoch 137/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4688 - categorical_accuracy: 0.8358 - val_loss: 3.8735 - val_categorical_accuracy: 0.2178
# Epoch 138/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5051 - categorical_accuracy: 0.8215 - val_loss: 3.9231 - val_categorical_accuracy: 0.2277
# Epoch 139/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4738 - categorical_accuracy: 0.8200 - val_loss: 4.1348 - val_categorical_accuracy: 0.1782
# Epoch 140/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4631 - categorical_accuracy: 0.8270 - val_loss: 4.0008 - val_categorical_accuracy: 0.1683
# Epoch 141/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4994 - categorical_accuracy: 0.8242 - val_loss: 4.3038 - val_categorical_accuracy: 0.1980
# Epoch 142/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5172 - categorical_accuracy: 0.8297 - val_loss: 3.8216 - val_categorical_accuracy: 0.2574
# Epoch 143/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4781 - categorical_accuracy: 0.8267 - val_loss: 3.9283 - val_categorical_accuracy: 0.1980
# Epoch 144/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4792 - categorical_accuracy: 0.8377 - val_loss: 4.4383 - val_categorical_accuracy: 0.1980
# Epoch 145/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5159 - categorical_accuracy: 0.8096 - val_loss: 4.4228 - val_categorical_accuracy: 0.1980
# Epoch 146/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.7072 - categorical_accuracy: 0.7754 - val_loss: 4.3738 - val_categorical_accuracy: 0.1980
# Epoch 147/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5263 - categorical_accuracy: 0.8096 - val_loss: 4.2686 - val_categorical_accuracy: 0.1980
# Epoch 148/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4746 - categorical_accuracy: 0.8245 - val_loss: 4.0585 - val_categorical_accuracy: 0.1881
# Epoch 149/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4772 - categorical_accuracy: 0.8276 - val_loss: 4.1189 - val_categorical_accuracy: 0.2079
# Epoch 150/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4034 - categorical_accuracy: 0.8425 - val_loss: 4.3128 - val_categorical_accuracy: 0.1485
# Epoch 151/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4364 - categorical_accuracy: 0.8383 - val_loss: 4.2360 - val_categorical_accuracy: 0.1980
# Epoch 152/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4497 - categorical_accuracy: 0.8395 - val_loss: 4.2058 - val_categorical_accuracy: 0.2772
# Epoch 153/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3982 - categorical_accuracy: 0.8486 - val_loss: 4.2506 - val_categorical_accuracy: 0.2376
# Epoch 154/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4505 - categorical_accuracy: 0.8422 - val_loss: 4.4816 - val_categorical_accuracy: 0.2376
# Epoch 155/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4012 - categorical_accuracy: 0.8425 - val_loss: 4.2712 - val_categorical_accuracy: 0.2475
# Epoch 156/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5589 - categorical_accuracy: 0.7962 - val_loss: 4.5806 - val_categorical_accuracy: 0.1683
# Epoch 157/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4939 - categorical_accuracy: 0.8291 - val_loss: 4.4242 - val_categorical_accuracy: 0.1584
# Epoch 158/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5200 - categorical_accuracy: 0.8160 - val_loss: 4.3865 - val_categorical_accuracy: 0.2277
# Epoch 159/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5366 - categorical_accuracy: 0.8093 - val_loss: 4.3393 - val_categorical_accuracy: 0.2079
# Epoch 160/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4793 - categorical_accuracy: 0.8221 - val_loss: 4.4754 - val_categorical_accuracy: 0.2178
# Epoch 161/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3882 - categorical_accuracy: 0.8560 - val_loss: 4.1073 - val_categorical_accuracy: 0.2673
# Epoch 162/500
# 26/26 [==============================] - 0s 3ms/step - loss: 0.3823 - categorical_accuracy: 0.8572 - val_loss: 4.1922 - val_categorical_accuracy: 0.2871
# Epoch 163/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3813 - categorical_accuracy: 0.8547 - val_loss: 3.9683 - val_categorical_accuracy: 0.2574
# Epoch 164/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3781 - categorical_accuracy: 0.8529 - val_loss: 4.2109 - val_categorical_accuracy: 0.2574
# Epoch 165/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3526 - categorical_accuracy: 0.8642 - val_loss: 4.4779 - val_categorical_accuracy: 0.2178
# Epoch 166/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3625 - categorical_accuracy: 0.8627 - val_loss: 4.3724 - val_categorical_accuracy: 0.2277
# Epoch 167/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3775 - categorical_accuracy: 0.8493 - val_loss: 4.3418 - val_categorical_accuracy: 0.2178
# Epoch 168/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3962 - categorical_accuracy: 0.8462 - val_loss: 4.2536 - val_categorical_accuracy: 0.2277
# Epoch 169/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4682 - categorical_accuracy: 0.8557 - val_loss: 4.8022 - val_categorical_accuracy: 0.2079
# Epoch 170/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4738 - categorical_accuracy: 0.8444 - val_loss: 4.2905 - val_categorical_accuracy: 0.2376
# Epoch 171/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3460 - categorical_accuracy: 0.8639 - val_loss: 4.5308 - val_categorical_accuracy: 0.2079
# Epoch 172/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3446 - categorical_accuracy: 0.8657 - val_loss: 4.4559 - val_categorical_accuracy: 0.2277
# Epoch 173/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3517 - categorical_accuracy: 0.8618 - val_loss: 4.3859 - val_categorical_accuracy: 0.2475
# Epoch 174/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3536 - categorical_accuracy: 0.8560 - val_loss: 4.4054 - val_categorical_accuracy: 0.2772
# Epoch 175/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3492 - categorical_accuracy: 0.8688 - val_loss: 4.5486 - val_categorical_accuracy: 0.2178
# Epoch 176/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3528 - categorical_accuracy: 0.8691 - val_loss: 4.5777 - val_categorical_accuracy: 0.1584
# Epoch 177/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3592 - categorical_accuracy: 0.8566 - val_loss: 4.6283 - val_categorical_accuracy: 0.2079
# Epoch 178/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3263 - categorical_accuracy: 0.8712 - val_loss: 4.4407 - val_categorical_accuracy: 0.2376
# Epoch 179/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3273 - categorical_accuracy: 0.8749 - val_loss: 4.3587 - val_categorical_accuracy: 0.1980
# Epoch 180/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3710 - categorical_accuracy: 0.8605 - val_loss: 4.4898 - val_categorical_accuracy: 0.2673
# Epoch 181/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3629 - categorical_accuracy: 0.8670 - val_loss: 4.6471 - val_categorical_accuracy: 0.1980
# Epoch 182/500
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5363 - categorical_accuracy: 0.8154 - val_loss: 5.0092 - val_categorical_accuracy: 0.2277
# 4/4 [==============================] - 0s 847us/step - loss: 4.1278 - categorical_accuracy: 0.2970
# Validation loss: 4.1278 ± 0.0000
# Validation accuracy: 0.2970 ± 0.0000

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

test='_test'
description = 'test'
# Store best parameters and best model in variables.
# best_model = load_model(f'../results/model/NNCheckpoint1.hdf5')
best_model = clf

# # Get the labels as names
# y_names = dataset[label_scheme].to_numpy()
# # Encode the labels
# enc = LabelEncoder().fit(y_names)
# y_num = enc.transform(y_names)
# # One hot encode the labels
# y = to_categorical(y_num)

# Collect unique class labels in order of y_test.
y_test_labels = np.argmax(y_test, axis=1)
class_labels = enc.inverse_transform(np.unique(y_test_labels))

# Make predictions and gather probabilities for applying model to test set.

y_pred_prob = best_model.predict(test_data[0])
y_pred = np.argmax(y_pred_prob, axis=1)

# Plot confusion matrix
cm = confusion_matrix(y_test_labels, y_pred, normalize=None)
disp = ConfusionMatrixDisplay(cm, display_labels=class_labels)
disp.plot(xticks_rotation='vertical', cmap='magma')
disp.figure_.savefig(f'../results/1dcnn/cm/cm_{description}{test}.pdf', format='pdf', bbox_inches='tight')


# Print and save the classification report
pd.options.display.max_rows=None
cr = classification_report(y_test_labels, y_pred, target_names=enc.inverse_transform(np.unique(y_train_labels)), output_dict=True, zero_division=0)
cr_df = pd.DataFrame(cr).transpose().round({'precision':2, 'recall':2, 'f1-score':2}).astype({'support':'int64'})
cr_df.to_csv(f'../results/1dcnn/cr/cr_{description}{test}.csv')
print(cr_df)

plot_roc(y_train_labels, y_test_labels, y_pred_prob, enc, path=f'../results/1dcnn/roc_curve/{description}{test}.pdf')

clf.save(f'../results/1dcnn/model/{description}{test}.h5')

keras.utils.plot_model(clf, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# 14/14 [==============================] - 0s 596us/step
#                    precision  recall  f1-score  support
# AMCVn                   0.10    0.21      0.14       14
# dwarf_nova_SU_UMa       0.54    0.19      0.28      172
# dwarf_nova_U_Gem        0.09    0.20      0.12       35
# dwarf_nova_WZ_Sge       0.00    0.00      0.00       17
# dwarf_nova_Z_Cam        0.17    0.10      0.12       52
# int_polar               0.11    0.27      0.15       15
# nova                    0.14    0.57      0.22       14
# nova_like               0.26    0.21      0.23       43
# nova_like_VY_Scl        0.20    0.33      0.25       36
# polar                   0.08    0.09      0.08       34
# accuracy                0.19    0.19      0.19        0
# macro avg               0.17    0.22      0.16      432
# weighted avg            0.30    0.19      0.20      432
